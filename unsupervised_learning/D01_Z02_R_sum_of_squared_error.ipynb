# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# ## Zad.
#
# Narysuj dane iris data wybierając dwie pierwsze współrzędne.

# %%
from sklearn import datasets
iris = datasets.load_iris()

X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %% [markdown]
# ## Zad.
#
# Wykonaj klastrowanie k-means na danych iris z ilością grup (k=1,2,3,...,20) oraz narysuj wykres jak zmienia się suma kwadratów odległości (SSE) od centrów grup (Sum of distances of samples to their closest cluster center) w zależności od ilości grup.

# %%
SSE_array = []
for i in range(1,20):
    km = KMeans(n_clusters=i, 
                init='random', 
                n_init=10, 
                max_iter=300,
                tol=1e-04,
                random_state=0
               )

    y_km = km.fit_predict(X)
    
    SSE_array.append(km.inertia_)
    
    plt.scatter(X[:, 0], X[:, 1], c=y_km)
    plt.show()

# %%
SSE_array = []
for i in range(1,20):
    km = KMeans(n_clusters=i)
    km.fit(X)
    SSE_array.append(km.inertia_)
    
plt.plot(SSE_array)
plt.show()
