# %%
import tensorflow as tf
from tensorflow import keras as keras
print(tf.__version__)

print(keras.__version__)
# Out:
# 2.3.1
# 2.4.0

# %%
# Wczytaj dane treningowe i testowe
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

train_set = pd.read_csv('Dane/adult/adult.data', sep=", ",header = None)
test_set = pd.read_csv('Dane/adult/adult.test', sep=", ",skiprows = 1, header = None) # Make sure to skip a row for the test set

col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 
              'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
             'wage_class']
train_set.columns = col_labels
test_set.columns = col_labels

train = train_set.replace('?', np.nan).dropna()
test = test_set.replace('?', np.nan).dropna()

train_set.head()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# C:\Users\admin\anaconda3\lib\site-packages\ipykernel_launcher.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   import sys
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country wage_class
# 0          2174             0              40  United-States      <=50K
# 1             0             0              13  United-States      <=50K
# 2             0             0              40  United-States      <=50K
# 3             0             0              40  United-States      <=50K
# 4             0             0              40           Cuba      <=50K

# %%
dataset = pd.concat([train,test])

dataset['wage_class'] = dataset.wage_class.replace({'<=50K.': 0,'<=50K':0, '>50K.':1, '>50K':1})

dataset.drop(["fnlwgt"],axis=1,inplace=True)

dataset.drop(["education"],axis=1,inplace=True)

x = dataset.groupby('native_country')["wage_class"].mean()

d = dict(pd.cut(x[x.index!=" United-States"],5,labels=range(5)))

dataset['native_country'] = dataset['native_country'].replace(d)

dataset = pd.get_dummies(dataset,drop_first=True)

train = dataset.iloc[:train.shape[0]]
test = dataset.iloc[train.shape[0]:]

X_train = train.drop("wage_class",axis=1)
y_train = train.wage_class

X_test = test.drop("wage_class",axis=1)
y_test = test.wage_class

# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# print(X_train.shape)
# X_test.shape

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import ModelCheckpoint

from tensorflow.keras.callbacks import History

# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.0001
    drop = 0.5
    epochs_drop = 10.0
    lrate = initial_lrate * np.power(drop, np.floor((1+epoch)/epochs_drop))
    return lrate


history_Adam = History()
model = Sequential()
model.add(Dense(100,activation="sigmoid",input_shape=(X_train.shape[1],)))
model.add(Dense(50,activation="sigmoid"))
model.add(Dense(10,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))
model.summary()

Adam = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss="binary_crossentropy",optimizer=Adam, metrics=["accuracy"])

save_best_model = ModelCheckpoint("/tmp/test_weights.h5",save_best_only=True)
lrate = LearningRateScheduler(step_decay)
model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=32,epochs=100, callbacks=[lrate, history_Adam, save_best_model])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 100)               4200
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 9,771
# Trainable params: 9,771
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.5806 - accuracy: 0.7032 - val_loss: 0.5269 - val_accuracy: 0.7543
# Epoch 2/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.5176 - accuracy: 0.7732 - val_loss: 0.5063 - val_accuracy: 0.7749
# Epoch 3/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.4952 - accuracy: 0.7774 - val_loss: 0.4750 - val_accuracy: 0.7825
# Epoch 4/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.4519 - accuracy: 0.7800 - val_loss: 0.4254 - val_accuracy: 0.7856
# Epoch 5/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.4071 - accuracy: 0.8064 - val_loss: 0.3886 - val_accuracy: 0.8308
# Epoch 6/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3811 - accuracy: 0.8382 - val_loss: 0.3707 - val_accuracy: 0.8417
# Epoch 7/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3669 - accuracy: 0.8418 - val_loss: 0.3595 - val_accuracy: 0.8426
# Epoch 8/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3583 - accuracy: 0.8425 - val_loss: 0.3554 - val_accuracy: 0.8388
# Epoch 9/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3530 - accuracy: 0.8431 - val_loss: 0.3530 - val_accuracy: 0.8433
# Epoch 10/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3472 - accuracy: 0.8456 - val_loss: 0.3463 - val_accuracy: 0.8406
# Epoch 11/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3443 - accuracy: 0.8456 - val_loss: 0.3435 - val_accuracy: 0.8440
# Epoch 12/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3422 - accuracy: 0.8444 - val_loss: 0.3427 - val_accuracy: 0.8430
# Epoch 13/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3410 - accuracy: 0.8459 - val_loss: 0.3399 - val_accuracy: 0.8430
# Epoch 14/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3390 - accuracy: 0.8462 - val_loss: 0.3383 - val_accuracy: 0.8433
# Epoch 15/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3376 - accuracy: 0.8455 - val_loss: 0.3376 - val_accuracy: 0.8478
# Epoch 16/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3363 - accuracy: 0.8467 - val_loss: 0.3388 - val_accuracy: 0.8410
# Epoch 17/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3353 - accuracy: 0.8472 - val_loss: 0.3343 - val_accuracy: 0.8479
# Epoch 18/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3341 - accuracy: 0.8474 - val_loss: 0.3345 - val_accuracy: 0.8446
# Epoch 19/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3328 - accuracy: 0.8483 - val_loss: 0.3335 - val_accuracy: 0.8491
# Epoch 20/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3311 - accuracy: 0.8486 - val_loss: 0.3317 - val_accuracy: 0.8464
# Epoch 21/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3304 - accuracy: 0.8485 - val_loss: 0.3320 - val_accuracy: 0.8475
# Epoch 22/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3302 - accuracy: 0.8489 - val_loss: 0.3316 - val_accuracy: 0.8473
# Epoch 23/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3298 - accuracy: 0.8488 - val_loss: 0.3300 - val_accuracy: 0.8487
# Epoch 24/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3293 - accuracy: 0.8486 - val_loss: 0.3303 - val_accuracy: 0.8496
# Epoch 25/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3285 - accuracy: 0.8503 - val_loss: 0.3296 - val_accuracy: 0.8487
# Epoch 26/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3283 - accuracy: 0.8490 - val_loss: 0.3291 - val_accuracy: 0.8475
# Epoch 27/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3280 - accuracy: 0.8494 - val_loss: 0.3289 - val_accuracy: 0.8477
# Epoch 28/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3274 - accuracy: 0.8503 - val_loss: 0.3282 - val_accuracy: 0.8487
# Epoch 29/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3268 - accuracy: 0.8495 - val_loss: 0.3300 - val_accuracy: 0.8470
# Epoch 30/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3262 - accuracy: 0.8491 - val_loss: 0.3276 - val_accuracy: 0.8493
# Epoch 31/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3260 - accuracy: 0.8499 - val_loss: 0.3279 - val_accuracy: 0.8481
# Epoch 32/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3258 - accuracy: 0.8500 - val_loss: 0.3279 - val_accuracy: 0.8478
# Epoch 33/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3256 - accuracy: 0.8498 - val_loss: 0.3277 - val_accuracy: 0.8487
# Epoch 34/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3254 - accuracy: 0.8494 - val_loss: 0.3270 - val_accuracy: 0.8483
# Epoch 35/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3253 - accuracy: 0.8499 - val_loss: 0.3272 - val_accuracy: 0.8485
# Epoch 36/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3250 - accuracy: 0.8503 - val_loss: 0.3280 - val_accuracy: 0.8478
# Epoch 37/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3251 - accuracy: 0.8499 - val_loss: 0.3267 - val_accuracy: 0.8491
# Epoch 38/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3247 - accuracy: 0.8503 - val_loss: 0.3280 - val_accuracy: 0.8487
# Epoch 39/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3246 - accuracy: 0.8503 - val_loss: 0.3266 - val_accuracy: 0.8481
# Epoch 40/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3243 - accuracy: 0.8501 - val_loss: 0.3262 - val_accuracy: 0.8489
# Epoch 41/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3241 - accuracy: 0.8500 - val_loss: 0.3261 - val_accuracy: 0.8491
# Epoch 42/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3240 - accuracy: 0.8501 - val_loss: 0.3260 - val_accuracy: 0.8488
# Epoch 43/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3240 - accuracy: 0.8507 - val_loss: 0.3260 - val_accuracy: 0.8483
# Epoch 44/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3239 - accuracy: 0.8503 - val_loss: 0.3259 - val_accuracy: 0.8490
# Epoch 45/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3238 - accuracy: 0.8498 - val_loss: 0.3260 - val_accuracy: 0.8486
# Epoch 46/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3237 - accuracy: 0.8509 - val_loss: 0.3259 - val_accuracy: 0.8486
# Epoch 47/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3236 - accuracy: 0.8507 - val_loss: 0.3258 - val_accuracy: 0.8495
# Epoch 48/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3236 - accuracy: 0.8504 - val_loss: 0.3258 - val_accuracy: 0.8483
# Epoch 49/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3235 - accuracy: 0.8503 - val_loss: 0.3258 - val_accuracy: 0.8478
# Epoch 50/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3234 - accuracy: 0.8505 - val_loss: 0.3255 - val_accuracy: 0.8486
# Epoch 51/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3232 - accuracy: 0.8504 - val_loss: 0.3255 - val_accuracy: 0.8495
# Epoch 52/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3233 - accuracy: 0.8509 - val_loss: 0.3254 - val_accuracy: 0.8489
# Epoch 53/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3232 - accuracy: 0.8507 - val_loss: 0.3254 - val_accuracy: 0.8488
# Epoch 54/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3231 - accuracy: 0.8506 - val_loss: 0.3254 - val_accuracy: 0.8495
# Epoch 55/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3231 - accuracy: 0.8507 - val_loss: 0.3254 - val_accuracy: 0.8489
# Epoch 56/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3231 - accuracy: 0.8507 - val_loss: 0.3253 - val_accuracy: 0.8490
# Epoch 57/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3231 - accuracy: 0.8505 - val_loss: 0.3253 - val_accuracy: 0.8493
# Epoch 58/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3230 - accuracy: 0.8511 - val_loss: 0.3254 - val_accuracy: 0.8489
# Epoch 59/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3230 - accuracy: 0.8502 - val_loss: 0.3253 - val_accuracy: 0.8492
# Epoch 60/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3229 - accuracy: 0.8507 - val_loss: 0.3252 - val_accuracy: 0.8489
# Epoch 61/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3228 - accuracy: 0.8501 - val_loss: 0.3252 - val_accuracy: 0.8491
# Epoch 62/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3228 - accuracy: 0.8507 - val_loss: 0.3252 - val_accuracy: 0.8491
# Epoch 63/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3228 - accuracy: 0.8505 - val_loss: 0.3251 - val_accuracy: 0.8491
# Epoch 64/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3228 - accuracy: 0.8508 - val_loss: 0.3252 - val_accuracy: 0.8493
# Epoch 65/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3228 - accuracy: 0.8508 - val_loss: 0.3251 - val_accuracy: 0.8492
# Epoch 66/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3227 - accuracy: 0.8509 - val_loss: 0.3251 - val_accuracy: 0.8490
# Epoch 67/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3227 - accuracy: 0.8509 - val_loss: 0.3251 - val_accuracy: 0.8493
# Epoch 68/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3227 - accuracy: 0.8508 - val_loss: 0.3251 - val_accuracy: 0.8491
# Epoch 69/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3227 - accuracy: 0.8509 - val_loss: 0.3250 - val_accuracy: 0.8490
# Epoch 70/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8508 - val_loss: 0.3250 - val_accuracy: 0.8489
# Epoch 71/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8510 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 72/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8507 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 73/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8509 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 74/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8508 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 75/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8509 - val_loss: 0.3250 - val_accuracy: 0.8493
# Epoch 76/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8509 - val_loss: 0.3250 - val_accuracy: 0.8492
# Epoch 77/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8510 - val_loss: 0.3250 - val_accuracy: 0.8492
# Epoch 78/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8508 - val_loss: 0.3250 - val_accuracy: 0.8493
# Epoch 79/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3226 - accuracy: 0.8508 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 80/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8510 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 81/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8509 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 82/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8509 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 83/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8508 - val_loss: 0.3250 - val_accuracy: 0.8491
# Epoch 84/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8508 - val_loss: 0.3249 - val_accuracy: 0.8493
# Epoch 85/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8509 - val_loss: 0.3250 - val_accuracy: 0.8493
# Epoch 86/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8510 - val_loss: 0.3250 - val_accuracy: 0.8493
# Epoch 87/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8510 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 88/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8510 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 89/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8509 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 90/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8510 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 91/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8511 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 92/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8509 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 93/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8510 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 94/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8508 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 95/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8510 - val_loss: 0.3249 - val_accuracy: 0.8493
# Epoch 96/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8511 - val_loss: 0.3249 - val_accuracy: 0.8493
# Epoch 97/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8509 - val_loss: 0.3249 - val_accuracy: 0.8493
# Epoch 98/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8510 - val_loss: 0.3249 - val_accuracy: 0.8493
# Epoch 99/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8509 - val_loss: 0.3249 - val_accuracy: 0.8491
# Epoch 100/100
# 943/943 [==============================] - 1s 1ms/step - loss: 0.3224 - accuracy: 0.8509 - val_loss: 0.3249 - val_accuracy: 0.8491

# %%
plt.plot(history_Adam.history['accuracy'], label = "tarina Adam 0.0001 LR")
plt.plot(history_Adam.history['val_accuracy'], label = "test Adam 0.0001 LR")


plt.legend()
plt.show()

# %%
model.load_weights("/tmp/test_weights.h5")
model.evaluate(X_test,y_test)
# Out:
# 471/471 [==============================] - 0s 650us/step - loss: 0.3249 - accuracy: 0.8491
# [0.3249128460884094, 0.8491367697715759]

# %% [markdown]
# # Zad.
# Zapisz 3 modele z różnymi parametrami.
