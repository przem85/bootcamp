# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tempfile
import os
import os.path
import wave
from IPython.display import Audio, display

import librosa
import librosa.display
#https://musicinformationretrieval.com/ipython_audio.html

# %% [markdown]
# # Zad
#
# Pobierz dane ze strony
#
# https://cnx.org/contents/XIZLCxRf@1/Blind-Source-Separation-Via-ICA-Audio-Demonstration
#
# i wykonaj na nich ICA (odmieszaj sygnały)

# %%
file1 = 'vawe/Mixed Signal 1A.wav'
file2 = 'vawe/Mixed Signal 1B.wav'

x1, fs1 = librosa.load(file1)
plt.plot(x1)
plt.show()

x2, fs2 = librosa.load(file2)
plt.plot(x2)
plt.show()

# %%
import IPython.display as ipd
ipd.Audio(x1, rate=fs1) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
ipd.Audio(x2, rate=fs2) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from sklearn import preprocessing
X=np.vstack((x1,x2)).T

# %%
X
# Out:
# array([[ 2.1240569e-04,  2.6449238e-04],
#        [-4.0479572e-04, -3.8248076e-04],
#        [ 5.3708471e-04,  4.2095530e-04],
#        ...,
#        [ 4.3860495e-01,  4.0051773e-01],
#        [ 3.1721127e-01,  3.2200789e-01],
#        [ 2.5887662e-01,  2.8504613e-01]], dtype=float32)

# %%
from sklearn.decomposition import FastICA
# Compute ICA
ica = FastICA(n_components=2)
S_ = ica.fit_transform(X)  # Reconstruct signals
A_ = ica.mixing_  # Get estimated mixing matrix

#S_ = preprocessing.scale(S_)
# plt.plot(S_[:,0])
# plt.show()

# %%
ipd.Audio(10*S_[:, 0], rate=fs1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(10*S_[:, 1], rate=fs1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
