# %% [markdown]
# # Case study - lokalizacja Wi-Fi

# %% [markdown]
# W folderze UJIndoorLoc znajdziecie pliki z danymi dotyczącymi lokalizacji w budynku na podstawie sygnałów z sieci WiFi. Problem jest o tyle ciekawy, że o ile lokalizacja na zewnątrz jest problemem prostym do rozwiązania (dobra jakość sygnału GPS), tak wewnątrz budynku jest już trudniej.
#
# Jednym z proponowanych rozwiązań jest użycie mocy sygnału WiFi z punktów dostępu rozlokowanych wewnątrz budynku. Sygnał ten jednak jest na tyle niestabilny, że ciężko deterministycznie określić na jego podstawie dokładne położenie. Na szczęście z pomocą przychodzi machine learning!
#
# Waszym zadaniem jest skonstruowanie algorytmu, który będzie określał położenie użytkownika (tzn wysokość i szerokość geograficna oraz numer piętra) na podstawie wejściowych danych. Zależy nam zarówno na wysokiej skuteczności, jak i na szybkim czasie predykcji.
#
# Opis danych: https://archive.ics.uci.edu/ml/datasets/ujiindoorloc

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('./UJIndoorLoc/UJIndoorLoc/trainingData.csv')

# %%
test_data = pd.read_csv('./UJIndoorLoc/UJIndoorLoc/validationData.csv')

# %%
train_data.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 0                 2       2       23  1371713733
# 1                 2       2       23  1371713691
# 2                 2       2       23  1371714095
# 3                 2       2       23  1371713807
# 4                 2      11       13  1369909710
#
# [5 rows x 529 columns]

# %%
test_data['BUILDINGID'].value_counts()
# Out:
# 0    536
# 1    307
# 2    268
# Name: BUILDINGID, dtype: int64

# %%
train_data['BUILDINGID'].value_counts()
# Out:
# 2    9492
# 0    5249
# 1    5196
# Name: BUILDINGID, dtype: int64

# %%
sns.distplot(train_data[['BUILDINGID']],kde=False)
plt.show()

# %%
np.unique(train_data['BUILDINGID'])
# Out:
# array([0, 1, 2], dtype=int64)

# %%
from matplotlib.colors import ListedColormap
markers = ('s', 'x', 'o', '^', 'v')
colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
cmap = ListedColormap(colors[:len(np.unique(train_data['BUILDINGID']))])

for idx, cl in enumerate(np.unique(train_data['BUILDINGID'])):
        plt.scatter(x=train_data.loc[train_data.BUILDINGID== cl]['LATITUDE'], 
                    y=train_data.loc[train_data.BUILDINGID== cl]['LONGITUDE'],
                    alpha=0.6, 
                    c=cmap(idx),
                    edgecolor='black',
                    marker=markers[idx], 
                    label=cl)

plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# <img src="http://www.analyzingdata.org/Wf-gmap.png" width="550">

# %% [markdown]
# ## Uczymy na budynku nr 0.

# %%
X_train = train_data[train_data['BUILDINGID']==0]
X_test = test_data[test_data['BUILDINGID']==0]

# %%
plt.scatter(x=X_train['LATITUDE'], y=X_train['LONGITUDE'], alpha=0.2)
plt.scatter(x=X_test['LATITUDE'], y=X_test['LONGITUDE'], alpha=0.2)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X_train['LATITUDE'], X_train['LONGITUDE'], X_train['FLOOR'])
ax.scatter(X_test['LATITUDE'], X_test['LONGITUDE'], X_test['FLOOR'])

plt.show()

# %% [markdown]
# # Mamy missing data
#
# WAP001-WAP520: Intensity value for Wireless Access Point (WAP). WAP will be the acronym used for rest of this notebook. Negative integer values from -104 to 0 and +100. Censored data: Positive value 100 used if WAP was not detected.

# %%
X_train = (X_train
             .replace(to_replace=100,value=np.nan))

# Perform the same transform on Test data
X_test = (X_test
             .replace(to_replace=100,value=np.nan))

# %%
X_train.isnull().sum()
# Out:
# WAP001              5231
# WAP002              5230
# WAP003              5249
# WAP004              5249
# WAP005              5249
# WAP006              5249
# WAP007              4671
# WAP008              5128
# WAP009              4654
# WAP010              5249
# WAP011              5249
# WAP012              5249
# WAP013              3274
# WAP014              3294
# WAP015              5249
# WAP016              5249
# WAP017              5168
# WAP018              5162
# WAP019              4831
# WAP020              4859
# WAP021              5249
# WAP022              5249
# WAP023              4531
# WAP024              4523
# WAP025              4618
# WAP026              4594
# WAP027              4531
# WAP028              4494
# WAP029              3767
# WAP030              3718
#                     ...
# WAP500              5145
# WAP501              5249
# WAP502              5249
# WAP503              5249
# WAP504              5249
# WAP505              5249
# WAP506              5249
# WAP507              5249
# WAP508              5236
# WAP509              5249
# WAP510              5249
# WAP511              5249
# WAP512              5249
# WAP513              5249
# WAP514              5249
# WAP515              5189
# WAP516              5249
# WAP517              5249
# WAP518              5249
# WAP519              5246
# WAP520              5249
# LONGITUDE              0
# LATITUDE               0
# FLOOR                  0
# BUILDINGID             0
# SPACEID                0
# RELATIVEPOSITION       0
# USERID                 0
# PHONEID                0
# TIMESTAMP              0
# Length: 529, dtype: int64

# %%
X_train.head(10)
# Out:
#       WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 4        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7119     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7120     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7121     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7122     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7123     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7124     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7125     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7126     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7127     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#       WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  \
# 4        NaN  ...     NaN -7632.1436  4.864982e+06      0           0
# 7119     NaN  ...     NaN -7637.2570  4.864950e+06      0           0
# 7120     NaN  ...     NaN -7628.1345  4.864977e+06      0           0
# 7121     NaN  ...     NaN -7622.0546  4.864976e+06      0           0
# 7122     NaN  ...     NaN -7636.2057  4.864967e+06      0           0
# 7123     NaN  ...     NaN -7633.7295  4.864965e+06      0           0
# 7124     NaN  ...     NaN -7605.4193  4.864979e+06      0           0
# 7125     NaN  ...     NaN -7607.2476  4.864979e+06      0           0
# 7126     NaN  ...     NaN -7616.5560  4.864976e+06      0           0
# 7127     NaN  ...     NaN -7618.5869  4.864975e+06      0           0
#
#       SPACEID  RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 4         122                 2      11       13  1369909710
# 7119      102                 2      11       13  1369908951
# 7120      110                 2      11       13  1369909107
# 7121      111                 2      11       13  1369909166
# 7122      107                 2      11       13  1369909011
# 7123      106                 2      11       13  1369909056
# 7124      115                 2      11       13  1369909334
# 7125      114                 2      11       13  1369909296
# 7126      113                 2      11       13  1369909254
# 7127      112                 2      11       13  1369909217
#
# [10 rows x 529 columns]

# %% [markdown]
# # Zad
# 1. Zbuduj model dla przewidzenia pietra budynku.
# 2. Następnie wyznacz połozenie.
#
# * rozwiąż problem missing data
# * wykonaj standaryzacja danych
# * selekcja cech (doczytaj co robi ponizsz funkcj i użyj jej)
#   ```python
#   from sklearn.feature_selection import VarianceThreshold
#   ```
# * redukcja wymiarowości
# * zbudować model
#   * - na piętro - klasyfikacja,
#   * - długość i szerokość - regresja
# * przetestować na zbiorze testowym
# * wykonaj rysunek

# %%
y_lon_train = X_train['LONGITUDE'].values
y_lat_train = X_train['LATITUDE'].values
y_floor_train = X_train['FLOOR'].values

y_lon_test = X_test['LONGITUDE'].values
y_lat_test = X_test['LATITUDE'].values
y_floor_test = X_test['FLOOR'].values

# %%
cols_to_train = [i for i in train_data.columns if 'WAP' in i]
print(cols_to_train)
# Out:
# ['WAP001', 'WAP002', 'WAP003', 'WAP004', 'WAP005', 'WAP006', 'WAP007', 'WAP008', 'WAP009', 'WAP010', 'WAP011', 'WAP012', 'WAP013', 'WAP014', 'WAP015', 'WAP016', 'WAP017', 'WAP018', 'WAP019', 'WAP020', 'WAP021', 'WAP022', 'WAP023', 'WAP024', 'WAP025', 'WAP026', 'WAP027', 'WAP028', 'WAP029', 'WAP030', 'WAP031', 'WAP032', 'WAP033', 'WAP034', 'WAP035', 'WAP036', 'WAP037', 'WAP038', 'WAP039', 'WAP040', 'WAP041', 'WAP042', 'WAP043', 'WAP044', 'WAP045', 'WAP046', 'WAP047', 'WAP048', 'WAP049', 'WAP050', 'WAP051', 'WAP052', 'WAP053', 'WAP054', 'WAP055', 'WAP056', 'WAP057', 'WAP058', 'WAP059', 'WAP060', 'WAP061', 'WAP062', 'WAP063', 'WAP064', 'WAP065', 'WAP066', 'WAP067', 'WAP068', 'WAP069', 'WAP070', 'WAP071', 'WAP072', 'WAP073', 'WAP074', 'WAP075', 'WAP076', 'WAP077', 'WAP078', 'WAP079', 'WAP080', 'WAP081', 'WAP082', 'WAP083', 'WAP084', 'WAP085', 'WAP086', 'WAP087', 'WAP088', 'WAP089', 'WAP090', 'WAP091', 'WAP092', 'WAP093', 'WAP094', 'WAP095', 'WAP096', 'WAP097', 'WAP098', 'WAP099', 'WAP100', 'WAP101', 'WAP102', 'WAP103', 'WAP104', 'WAP105', 'WAP106', 'WAP107', 'WAP108', 'WAP109', 'WAP110', 'WAP111', 'WAP112', 'WAP113', 'WAP114', 'WAP115', 'WAP116', 'WAP117', 'WAP118', 'WAP119', 'WAP120', 'WAP121', 'WAP122', 'WAP123', 'WAP124', 'WAP125', 'WAP126', 'WAP127', 'WAP128', 'WAP129', 'WAP130', 'WAP131', 'WAP132', 'WAP133', 'WAP134', 'WAP135', 'WAP136', 'WAP137', 'WAP138', 'WAP139', 'WAP140', 'WAP141', 'WAP142', 'WAP143', 'WAP144', 'WAP145', 'WAP146', 'WAP147', 'WAP148', 'WAP149', 'WAP150', 'WAP151', 'WAP152', 'WAP153', 'WAP154', 'WAP155', 'WAP156', 'WAP157', 'WAP158', 'WAP159', 'WAP160', 'WAP161', 'WAP162', 'WAP163', 'WAP164', 'WAP165', 'WAP166', 'WAP167', 'WAP168', 'WAP169', 'WAP170', 'WAP171', 'WAP172', 'WAP173', 'WAP174', 'WAP175', 'WAP176', 'WAP177', 'WAP178', 'WAP179', 'WAP180', 'WAP181', 'WAP182', 'WAP183', 'WAP184', 'WAP185', 'WAP186', 'WAP187', 'WAP188', 'WAP189', 'WAP190', 'WAP191', 'WAP192', 'WAP193', 'WAP194', 'WAP195', 'WAP196', 'WAP197', 'WAP198', 'WAP199', 'WAP200', 'WAP201', 'WAP202', 'WAP203', 'WAP204', 'WAP205', 'WAP206', 'WAP207', 'WAP208', 'WAP209', 'WAP210', 'WAP211', 'WAP212', 'WAP213', 'WAP214', 'WAP215', 'WAP216', 'WAP217', 'WAP218', 'WAP219', 'WAP220', 'WAP221', 'WAP222', 'WAP223', 'WAP224', 'WAP225', 'WAP226', 'WAP227', 'WAP228', 'WAP229', 'WAP230', 'WAP231', 'WAP232', 'WAP233', 'WAP234', 'WAP235', 'WAP236', 'WAP237', 'WAP238', 'WAP239', 'WAP240', 'WAP241', 'WAP242', 'WAP243', 'WAP244', 'WAP245', 'WAP246', 'WAP247', 'WAP248', 'WAP249', 'WAP250', 'WAP251', 'WAP252', 'WAP253', 'WAP254', 'WAP255', 'WAP256', 'WAP257', 'WAP258', 'WAP259', 'WAP260', 'WAP261', 'WAP262', 'WAP263', 'WAP264', 'WAP265', 'WAP266', 'WAP267', 'WAP268', 'WAP269', 'WAP270', 'WAP271', 'WAP272', 'WAP273', 'WAP274', 'WAP275', 'WAP276', 'WAP277', 'WAP278', 'WAP279', 'WAP280', 'WAP281', 'WAP282', 'WAP283', 'WAP284', 'WAP285', 'WAP286', 'WAP287', 'WAP288', 'WAP289', 'WAP290', 'WAP291', 'WAP292', 'WAP293', 'WAP294', 'WAP295', 'WAP296', 'WAP297', 'WAP298', 'WAP299', 'WAP300', 'WAP301', 'WAP302', 'WAP303', 'WAP304', 'WAP305', 'WAP306', 'WAP307', 'WAP308', 'WAP309', 'WAP310', 'WAP311', 'WAP312', 'WAP313', 'WAP314', 'WAP315', 'WAP316', 'WAP317', 'WAP318', 'WAP319', 'WAP320', 'WAP321', 'WAP322', 'WAP323', 'WAP324', 'WAP325', 'WAP326', 'WAP327', 'WAP328', 'WAP329', 'WAP330', 'WAP331', 'WAP332', 'WAP333', 'WAP334', 'WAP335', 'WAP336', 'WAP337', 'WAP338', 'WAP339', 'WAP340', 'WAP341', 'WAP342', 'WAP343', 'WAP344', 'WAP345', 'WAP346', 'WAP347', 'WAP348', 'WAP349', 'WAP350', 'WAP351', 'WAP352', 'WAP353', 'WAP354', 'WAP355', 'WAP356', 'WAP357', 'WAP358', 'WAP359', 'WAP360', 'WAP361', 'WAP362', 'WAP363', 'WAP364', 'WAP365', 'WAP366', 'WAP367', 'WAP368', 'WAP369', 'WAP370', 'WAP371', 'WAP372', 'WAP373', 'WAP374', 'WAP375', 'WAP376', 'WAP377', 'WAP378', 'WAP379', 'WAP380', 'WAP381', 'WAP382', 'WAP383', 'WAP384', 'WAP385', 'WAP386', 'WAP387', 'WAP388', 'WAP389', 'WAP390', 'WAP391', 'WAP392', 'WAP393', 'WAP394', 'WAP395', 'WAP396', 'WAP397', 'WAP398', 'WAP399', 'WAP400', ...

# %%
y_lat_train
# Out:
# array([4864982.2171, 4864949.8143, 4864977.0212, ..., 4864932.3486,
#        4864948.8147, 4864947.852 ])

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import VarianceThreshold, RFE
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA

# A class to select numerical or categorical columns 
# since Scikit-Learn doesn't handle DataFrames yet
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names]

preprocessing_pipeline_classification = Pipeline([
    ("select_cat", DataFrameSelector(cols_to_train)),
    ("imputer", SimpleImputer(strategy="median")),
    ('data scaling', MinMaxScaler()),
    ('remove zero variance', VarianceThreshold()),
    ('dimention reduction', PCA(100))
])


preprocessing_pipeline_regression = Pipeline([
    ("select_cat", DataFrameSelector(cols_to_train)),
    ("imputer", SimpleImputer(strategy="median")),
    ('data scaling', MinMaxScaler()),
    ('remove zero variance', VarianceThreshold()),
    ('dimention reduction', PCA(100))
])

# %%
XX= preprocessing_pipeline_classification.fit_transform(X_train, y_floor_train)
XX.shape
# Out:
# (5249, 100)

# %%
XX= preprocessing_pipeline_regression.fit_transform(X_train, y_floor_train)
XX.shape
# Out:
# (5249, 100)

# %%
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsRegressor

from sklearn.linear_model import LinearRegression

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


seed=123
kfold_floor = StratifiedKFold(n_splits=5, random_state=seed)
seed=123
kfold_lon = KFold(n_splits=5, random_state=seed)

pipe_floor = Pipeline([
    ('preprocessing', preprocessing_pipeline_classification), 
    ('classifier', KNeighborsClassifier())])
param_floor_grid = {
            'classifier__n_neighbors': [5, 10, 20, 100]
}
grid_floor_1 = GridSearchCV(pipe_floor, param_floor_grid, cv=kfold_floor)
grid_floor_1.fit(X_train, y_floor_train)
grid_floor_1.best_params_


pipe_lon_1 = Pipeline([
    ('preprocessing', preprocessing_pipeline_regression), 
    ('regression', KNeighborsRegressor())])


param_lon_grid = {
            'regression__n_neighbors': [5, 10, 20, 100]
}
grid_lon_1 = GridSearchCV(pipe_lon_1, param_lon_grid, cv=kfold_lon)
grid_lon_1.fit(X_train, y_lon_train)
grid_lon_1.best_params_



pipe_lat_1 = Pipeline([
    ('preprocessing', preprocessing_pipeline_regression), 
    ('regression', KNeighborsRegressor())])


param_lat_grid = {
            'regression__n_neighbors': [5, 10, 20, 100]
}
grid_lat_1 = GridSearchCV(pipe_lat_1, param_lat_grid, cv=kfold_lon)
grid_lat_1.fit(X_train, y_lat_train)
grid_lat_1.best_params_
# Out:
# {'regression__n_neighbors': 5}

# %%
X_test[:1]
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    WAP010  ...  WAP520    LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 4     NaN  ...     NaN -7641.499303  4.864922e+06      2           0        0
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 4                 0       0        2  1380877774
#
# [1 rows x 529 columns]

# %%
x1 = X_test[:1]
flor = grid_floor_1.best_estimator_.predict(x1)
lon = grid_lon_1.best_estimator_.predict(x1)
lat = grid_lat_1.best_estimator_.predict(x1)

print("Flor = ", flor)
print("LATITUDE , LONGITUDE = ", lat, " ",lon )

print("Flor = ", x1['FLOOR'].values)
print("LATITUDE , LONGITUDE = ", x1['LATITUDE'].values, " ",x1['LONGITUDE'].values )
# Out:
# Flor =  [3]
# LATITUDE , LONGITUDE =  [4864904.70462]   [-7637.15038]
# Flor =  [2]
# LATITUDE , LONGITUDE =  [4864922.39917781]   [-7641.49930337]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X_train['LATITUDE'], X_train['LONGITUDE'], X_train['FLOOR'], alpha =0.01)
ax.scatter(lat, lon, flor, s=120, c="red")
ax.scatter(x1['LATITUDE'], x1['LONGITUDE'], x1['FLOOR'].values, s=120, c="black")
# ax.scatter(X_test['LATITUDE'], X_test['LONGITUDE'], X_test['FLOOR'])

plt.show()
