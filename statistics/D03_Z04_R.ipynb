# %% [markdown]
# # Rozkład chi kwadrat z $n$ stopniami swobody
# Rozkład chi kwadrat ma gęstość:
#
# $$
# f_{X}(x) =
# \left\{ \begin{array}{ll}
# {\frac {1}{2^{\frac {n}{2}}\Gamma \left({\frac {n}{2}}\right)}}\;x^{{\frac {n}{2}}-1}e^{-{\frac {x}{2}}}
#    & \textrm{gdy } x \geq 0\\
# 0 & \textrm{gdy } x < 0
# \end{array} \right. ,
# $$
#
# gdzie $\Gamma$ oznacza funkcję Gamma https://pl.wikipedia.org/wiki/Funkcja_\%CE\%93

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %% [markdown]
# # Definiujemy zmienną losową

# %%
t = np.arange(0, 40, 0.05)
n=4
X=stats.chi2(n)

# %% [markdown]
# # Narysujmy gętość zmiennej losowej

# %%
fig, ax = plt.subplots(1, 1)
plt.plot(t, stats.chi2(4).pdf(t), '--', ms=8, label='n=4')
plt.plot(t, stats.chi2(6).pdf(t), '--', ms=8, label='n=6')
plt.plot(t, stats.chi2(8).pdf(t), '--', ms=8, label='n=8')
plt.plot(t, stats.chi2(10).pdf(t), '--', ms=8, label='n=10')
plt.plot(t, stats.chi2(20).pdf(t), '--', ms=8, label='n=20')
plt.legend()
plt.show()

# %%
t = np.arange(-3, 0, 0.05)
fig, ax = plt.subplots(1, 1)
plt.plot(t, stats.chi2(1).pdf( np.abs(t) ), ms=8, c ="k" )
# plt.legend()
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
# plt.axis('off')
ax.set_yticks([])
plt.show()

# %%
t = np.arange(-3.5, 3.5, 0.05)
fig, ax = plt.subplots(1, 1)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_yticks([])
ax.plot(t, stats.norm.pdf(t, 0, 1), ms=8, c ="k" ) 
# ax.axis('off')
# plt[0].spines['right'].set_color('none')
# plt[0].spines['top'].set_color('none')

plt.show()

# %% [markdown]
# # Narysujmy dystrybuantę zmiennej losowej

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(t, X.cdf(t), '--', ms=8, label='bernoulli cdf')
plt.show()

# %% [markdown]
# # Wylosujmy próbkę i narysujmy histogram na jednym obrazku

# %%
r = X.rvs(size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, normed=True, histtype='stepfilled', alpha=0.5, label='histogram')
ax.legend(loc='best', frameon=False)
ax.plot(t, X.pdf(t), 'k-', lw=2, label='a=-1, b=1')
ax.legend()
plt.show()

# %% [markdown]
# # Narysuj gęstości rozkładu jednostajnego z różnymi parametrami

# %%
n_values = [1, 2, 3]
fig, ax = plt.subplots(1, 1)
for n in n_values:
    dist = stats.chi2(n)
    plt.plot(t, dist.pdf(t), ls="--",label=r'$n=%1.f' % n)  
plt.legend()
plt.show()

# %% [markdown]
# # Narysuj kilka histogramów różnych próbek z roskładu jednostajnego o tych samych parametrach.

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, figsize=(10, 10))

for i in np.arange(0,5):
    for j in np.arange(0,5):
        r = X.rvs(size=100)
        ax[i,j].hist(r, normed=True)
plt.show()
