# %% [markdown]
# # Zadanie
# Zmienna losowa $X$ ma rozkład t-Studenta o $n = 15$ stopniach swobody. Oblicz prawdopodobieństwa:
# <ul>
# <li>
# $$
# P( | X | \geq 1.753)
# $$
# </li>
# <li>
# $$
# P( | X | < 2.13)
# $$
# </li>
# <li>
# $$
# P( X \geq 2.95)
# $$
# </li>
# </ul>
# Zaznacz odpowiednie wartości na wykresie gęstości i dystrybuanty.

# %%
import numpy as np
from scipy import stats
from scipy import integrate
import matplotlib.pyplot as plt

# %% [markdown]
# Zdefiniujmy zmienną losową o rozkładzie chi kwadrat z $n-1$ stopniami swobody:

# %%
n = 15
X = stats.t(n)

# %% [markdown]
# $$
# P( | X | \geq 1.753) =
# $$

# %% [markdown]
# $$
# P( | X | < 2.13)
# $$

# %% [markdown]
# $$
# P( X \geq 2.95)
# $$
