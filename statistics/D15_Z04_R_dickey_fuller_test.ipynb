# %% [markdown]
# # Dickey Fuller Test
# Test Dickey-Fuller: jest to jeden ze statystycznych testów sprawdzających stacjonarność. Tutaj hipoteza zerowa to, że szereg czasowy jest niestacjonarny.
# Wyniki testu obejmują statystykę testu oraz niektóre wartości krytyczne dla różnych poziomów ufności. Jeśli statystyka testowa jest mniejsza niż  wartość krytyczna, możemy odrzucić hipotezę zerową i powiedzieć, że szereg czasowy jest stacjonarny.

# %%
import numpy as np
import pandas as pd
import scipy
import random
import matplotlib.pylab as plt
from statsmodels.tsa.stattools import adfuller

# %%
x = [0]
for j in range(1000):
    x.append(x[j] + np.random.normal())

# %%
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                   -1.879571
# p-value                           0.341732
# #Lags Used                        0.000000
# Number of Observations Used    1000.000000
# Critical Value (1%)              -3.436906
# Critical Value (5%)              -2.864435
# Critical Value (10%)             -2.568311
# dtype: float64

# %%
_,pval,_,_,_,_ =adfuller(df, autolag='AIC')
pval
# Out:
# 0.34173156447870345

# %% [markdown]
# # rho=0

# %%
rho=0.98
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                -9.448486e+00
# p-value                        4.685224e-16
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.000000e+04
# Critical Value (1%)           -3.431004e+00
# Critical Value (5%)           -2.861829e+00
# Critical Value (10%)          -2.566924e+00
# dtype: float64

# %% [markdown]
# # rho=0.5

# %%
rho=0.5
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                -1.714795e+01
# p-value                        6.973560e-30
# #Lags Used                     1.000000e+00
# Number of Observations Used    9.990000e+02
# Critical Value (1%)           -3.436913e+00
# Critical Value (5%)           -2.864437e+00
# Critical Value (10%)          -2.568313e+00
# dtype: float64

# %% [markdown]
# # rho=0.9

# %%
rho=0.9
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                -7.752828e+00
# p-value                        9.915219e-12
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.000000e+03
# Critical Value (1%)           -3.436906e+00
# Critical Value (5%)           -2.864435e+00
# Critical Value (10%)          -2.568311e+00
# dtype: float64

# %% [markdown]
# # rho=1

# %%
rho=1
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # Zadanie
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                   -1.285454
# p-value                           0.635801
# #Lags Used                        0.000000
# Number of Observations Used    1000.000000
# Critical Value (1%)              -3.436906
# Critical Value (5%)              -2.864435
# Critical Value (10%)             -2.568311
# dtype: float64
