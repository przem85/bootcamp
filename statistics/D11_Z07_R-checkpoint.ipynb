# %% [markdown]
# # Ridge Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy.stats as stats
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
true_fun = lambda X: np.cos(1.5 * np.pi * X)
n_samples=20
x = np.sort(np.random.rand(n_samples))
y = true_fun(x) + np.random.randn(n_samples) * 0.1
x=np.vstack(x)

# %% [markdown]
# # Zadanie
# Proszę wykonać regresję (Ridge Regression) na powyższym zbiorze danych

# %%
clf = Ridge(alpha=1.0)
clf.fit(x, y) 

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, clf.predict(x_plot), color='blue',linewidth=3)
plt.plot(x, y, 'ok');
plt.show()

# %% [markdown]
# ## Regresja liniowa

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 100))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 100))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zadanie
# Proszę wykonać
# * regresję dla wielomianów o stopniu **20**
# * regresję (Ridge Regression) dla wielomianów o stopniu **20**

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))
models.append(('Ridge degree 20', make_pipeline(PolynomialFeatures(20), linear_model.Ridge()) ))

x_plot = np.vstack(np.linspace(-3, 3, 100))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 100))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 20
# Ridge degree 20

# %% [markdown]
# # Zadanie
# Wykonaj k-fold cross-validation dla:
#
# - regrsji linowej
# - regrsji wielomianowej stopnia 2
# - regrsji wielomianowej stopnia 5
# - regrsji wielomianowej stopnia 25
# - regrsji Ridge wielomianowej stopnia 2 alpha=10.0
# - regrsji Ridge wielomianowej stopnia 5 alpha=10.0
# - regrsji Ridge wielomianowej stopnia 25 alpha=10.0
#
# oraz podaj uśrednione wartości dla każdej z nich oraz wykonaj barplot.

# %%
# prepare models
models = []
models.append(('LR', linear_model.LinearRegression()))
models.append(('Ridge LR', linear_model.Ridge(alpha=1.0)))
models.append(('PR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('Ridge PR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.Ridge(alpha=10.0)) ))
models.append(('PR degree 3', make_pipeline(PolynomialFeatures(3), linear_model.LinearRegression()) ))
models.append(('Ridge PR degree 3', make_pipeline(PolynomialFeatures(3), linear_model.Ridge(alpha=1.0)) ))
models.append(('PR degree 4', make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression()) ))
models.append(('Ridge PR degree 4', make_pipeline(PolynomialFeatures(4), linear_model.Ridge(alpha=1.0)) ))
models.append(('PR degree 110', make_pipeline(PolynomialFeatures(10), linear_model.LinearRegression()) ))
models.append(('Ridge PR degree 10', make_pipeline(PolynomialFeatures(10), linear_model.Ridge(alpha=10.0)) ))

# evaluate each model in turn
results = []
names = []
scoring = 'neg_mean_absolute_error'
#scoring = 'r2'

# %%
seed = 7
for name, model in models:
    kfold = model_selection.KFold(n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(model, x, y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: -0.389889 (0.353928)
# Ridge LR: -0.500233 (0.197047)
# PR degree 2: -0.311353 (0.294319)
# Ridge PR degree 2: -0.680475 (0.263346)
# PR degree 3: -0.091916 (0.059787)
# Ridge PR degree 3: -0.536369 (0.277337)
# PR degree 4: -0.169358 (0.178286)
# Ridge PR degree 4: -0.542512 (0.302177)
# PR degree 110: -128.658614 (341.839313)
# Ridge PR degree 10: -0.679660 (0.253536)

# %%
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names, rotation=45, ha='right', fontsize=14)
plt.show()

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr alpha.

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), linear_model.Ridge()),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7],
                    'ridge__alpha': [0.1, 1, 2, 3]},
                    cv=5,
                    refit=False)
grid.fit(x, y)
grid.best_params_
# Out:
# {'polynomialfeatures__degree': 7, 'ridge__alpha': 0.1}

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr <tt>alpha</tt> za pomocą metody <tt>GridSearchCV</tt> dla danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.

# %%
import pandas as pd
df_adv = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
from sklearn.model_selection import GridSearchCV
seed=123
kfold = model_selection.KFold(n_splits=5, random_state=seed)

grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), linear_model.Ridge()),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7],
                    'ridge__alpha': [0.1, 1, 2, 3,10]},
                    cv=kfold,
                    refit=False)
grid.fit(X, y)
grid.best_params_
# Out:
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.0183447233767895e-17 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 9.238333693498278e-18 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.0066862902081973e-17 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 9.475120516633026e-18 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.037731072493423e-17 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.0183447233767893e-16 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 9.238333693498274e-17 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.006686290208197e-16 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 9.475120516633024e-17 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.0377310724934227e-16 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.3185573328205078e-22 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.175994027035053e-22 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.3197673968535345e-22 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.198204600644049e-22 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.3701016811038262e-22 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.3185573328205073e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.1759940270350529e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.3197673968535342e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.1982046006440486e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.370101681103826e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.6371146656410154e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.351988054070106e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.6395347937070692e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.396409201288098e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.7402033622076523e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.9556719984615215e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.527982081105158e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.959302190560602e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.594613801932145e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.110305043311477e-21 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.3185573328205075e-20 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.1759940270350528e-20 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.3197673968535342e-20 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.1982046006440486e-20 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.370101681103826e-20 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.6938446706913866e-27 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.4942684055475394e-27 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.7154439391651702e-27 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.5108774940664044e-27 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.78763498278245e-27 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.6938446706913864e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.494268405547539e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.7154439391651698e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.5108774940664042e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.7876349827824498e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.3876893413827733e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.988536811095079e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.4308878783303407e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.021754988132809e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.5752699655649e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 5.081534012074158e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.4828052166426165e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 5.146331817495509e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.5326324821992115e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 5.362904948347349e-26 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.6938446706913863e-25 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.494268405547539e-25 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.7154439391651698e-25 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.5108774940664042e-25 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.78763498278245e-25 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.145607885081389e-32 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.879505647464139e-32 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.1988697361322014e-32 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.8845771592160566e-32 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.2864227287779811e-32 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.1456078850813886e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.8795056474641387e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.1988697361322007e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.8845771592160563e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.2864227287779806e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.005854177808908e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.759011294928278e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.397739472264403e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.6557235843977745e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.572845457555963e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 5.762130108909624e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 5.6385169423924155e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 6.596609208396601e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 5.251861586547513e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 6.859268186333941e-31 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.8176874449324078e-30 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.8795056474641386e-30 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.029303917904342e-30 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.66355670886941e-30 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.1275331286970706e-30 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.6834201294765526e-37 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.340149780010859e-37 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.783965748740421e-37 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.326222091575388e-37 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.871690895499924e-37 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.510487848125913e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.3401497800108588e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.4888252542007485e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.3262220915753876e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.5869869408755054e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.831262383402686e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.9974725310143153e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.78735324234232e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.6524441831507766e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 5.007110543353306e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 7.164185364538075e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 5.946698228156242e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 7.092019863764591e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 6.978666274726162e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 7.434098753799335e-36 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.2317112999718364e-35 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.3401497800108587e-35 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.3352802072311167e-35 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.3262220915753875e-35 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.4512667434487183e-35 / 1.1102230246251565e-16
#   RuntimeWarning)
# {'polynomialfeatures__degree': 4, 'ridge__alpha': 10}
