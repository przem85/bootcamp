# %% [markdown]
# # Ridge Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy.stats as stats
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
true_fun = lambda X: np.cos(1.5 * np.pi * X)
n_samples=20
x = np.sort(np.random.rand(n_samples))
y = true_fun(x) + np.random.randn(n_samples) * 0.1
x=np.vstack(x)

# %% [markdown]
# # Zadanie
# Proszę wykonać regresję (Ridge Regression) na powyższym zbiorze danych

# %%
clf = Ridge(alpha=1.0)
clf.fit(x, y) 

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, clf.predict(x_plot), color='blue',linewidth=3)
plt.plot(x, y, 'ok');
plt.show()

# %% [markdown]
# ## Regresja liniowa

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zadanie
# Proszę wykonać
# * regresję dla wielomianów o stopniu **20**
# * regresję (Ridge Regression) dla wielomianów o stopniu **20**

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))
models.append(('Ridge degree 20', make_pipeline(PolynomialFeatures(20), linear_model.Ridge(alpha=1)) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 20
# Ridge degree 20

# %% [markdown]
# # Zadanie
# Wykonaj k-fold cross-validation dla:
#
# - regrsji linowej
# - regrsji wielomianowej stopnia 2
# - regrsji wielomianowej stopnia 5
# - regrsji wielomianowej stopnia 25
# - regrsji Ridge wielomianowej stopnia 2 alpha=10.0
# - regrsji Ridge wielomianowej stopnia 5 alpha=10.0
# - regrsji Ridge wielomianowej stopnia 25 alpha=10.0
#
# oraz podaj uśrednione wartości dla każdej z nich oraz wykonaj barplot.

# %%
# prepare models
models = []
models.append(('LR', linear_model.LinearRegression()))
models.append(('Ridge LR', linear_model.Ridge(alpha=1.0)))
models.append(('PR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('Ridge PR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.Ridge(alpha=10.0)) ))
models.append(('PR degree 3', make_pipeline(PolynomialFeatures(3), linear_model.LinearRegression()) ))
models.append(('Ridge PR degree 3', make_pipeline(PolynomialFeatures(3), linear_model.Ridge(alpha=1.0)) ))
models.append(('PR degree 4', make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression()) ))
models.append(('Ridge PR degree 4', make_pipeline(PolynomialFeatures(4), linear_model.Ridge(alpha=1.0)) ))
models.append(('PR degree 110', make_pipeline(PolynomialFeatures(10), linear_model.LinearRegression()) ))
models.append(('Ridge PR degree 10', make_pipeline(PolynomialFeatures(10), linear_model.Ridge(alpha=10.0)) ))

# evaluate each model in turn
results = []
names = []
scoring = 'neg_mean_absolute_error'
#scoring = 'r2'

# %%
seed = 7
for name, model in models:
    kfold = model_selection.KFold(n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(model, x, y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: -0.425397 (0.312009)
# Ridge LR: -0.408316 (0.280123)
# PR degree 2: -0.192806 (0.102453)
# Ridge PR degree 2: -0.465587 (0.317624)
# PR degree 3: -0.140955 (0.103494)
# Ridge PR degree 3: -0.428930 (0.306233)
# PR degree 4: -0.118655 (0.072356)
# Ridge PR degree 4: -0.425296 (0.301934)
# PR degree 110: -11.791699 (27.448457)
# Ridge PR degree 10: -0.480113 (0.303935)

# %%
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names, rotation=45, ha='right', fontsize=14)
plt.show()

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr alpha.

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), linear_model.Ridge()),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7],
                    'ridge__alpha': [0.1, 1, 2, 3]},
                    cv=5,
                    refit=False)
grid.fit(x, y)
grid.best_params_
# Out:
# {'polynomialfeatures__degree': 7, 'ridge__alpha': 0.1}

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr <tt>alpha</tt> za pomocą metody <tt>GridSearchCV</tt> dla danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.

# %%
import pandas as pd
df_adv = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
from sklearn.model_selection import GridSearchCV
seed=123
kfold = model_selection.KFold(n_splits=5, random_state=seed)

grid = GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), linear_model.Ridge(random_state=seed)),
                    param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 6, 7],
                    'ridge__alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 200, 201, 300, 1000]},
                    cv=kfold,
                    refit=True)
grid.fit(X, y)
grid.best_params_
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.01834e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.23833e-21): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.00669e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.47512e-21): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.03773e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.01834e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.23833e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.00669e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.47512e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.03773e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.01834e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.23833e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.00669e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.47512e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.03773e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.01834e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.23833e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.00669e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.47512e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.03773e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.01834e-16): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.23833e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.00669e-16): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=9.47512e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.03773e-16): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31856e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.17599e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31977e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.1982e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.3701e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31856e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.17599e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31977e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.1982e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.3701e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31856e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.17599e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31977e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.1982e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.3701e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31856e-22): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.17599e-22): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31977e-22): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.1982e-22): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.3701e-22): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31856e-21): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.17599e-21): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31977e-21): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.1982e-21): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.3701e-21): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31856e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.17599e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31977e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.1982e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.3701e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31856e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.17599e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.31977e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.1982e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.3701e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.54419e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.35199e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.63953e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.39641e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.7402e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.5559e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.36375e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.65273e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.40839e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.7539e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.72129e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.52798e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.9593e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.59461e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.04884e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.29513e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.10794e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.25113e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.13931e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.28287e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.69384e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.49427e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.71544e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.51088e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.78763e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.69384e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.49427e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.71544e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.51088e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.78763e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.69384e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.49427e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.71544e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.51088e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.78763e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.69384e-27): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.49427e-27): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.71544e-27): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.51088e-27): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.78763e-27): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.69384e-26): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.49427e-26): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.71544e-26): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.51088e-26): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.78763e-26): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.69384e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.49427e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.71544e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.51088e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.78763e-25): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.65341e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.41015e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.61844e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.38634e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.65915e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.18329e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.74361e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.15078e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.74162e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.24307e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.19861e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.75698e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.16614e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.75523e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.25898e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.71683e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.0833e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.68939e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.10657e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.83823e-24): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.55387e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.49427e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.71544e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.51088e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.78763e-23): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.14561e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.87951e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.19887e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.88458e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.28642e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.14561e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.87951e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.19887e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.88458e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.28642e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.14561e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.87951e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.19887e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.88458e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.28642e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.14561e-32): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.87951e-32): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.19887e-32): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.88458e-32): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.28642e-32): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.14561e-31): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.87951e-31): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.19887e-31): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.88458e-31): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.28642e-31): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.81769e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.87951e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.0293e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.66356e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.12753e-30): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.83777e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.87951e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.19887e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.88458e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.98829e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.91348e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.75901e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.89012e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.76915e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.26467e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.93093e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.77781e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.90779e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.788e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.28369e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=5.67379e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=5.25905e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=5.66977e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=5.3022e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=6.1763e-29): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.85818e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.70564e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.86871e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.73002e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.00117e-28): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.68342e-40): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.34015e-40): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.78397e-40): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.32622e-40): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.87169e-40): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.68342e-39): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.34015e-39): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.78397e-39): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.32622e-39): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.87169e-39): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.68342e-38): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.34015e-38): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.78397e-38): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.32622e-38): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.87169e-38): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.68342e-37): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.34015e-37): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.78397e-37): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.32622e-37): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.87169e-37): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.51049e-36): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.34015e-36): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.48883e-36): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.32622e-36): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.58699e-36): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.23171e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.34015e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.33528e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.32622e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.45127e-35): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.17286e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.98677e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.23993e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.32622e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.40171e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.8986e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.04083e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.60484e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.51273e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.90457e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.91727e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.06159e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.62888e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=3.52948e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=4.92992e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=5.78782e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=6.12922e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=8.3519e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=6.97867e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=7.45986e-34): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.07805e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.7784e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.78397e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=1.83864e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.32725e-33): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: Ill-conditioned matrix (rcond=2.03325e-19): result may not be accurate.
#   overwrite_a=True).T
# {'polynomialfeatures__degree': 4, 'ridge__alpha': 200}

# %%
from sklearn import  metrics
metrics.r2_score(grid.best_estimator_.predict(X) , y )
# Out:
# 0.9946169465598221
