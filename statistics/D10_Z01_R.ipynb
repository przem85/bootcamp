# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
M6 = np.vstack( (np.ones_like(x), x, x**3, x**4, x**5, x**6) ).T
p6 = np.linalg.lstsq(M6, y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
M55 = np.vstack( (np.ones_like(x), x, x**3, x**4) ).T
p55 = np.linalg.lstsq(M55, y)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_1 = f_lr_1(x_tr)
y_f_lr_2 = f_lr_2(x_tr)
y_f_lr_3 = f_lr_3(x_tr)
y_f_lr_4 = f_lr_4(x_tr)
y_f_lr_5 = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_1, 'r');
plt.plot(x_f_lr, y_f_lr_2, 'g');
plt.plot(x_f_lr, y_f_lr_3, 'b');
plt.plot(x_f_lr, y_f_lr_4, 'c');
plt.plot(x_f_lr, y_f_lr_5, 'r');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res55 = sm.OLS(y, M55).fit()

print(Res55.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -36.2012
# Date:               2018-08-26 14:27 BIC:                -25.7806
# No. Observations:   100              Log-Likelihood:     22.101
# Df Model:           3                F-statistic:        5.778e+04
# Df Residuals:       96               Prob (F-statistic): 3.69e-156
# R-squared:          0.999            Scale:              0.039200
# --------------------------------------------------------------------
#           Coef.    Std.Err.       t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const    -0.6799     0.0744     -9.1431   0.0000   -0.8275   -0.5323
# x1        8.5559     0.1286     66.5234   0.0000    8.3006    8.8112
# x2       -6.0183     0.0594   -101.2808   0.0000   -6.1362   -5.9003
# x3        2.1682     0.0169    128.4320   0.0000    2.1347    2.2017
# ------------------------------------------------------------------
# Omnibus:               6.719        Durbin-Watson:           1.835
# Prob(Omnibus):         0.035        Jarque-Bera (JB):        3.071
# Skew:                  0.125        Prob(JB):                0.215
# Kurtosis:              2.178        Condition No.:           226
# ==================================================================
#
# .....................................
# .....................................
# .....................................

# %%
M_5_3 = np.vstack( (np.ones_like(x), x, x**3, x**4, x**5) ).T

import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()
Res6 = sm.OLS(y, M_5_3).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res6.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.452
# Dependent Variable: y                AIC:                612.7413
# Date:               2018-05-20 12:40 BIC:                617.9517
# No. Observations:   100              Log-Likelihood:     -304.37
# Df Model:           1                F-statistic:        82.62
# Df Residuals:       98               Prob (F-statistic): 1.14e-14
# R-squared:          0.457            Scale:              26.304
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -2.3572     0.9997   -2.3578   0.0204   -4.3411   -0.3733
# x1         5.5355     0.6090    9.0896   0.0000    4.3270    6.7441
# -----------------------------------------------------------------
# Omnibus:             46.481       Durbin-Watson:          2.246
# Prob(Omnibus):       0.000        Jarque-Bera (JB):       118.604
# Skew:                1.737        Prob(JB):               0.000
# Kurtosis:            7.049        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.740
# Dependent Variable: y                AIC:                539.2889
# Date:               2018-05-20 12:40 BIC:                547.1044
# No. Observations:   100              Log-Likelihood:     -266.64
# Df Model:           2                F-statistic:        141.6
# Df Residuals:       97               Prob (F-statistic): 1.69e-29
# R-squared:          0.745            Scale:              12.497
# -------------------------------------------------------------------
#          Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# const     4.9360     0.9806    5.0337   0.0000     2.9898    6.8822
# x1      -10.3782     1.5791   -6.5722   0.0000   -13.5123   -7.2441
# x2        5.6148     0.5371   10.4537   0.0000     4.5488    6.6808
# -----------------------------------------------------------------
# Omnibus:              6.756        Durbin-Watson:           2.131
# Prob(Omnibus):        0.034        Jarque-Bera (JB):        6.914
# Skew:                 0.642        Prob(JB):                0.032
# Kurtosis:             2.898        Condition No.:           22
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.987
# Dependent Variable: y                AIC:                240.4416
# Date:               2018-05-20 12:40 BIC:                250.8623
# No. Observations:   100              Log-Likelihood:     -116.22
# Df Model:           3                F-statistic:        2509.
# Df Residuals:       96               Prob (F-statistic): 5.06e-91
# R-squared:          0.987            Scale:              0.62336
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -3.0130    0.2866  -10.5126  0.0000   -3.5819   -2.4441
# x1         24.4101    0.8826   27.6559  0.0000   22.6581   26.1621
# x2        -24.2758    0.7055  -34.4105  0.0000  -25.6761  -22.8754
# x3          6.7979    0.1581   42.9956  0.0000    6.4841    7.1117
# -----------------------------------------------------------------
# Omnibus:              6.172        Durbin-Watson:           1.985
# Prob(Omnibus):        0.046        Jarque-Bera (JB):        3.244
# Skew:                 0.203        Prob(JB):                0.198
# Kurtosis:             2.217        Condition No.:           144
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -27.6171
# Date:               2018-05-20 12:40 BIC:                -14.5913
# No. Observations:   100              Log-Likelihood:     18.809
# Df Model:           4                F-statistic:        2.805e+04
# Df Residuals:       95               Prob (F-statistic): 5.43e-145
# R-squared:          0.999            Scale:              0.042309
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.9474     0.0939   -10.0945   0.0000   -1.1338   -0.7611
# x1         9.6255     0.4675    20.5897   0.0000    8.6974   10.5535
# x2        -1.4759     0.6540    -2.2565   0.0263   -2.7743   -0.1774
# x3        -5.2646     0.3346   -15.7327   0.0000   -5.9289   -4.6003
# x4         2.0443     0.0563    36.3236   0.0000    1.9326    2.1560
# ------------------------------------------------------------------
# Omnibus:               3.711        Durbin-Watson:           2.010
# Prob(Omnibus):         0.156        Jarque-Bera (JB):        2.082
# Skew:                  0.039        Prob(JB):                0.353
# Kurtosis:              2.298        Condition No.:           1060
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -26.0137
# Date:               2018-05-20 12:40 BIC:                -10.3827
# No. Observations:   100              Log-Likelihood:     19.007
# Df Model:           5                F-statistic:        2.229e+04
# Df Residuals:       94               Prob (F-statistic): 8.05e-143
# R-squared:          0.999            Scale:              0.042590
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -0.9934     0.1205   -8.2436   0.0000   -1.2326   -0.7541
# x1         10.0862     0.8879   11.3602   0.0000    8.3233   11.8490
# x2         -2.5477     1.8725   -1.3606   0.1769   -6.2656    1.1703
# x3         -4.3127     1.5933   -2.7067   0.0081   -7.4763   -1.1491
# x4          1.6866     0.5880    2.8683   0.0051    0.5191    2.8541
# x5          0.0479     0.0783    0.6111   0.5426   -0.1077    0.2034
# ------------------------------------------------------------------
# Omnibus:               3.913        Durbin-Watson:           2.001
# Prob(Omnibus):         0.141        Jarque-Bera (JB):        2.174
# Skew:                  0.064        Prob(JB):                0.337
# Kurtosis:              2.289        Condition No.:           8604
# ==================================================================
# * The condition number is large (9e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -26.0636
# Date:               2018-05-20 12:40 BIC:                -13.0377
# No. Observations:   100              Log-Likelihood:     18.032
# Df Model:           4                F-statistic:        2.762e+04
# Df Residuals:       95               Prob (F-statistic): 1.14e-144
# R-squared:          0.999            Scale:              0.042971
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.8642     0.0745   -11.6010   0.0000   -1.0120   -0.7163
# x1         8.9087     0.1993    44.7004   0.0000    8.5131    9.3044
# x2        -6.4554     0.2431   -26.5598   0.0000   -6.9379   -5.9729
# x3         2.4583     0.1559    15.7716   0.0000    2.1488    2.7677
# x4        -0.0520     0.0276    -1.8839   0.0626   -0.1067    0.0028
# ------------------------------------------------------------------
# Omnibus:               3.226        Durbin-Watson:           2.019
# Prob(Omnibus):         0.199        Jarque-Bera (JB):        1.905
# Skew:                  0.011        Prob(JB):                0.386
# Kurtosis:              2.324        Condition No.:           1118
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()
Res3F = smf.ols('y ~ x+I(x**2)+I(x**3)', df).fit()
Res4F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     82.62
# Date:                Sun, 20 May 2018   Prob (F-statistic):           1.14e-14
# Time:                        12:31:51   Log-Likelihood:                -304.37
# No. Observations:                 100   AIC:                             612.7
# Df Residuals:                      98   BIC:                             618.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.3572      1.000     -2.358      0.020      -4.341      -0.373
# x              5.5355      0.609      9.090      0.000       4.327       6.744
# ==============================================================================
# Omnibus:                       46.481   Durbin-Watson:                   2.246
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.604
# Skew:                           1.737   Prob(JB):                     1.76e-26
# Kurtosis:                       7.049   Cond. No.                         4.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     141.6
# Date:                Sun, 20 May 2018   Prob (F-statistic):           1.69e-29
# Time:                        12:31:51   Log-Likelihood:                -266.64
# No. Observations:                 100   AIC:                             539.3
# Df Residuals:                      97   BIC:                             547.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.9360      0.981      5.034      0.000       2.990       6.882
# x            -10.3782      1.579     -6.572      0.000     -13.512      -7.244
# I(x ** 2)      5.6148      0.537     10.454      0.000       4.549       6.681
# ==============================================================================
# Omnibus:                        6.756   Durbin-Watson:                   2.131
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                6.914
# Skew:                           0.642   Prob(JB):                       0.0315
# Kurtosis:                       2.898   Cond. No.                         21.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                     2509.
# Date:                Sun, 20 May 2018   Prob (F-statistic):           5.06e-91
# Time:                        12:31:51   Log-Likelihood:                -116.22
# No. Observations:                 100   AIC:                             240.4
# Df Residuals:                      96   BIC:                             250.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.0130      0.287    -10.513      0.000      -3.582      -2.444
# x             24.4101      0.883     27.656      0.000      22.658      26.162
# I(x ** 2)    -24.2758      0.705    -34.411      0.000     -25.676     -22.875
# I(x ** 3)      6.7979      0.158     42.996      0.000       6.484       7.112
# ==============================================================================
# Omnibus:                        6.172   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                3.244
# Skew:                           0.203   Prob(JB):                        0.198
# Kurtosis:                       2.217   Cond. No.                         144.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.805e+04
# Date:                Sun, 20 May 2018   Prob (F-statistic):          5.43e-145
# Time:                        12:31:51   Log-Likelihood:                 18.809
# No. Observations:                 100   AIC:                            -27.62
# Df Residuals:                      95   BIC:                            -14.59
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9474      0.094    -10.094      0.000      -1.134      -0.761
# x              9.6255      0.467     20.590      0.000       8.697      10.554
# I(x ** 2)     -1.4759      0.654     -2.257      0.026      -2.774      -0.177
# I(x ** 3)     -5.2646      0.335    -15.733      0.000      -5.929      -4.600
# I(x ** 4)      2.0443      0.056     36.324      0.000       1.933       2.156
# ==============================================================================
# Omnibus:                        3.711   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.156   Jarque-Bera (JB):                2.082
# Skew:                           0.039   Prob(JB):                        0.353
# Kurtosis:                       2.298   Cond. No.                     1.06e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.229e+04
# Date:                Sun, 20 May 2018   Prob (F-statistic):          8.05e-143
# Time:                        12:31:51   Log-Likelihood:                 19.007
# No. Observations:                 100   AIC:                            -26.01
# Df Residuals:                      94   BIC:                            -10.38
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9934      0.121     -8.244      0.000      -1.233      -0.754
# x             10.0862      0.888     11.360      0.000       8.323      11.849
# I(x ** 2)     -2.5477      1.873     -1.361      0.177      -6.266       1.170
# I(x ** 3)     -4.3127      1.593     -2.707      0.008      -7.476      -1.149
# I(x ** 4)      1.6866      0.588      2.868      0.005       0.519       2.854
# I(x ** 5)      0.0479      0.078      0.611      0.543      -0.108       0.203
# ==============================================================================
# Omnibus:                        3.913   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.174
# Skew:                           0.064   Prob(JB):                        0.337
# Kurtosis:                       2.289   Cond. No.                     8.60e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
Res2F.params
# Out:
# Intercept     5.521609
# x           -10.830084
# I(x ** 2)     5.839260
# dtype: float64

# %%
Res2F.bse
# Out:
# Intercept    1.079076
# x            1.694912
# I(x ** 2)    0.559905
# dtype: float64

# %%
Res2F.conf_int()
# Out:
#                    0         1
# Intercept   3.379941  7.663276
# x         -14.194015 -7.466152
# I(x ** 2)   4.728004  6.950515
