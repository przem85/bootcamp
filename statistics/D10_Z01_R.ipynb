# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y)

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y)

# %%
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y)

# %%
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
M6 = np.vstack( (np.ones_like(x), x, x**3, x**4, x**5, x**6) ).T
p6 = np.linalg.lstsq(M6, y)

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_1 = f_lr_1(x_tr)
y_f_lr_2 = f_lr_2(x_tr)
y_f_lr_3 = f_lr_3(x_tr)
y_f_lr_4 = f_lr_4(x_tr)
y_f_lr_5 = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_1, 'r');
plt.plot(x_f_lr, y_f_lr_2, 'g');
plt.plot(x_f_lr, y_f_lr_3, 'b');
plt.plot(x_f_lr, y_f_lr_4, 'c');
plt.plot(x_f_lr, y_f_lr_5, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()
Res6 = sm.OLS(y, M6).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res6.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.536
# Dependent Variable: y                AIC:                570.4447
# Date:               2017-11-26 10:36 BIC:                575.6550
# No. Observations:   100              Log-Likelihood:     -283.22
# Df Model:           1                F-statistic:        115.3
# Df Residuals:       98               Prob (F-statistic): 3.03e-18
# R-squared:          0.541            Scale:              17.232
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -2.1124     0.8354   -2.5287   0.0130   -3.7701   -0.4546
# x1         5.2671     0.4905   10.7391   0.0000    4.2938    6.2404
# -----------------------------------------------------------------
# Omnibus:              22.089       Durbin-Watson:          2.045
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       30.094
# Skew:                 1.073        Prob(JB):               0.000
# Kurtosis:             4.618        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.749
# Dependent Variable: y                AIC:                509.9594
# Date:               2017-11-26 10:36 BIC:                517.7750
# No. Observations:   100              Log-Likelihood:     -251.98
# Df Model:           2                F-statistic:        148.7
# Df Residuals:       97               Prob (F-statistic): 2.85e-30
# R-squared:          0.754            Scale:              9.3201
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const      3.6144     0.8758    4.1272   0.0001    1.8763    5.3526
# x1        -7.0802     1.3932   -5.0821   0.0000   -9.8452   -4.3152
# x2         4.3168     0.4705    9.1757   0.0000    3.3831    5.2506
# -----------------------------------------------------------------
# Omnibus:              3.744        Durbin-Watson:           1.920
# Prob(Omnibus):        0.154        Jarque-Bera (JB):        3.392
# Skew:                 0.371        Prob(JB):                0.183
# Kurtosis:             2.488        Condition No.:           23
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.986
# Dependent Variable: y                AIC:                219.9329
# Date:               2017-11-26 10:36 BIC:                230.3536
# No. Observations:   100              Log-Likelihood:     -105.97
# Df Model:           3                F-statistic:        2381.
# Df Residuals:       96               Prob (F-statistic): 5.97e-90
# R-squared:          0.987            Scale:              0.50777
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -2.4543    0.2523   -9.7282  0.0000   -2.9551   -1.9535
# x1         22.5928    0.7928   28.4991  0.0000   21.0192   24.1664
# x2        -22.5822    0.6645  -33.9817  0.0000  -23.9013  -21.2631
# x3          6.3509    0.1547   41.0419  0.0000    6.0438    6.6581
# -----------------------------------------------------------------
# Omnibus:              8.214        Durbin-Watson:           1.756
# Prob(Omnibus):        0.016        Jarque-Bera (JB):        4.627
# Skew:                 0.335        Prob(JB):                0.099
# Kurtosis:             2.187        Condition No.:           152
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -25.9264
# Date:               2017-11-26 10:36 BIC:                -12.9005
# No. Observations:   100              Log-Likelihood:     17.963
# Df Model:           4                F-statistic:        2.133e+04
# Df Residuals:       95               Prob (F-statistic): 2.37e-139
# R-squared:          0.999            Scale:              0.043030
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -1.0988     0.0846   -12.9812   0.0000   -1.2668   -0.9307
# x1        10.5944     0.4381    24.1799   0.0000    9.7245   11.4642
# x2        -2.8087     0.6436    -4.3643   0.0000   -4.0863   -1.5311
# x3        -4.5946     0.3427   -13.4058   0.0000   -5.2751   -3.9142
# x4         1.9307     0.0599    32.2153   0.0000    1.8117    2.0496
# ------------------------------------------------------------------
# Omnibus:               2.816        Durbin-Watson:           1.962
# Prob(Omnibus):         0.245        Jarque-Bera (JB):        2.741
# Skew:                  0.348        Prob(JB):                0.254
# Kurtosis:              2.583        Condition No.:           1053
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -23.9474
# Date:               2017-11-26 10:36 BIC:                -8.3164
# No. Observations:   100              Log-Likelihood:     17.974
# Df Model:           5                F-statistic:        1.689e+04
# Df Residuals:       94               Prob (F-statistic): 3.66e-137
# R-squared:          0.999            Scale:              0.043479
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -1.1048     0.0952   -11.6096   0.0000   -1.2937   -0.9158
# x1        10.6821     0.7634    13.9923   0.0000    9.1663   12.1979
# x2        -3.0388     1.7592    -1.7274   0.0874   -6.5317    0.4542
# x3        -4.3751     1.5988    -2.7365   0.0074   -7.5495   -1.2006
# x4         1.8436     0.6219     2.9644   0.0038    0.6088    3.0784
# x5         0.0122     0.0867     0.1406   0.8885   -0.1600    0.1844
# ------------------------------------------------------------------
# Omnibus:               2.874        Durbin-Watson:           1.956
# Prob(Omnibus):         0.238        Jarque-Bera (JB):        2.802
# Skew:                  0.354        Prob(JB):                0.246
# Kurtosis:              2.587        Condition No.:           8179
# ==================================================================
# * The condition number is large (8e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -24.5098
# Date:               2017-11-26 10:36 BIC:                -8.8788
# No. Observations:   100              Log-Likelihood:     18.255
# Df Model:           5                F-statistic:        1.699e+04
# Df Residuals:       94               Prob (F-statistic): 2.81e-137
# R-squared:          0.999            Scale:              0.043235
# --------------------------------------------------------------------
#           Coef.    Std.Err.      t       P>|t|     [0.025     0.975]
# --------------------------------------------------------------------
# const    -1.0656     0.0813   -13.1127   0.0000    -1.2269   -0.9042
# x1        9.8650     0.3153    31.2879   0.0000     9.2390   10.4911
# x2       -8.7019     0.8935    -9.7387   0.0000   -10.4760   -6.9277
# x3        4.6970     0.9855     4.7658   0.0000     2.7401    6.6538
# x4       -0.8670     0.3950    -2.1947   0.0307    -1.6513   -0.0826
# x5        0.1024     0.0545     1.8790   0.0633    -0.0058    0.2106
# ------------------------------------------------------------------
# Omnibus:               3.363        Durbin-Watson:           1.929
# Prob(Omnibus):         0.186        Jarque-Bera (JB):        3.184
# Skew:                  0.372        Prob(JB):                0.204
# Kurtosis:              2.540        Condition No.:           11942
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()
Res3F = smf.ols('y ~ x+I(x**2)+I(x**3)', df).fit()
Res4F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.479
# Method:                 Least Squares   F-statistic:                     91.84
# Date:                Sun, 07 May 2017   Prob (F-statistic):           9.71e-16
# Time:                        09:51:44   Log-Likelihood:                -309.90
# No. Observations:                 100   AIC:                             623.8
# Df Residuals:                      98   BIC:                             629.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.8155      1.050     -2.681      0.009        -4.900    -0.731
# x              6.2182      0.649      9.584      0.000         4.931     7.506
# ==============================================================================
# Omnibus:                       47.793   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.419
# Skew:                           1.721   Prob(JB):                     2.38e-30
# Kurtosis:                       7.571   Cond. No.                         4.09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     150.8
# Date:                Sun, 07 May 2017   Prob (F-statistic):           1.71e-30
# Time:                        09:51:44   Log-Likelihood:                -272.30
# No. Observations:                 100   AIC:                             550.6
# Df Residuals:                      97   BIC:                             558.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      5.5216      1.079      5.117      0.000         3.380     7.663
# x            -10.8301      1.695     -6.390      0.000       -14.194    -7.466
# I(x ** 2)      5.8393      0.560     10.429      0.000         4.728     6.951
# ==============================================================================
# Omnibus:                        6.668   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                6.090
# Skew:                           0.545   Prob(JB):                       0.0476
# Kurtosis:                       3.521   Cond. No.                         21.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                     2657.
# Date:                Sun, 07 May 2017   Prob (F-statistic):           3.34e-92
# Time:                        09:51:44   Log-Likelihood:                -121.41
# No. Observations:                 100   AIC:                             250.8
# Df Residuals:                      96   BIC:                             261.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -3.2823      0.315    -10.429      0.000        -3.907    -2.658
# x             25.3490      0.918     27.606      0.000        23.526    27.172
# I(x ** 2)    -25.0653      0.726    -34.524      0.000       -26.506   -23.624
# I(x ** 3)      6.9869      0.162     43.206      0.000         6.666     7.308
# ==============================================================================
# Omnibus:                        4.473   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.107   Jarque-Bera (JB):                4.409
# Skew:                           0.471   Prob(JB):                        0.110
# Kurtosis:                       2.589   Cond. No.                         143.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.841e+04
# Date:                Sun, 07 May 2017   Prob (F-statistic):          1.79e-151
# Time:                        09:51:44   Log-Likelihood:                 26.500
# No. Observations:                 100   AIC:                            -43.00
# Df Residuals:                      95   BIC:                            -29.97
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -1.0770      0.089    -12.041      0.000        -1.255    -0.899
# x             10.3835      0.416     24.941      0.000         9.557    11.210
# I(x ** 2)     -2.4904      0.567     -4.393      0.000        -3.616    -1.365
# I(x ** 3)     -4.7658      0.285    -16.747      0.000        -5.331    -4.201
# I(x ** 4)      1.9634      0.047     41.653      0.000         1.870     2.057
# ==============================================================================
# Omnibus:                        0.263   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.877   Jarque-Bera (JB):                0.049
# Skew:                           0.039   Prob(JB):                        0.976
# Kurtosis:                       3.076   Cond. No.                     1.03e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.124e+04
# Date:                Sun, 07 May 2017   Prob (F-statistic):          1.05e-149
# Time:                        09:51:44   Log-Likelihood:                 27.855
# No. Observations:                 100   AIC:                            -43.71
# Df Residuals:                      94   BIC:                            -28.08
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.9825      0.106     -9.231      0.000        -1.194    -0.771
# x              9.4085      0.734     12.821      0.000         7.951    10.866
# I(x ** 2)     -0.1850      1.541     -0.120      0.905        -3.244     2.874
# I(x ** 3)     -6.8335      1.317     -5.188      0.000        -9.449    -4.218
# I(x ** 4)      2.7427      0.487      5.630      0.000         1.775     3.710
# I(x ** 5)     -0.1041      0.065     -1.607      0.111        -0.233     0.025
# ==============================================================================
# Omnibus:                        0.495   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.781   Jarque-Bera (JB):                0.362
# Skew:                           0.147   Prob(JB):                        0.834
# Kurtosis:                       2.989   Cond. No.                     8.12e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
Res2F.params
# Out:
# Intercept     5.521609
# x           -10.830084
# I(x ** 2)     5.839260
# dtype: float64

# %%
Res2F.bse
# Out:
# Intercept    1.079076
# x            1.694912
# I(x ** 2)    0.559905
# dtype: float64

# %%
Res2F.conf_int()
# Out:
#                    0         1
# Intercept   3.379941  7.663276
# x         -14.194015 -7.466152
# I(x ** 2)   4.728004  6.950515
