# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y)
# Out:
# C:\Users\przem\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y)
# Out:
# C:\Users\przem\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y)
# Out:
# C:\Users\przem\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y)
# Out:
# C:\Users\przem\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y)
# Out:
# C:\Users\przem\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
M6 = np.vstack( (np.ones_like(x), x, x**3, x**4, x**5, x**6) ).T
p6 = np.linalg.lstsq(M6, y)
# Out:
# C:\Users\przem\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
M55 = np.vstack( (np.ones_like(x), x, x**3, x**4) ).T
p55 = np.linalg.lstsq(M55, y)
# Out:
# C:\Users\przem\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr_1 = f_lr_1(x_tr)
y_f_lr_2 = f_lr_2(x_tr)
y_f_lr_3 = f_lr_3(x_tr)
y_f_lr_4 = f_lr_4(x_tr)
y_f_lr_5 = f_lr_5(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr_1, 'r', label= "1")
plt.plot(x_f_lr, y_f_lr_2, 'g', label= "2")
plt.plot(x_f_lr, y_f_lr_3, 'b', label= "3")
plt.plot(x_f_lr, y_f_lr_4, 'c', label= "4")
plt.plot(x_f_lr, y_f_lr_5, 'gray', label= "5")
plt.plot(x, y, 'ok', ms=10, alpha=0.2)
plt.legend()
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res55 = sm.OLS(y, M55).fit()

print(Res55.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -16.6077
# Date:               2019-01-20 12:32 BIC:                -6.1870
# No. Observations:   100              Log-Likelihood:     12.304
# Df Model:           3                F-statistic:        4.082e+04
# Df Residuals:       96               Prob (F-statistic): 6.41e-149
# R-squared:          0.999            Scale:              0.047685
# --------------------------------------------------------------------
#           Coef.    Std.Err.       t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const    -0.8209     0.0660    -12.4418   0.0000   -0.9519   -0.6900
# x1        8.6506     0.1178     73.4197   0.0000    8.4167    8.8845
# x2       -6.0244     0.0579   -104.0503   0.0000   -6.1394   -5.9095
# x3        2.1700     0.0167    129.9835   0.0000    2.1369    2.2031
# ------------------------------------------------------------------
# Omnibus:               1.676        Durbin-Watson:           1.652
# Prob(Omnibus):         0.433        Jarque-Bera (JB):        1.306
# Skew:                  0.046        Prob(JB):                0.520
# Kurtosis:              2.448        Condition No.:           167
# ==================================================================
#
# .....................................
# .....................................
# .....................................

# %%
M_5_3 = np.vstack( (np.ones_like(x), x, x**3, x**4, x**5) ).T

M_5_3_1 = np.vstack( (np.ones_like(x), x, x**3, x**4) ).T

import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()
Res6 = sm.OLS(y, M_5_3).fit()
Res7 = sm.OLS(y, M_5_3_1).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res6.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res7.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.462
# Dependent Variable: y                AIC:                570.2052
# Date:               2019-11-17 12:28 BIC:                575.4155
# No. Observations:   100              Log-Likelihood:     -283.10
# Df Model:           1                F-statistic:        85.86
# Df Residuals:       98               Prob (F-statistic): 4.75e-15
# R-squared:          0.467            Scale:              17.191
# -------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025   0.975]
# -------------------------------------------------------------------
# const      -1.2393     0.7598   -1.6312   0.1061   -2.7471   0.2684
# x1          4.6452     0.5013    9.2658   0.0000    3.6503   5.6400
# -----------------------------------------------------------------
# Omnibus:             57.247       Durbin-Watson:          1.986
# Prob(Omnibus):       0.000        Jarque-Bera (JB):       224.102
# Skew:                1.941        Prob(JB):               0.000
# Kurtosis:            9.222        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.687
# Dependent Variable: y                AIC:                516.9035
# Date:               2019-11-17 12:28 BIC:                524.7190
# No. Observations:   100              Log-Likelihood:     -255.45
# Df Model:           2                F-statistic:        109.7
# Df Residuals:       97               Prob (F-statistic): 1.26e-25
# R-squared:          0.693            Scale:              9.9903
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const      3.6698     0.8197    4.4770   0.0000    2.0429    5.2966
# x1        -6.9313     1.4202   -4.8806   0.0000   -9.7500   -4.1126
# x2         4.2636     0.5037    8.4637   0.0000    3.2638    5.2634
# -----------------------------------------------------------------
# Omnibus:              11.803       Durbin-Watson:          1.868
# Prob(Omnibus):        0.003        Jarque-Bera (JB):       13.277
# Skew:                 0.681        Prob(JB):               0.001
# Kurtosis:             4.154        Condition No.:          19
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.982
# Dependent Variable: y                AIC:                234.4066
# Date:               2019-11-17 12:28 BIC:                244.8273
# No. Observations:   100              Log-Likelihood:     -113.20
# Df Model:           3                F-statistic:        1763.
# Df Residuals:       96               Prob (F-statistic): 8.74e-84
# R-squared:          0.982            Scale:              0.58685
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const      -2.7873    0.2574  -10.8270  0.0000   -3.2983   -2.2763
# x1         23.2783    0.8398   27.7190  0.0000   21.6113   24.9453
# x2        -23.1719    0.7063  -32.8072  0.0000  -24.5739  -21.7699
# x3          6.5156    0.1652   39.4373  0.0000    6.1876    6.8435
# -----------------------------------------------------------------
# Omnibus:              3.687        Durbin-Watson:           2.236
# Prob(Omnibus):        0.158        Jarque-Bera (JB):        3.550
# Skew:                 0.405        Prob(JB):                0.169
# Kurtosis:             2.559        Condition No.:           126
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -33.5773
# Date:               2019-11-17 12:28 BIC:                -20.5514
# No. Observations:   100              Log-Likelihood:     21.789
# Df Model:           4                F-statistic:        1.980e+04
# Df Residuals:       95               Prob (F-statistic): 8.20e-138
# R-squared:          0.999            Scale:              0.039861
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.9640     0.0838   -11.5030   0.0000   -1.1304   -0.7976
# x1         9.6863     0.4336    22.3375   0.0000    8.8254   10.5471
# x2        -1.4547     0.6258    -2.3246   0.0222   -2.6971   -0.2124
# x3        -5.3342     0.3292   -16.2042   0.0000   -5.9877   -4.6807
# x4         2.0659     0.0569    36.3090   0.0000    1.9530    2.1789
# ------------------------------------------------------------------
# Omnibus:               1.111        Durbin-Watson:           2.233
# Prob(Omnibus):         0.574        Jarque-Bera (JB):        1.029
# Skew:                  0.058        Prob(JB):                0.598
# Kurtosis:              2.517        Condition No.:           892
# ==================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -33.2737
# Date:               2019-11-17 12:28 BIC:                -17.6427
# No. Observations:   100              Log-Likelihood:     22.637
# Df Model:           5                F-statistic:        1.594e+04
# Df Residuals:       94               Prob (F-statistic): 5.55e-136
# R-squared:          0.999            Scale:              0.039607
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025     0.975]
# --------------------------------------------------------------------
# const     -0.8951     0.0997   -8.9821   0.0000    -1.0930   -0.6972
# x1         8.9135     0.7471   11.9312   0.0000     7.4302   10.3969
# x2         0.5177     1.6758    0.3089   0.7581    -2.8096    3.8449
# x3        -7.2183     1.5215   -4.7443   0.0000   -10.2392   -4.1974
# x4         2.8163     0.5944    4.7381   0.0000     1.6361    3.9965
# x5        -0.1054     0.0831   -1.2682   0.2079    -0.2704    0.0596
# ------------------------------------------------------------------
# Omnibus:               1.184        Durbin-Watson:           2.255
# Prob(Omnibus):         0.553        Jarque-Bera (JB):        1.053
# Skew:                  0.032        Prob(JB):                0.591
# Kurtosis:              2.501        Condition No.:           6855
# ==================================================================
# * The condition number is large (7e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -35.1723
# Date:               2019-11-17 12:28 BIC:                -22.1464
# No. Observations:   100              Log-Likelihood:     22.586
# Df Model:           4                F-statistic:        2.012e+04
# Df Residuals:       95               Prob (F-statistic): 3.84e-138
# R-squared:          0.999            Scale:              0.039230
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.9178     0.0670   -13.7080   0.0000   -1.0507   -0.7849
# x1         9.1364     0.1933    47.2703   0.0000    8.7527    9.5201
# x2        -6.7552     0.2578   -26.2062   0.0000   -7.2669   -6.2434
# x3         2.6404     0.1699    15.5367   0.0000    2.3030    2.9778
# x4        -0.0816     0.0308    -2.6491   0.0095   -0.1427   -0.0204
# ------------------------------------------------------------------
# Omnibus:               1.136        Durbin-Watson:           2.254
# Prob(Omnibus):         0.567        Jarque-Bera (JB):        1.031
# Skew:                  0.039        Prob(JB):                0.597
# Kurtosis:              2.509        Condition No.:           1021
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -30.0450
# Date:               2019-11-17 12:28 BIC:                -19.6244
# No. Observations:   100              Log-Likelihood:     19.023
# Df Model:           3                F-statistic:        2.524e+04
# Df Residuals:       96               Prob (F-statistic): 6.57e-139
# R-squared:          0.999            Scale:              0.041690
# --------------------------------------------------------------------
#           Coef.    Std.Err.       t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const    -0.8194     0.0574    -14.2709   0.0000   -0.9333   -0.7054
# x1        8.7099     0.1103     78.9946   0.0000    8.4910    8.9288
# x2       -6.0883     0.0572   -106.3830   0.0000   -6.2019   -5.9747
# x3        2.1924     0.0171    128.0867   0.0000    2.1584    2.2263
# ------------------------------------------------------------------
# Omnibus:               1.522        Durbin-Watson:           2.160
# Prob(Omnibus):         0.467        Jarque-Bera (JB):        1.223
# Skew:                  0.029        Prob(JB):                0.542
# Kurtosis:              2.461        Condition No.:           138
# ==================================================================

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()
Res3F = smf.ols('y ~ x+I(x**2)+I(x**3)', df).fit()
Res4F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res3F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res4F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res5F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     82.62
# Date:                Sun, 20 May 2018   Prob (F-statistic):           1.14e-14
# Time:                        12:31:51   Log-Likelihood:                -304.37
# No. Observations:                 100   AIC:                             612.7
# Df Residuals:                      98   BIC:                             618.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.3572      1.000     -2.358      0.020      -4.341      -0.373
# x              5.5355      0.609      9.090      0.000       4.327       6.744
# ==============================================================================
# Omnibus:                       46.481   Durbin-Watson:                   2.246
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.604
# Skew:                           1.737   Prob(JB):                     1.76e-26
# Kurtosis:                       7.049   Cond. No.                         4.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     141.6
# Date:                Sun, 20 May 2018   Prob (F-statistic):           1.69e-29
# Time:                        12:31:51   Log-Likelihood:                -266.64
# No. Observations:                 100   AIC:                             539.3
# Df Residuals:                      97   BIC:                             547.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.9360      0.981      5.034      0.000       2.990       6.882
# x            -10.3782      1.579     -6.572      0.000     -13.512      -7.244
# I(x ** 2)      5.6148      0.537     10.454      0.000       4.549       6.681
# ==============================================================================
# Omnibus:                        6.756   Durbin-Watson:                   2.131
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                6.914
# Skew:                           0.642   Prob(JB):                       0.0315
# Kurtosis:                       2.898   Cond. No.                         21.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                     2509.
# Date:                Sun, 20 May 2018   Prob (F-statistic):           5.06e-91
# Time:                        12:31:51   Log-Likelihood:                -116.22
# No. Observations:                 100   AIC:                             240.4
# Df Residuals:                      96   BIC:                             250.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.0130      0.287    -10.513      0.000      -3.582      -2.444
# x             24.4101      0.883     27.656      0.000      22.658      26.162
# I(x ** 2)    -24.2758      0.705    -34.411      0.000     -25.676     -22.875
# I(x ** 3)      6.7979      0.158     42.996      0.000       6.484       7.112
# ==============================================================================
# Omnibus:                        6.172   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                3.244
# Skew:                           0.203   Prob(JB):                        0.198
# Kurtosis:                       2.217   Cond. No.                         144.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.805e+04
# Date:                Sun, 20 May 2018   Prob (F-statistic):          5.43e-145
# Time:                        12:31:51   Log-Likelihood:                 18.809
# No. Observations:                 100   AIC:                            -27.62
# Df Residuals:                      95   BIC:                            -14.59
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9474      0.094    -10.094      0.000      -1.134      -0.761
# x              9.6255      0.467     20.590      0.000       8.697      10.554
# I(x ** 2)     -1.4759      0.654     -2.257      0.026      -2.774      -0.177
# I(x ** 3)     -5.2646      0.335    -15.733      0.000      -5.929      -4.600
# I(x ** 4)      2.0443      0.056     36.324      0.000       1.933       2.156
# ==============================================================================
# Omnibus:                        3.711   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.156   Jarque-Bera (JB):                2.082
# Skew:                           0.039   Prob(JB):                        0.353
# Kurtosis:                       2.298   Cond. No.                     1.06e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.229e+04
# Date:                Sun, 20 May 2018   Prob (F-statistic):          8.05e-143
# Time:                        12:31:51   Log-Likelihood:                 19.007
# No. Observations:                 100   AIC:                            -26.01
# Df Residuals:                      94   BIC:                            -10.38
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9934      0.121     -8.244      0.000      -1.233      -0.754
# x             10.0862      0.888     11.360      0.000       8.323      11.849
# I(x ** 2)     -2.5477      1.873     -1.361      0.177      -6.266       1.170
# I(x ** 3)     -4.3127      1.593     -2.707      0.008      -7.476      -1.149
# I(x ** 4)      1.6866      0.588      2.868      0.005       0.519       2.854
# I(x ** 5)      0.0479      0.078      0.611      0.543      -0.108       0.203
# ==============================================================================
# Omnibus:                        3.913   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.174
# Skew:                           0.064   Prob(JB):                        0.337
# Kurtosis:                       2.289   Cond. No.                     8.60e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
Res2F.params
# Out:
# Intercept     5.521609
# x           -10.830084
# I(x ** 2)     5.839260
# dtype: float64

# %%
Res2F.bse
# Out:
# Intercept    1.079076
# x            1.694912
# I(x ** 2)    0.559905
# dtype: float64

# %%
Res2F.conf_int()
# Out:
#                    0         1
# Intercept   3.379941  7.663276
# x         -14.194015 -7.466152
# I(x ** 2)   4.728004  6.950515
