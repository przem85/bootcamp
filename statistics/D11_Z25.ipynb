# %%
import pandas as pd
import numpy as np

from sklearn import model_selection
from sklearn import  metrics
from statsmodels.formula.api import ols

# %% [markdown]
# # Zadanie
# Proszę pobrać dane z
#
# http://archive.ics.uci.edu/ml/datasets/Auto+MPG
#
# http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data

# %%
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "car name"]

# %%
data = pd.read_csv(url, names=names, delimiter="\s+", na_values=["?"])
print(data.shape)
# Out:
# (398, 9)

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %% [markdown]
# # Zadanie
# Proszę usunąć kolumny, które nie są numeyczne.

# %%
drop_list = ['car name']

# %%
data=data.drop(drop_list, axis=1)
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %% [markdown]
# # Zadanie
# Prosze usunąć brakujące dane.

# %%
null_counts = data.isnull().sum()
print("Number of null values in each column:\n{}".format(null_counts))
# Out:
# Number of null values in each column:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
data=data.dropna()
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
data.columns  = [i.replace(" ","_") for i in data.columns.values  ]

data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
model = ols("acceleration ~ displacement + model_year:origin", data).fit()
# Print the summary
print((model.summary2()))
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.313
# Dependent Variable: acceleration     AIC:                1763.9861
# Date:               2019-02-02 00:52 BIC:                1775.8999
# No. Observations:   392              Log-Likelihood:     -878.99
# Df Model:           2                F-statistic:        90.00
# Df Residuals:       389              Prob (F-statistic): 7.51e-33
# R-squared:          0.316            Scale:              5.2303
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         19.8790   0.5141  38.6654 0.0000 18.8682 20.8898
# displacement      -0.0174   0.0014 -12.2810 0.0000 -0.0201 -0.0146
# model_year:origin -0.0080   0.0023  -3.4258 0.0007 -0.0126 -0.0034
# ------------------------------------------------------------------
# Omnibus:               30.280       Durbin-Watson:          1.480
# Prob(Omnibus):         0.000        Jarque-Bera (JB):       36.716
# Skew:                  0.643        Prob(JB):               0.000
# Kurtosis:              3.772        Condition No.:          1073
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
