# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# W poniższym przykładzie posłużymy się zestawem danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.

# %%
df_adv = pd.read_csv('Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
## fit a OLS model with intercept on TV and Radio
#X = sm.add_constant(X)
#est = sm.OLS(y, X).fit()
#est.summary()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
import seaborn as sns
sns.pairplot(df_adv)
plt.show()

# %%
sns.set(style="darkgrid")

corr = df_adv.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
plt.show()
corr
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# # Zadanie 1
# Wykonaj model pozwalający przewidzieć zmienną "Sales" na podstawie innych zmiennych.
#
# Wykonaj kilka modeli i je porównaj.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~ radio + I(TV) + I(radio):I(TV) ', data=df_adv).fit()
print((est.summary2()))
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.967
# Dependent Variable: sales            AIC:                548.2778
# Date:               2020-08-09 14:59 BIC:                561.4711
# No. Observations:   200              Log-Likelihood:     -270.14
# Df Model:           3                F-statistic:        1963.
# Df Residuals:       196              Prob (F-statistic): 6.68e-146
# R-squared:          0.968            Scale:              0.89022
# -------------------------------------------------------------------
#                   Coef.   Std.Err.     t     P>|t|   [0.025  0.975]
# -------------------------------------------------------------------
# Intercept         6.7502    0.2479  27.2328  0.0000  6.2614  7.2391
# radio             0.0289    0.0089   3.2408  0.0014  0.0113  0.0464
# I(TV)             0.0191    0.0015  12.6990  0.0000  0.0161  0.0221
# I(radio):I(TV)    0.0011    0.0001  20.7266  0.0000  0.0010  0.0012
# ------------------------------------------------------------------
# Omnibus:              128.132      Durbin-Watson:         2.224
# Prob(Omnibus):        0.000        Jarque-Bera (JB):      1183.719
# Skew:                 -2.323       Prob(JB):              0.000
# Kurtosis:             13.975       Condition No.:         17997
# ==================================================================
# * The condition number is large (2e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~   I(newspaper)*I(TV)   ', data=df_adv).fit()
print((est.summary2()))
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.643
# Dependent Variable: sales            AIC:                1026.2452
# Date:               2020-08-09 15:11 BIC:                1039.4385
# No. Observations:   200              Log-Likelihood:     -509.12
# Df Model:           3                F-statistic:        120.6
# Df Residuals:       196              Prob (F-statistic): 2.84e-44
# R-squared:          0.649            Scale:              9.7138
# ------------------------------------------------------------------
#                       Coef.  Std.Err.   t    P>|t|   [0.025 0.975]
# ------------------------------------------------------------------
# Intercept             6.4042   0.7334 8.7324 0.0000  4.9579 7.8505
# I(newspaper)          0.0241   0.0193 1.2511 0.2124 -0.0139 0.0621
# I(TV)                 0.0427   0.0043 9.8965 0.0000  0.0342 0.0512
# I(newspaper):I(TV)    0.0001   0.0001 1.2280 0.2209 -0.0001 0.0003
# ------------------------------------------------------------------
# Omnibus:              1.120         Durbin-Watson:           1.940
# Prob(Omnibus):        0.571         Jarque-Bera (JB):        0.778
# Skew:                 -0.084        Prob(JB):                0.678
# Kurtosis:             3.256         Condition No.:           22271
# ==================================================================
# * The condition number is large (2e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~   I(newspaper)*I(TV)*I(radio)', data=df_adv).fit()
print((est.summary2()))
# Out:
#                      Results: Ordinary least squares
# ==========================================================================
# Model:                  OLS                Adj. R-squared:       0.968
# Dependent Variable:     sales              AIC:                  550.9065
# Date:                   2020-08-09 15:16   BIC:                  577.2930
# No. Observations:       200                Log-Likelihood:       -267.45
# Df Model:               7                  F-statistic:          847.3
# Df Residuals:           192                Prob (F-statistic):   1.16e-140
# R-squared:              0.969              Scale:                0.88469
# --------------------------------------------------------------------------
#                              Coef.  Std.Err.    t    P>|t|   [0.025 0.975]
# --------------------------------------------------------------------------
# Intercept                    6.5559   0.4655 14.0825 0.0000  5.6377 7.4741
# I(newspaper)                 0.0131   0.0172  0.7615 0.4473 -0.0208 0.0471
# I(TV)                        0.0197   0.0027  7.2498 0.0000  0.0143 0.0251
# I(newspaper):I(TV)          -0.0001   0.0001 -0.5946 0.5528 -0.0002 0.0001
# I(radio)                     0.0196   0.0164  1.1971 0.2328 -0.0127 0.0520
# I(newspaper):I(radio)        0.0000   0.0005  0.0188 0.9851 -0.0009 0.0010
# I(TV):I(radio)               0.0012   0.0001 11.9089 0.0000  0.0010 0.0014
# I(newspaper):I(TV):I(radio) -0.0000   0.0000 -0.2818 0.7784 -0.0000 0.0000
# --------------------------------------------------------------------------
# Omnibus:                 110.676         Durbin-Watson:            2.224
# Prob(Omnibus):           0.000           Jarque-Bera (JB):         751.534
# Skew:                    -2.035          Prob(JB):                 0.000
# Kurtosis:                11.580          Condition No.:            1557292
# ==========================================================================
# * The condition number is large (2e+06). This might indicate
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~   I(newspaper)*I(TV)*I(radio)*I(newspaper**2 )', data=df_adv).fit()
print((est.summary2()))
# Out:
#                                Results: Ordinary least squares
# =============================================================================================
# Model:                       OLS                       Adj. R-squared:              0.968
# Dependent Variable:          sales                     AIC:                         552.3879
# Date:                        2020-08-09 15:15          BIC:                         605.1610
# No. Observations:            200                       Log-Likelihood:              -260.19
# Df Model:                    15                        F-statistic:                 408.4
# Df Residuals:                184                       Prob (F-statistic):          1.92e-132
# R-squared:                   0.971                     Scale:                       0.85851
# ---------------------------------------------------------------------------------------------
#                                                Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                      5.8133   0.7667  7.5818 0.0000  4.3006  7.3260
# I(newspaper)                                   0.2115   0.0978  2.1632 0.0318  0.0186  0.4045
# I(TV)                                          0.0217   0.0048  4.5274 0.0000  0.0123  0.0312
# I(newspaper):I(TV)                            -0.0008   0.0006 -1.4433 0.1506 -0.0020  0.0003
# I(radio)                                       0.0197   0.0305  0.6439 0.5205 -0.0406  0.0799
# I(newspaper):I(radio)                         -0.0037   0.0035 -1.0435 0.2981 -0.0106  0.0033
# I(TV):I(radio)                                 0.0012   0.0002  6.5457 0.0000  0.0008  0.0016
# I(newspaper):I(TV):I(radio)                    0.0000   0.0000  0.6122 0.5412 -0.0000  0.0001
# I(newspaper ** 2)                             -0.0088   0.0034 -2.5486 0.0116 -0.0156 -0.0020
# I(newspaper):I(newspaper ** 2)                 0.0001   0.0000  2.7533 0.0065  0.0000  0.0002
# I(TV):I(newspaper ** 2)                        0.0000   0.0000  1.9556 0.0520 -0.0000  0.0001
# I(newspaper):I(TV):I(newspaper ** 2)          -0.0000   0.0000 -2.3142 0.0218 -0.0000 -0.0000
# I(radio):I(newspaper ** 2)                     0.0002   0.0001  1.8757 0.0623 -0.0000  0.0004
# I(newspaper):I(radio):I(newspaper ** 2)       -0.0000   0.0000 -2.3163 0.0216 -0.0000 -0.0000
# I(TV):I(radio):I(newspaper ** 2)              -0.0000   0.0000 -1.4044 0.1619 -0.0000  0.0000
# I(newspaper):I(TV):I(radio):I(newspaper ** 2)  0.0000   0.0000  1.8938 0.0598 -0.0000  0.0000
# ---------------------------------------------------------------------------------------------
# Omnibus:                      104.545              Durbin-Watson:                 2.234
# Prob(Omnibus):                0.000                Jarque-Bera (JB):              665.856
# Skew:                         -1.918               Prob(JB):                      0.000
# Kurtosis:                     11.074               Condition No.:                 13259091437
# =============================================================================================
# * The condition number is large (1e+10). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~   I(newspaper) + I(TV):I(radio) + I(np.power(TV,2)):I(radio)  ', data=df_adv).fit()
print((est.summary2()))
# Out:
#                      Results: Ordinary least squares
# ==========================================================================
# Model:                  OLS                Adj. R-squared:       0.929
# Dependent Variable:     sales              AIC:                  701.9754
# Date:                   2020-08-09 15:02   BIC:                  715.1687
# No. Observations:       200                Log-Likelihood:       -346.99
# Df Model:               3                  F-statistic:          875.3
# Df Residuals:           196                Prob (F-statistic):   3.34e-113
# R-squared:              0.931              Scale:                1.9198
# --------------------------------------------------------------------------
#                              Coef.  Std.Err.    t    P>|t|   [0.025 0.975]
# --------------------------------------------------------------------------
# Intercept                    8.7715   0.1943 45.1406 0.0000  8.3883 9.1548
# I(newspaper)                -0.0043   0.0047 -0.9226 0.3573 -0.0135 0.0049
# I(TV):I(radio)               0.0017   0.0001 14.9106 0.0000  0.0015 0.0019
# I(np.power(TV, 2)):I(radio) -0.0000   0.0000 -1.8061 0.0724 -0.0000 0.0000
# --------------------------------------------------------------------------
# Omnibus:                72.214          Durbin-Watson:             2.467
# Prob(Omnibus):          0.000           Jarque-Bera (JB):          246.794
# Skew:                   -1.452          Prob(JB):                  0.000
# Kurtosis:               7.603           Condition No.:             2218225
# ==========================================================================
# * The condition number is large (2e+06). This might indicate
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~   I(newspaper) + I(TV):I(radio) + I(np.power(TV,2)):I(radio) + I(np.power(TV,5)):I(np.power(radio,2))  ', data=df_adv).fit()
print((est.summary2()))
# Out:
#                             Results: Ordinary least squares
# ========================================================================================
# Model:                      OLS                     Adj. R-squared:            0.252
# Dependent Variable:         sales                   AIC:                       1174.2251
# Date:                       2020-08-09 15:03        BIC:                       1187.4184
# No. Observations:           200                     Log-Likelihood:            -583.11
# Df Model:                   3                       F-statistic:               23.37
# Df Residuals:               196                     Prob (F-statistic):        5.66e-13
# R-squared:                  0.263                   Scale:                     20.358
# ----------------------------------------------------------------------------------------
#                                           Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# ----------------------------------------------------------------------------------------
# Intercept                                 0.0018   0.0002  9.7426 0.0000  0.0014  0.0021
# I(newspaper)                              0.1235   0.0127  9.7383 0.0000  0.0985  0.1486
# I(TV):I(radio)                            0.0026   0.0005  5.6676 0.0000  0.0017  0.0036
# I(np.power(TV, 2)):I(radio)               0.0000   0.0000  0.2933 0.7696 -0.0000  0.0000
# I(np.power(TV, 5)):I(np.power(radio, 2)) -0.0000   0.0000 -3.8079 0.0002 -0.0000 -0.0000
# ----------------------------------------------------------------------------------------
# Omnibus:                   10.869           Durbin-Watson:              1.418
# Prob(Omnibus):             0.004            Jarque-Bera (JB):           10.831
# Skew:                      -0.526           Prob(JB):                   0.004
# Kurtosis:                  2.562            Condition No.:              1515288396194515
# ========================================================================================
# * The condition number is large (2e+15). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
import statsmodels 
statsmodels.__version__
# Out:
# '0.8.0'

# %%
import pandas 
pandas.__version__
# Out:
# '0.23.3'
