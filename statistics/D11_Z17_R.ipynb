# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Out:
# C:\Users\przem85\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# Zmienna <tt>famhist</tt> przechoruje informację czy pacjent ma historię choroby wieńcowej. Jest to zmienna kategoryczna.

# %%
df = pd.read_csv('https://web.stanford.edu/~hastie/ElemStatLearn/datasets/SAheart.data', index_col=0)
# copy data and separate predictors and response
X = df.copy()
y = X.pop('chd')
df.head()
# Out:
#            sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 1          160    12.00  5.73      23.11  Present     49    25.30    97.20
# 2          144     0.01  4.41      28.61   Absent     55    28.87     2.06
# 3          118     0.08  3.48      32.28  Present     52    29.14     3.81
# 4          170     7.50  6.41      38.03  Present     51    31.99    24.26
# 5          134    13.60  3.50      27.78  Present     60    25.99    57.34
#
#            age  chd
# row.names
# 1           52    1
# 2           63    1
# 3           46    0
# 4           58    1
# 5           49    1

# %%
# compute percentage of chronic heart disease for famhist
y.groupby(X.famhist).mean()
# Out:
# famhist
# Absent     0.237037
# Present    0.500000
# Name: chd, dtype: float64

# %% [markdown]
# # Zadanie
# Naucz model postaci "chd ~ famhist"

# %%
import statsmodels.formula.api as smf

# encode df.famhist as a numeric via pd.Factor
df['famhist_ord'] = pd.Categorical(df.famhist).codes
df.head()
# Out:
#            sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# row.names
# 1          160    12.00  5.73      23.11  Present     49    25.30    97.20
# 2          144     0.01  4.41      28.61   Absent     55    28.87     2.06
# 3          118     0.08  3.48      32.28  Present     52    29.14     3.81
# 4          170     7.50  6.41      38.03  Present     51    31.99    24.26
# 5          134    13.60  3.50      27.78  Present     60    25.99    57.34
#
#            age  chd  famhist_ord
# row.names
# 1           52    1            1
# 2           63    1            0
# 3           46    0            1
# 4           58    1            1
# 5           49    1            1

# %%
est = smf.ols(formula="chd ~ famhist_ord", data=df).fit()
print((est.summary()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    chd   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     36.86
# Date:                Wed, 10 May 2017   Prob (F-statistic):           2.66e-09
# Time:                        12:34:51   Log-Likelihood:                -294.59
# No. Observations:                 462   AIC:                             593.2
# Df Residuals:                     460   BIC:                             601.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       0.2370      0.028      8.489      0.000         0.182     0.292
# famhist_ord     0.2630      0.043      6.071      0.000         0.178     0.348
# ==============================================================================
# Omnibus:                      768.898   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.778
# Skew:                           0.579   Prob(JB):                     1.72e-13
# Kurtosis:                       1.692   Cond. No.                         2.47
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
