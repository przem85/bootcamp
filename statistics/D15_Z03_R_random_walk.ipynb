# %% [markdown]
# # Random Walk

# %%
import numpy as np
import pandas as pd
import scipy
import random
import matplotlib.pylab as plt

# %%
x = [0]
for j in range(1000):
    x.append(x[j] + np.random.normal())

# %%
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 0.6396034608907589

# %% [markdown]
# # rho=0

# %%
rho=0
x = [0]
for j in range(1000):
    x.append(rho
             *x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()

# %%
df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 0.0

# %% [markdown]
# # rho=0.5

# %%
rho=0.5
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()

# %%
df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 3.244940188501776e-30

# %% [markdown]
# # rho=0.9

# %%
rho=0.9
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()

# %%
df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 3.1510761816620077e-10

# %% [markdown]
# # rho=1

# %%
rho=1
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 0.9313172452919398

# %%
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()

# %% [markdown]
# # rho=1.1

# %%
rho=1.1
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()
