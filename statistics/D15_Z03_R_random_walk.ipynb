# %% [markdown]
# # Random Walk

# %%
import numpy as np
import pandas as pd
import scipy
import random
import matplotlib.pylab as plt

# %%
x = [0]
for j in range(1000):
    x.append(x[j] + np.random.normal())

# %%
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 0.7120979095812884

# %% [markdown]
# # rho=0

# %%
rho=0
x = [0]
for j in range(1000):
    x.append(rho
             *x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()

# %%
df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 0.0

# %% [markdown]
# # rho=0.5

# %%
rho=0.5
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
from pandas.tools.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 2.8949609509777643e-30

# %% [markdown]
# # rho=0.9

# %%
rho=0.9
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
from pandas.tools.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 1.3253669965720007e-08

# %% [markdown]
# # rho=1

# %%
rho=1
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %%
df=pd.Series(x)
_,p,_,_,_,_ = adfuller(df, autolag='AIC')
print(p)
# Out:
# 0.8667371511098917

# %%
from pandas.tools.plotting import autocorrelation_plot
plt.figure(figsize=(10,7));
autocorrelation_plot(x)
plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # rho=1.1

# %%
rho=1.1
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()
