# %%
from urllib import request
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# # Zad
# Zczytaj z wikipedi artykuły o tytułach
# ```python
# ["Integral", "Riemann_integral", "Riemann-Stieltjes_integral", "Derivative",
#     "Limit_of_a_sequence", "Edvard_Munch", "Vincent_van_Gogh", "Jan_Matejko",
#     "Lev_Tolstoj", "Franz_Kafka", "J._R._R._Tolkien"]
# ```
# i zapisz w tablicy zawartości tych podstron ($id="bodyContent"$)

# %%
wiki = "http://en.wikipedia.org/wiki/"
titles = ["Integral", "Riemann_integral", "Riemann-Stieltjes_integral", "Derivative",
    "Limit_of_a_sequence", "Edvard_Munch", "Vincent_van_Gogh", "Jan_Matejko",
    "Lev_Tolstoj", "Franz_Kafka", "J._R._R._Tolkien"]

# %%
def parse(url):        
    x = urlopen(url).read()
    x = BeautifulSoup(x).find("div",id="bodyContent").find_all("p")
    return(x)

articles = [parse(url) for url in [wiki+x for x in titles]]
articles = [" ".join([str(paragraph) for paragraph in article]) for article in articles]

articles[0][:200]
# Out:
# '<p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, an <b>integral</b> assigns numbers to functions in a way that can describe displacement, area, volume, and other concepts that ar'

# %%
import re
articles = [re.sub("<.+?>"," ",a) for a in articles] # ew (str(a))

# %%
articles[0]
# Out:
# ' In  mathematics , an  integral  assigns numbers to functions in a way that can describe displacement, area, volume, and other concepts that arise by combining  infinitesimal  data. Integration is one of the two main operations of  calculus ; its inverse operation,  differentiation , is the other. Given a  function   f  of a  real   variable   x  and an  interval   [ a ,  b ]  of the  real line , the  definite integral  of  f  from   a   to   b   can be interpreted informally as the signed  area  of the region in the  xy -plane that is bounded by the  graph  of  f , the  x -axis and the vertical lines   x  =  a   and   x  =  b  . It is denoted\n   The operation of integration, up to an additive constant, is the inverse of the operation of differentiation. For this reason, the term  integral  may also refer to the related notion of the  antiderivative , called an  indefinite integral , a function  F  whose  derivative  is the given function  f . In this case, it is written:\n   The integrals discussed in this article are those termed  definite integrals . It is the  fundamental theorem of calculus  that connects differentiation with the definite integral: if  f  is a continuous real-valued function defined on a  closed interval   [ a ,  b ] , then once an antiderivative  F  of  f  is known, the definite integral of  f  over that interval is given by\n   The principles of integration were formulated independently by  Isaac Newton  and  Gottfried Wilhelm Leibniz  in the late 17th century, who thought of the integral as an infinite sum of rectangles of  infinitesimal  width.  Bernhard Riemann  later gave a rigorous mathematical definition of integrals, which is based on a limiting procedure that approximates the area of a  curvilinear  region by breaking the region into thin vertical slabs. Beginning in the 19th century, more sophisticated notions of integrals began to appear, where the type of the function as well as the  domain  over which the integration is performed has been generalized. A  line integral  is defined for functions of two or more variables, and the interval of integration  [ a ,  b ]  is replaced by a  curve  connecting the two endpoints. In a  surface integral , the curve is replaced by a piece of a  surface  in  three-dimensional space .\n   The first documented systematic technique capable of determining integrals is the  method of exhaustion  of the  ancient Greek  astronomer  Eudoxus  ( ca.  370 BC), which sought to find areas and volumes by breaking them up into an infinite number of divisions for which the area or volume was known.  [1]   This method was further developed and employed by  Archimedes  in the 3rd century BC and used to calculate the  area of a circle , the  surface area  and  volume  of a  sphere , area of an  ellipse , the area under a  parabola , the volume of a segment of a  paraboloid  of revolution, the volume of a segment of a  hyperboloid  of revolution, and the area of a  spiral .  [2]  \n   A similar method was independently developed in China around the 3rd century AD by  Liu Hui , who used it to find the area of the circle. This method was later used in the 5th century by Chinese father-and-son mathematicians  Zu Chongzhi  and  Zu Geng  to find the volume of a sphere.  [3]  \n   In the Middle East, Hasan Ibn al-Haytham, Latinized as  Alhazen  ( c.  \u2009965 \xa0– c. \u20091040 \xa0AD) derived a formula for the sum of  fourth powers . He used the results to carry out what would now be called an integration of this function, where the formulae for the sums of integral squares and fourth powers allowed him to calculate the volume of a  paraboloid .  [4]  \n   The next significant advances in integral calculus did not begin to appear until the 17th century. At this time, the work of  Cavalieri  with his  method of Indivisibles , and work by  Fermat , began to lay the foundations of modern calculus, with Cavalieri computing the integrals of   x   n    up to degree   n  = 9  in  Cava ...

# %%
articles[1]
# Out:
# ' In the branch of  mathematics  known as  real analysis , the  Riemann integral , created by  Bernhard Riemann , was the first rigorous definition of the  integral  of a  function  on an  interval .  It was presented to the faculty at the  University of Göttingen  in 1854, but not published in a journal until 1868.  [1]   For many functions and practical applications, the Riemann integral can be evaluated by the  fundamental theorem of calculus  or approximated by  numerical integration .\n   The Riemann integral is unsuitable for many theoretical purposes. Some of the technical deficiencies in Riemann integration can be remedied with the  Riemann–Stieltjes integral , and most disappear with the  Lebesgue integral , though the latter does not have a satisfactory treatment of  improper integrals .  The  gauge integral  is a generalisation of the Lebesgue integral that is at once closer to the Riemann integral.   \nThese more general theories allow for the integration of more "jagged" or "highly oscillating" functions whose Riemann integral does not exist; but the theories give the same value as the Riemann integral when it does exist.\n   In educational settings, the  Darboux integral  offers a simpler definition that is easier to work with; it can be used to introduce the Riemann integral. The Darboux integral is defined whenever the Riemann integral is, and always gives the same result. Conversely, the  gauge integral  is a simple but more powerful generalization of the Riemann integral and has led some educators to advocate that it should replace the Riemann integral in introductory calculus courses.  [2]  \n   Let  f  be a non-negative  real -valued function on the interval  [ a ,  b ] , and let\n   be the region of the plane under the graph of the function  f  and above the interval  [ a ,  b ]  (see the figure on the top right). We are interested in measuring the area of  S . Once we have measured it, we will denote the area by:\n   The basic idea of the Riemann integral is to use very simple approximations for the area of  S . By taking better and better approximations, we can say that "in the limit" we get exactly the area of  S  under the curve.\n   Note that where  f  can be both positive and negative, the definition of  S  is modified so that the integral corresponds to the  signed area  under the graph of  f : that is, the area above the  x -axis minus the area below the  x -axis.\n   A  partition of an interval   [ a ,  b ]  is a finite sequence of numbers of the form\n   Each  [ x i  ,  x   i  + 1 ]  is called a  sub-interval  of the partition. The  mesh  or  norm  of a partition is defined to be the length of the longest sub-interval, that is,\n   A  tagged partition    P ( x ,  t )  of an interval  [ a ,  b ]  is a partition together with a finite sequence of numbers   t  0 , ...,  t   n  − 1   subject to the conditions that for each  i ,   t i   ∈ [ x i  ,  x   i  + 1 ] . In other words, it is a partition together with a distinguished point of every sub-interval. The mesh of a tagged partition is the same as that of an ordinary partition.\n   Suppose that two partitions   P ( x ,  t )  and   Q ( y ,  s )  are both partitions of the interval  [ a ,  b ] . We say that   Q ( y ,  s )  is a  refinement  of   P ( x ,  t )  if for each integer  i , with   i  ∈ [0,  n ] , there exists an integer   r ( i )  such that   x i   =  y   r ( i )   and such that   t i   =  s j    for some  j  with   j  ∈ [ r ( i ),  r ( i  + 1)) . Said more simply, a refinement of a tagged partition breaks up some of the sub-intervals and adds tags to the partition where necessary, thus it "refines" the accuracy of the partition.\n   We can define a  partial order  on the set of all tagged partitions by saying that one tagged partition is greater than or equal to another if the former is a refinement of the latter.\n   Let  f  be a real-valued function defined on the interval  [ a ,  b ] . The   Riemann sum   of  f  with respect to the tagge ...

# %%
import numpy as np
with open ('wiki_mycorpus.txt', 'w', encoding="utf-8") as f:
    for el in articles:
        f.write(el)

# %% [markdown]
# # Zad
#
# Oczyszczamy tekst:
#
# * tokenizacja
#
# * usuwanie stopwords
#
# * usuwanie tokenów występujących tylko 1 raz
#
# * zmiana dużych liter na małe

# %%
from pprint import pprint  # pretty-printer
from collections import defaultdict
from nltk.corpus import stopwords
import string

# remove common words and tokenize
stoplist = set('for a of the and to in'.split() + list(string.punctuation) + stopwords.words('english') )
texts = [[word for word in articles.lower().split() if word not in stoplist] for articles in articles]

# remove words that appear only once
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1]
         for text in texts]
print(len(texts))
pprint(texts)
# Out:
# 11
# [['mathematics',
#   'integral',
#   'assigns',
#   'numbers',
#   'functions',
#   'way',
#   'describe',
#   'displacement,',
#   'area,',
#   'volume,',
#   'concepts',
#   'arise',
#   'combining',
#   'infinitesimal',
#   'integration',
#   'one',
#   'two',
#   'main',
#   'operations',
#   'calculus',
#   'inverse',
#   'differentiation',
#   'other.',
#   'given',
#   'function',
#   'f',
#   'real',
#   'variable',
#   'x',
#   'interval',
#   'b',
#   'real',
#   'line',
#   'definite',
#   'integral',
#   'f',
#   'b',
#   'interpreted',
#   'signed',
#   'area',
#   'region',
#   'bounded',
#   'graph',
#   'f',
#   'x',
#   '-axis',
#   'vertical',
#   'lines',
#   'x',
#   'x',
#   'b',
#   'denoted',
#   'operation',
#   'integration,',
#   'inverse',
#   'operation',
#   'differentiation.',
#   'reason,',
#   'term',
#   'integral',
#   'may',
#   'also',
#   'refer',
#   'related',
#   'notion',
#   'antiderivative',
#   'called',
#   'indefinite',
#   'integral',
#   'function',
#   'f',
#   'whose',
#   'derivative',
#   'given',
#   'function',
#   'f',
#   'case,',
#   'integrals',
#   'discussed',
#   'article',
#   'termed',
#   'definite',
#   'integrals',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'differentiation',
#   'definite',
#   'f',
#   'continuous',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'antiderivative',
#   'f',
#   'f',
#   'known,',
#   'definite',
#   'integral',
#   'f',
#   'interval',
#   'given',
#   'principles',
#   'integration',
#   'formulated',
#   'independently',
#   'isaac',
#   'newton',
#   'gottfried',
#   'wilhelm',
#   'leibniz',
#   'late',
#   '17th',
#   'century,',
#   'thought',
#   'integral',
#   'infinite',
#   'sum',
#   'rectangles',
#   'infinitesimal',
#   'width.',
#   'bernhard',
#   'riemann',
#   'later',
#   'gave',
#   'rigorous',
#   'mathematical',
#   'definition',
#   'integrals,',
#   'based',
#   'limiting',
#   'procedure',
#   'approximates',
#   'area',
#   'region',
#   'breaking',
#   'region',
#   'thin',
#   'vertical',
#   'beginning',
#   'century,',
#   'sophisticated',
#   'notions',
#   'integrals',
#   'began',
#   'type',
#   'function',
#   'well',
#   'domain',
#   'integration',
#   'performed',
#   'line',
#   'integral',
#   'defined',
#   'functions',
#   'two',
#   'variables,',
#   'interval',
#   'integration',
#   'b',
#   'replaced',
#   'curve',
#   'two',
#   'surface',
#   'integral',
#   'curve',
#   'replaced',
#   'piece',
#   'surface',
#   'three-dimensional',
#   'space',
#   'first',
#   'documented',
#   'systematic',
#   'technique',
#   'integrals',
#   'method',
#   'exhaustion',
#   'ancient',
#   'greek',
#   'astronomer',
#   'eudoxus',
#   'sought',
#   'find',
#   'areas',
#   'volumes',
#   'breaking',
#   'infinite',
#   'number',
#   'area',
#   'volume',
#   'known.',
#   '[1]',
#   'method',
#   'developed',
#   'employed',
#   'archimedes',
#   '3rd',
#   'century',
#   'used',
#   'calculate',
#   'area',
#   'circle',
#   'surface',
#   'area',
#   'volume',
#   'area',
#   'area',
#   'volume',
#   'segment',
#   'paraboloid',
#   'revolution,',
#   'volume',
#   'segment',
#   'revolution,',
#   'area',
#   '[2]',
#   'similar',
#   'method',
#   'independently',
#   'developed',
#   'china',
#   'around',
#   '3rd',
#   'century',
#   'used',
#   'find',
#   'area',
#   'circle.',
#   'method',
#   'later',
#   'used',
#   'century',
#   'chinese',
#   'mathematicians',
#   'zu',
#   'zu',
#   'find',
#   'volume',
#   '[3]',
#   'middle',
#   'c.',
#   '–',
#   'c.',
#   'derived',
#   'formula',
#   'sum',
#   'fourth',
#   'powers',
#   'used',
#   'results',
#   'carry',
#   'would',
#   'called',
#   'integration',
#   'function,',
#   'formulae',
#   'sums',
#   'integral',
#   'squares',
#   'fourth',
#   'powers',
#   'allowed',
#   'calculate',
#   'volume',
#   'paraboloid',
#   '[4]',
#   'next',
#   'significant',
#   'integral',
#   'calculus',
#   'begin',
#   'appear',
#   '17th',
#   'century.',
#   'time,',
#   'work',
#   'cavalieri',
#   'method',
#   'work',
#   'began',
#   'lay',
#   'foundations',
#   'modern',
#   'calculus,',
#   'cavalieri',
#   'computing',
#   'integrals',
#   'x',
#   'n',
#   'degree',
#   'n',
#   '9',
#   "cavalieri's",
#   'quadrature',
#   'formula',
#   '[5]',
#   'steps',
#   'made',
#   'early',
#   '17th',
#   'century',
#   'barrow',
#   'provided',
#   'first',
#   'hints',
#   'connection',
#   'integration',
#   'differentiation',
#   'barrow',
#   'provided',
#   'first',
#   'proof',
#   'fundamental',
#   'theorem',
#   'calculus',
#   '[6]',
#   'generalized',
#   "cavalieri's",
#   'method,',
#   'computing',
#   'integrals',
#   'x',
#   'general',
#   'power,',
#   'including',
#   'negative',
#   'powers',
#   'fractional',
#   'powers.',
#   '[7]',
#   'major',
#   'advance',
#   'integration',
#   'came',
#   '17th',
#   'century',
#   'independent',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'leibniz',
#   'newton',
#   '[8]',
#   'leibniz',
#   'published',
#   'work',
#   'calculus',
#   'theorem',
#   'demonstrates',
#   'connection',
#   'integration',
#   'differentiation.',
#   'combined',
#   'comparative',
#   'differentiation,',
#   'calculate',
#   'integrals.',
#   'particular,',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'allows',
#   'one',
#   'much',
#   'class',
#   'problems.',
#   'equal',
#   'importance',
#   'comprehensive',
#   'mathematical',
#   'framework',
#   'leibniz',
#   'newton',
#   'given',
#   'name',
#   'infinitesimal',
#   'calculus',
#   'allowed',
#   'precise',
#   'analysis',
#   'functions',
#   'within',
#   'continuous',
#   'framework',
#   'eventually',
#   'became',
#   'modern',
#   'calculus',
#   'whose',
#   'notation',
#   'integrals',
#   'drawn',
#   'directly',
#   'work',
#   'newton',
#   'leibniz',
#   'provided',
#   'systematic',
#   'approach',
#   'integration,',
#   'work',
#   'lacked',
#   'degree',
#   'rigour',
#   'attacked',
#   'used',
#   'calling',
#   'quantities',
#   '".',
#   '[9]',
#   'calculus',
#   'acquired',
#   'development',
#   'limits',
#   'integration',
#   'first',
#   'rigorously',
#   'using',
#   'limits,',
#   'riemann',
#   '[10]',
#   'although',
#   'bounded',
#   'piecewise',
#   'continuous',
#   'functions',
#   'riemann-integrable',
#   'bounded',
#   'interval,',
#   'general',
#   'functions',
#   'context',
#   'fourier',
#   'analysis',
#   '—to',
#   "riemann's",
#   'definition',
#   '1904,',
#   'lebesgue',
#   'formulated',
#   'different',
#   'definition',
#   'integral',
#   'founded',
#   'measure',
#   'theory',
#   '(a',
#   'real',
#   'analysis',
#   ').',
#   '[11]',
#   '[12]',
#   'definitions',
#   'integral,',
#   'extending',
#   "riemann's",
#   "lebesgue's",
#   'proposed.',
#   'approaches',
#   'based',
#   'real',
#   'number',
#   'system',
#   'ones',
#   'common',
#   'today,',
#   'alternative',
#   'approaches',
#   'exist,',
#   'definition',
#   'integral',
#   'standard',
#   'part',
#   'infinite',
#   'riemann',
#   'sum,',
#   'based',
#   'hyperreal',
#   'number',
#   'system.',
#   'notation',
#   'indefinite',
#   'integral',
#   'introduced',
#   'gottfried',
#   'wilhelm',
#   'leibniz',
#   '1675.',
#   '[13]',
#   'adapted',
#   'integral',
#   'symbol',
#   '∫',
#   'letter',
#   'long',
#   '),',
#   'standing',
#   '(written',
#   'latin',
#   'modern',
#   'notation',
#   'definite',
#   'integral,',
#   'limits',
#   'integral',
#   'first',
#   'used',
#   'joseph',
#   'fourier',
#   'french',
#   'academy',
#   'around',
#   'reprinted',
#   'book',
#   '[14]',
#   'isaac',
#   'newton',
#   'used',
#   'small',
#   'vertical',
#   'bar',
#   'variable',
#   'indicate',
#   'integration,',
#   'placed',
#   'variable',
#   'inside',
#   'vertical',
#   'bar',
#   'easily',
#   'confused',
#   'x',
#   'x',
#   '′',
#   'used',
#   'indicate',
#   'differentiation,',
#   'box',
#   'notation',
#   'difficult',
#   'printers',
#   'notations',
#   'widely',
#   '[15]',
#   'word',
#   'integral',
#   'first',
#   'used',
#   'print',
#   'jacob',
#   'issue',
#   'wrote:',
#   'et',
#   '[16]',
#   '[17]',
#   'term',
#   'used',
#   'easy',
#   'understand',
#   'paragraph',
#   'de',
#   '[18]',
#   'dans',
#   'tout',
#   'la',
#   'du',
#   'calcul',
#   'de',
#   'm.',
#   'consiste',
#   'à',
#   'des',
#   'grandeurs',
#   'à',
#   'infiniment',
#   'et',
#   'à',
#   'ces',
#   'infiniment',
#   'petits',
#   'de',
#   'genre',
#   'ce',
#   "qu'on",
#   'calcul',
#   'pour',
#   "qu'on",
#   'calcul',
#   'et',
#   'qui',
#   'consiste',
#   'à',
#   'de',
#   'ces',
#   'infiniment',
#   'petits',
#   'aux',
#   'grandeurs',
#   'aux',
#   'les',
#   'à',
#   'en',
#   'les',
#   'de',
#   'le',
#   'm.',
#   'leibniz',
#   "qu'il",
#   'dans',
#   "qu'il",
#   'de',
#   'scientia',
#   'infiniti,',
#   'de',
#   'le',
#   'public',
#   'qui',
#   'tout',
#   'ce',
#   "qu'il",
#   'de',
#   'plus',
#   'pour',
#   'la',
#   'inverse',
#   'des',
#   'literally',
#   'translated',
#   'as:',
#   '"in',
#   'still',
#   'first',
#   'part',
#   'm.',
#   'leibniz',
#   'calculus,',
#   'going',
#   'integral',
#   'quantities',
#   'infinitely',
#   'small',
#   'differences,',
#   'one',
#   'another',
#   'infinitely',
#   'smalls',
#   'possible',
#   'called',
#   'differential',
#   'calculus.',
#   'part,',
#   'called',
#   'integral',
#   'calculus,',
#   'consists',
#   'going',
#   'back',
#   'infinitely',
#   'smalls',
#   'full',
#   'parts',
#   'differences,',
#   'say',
#   'find',
#   'sums,',
#   'also',
#   'intention',
#   'expose',
#   'it.',
#   'considering',
#   'm.',
#   'leibniz',
#   'wrote',
#   'working',
#   'book',
#   'calls',
#   'de',
#   'scientia',
#   'infiniti,',
#   'took',
#   'care',
#   'public',
#   'beautiful',
#   'work',
#   'due',
#   'contain',
#   'curious',
#   'reverse',
#   'method',
#   'integral',
#   'respect',
#   'x',
#   'real-valued',
#   'function',
#   'f',
#   'real',
#   'variable',
#   'x',
#   'interval',
#   'b',
#   'written',
#   'integral',
#   'sign',
#   '∫',
#   'represents',
#   'integration.',
#   'symbol',
#   'dx',
#   'called',
#   'differential',
#   'variable',
#   'x',
#   'indicates',
#   'variable',
#   'integration',
#   'x',
#   'function',
#   'f',
#   'x',
#   'integrated',
#   'called',
#   'integrand.',
#   'function',
#   'said',
#   'integrable',
#   'integral',
#   'function',
#   'domain',
#   'points',
#   'b',
#   'called',
#   'limits',
#   'integral.',
#   'integral',
#   'limits',
#   'specified',
#   'called',
#   'definite',
#   'integral.',
#   'integral',
#   'said',
#   'interval',
#   'b',
#   'integral',
#   'goes',
#   'finite',
#   'value',
#   'upper',
#   'limit',
#   'infinity,',
#   'expresses',
#   'limit',
#   'integral',
#   'value',
#   'b',
#   'b',
#   'goes',
#   'infinity.',
#   'value',
#   'integral',
#   'gets',
#   'closer',
#   'closer',
#   'finite',
#   'value,',
#   'integral',
#   'said',
#   'converge',
#   'said',
#   'limits',
#   'integral',
#   'called',
#   'indefinite',
#   'integral,',
#   'represents',
#   'class',
#   'functions',
#   '(the',
#   'antiderivative',
#   'whose',
#   'derivative',
#   'integrand.',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'relates',
#   'definite',
#   'integrals',
#   'indefinite',
#   'integrals.',
#   'occasionally,',
#   'limits',
#   'integration',
#   'omitted',
#   'definite',
#   'integrals',
#   'limits',
#   'occur',
#   'repeatedly',
#   'particular',
#   'author',
#   'make',
#   'convention',
#   'clear',
#   'beginning',
#   'relevant',
#   'text.',
#   'several',
#   'notation',
#   'integrals',
#   'encompass',
#   'integration',
#   'unbounded',
#   'domains',
#   'multiple',
#   'dimensions',
#   '(see',
#   'later',
#   'sections',
#   'historically,',
#   'symbol',
#   'dx',
#   'taken',
#   'represent',
#   'independent',
#   'variable',
#   'x',
#   'multiplied',
#   'integrand',
#   'summed',
#   'infinite',
#   'sense.',
#   'notion',
#   'still',
#   'useful,',
#   'later',
#   'mathematicians',
#   'deemed',
#   'infinitesimal',
#   'quantities',
#   'real',
#   'number',
#   'system.',
#   '[note',
#   '1]',
#   'introductory',
#   'calculus,',
#   'expression',
#   'dx',
#   'therefore',
#   'assigned',
#   'independent',
#   'meaning;',
#   'instead,',
#   'viewed',
#   'part',
#   'symbol',
#   'integration',
#   'serves',
#   'right',
#   'side',
#   'expression',
#   'integrated.',
#   'sophisticated',
#   'dx',
#   'meaning',
#   'depending',
#   'particular',
#   'area',
#   'mathematics',
#   'used',
#   'one',
#   'ways,',
#   'original',
#   'leibniz',
#   'notation',
#   'apply',
#   'generalization',
#   'original',
#   'definition',
#   'integral.',
#   'common',
#   'interpretations',
#   'dx',
#   'include:',
#   'integrator',
#   'function',
#   'integration',
#   '(indicated',
#   'x',
#   'general),',
#   'measure',
#   'lebesgue',
#   'theory',
#   '(indicated',
#   'general),',
#   'differential',
#   'form',
#   'exterior',
#   'calculus',
#   '(indicated',
#   'x',
#   '1',
#   '∧',
#   '∧',
#   'x',
#   'k',
#   '{\\displaystyle',
#   '\\wedge',
#   'last',
#   'case,',
#   'even',
#   'letter',
#   'independent',
#   'meaning',
#   '—',
#   'exterior',
#   'derivative',
#   'operator',
#   'differential',
#   'conversely,',
#   'settings,',
#   'leave',
#   'dx',
#   'simple',
#   'riemann',
#   'integral',
#   'used,',
#   'exact',
#   'type',
#   'integral',
#   'instance,',
#   'one',
#   'might',
#   'write',
#   '∫',
#   'b',
#   'c',
#   '1',
#   'f',
#   'c',
#   '2',
#   'g',
#   'c',
#   '1',
#   '∫',
#   'b',
#   'f',
#   'c',
#   '2',
#   '∫',
#   'b',
#   'g',
#   '{\\textstyle',
#   '\\int',
#   'express',
#   'linearity',
#   'integral,',
#   'property',
#   'shared',
#   'riemann',
#   'integral',
#   'modern',
#   'arabic',
#   'mathematical',
#   'notation',
#   'reflected',
#   'integral',
#   'symbol',
#   'used',
#   'instead',
#   'symbol',
#   '∫',
#   'since',
#   'arabic',
#   'mathematical',
#   'expressions',
#   'go',
#   'right',
#   '[19]',
#   'authors,',
#   'particularly',
#   'european',
#   'origin,',
#   'use',
#   '"d"',
#   'indicate',
#   'variable',
#   'integration',
#   '(i.e.,',
#   'x',
#   'instead',
#   'dx',
#   '),',
#   'since',
#   'properly',
#   'speaking,',
#   '"d"',
#   'variable.',
#   'symbol',
#   'dx',
#   'always',
#   'placed',
#   'f',
#   'x',
#   'instance',
#   'first',
#   'expression,',
#   'differential',
#   'treated',
#   'infinitesimal',
#   'formally',
#   'following',
#   'expression',
#   '3',
#   'x',
#   '2',
#   '1',
#   '{\\displaystyle',
#   '{\\frac',
#   'second',
#   'expression,',
#   'showing',
#   'differentials',
#   'first',
#   'variables',
#   'integrated',
#   'respect',
#   'to,',
#   'practice',
#   'particularly',
#   'popular',
#   'integrals',
#   'appear',
#   'many',
#   'practical',
#   'situations.',
#   'rectangular',
#   'flat',
#   'bottom,',
#   'length,',
#   'width,',
#   'depth',
#   'easily',
#   'determine',
#   'volume',
#   'water',
#   'contain',
#   '(to',
#   'fill',
#   'it),',
#   'area',
#   'surface',
#   '(to',
#   'cover',
#   'it),',
#   'length',
#   'edge',
#   '(to',
#   'rounded',
#   'bottom,',
#   'quantities',
#   'call',
#   'integrals.',
#   'practical',
#   'approximations',
#   'may',
#   'trivial',
#   'precision',
#   'engineering',
#   '(of',
#   'requires',
#   'exact',
#   'rigorous',
#   'values',
#   'elements.',
#   'start',
#   'off,',
#   'consider',
#   'curve',
#   'f',
#   'x',
#   'x',
#   '0',
#   'x',
#   '1',
#   'f',
#   'x',
#   '√',
#   'x',
#   'illustrated',
#   'call',
#   'area',
#   'integral',
#   'f',
#   'first',
#   'approximation,',
#   'area',
#   'unit',
#   'square',
#   'given',
#   'sides',
#   'x',
#   '0',
#   'x',
#   '1',
#   'f',
#   '(0)',
#   '0',
#   'f',
#   '(1)',
#   '1',
#   'exactly',
#   'true',
#   'value',
#   'must',
#   'somewhat',
#   'smaller.',
#   'decreasing',
#   'width',
#   'approximation',
#   'rectangles',
#   'increasing',
#   'number',
#   'rectangles',
#   'gives',
#   'better',
#   'result.',
#   'instance,',
#   'cross',
#   'interval',
#   'five',
#   'using',
#   'approximation',
#   'points',
#   '0,',
#   '1,',
#   'fit',
#   'box',
#   'step',
#   'using',
#   'right',
#   'end',
#   'height',
#   'curve',
#   'piece',
#   '√',
#   '√',
#   '√',
#   '1',
#   '1',
#   '),',
#   'sum',
#   'areas',
#   'rectangles',
#   'get',
#   'better',
#   'approximation',
#   'sought',
#   'integral,',
#   'namely',
#   'taking',
#   'sum',
#   'finitely',
#   'many',
#   'function',
#   'values',
#   'f',
#   'multiplied',
#   'differences',
#   'two',
#   'subsequent',
#   'approximation',
#   'points.',
#   'approximation',
#   'easily',
#   'seen',
#   'still',
#   'using',
#   'steps',
#   'produces',
#   'closer',
#   'approximation,',
#   'always',
#   'high',
#   'never',
#   'replacing',
#   'subintervals',
#   'ones',
#   'left',
#   'end',
#   'height',
#   'piece,',
#   'get',
#   'approximation',
#   'example,',
#   'twelve',
#   'approximate',
#   'value',
#   'area',
#   'key',
#   'idea',
#   'transition',
#   'adding',
#   'finitely',
#   'many',
#   'differences',
#   'approximation',
#   'points',
#   'multiplied',
#   'function',
#   'values',
#   'using',
#   'infinitely',
#   'many',
#   'fine,',
#   'infinitesimal',
#   'transition',
#   'completed',
#   'example,',
#   'turns',
#   'area',
#   'curve',
#   'within',
#   'stated',
#   'bounds',
#   'notation',
#   'integral',
#   'weighted',
#   'sum,',
#   'denoted',
#   'function',
#   'values,',
#   'f',
#   'x',
#   'multiplied',
#   'infinitesimal',
#   'step',
#   'called',
#   'differentials',
#   'denoted',
#   'dx',
#   'historically,',
#   'early',
#   'efforts',
#   'rigorously',
#   'interpret',
#   'riemann',
#   'formally',
#   'defined',
#   'integrals',
#   'limit',
#   'weighted',
#   'sums,',
#   'dx',
#   'suggested',
#   'limit',
#   'difference',
#   'interval',
#   "riemann's",
#   'intervals',
#   'continuity',
#   'definitions,',
#   'especially',
#   'lebesgue',
#   'integral',
#   'founded',
#   'ability',
#   'extend',
#   'idea',
#   'much',
#   'flexible',
#   'ways.',
#   'thus',
#   'notation',
#   'refers',
#   'weighted',
#   'sum',
#   'function',
#   'values',
#   'μ',
#   'measuring',
#   'weight',
#   'assigned',
#   'value.',
#   'denotes',
#   'region',
#   'integration.',
#   'many',
#   'ways',
#   'formally',
#   'integral,',
#   'equivalent.',
#   'differences',
#   'exist',
#   'mostly',
#   'deal',
#   'special',
#   'cases',
#   'may',
#   'possible',
#   'integrate',
#   'definitions,',
#   'also',
#   'occasionally',
#   'commonly',
#   'used',
#   'definitions',
#   'integral',
#   'riemann',
#   'integrals',
#   'lebesgue',
#   'integrals.',
#   'riemann',
#   'integral',
#   'defined',
#   'terms',
#   'riemann',
#   'sums',
#   'functions',
#   'respect',
#   'tagged',
#   'partitions',
#   'interval.',
#   '[20]',
#   'let',
#   'b',
#   'closed',
#   'interval',
#   'real',
#   'tagged',
#   'partition',
#   'b',
#   'finite',
#   'sequence',
#   'partitions',
#   'interval',
#   'b',
#   'n',
#   'sub-intervals',
#   'x',
#   '−1',
#   'x',
#   'indexed',
#   'distinguished',
#   'point',
#   '∈',
#   'x',
#   '−1',
#   'x',
#   'riemann',
#   'sum',
#   'function',
#   'f',
#   'respect',
#   'tagged',
#   'partition',
#   'defined',
#   'thus',
#   'term',
#   'sum',
#   'area',
#   'rectangle',
#   'height',
#   'equal',
#   'function',
#   'value',
#   'distinguished',
#   'point',
#   'given',
#   'sub-interval,',
#   'width',
#   'sub-interval',
#   'width.',
#   'let',
#   'δ',
#   'x',
#   '−',
#   'x',
#   '−1',
#   'width',
#   'sub-interval',
#   'mesh',
#   'tagged',
#   'partition',
#   'width',
#   'largest',
#   'sub-interval',
#   'formed',
#   'partition,',
#   'max',
#   'n',
#   'δ',
#   'riemann',
#   'integral',
#   'function',
#   'f',
#   'interval',
#   'b',
#   'equal',
#   'chosen',
#   'tags',
#   'give',
#   'maximum',
#   '(respectively,',
#   'value',
#   'interval,',
#   'riemann',
#   'sum',
#   'becomes',
#   'upper',
#   '(respectively,',
#   'darboux',
#   'sum',
#   'suggesting',
#   'close',
#   'connection',
#   'riemann',
#   'integral',
#   'darboux',
#   'integral',
#   'often',
#   'interest,',
#   'theory',
#   'applications,',
#   'able',
#   'pass',
#   'limit',
#   'integral.',
#   'instance,',
#   'sequence',
#   'functions',
#   'frequently',
#   'constructed',
#   'suitable',
#   'sense,',
#   'solution',
#   'integral',
#   'solution',
#   'function',
#   'limit',
#   'integrals',
#   'approximations.',
#   'however,',
#   'many',
#   'functions',
#   'obtained',
#   'limits',
#   'riemann-integrable,',
#   'limit',
#   'theorems',
#   'hold',
#   'riemann',
#   'integral.',
#   'therefore,',
#   'great',
#   'importance',
#   'definition',
#   'integral',
#   'allows',
#   'wider',
#   'class',
#   'functions',
#   'integrated.',
#   '[21]',
#   'integral',
#   'lebesgue',
#   'integral,',
#   'following',
#   'fact',
#   'class',
#   'integrable',
#   'functions:',
#   'values',
#   'function',
#   'rearranged',
#   'domain,',
#   'integral',
#   'function',
#   'remain',
#   'thus',
#   'henri',
#   'lebesgue',
#   'introduced',
#   'integral',
#   'name,',
#   'integral',
#   'thus',
#   'letter',
#   'paul',
#   'pay',
#   'certain',
#   'sum,',
#   'collected',
#   'take',
#   'bills',
#   'coins',
#   'pocket',
#   'give',
#   'order',
#   'find',
#   'reached',
#   'total',
#   'sum.',
#   'riemann',
#   'integral.',
#   'taken',
#   'money',
#   'pocket',
#   'order',
#   'bills',
#   'coins',
#   'according',
#   'values',
#   'pay',
#   'several',
#   'one',
#   'integral.',
#   'it,',
#   '"to',
#   'compute',
#   'riemann',
#   'integral',
#   'f',
#   'one',
#   'partitions',
#   'domain',
#   'b',
#   'lebesgue',
#   'integral,',
#   '"one',
#   'effect',
#   'partitioning',
#   'range',
#   'f',
#   '".',
#   '[22]',
#   'definition',
#   'lebesgue',
#   'integral',
#   'thus',
#   'begins',
#   'measure',
#   'simplest',
#   'case,',
#   'lebesgue',
#   'measure',
#   'μ',
#   'interval',
#   'b',
#   'width,',
#   'b',
#   '−',
#   'lebesgue',
#   'integral',
#   'riemann',
#   'integral',
#   'exist.',
#   'complicated',
#   'cases,',
#   'sets',
#   'measured',
#   'highly',
#   'continuity',
#   'resemblance',
#   'intervals.',
#   'using',
#   'range',
#   'f',
#   'philosophy,',
#   'integral',
#   'non-negative',
#   'function',
#   'f',
#   'r',
#   '→',
#   'r',
#   'sum',
#   'areas',
#   'thin',
#   'dt',
#   'area',
#   'μ',
#   'x',
#   'f',
#   'x',
#   '&gt;',
#   'dt',
#   'let',
#   'f',
#   '∗',
#   'μ',
#   'x',
#   'f',
#   'x',
#   '&gt;',
#   'lebesgue',
#   'integral',
#   'f',
#   'defined',
#   'integral',
#   'right',
#   'ordinary',
#   'improper',
#   'riemann',
#   'integral',
#   'f',
#   '∗',
#   'strictly',
#   'decreasing',
#   'positive',
#   'function,',
#   'therefore',
#   'well-defined',
#   'improper',
#   'riemann',
#   '[23]',
#   'suitable',
#   'class',
#   'functions',
#   '(the',
#   'measurable',
#   'functions',
#   'lebesgue',
#   'integral.',
#   'general',
#   'measurable',
#   'function',
#   'f',
#   'lebesgue-integrable',
#   'sum',
#   'absolute',
#   'values',
#   'areas',
#   'regions',
#   'graph',
#   'f',
#   'x',
#   '-axis',
#   'case,',
#   'integral',
#   'is,',
#   'case,',
#   'difference',
#   'area',
#   'x',
#   '-axis',
#   'area',
#   'x',
#   'although',
#   'riemann',
#   'lebesgue',
#   'integrals',
#   'widely',
#   'used',
#   'definitions',
#   'integral,',
#   'number',
#   'others',
#   'exist,',
#   'including',
#   'darboux',
#   'integral',
#   'defined',
#   'darboux',
#   'sums',
#   'riemann',
#   '[24]',
#   'yet',
#   'equivalent',
#   'riemann',
#   'integral;',
#   '[25]',
#   'riemann–stieltjes',
#   'integral',
#   'extension',
#   'riemann',
#   'integral',
#   'respect',
#   'function',
#   'opposed',
#   '[26]',
#   'lebesgue–stieltjes',
#   'integral',
#   'developed',
#   'johann',
#   'generalizes',
#   'riemann–stieltjes',
#   'lebesgue',
#   'integrals;',
#   '[27]',
#   'daniell',
#   'integral',
#   'subsumes',
#   'lebesgue',
#   'integral',
#   'lebesgue–stieltjes',
#   'integral',
#   'without',
#   'depending',
#   'measures',
#   '[28]',
#   'haar',
#   'integral',
#   'used',
#   'integration',
#   'locally',
#   'compact',
#   'topological',
#   'introduced',
#   'haar',
#   'henstock–kurzweil',
#   'integral',
#   'defined',
#   'oskar',
#   'gauge',
#   'integral)',
#   'developed',
#   'ralph',
#   'itô',
#   'integral',
#   'integral',
#   'define',
#   'integration',
#   'respect',
#   'semimartingales',
#   'brownian',
#   'motion',
#   'young',
#   'integral',
#   'kind',
#   'riemann–stieltjes',
#   'integral',
#   'respect',
#   'certain',
#   'functions',
#   'unbounded',
#   'variation',
#   'rough',
#   'path',
#   'integral,',
#   'defined',
#   'functions',
#   'additional',
#   'structure',
#   'generalizes',
#   'stochastic',
#   'integration',
#   'semimartingales',
#   'processes',
#   'fractional',
#   'brownian',
#   'motion',
#   'choquet',
#   'integral',
#   'integral',
#   'created',
#   'french',
#   'gustave',
#   'choquet',
#   'collection',
#   'riemann-integrable',
#   'functions',
#   'closed',
#   'interval',
#   'b',
#   'forms',
#   'vector',
#   'space',
#   'operations',
#   'pointwise',
#   'addition',
#   'multiplication',
#   'operation',
#   'integration',
#   'linear',
#   'functional',
#   'vector',
#   'space.',
#   'thus,',
#   'collection',
#   'integrable',
#   'functions',
#   'closed',
#   'taking',
#   'linear',
#   'combinations',
#   'and,',
#   'integral',
#   'linear',
#   'combination',
#   'linear',
#   'combination',
#   'similarly,',
#   'set',
#   'real',
#   '-valued',
#   'lebesgue-integrable',
#   'functions',
#   'given',
#   'measure',
#   'space',
#   'e',
#   'measure',
#   'μ',
#   'closed',
#   'taking',
#   'linear',
#   'combinations',
#   'hence',
#   'form',
#   'vector',
#   'space,',
#   'lebesgue',
#   'integral',
#   'linear',
#   'functional',
#   'vector',
#   'space,',
#   'generally,',
#   'consider',
#   'vector',
#   'space',
#   'measurable',
#   'functions',
#   'measure',
#   'space',
#   'e',
#   'μ',
#   'taking',
#   'values',
#   'locally',
#   'compact',
#   'complete',
#   'topological',
#   'vector',
#   'space',
#   'v',
#   'locally',
#   'compact',
#   'topological',
#   'field',
#   'k',
#   'f',
#   'e',
#   '→',
#   'v',
#   'one',
#   'may',
#   'define',
#   'abstract',
#   'integration',
#   'map',
#   'function',
#   'f',
#   'element',
#   'v',
#   'symbol',
#   '∞',
#   'linear',
#   'situation,',
#   'linearity',
#   'holds',
#   'functions',
#   'whose',
#   'integral',
#   'element',
#   'v',
#   '(i.e.',
#   'important',
#   'special',
#   'cases',
#   'arise',
#   'k',
#   'r',
#   'c',
#   'finite',
#   'extension',
#   'field',
#   'q',
#   'p',
#   'numbers',
#   'v',
#   'vector',
#   'space',
#   'k',
#   'k',
#   'c',
#   'v',
#   'complex',
#   'hilbert',
#   'space',
#   'together',
#   'natural',
#   'continuity',
#   'properties',
#   'certain',
#   'class',
#   'functions,',
#   'may',
#   'used',
#   'give',
#   'alternative',
#   'definition',
#   'integral.',
#   'approach',
#   'daniell',
#   'case',
#   'real-valued',
#   'functions',
#   'set',
#   'x',
#   'generalized',
#   'functions',
#   'values',
#   'locally',
#   'compact',
#   'topological',
#   'vector',
#   'space.',
#   'see',
#   'integral.',
#   'number',
#   'general',
#   'inequalities',
#   'hold',
#   'riemann-integrable',
#   'functions',
#   'defined',
#   'closed',
#   'bounded',
#   'interval',
#   'b',
#   'generalized',
#   'notions',
#   'integral',
#   'f',
#   'real-valued',
#   'riemann-integrable',
#   'function',
#   'integral',
#   'interval',
#   'b',
#   'defined',
#   '&lt;',
#   'b',
#   'means',
#   'upper',
#   'lower',
#   'sums',
#   'function',
#   'f',
#   'evaluated',
#   'partition',
#   'x',
#   '0',
#   '≤',
#   'x',
#   '1',
#   '≤',
#   '≤',
#   'x',
#   'n',
#   'b',
#   'whose',
#   'values',
#   'x',
#   'geometrically,',
#   'integration',
#   'takes',
#   'place',
#   'f',
#   'within',
#   'intervals',
#   'x',
#   'x',
#   '+1',
#   'interval',
#   'higher',
#   'index',
#   'lies',
#   'right',
#   'one',
#   'lower',
#   'values',
#   'b',
#   'interval',
#   'called',
#   'limits',
#   'integration',
#   'f',
#   'integrals',
#   'also',
#   'defined',
#   '&gt;',
#   'b',
#   'this,',
#   'b',
#   'implies:',
#   'first',
#   'convention',
#   'necessary',
#   'taking',
#   'integrals',
#   'subintervals',
#   'b',
#   'second',
#   'says',
#   'integral',
#   'taken',
#   'degenerate',
#   'interval,',
#   'point',
#   'zero',
#   'one',
#   'reason',
#   'first',
#   'convention',
#   'integrability',
#   'f',
#   'interval',
#   'b',
#   'implies',
#   'f',
#   'integrable',
#   'subinterval',
#   'c',
#   'particular',
#   'integrals',
#   'property',
#   'first',
#   'convention,',
#   'resulting',
#   'relation',
#   'well-defined',
#   'b',
#   'c',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'statement',
#   'differentiation',
#   'integration',
#   'inverse',
#   'continuous',
#   'function',
#   'first',
#   'integrated',
#   'original',
#   'function',
#   'important',
#   'sometimes',
#   'called',
#   'second',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'allows',
#   'one',
#   'compute',
#   'integrals',
#   'using',
#   'antiderivative',
#   'function',
#   'integrated.',
#   'let',
#   'f',
#   'continuous',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'let',
#   'f',
#   'function',
#   'x',
#   'b',
#   'then,',
#   'f',
#   'continuous',
#   'b',
#   'differentiable',
#   'open',
#   'interval',
#   'b',
#   'x',
#   'b',
#   'let',
#   'f',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'admits',
#   'antiderivative',
#   'f',
#   'b',
#   'is,',
#   'f',
#   'f',
#   'functions',
#   'x',
#   'b',
#   'f',
#   'integrable',
#   'b',
#   'second',
#   'fundamental',
#   'theorem',
#   'allows',
#   'many',
#   'integrals',
#   'calculated',
#   'example,',
#   'calculate',
#   'integral',
#   'square',
#   'function',
#   'f',
#   'x',
#   'x',
#   '1/2',
#   '0',
#   '1,',
#   'sufficient',
#   'find',
#   'antiderivative,',
#   'is,',
#   'function',
#   'f',
#   'x',
#   'whose',
#   'derivative',
#   'equals',
#   'f',
#   'x',
#   'one',
#   'function',
#   'f',
#   'x',
#   '2',
#   '3',
#   'x',
#   '3',
#   '2',
#   '{\\displaystyle',
#   'f(x)={\\tfrac',
#   'value',
#   'integral',
#   'question',
#   'case',
#   'general',
#   'rule,',
#   'f',
#   'x',
#   'x',
#   'q',
#   '{\\displaystyle',
#   'q',
#   '≠',
#   '−',
#   '1',
#   '{\\displaystyle',
#   'antiderivative',
#   'f',
#   'x',
#   '1',
#   'q',
#   '1',
#   'x',
#   'q',
#   '1',
#   '{\\displaystyle',
#   'f(x)={\\tfrac',
#   'tables',
#   'similar',
#   'antiderivatives',
#   'used',
#   'calculate',
#   'integrals',
#   'much',
#   'way',
#   'derivatives',
#   'may',
#   'obtained',
#   'integrals',
#   'used',
#   'extensively',
#   'many',
#   'areas.',
#   'example,',
#   'probability',
#   'theory',
#   'used',
#   'determine',
#   'probability',
#   'random',
#   'variable',
#   'within',
#   'certain',
#   '[29]',
#   'moreover,',
#   'integral',
#   'entire',
#   'probability',
#   'density',
#   'function',
#   'must',
#   'equal',
#   '1,',
#   'provides',
#   'whether',
#   'function',
#   'negative',
#   'values',
#   'could',
#   'density',
#   'function',
#   '[30]',
#   'integrals',
#   'used',
#   'computing',
#   'area',
#   'two-dimensional',
#   'region',
#   'curved',
#   'well',
#   'computing',
#   'volume',
#   'three-dimensional',
#   'object',
#   'curved',
#   'area',
#   'two-dimensional',
#   'region',
#   'calculated',
#   'using',
#   'definite',
#   'integral.',
#   '[31]',
#   'volume',
#   'three-dimensional',
#   'object',
#   'disc',
#   'outlined',
#   'disc',
#   'integration',
#   'computed',
#   'using',
#   'equation',
#   'volume',
#   'r',
#   '2',
#   'h',
#   '{\\displaystyle',
#   'r',
#   '{\\displaystyle',
#   'case',
#   'would',
#   'distance',
#   'curve',
#   'function',
#   'line',
#   'simple',
#   'radius',
#   'equation',
#   'function',
#   'minus',
#   'given',
#   'x',
#   '{\\displaystyle',
#   'x}',
#   '-value',
#   '{\\displaystyle',
#   'y}',
#   '-value',
#   'line.',
#   '[32]',
#   'instance,',
#   'radius',
#   'disc',
#   'created',
#   'quadratic',
#   '−',
#   'x',
#   '2',
#   '4',
#   '{\\displaystyle',
#   'y=-x^{2}+4}',
#   'around',
#   'line',
#   '−',
#   '1',
#   '{\\displaystyle',
#   'y=-1}',
#   'would',
#   'given',
#   'expression',
#   '−',
#   'x',
#   '2',
#   '4',
#   '−',
#   '−',
#   '1',
#   '{\\displaystyle',
#   '−',
#   'x',
#   '2',
#   '5',
#   '{\\displaystyle',
#   'order',
#   'find',
#   'volume',
#   'integral',
#   'bounds',
#   '{\\displaystyle',
#   'a}',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   '{\\displaystyle',
#   'a}',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   'line',
#   '−',
#   'x',
#   '2',
#   '4',
#   '{\\displaystyle',
#   'y=-x^{2}+4}',
#   '−',
#   '1',
#   '{\\displaystyle',
#   'y=-1}',
#   'would',
#   'used',
#   'follows:',
#   'integrals',
#   'also',
#   'used',
#   'physics,',
#   'areas',
#   'like',
#   'find',
#   'quantities',
#   'like',
#   'displacement',
#   'time',
#   'velocity',
#   'example,',
#   'displacement',
#   'object',
#   'time',
#   'interval',
#   'b',
#   '{\\displaystyle',
#   '[a,b]}',
#   'given',
#   'v',
#   '{\\displaystyle',
#   'velocity',
#   'expressed',
#   'function',
#   'time.',
#   '[33]',
#   'work',
#   'done',
#   'force',
#   'f',
#   'x',
#   '{\\displaystyle',
#   'f(x)}',
#   'function',
#   'initial',
#   'position',
#   '{\\displaystyle',
#   'a}',
#   'final',
#   'position',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   'is:',
#   '[34]',
#   'integrals',
#   'also',
#   'used',
#   'integration',
#   'used',
#   'calculate',
#   'difference',
#   'free',
#   'energy',
#   'two',
#   'given',
#   'states.',
#   'riemann',
#   'integral',
#   'integrand',
#   'defined',
#   'finite',
#   'closed',
#   'bounded',
#   'interval,',
#   'limits',
#   'integration.',
#   'improper',
#   'integral',
#   'one',
#   'conditions',
#   'cases',
#   'integrals',
#   'may',
#   'defined',
#   'considering',
#   'limit',
#   'sequence',
#   'proper',
#   'riemann',
#   'integrals',
#   'larger',
#   'intervals.',
#   'interval',
#   'instance',
#   'upper',
#   'end,',
#   'improper',
#   'integral',
#   'limit',
#   'endpoint',
#   'goes',
#   'integrand',
#   'defined',
#   'finite',
#   'interval,',
#   'instance',
#   'b',
#   'limit',
#   'may',
#   'provide',
#   'finite',
#   'is,',
#   'improper',
#   'integral',
#   'limit',
#   'proper',
#   'integrals',
#   'one',
#   'endpoint',
#   'interval',
#   'integration',
#   'approaches',
#   'either',
#   'specified',
#   'real',
#   'number',
#   '∞',
#   '[35]',
#   'complicated',
#   'cases,',
#   'limits',
#   'required',
#   'interior',
#   'points.',
#   'definite',
#   'integral',
#   'positive',
#   'function',
#   'one',
#   'variable',
#   'represents',
#   'area',
#   'region',
#   'graph',
#   'function',
#   'x',
#   '-axis,',
#   'double',
#   'integral',
#   'positive',
#   'function',
#   'two',
#   'variables',
#   'represents',
#   'volume',
#   'region',
#   'surface',
#   'defined',
#   'function',
#   'plane',
#   'domain.',
#   '[36]',
#   'example,',
#   'function',
#   'two',
#   'dimensions',
#   'depends',
#   'two',
#   'real',
#   'variables,',
#   'x',
#   'integral',
#   'function',
#   'f',
#   'rectangle',
#   'r',
#   'given',
#   'product',
#   'two',
#   'intervals',
#   'r',
#   'b',
#   '×',
#   'c',
#   '{\\displaystyle',
#   'written',
#   'differential',
#   'da',
#   'indicates',
#   'integration',
#   'taken',
#   'respect',
#   'area.',
#   'double',
#   'integral',
#   'defined',
#   'using',
#   'riemann',
#   'sums',
#   'represents',
#   '(signed)',
#   'volume',
#   'graph',
#   'z',
#   'f',
#   'x',
#   'domain',
#   'r',
#   '[37]',
#   'suitable',
#   'conditions',
#   '(e.g.,',
#   'f',
#   'theorem',
#   'states',
#   'integral',
#   'expressed',
#   'equivalent',
#   'integral',
#   '[38]',
#   'reduces',
#   'problem',
#   'computing',
#   'double',
#   'integral',
#   'computing',
#   'integrals.',
#   'this,',
#   'another',
#   'notation',
#   'integral',
#   'r',
#   'uses',
#   'double',
#   'integral',
#   'integration',
#   'general',
#   'domains',
#   'possible.',
#   'integral',
#   'function',
#   'f',
#   'respect',
#   'volume,',
#   'n',
#   'region',
#   'r',
#   'n',
#   '{\\displaystyle',
#   '\\mathbb',
#   '{r}',
#   '^{n}}',
#   'denoted',
#   'symbols',
#   'as:',
#   'concept',
#   'integral',
#   'extended',
#   'general',
#   'domains',
#   'integration,',
#   'curved',
#   'lines',
#   'inside',
#   'higher-dimensional',
#   'integrals',
#   'known',
#   'line',
#   'integrals',
#   'surface',
#   'integrals',
#   'important',
#   'applications',
#   'physics,',
#   'dealing',
#   'vector',
#   'fields',
#   'line',
#   'integral',
#   'called',
#   'path',
#   'integral',
#   'integral',
#   'function',
#   'integrated',
#   'evaluated',
#   'along',
#   'curve',
#   '[39]',
#   'various',
#   'different',
#   'line',
#   'integrals',
#   'use.',
#   'case',
#   'closed',
#   'curve',
#   'also',
#   'called',
#   'contour',
#   'integral',
#   'function',
#   'integrated',
#   'may',
#   'scalar',
#   'field',
#   'vector',
#   'field',
#   'value',
#   'line',
#   'integral',
#   'sum',
#   'values',
#   'field',
#   'points',
#   'weighted',
#   'scalar',
#   'function',
#   'curve',
#   'arc',
#   'length',
#   'vector',
#   'field,',
#   'scalar',
#   'product',
#   'vector',
#   'field',
#   'differential',
#   'vector',
#   'line',
#   'integral',
#   'simpler',
#   'integrals',
#   'defined',
#   'intervals',
#   'many',
#   'simple',
#   'formulas',
#   'physics',
#   'natural',
#   'continuous',
#   'terms',
#   'line',
#   'integrals;',
#   'example,',
#   'fact',
#   'work',
#   'equal',
#   'force',
#   'f',
#   'multiplied',
#   'displacement,',
#   'may',
#   'expressed',
#   '(in',
#   'terms',
#   'vector',
#   'as:',
#   'object',
#   'moving',
#   'along',
#   'path',
#   'c',
#   'vector',
#   'field',
#   'f',
#   'field',
#   'field',
#   'total',
#   'work',
#   'done',
#   'field',
#   'object',
#   'obtained',
#   'summing',
#   'differential',
#   'work',
#   'done',
#   'moving',
#   'gives',
#   'line',
#   'integral',
#   'surface',
#   'integral',
#   'generalizes',
#   'double',
#   'integrals',
#   'integration',
#   'surface',
#   '(which',
#   'may',
#   'curved',
#   'set',
#   'space',
#   ');',
#   'thought',
#   'double',
#   'integral',
#   'analog',
#   'line',
#   'integral',
#   'function',
#   'integrated',
#   'may',
#   'scalar',
#   'field',
#   'vector',
#   'field',
#   'value',
#   'surface',
#   'integral',
#   'sum',
#   'field',
#   'points',
#   'achieved',
#   'surface',
#   'surface',
#   'provide',
#   'partitioning',
#   'riemann',
#   'sums.',
#   '[40]',
#   'example',
#   'applications',
#   'surface',
#   'integrals,',
#   'consider',
#   'vector',
#   'field',
#   'v',
#   'surface',
#   'is,',
#   'point',
#   'x',
#   'v',
#   'x',
#   'vector.',
#   'fluid',
#   'flowing',
#   'v',
#   'x',
#   'determines',
#   'velocity',
#   'fluid',
#   'x',
#   'flux',
#   'defined',
#   'fluid',
#   'flowing',
#   'unit',
#   'amount',
#   'time.',
#   'find',
#   'need',
#   'take',
#   'dot',
#   'product',
#   'v',
#   'unit',
#   'surface',
#   'normal',
#   'point,',
#   'give',
#   'us',
#   'scalar',
#   'field,',
#   'integrate',
#   'fluid',
#   'flux',
#   'example',
#   'may',
#   'physical',
#   'fluid',
#   'water',
#   'thus',
#   'surface',
#   'integrals',
#   'applications',
#   'physics,',
#   'particularly',
#   'classical',
#   'theory',
#   'complex',
#   'analysis',
#   'integrand',
#   'function',
#   'complex',
#   'variable',
#   'z',
#   'instead',
#   'real',
#   'function',
#   'real',
#   'variable',
#   'x',
#   'complex',
#   'function',
#   'integrated',
#   'along',
#   'curve',
#   '{\\displaystyle',
#   'complex',
#   'integral',
#   'denoted',
#   'follows:',
#   'known',
#   'contour',
#   'integral',
#   'differential',
#   'form',
#   'mathematical',
#   'concept',
#   'fields',
#   'multivariable',
#   'calculus',
#   'differential',
#   'topology',
#   'differential',
#   'forms',
#   'organized',
#   'degree.',
#   'example,',
#   'one-form',
#   'weighted',
#   'sum',
#   'differentials',
#   'as:',
#   'e',
#   'f',
#   'g',
#   'functions',
#   'three',
#   'differential',
#   'one-form',
#   'integrated',
#   'oriented',
#   'resulting',
#   'integral',
#   'another',
#   'way',
#   'writing',
#   'line',
#   'integral.',
#   'basic',
#   'differentials',
#   'dx',
#   'dy',
#   'measure',
#   'infinitesimal',
#   'oriented',
#   'lengths',
#   'parallel',
#   'three',
#   'coordinate',
#   'axes.',
#   'differential',
#   'two-form',
#   'sum',
#   'form',
#   'basic',
#   'x',
#   '∧',
#   'z',
#   '∧',
#   'x',
#   '∧',
#   'z',
#   '{\\displaystyle',
#   'measure',
#   'oriented',
#   'areas',
#   'parallel',
#   'coordinate',
#   'symbol',
#   '∧',
#   '{\\displaystyle',
#   '\\wedge',
#   'denotes',
#   'wedge',
#   'product',
#   'similar',
#   'cross',
#   'product',
#   'sense',
#   'wedge',
#   'product',
#   'two',
#   'forms',
#   'representing',
#   'oriented',
#   'lengths',
#   'represents',
#   'oriented',
#   'area.',
#   'two-form',
#   'integrated',
#   'oriented',
#   'surface,',
#   'resulting',
#   'integral',
#   'equivalent',
#   'surface',
#   'integral',
#   'giving',
#   'flux',
#   'e',
#   'f',
#   'j',
#   'g',
#   'k',
#   '{\\displaystyle',
#   'unlike',
#   'cross',
#   'three-dimensional',
#   'vector',
#   'calculus,',
#   'wedge',
#   'product',
#   'calculus',
#   'differential',
#   'forms',
#   'makes',
#   'sense',
#   'arbitrary',
#   'dimension',
#   'general',
#   'higher-dimensional',
#   'exterior',
#   'derivative',
#   'plays',
#   'role',
#   'gradient',
#   'vector',
#   'calculus,',
#   'theorem',
#   'generalizes',
#   'three',
#   'theorems',
#   'vector',
#   'theorem',
#   'theorem',
#   'theorem',
#   'discrete',
#   'equivalent',
#   'integration',
#   'integrals',
#   'put',
#   'foundations',
#   'using',
#   'theory',
#   'lebesgue',
#   'integrals',
#   'time',
#   'calculus',
#   'basic',
#   'technique',
#   'computing',
#   'definite',
#   'integrals',
#   'one',
#   'real',
#   'variable',
#   'based',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'let',
#   'f',
#   'x',
#   'function',
#   'x',
#   'integrated',
#   'given',
#   'interval',
#   'b',
#   'then,',
#   'find',
#   'antiderivative',
#   'f',
#   'is,',
#   'function',
#   'f',
#   'f',
#   '′',
#   'f',
#   'interval.',
#   'provided',
#   'integrand',
#   'integral',
#   'singularities',
#   'path',
#   'integration,',
#   'fundamental',
#   'theorem',
#   'calculus,',
#   'integral',
#   'actually',
#   'antiderivative,',
#   'fundamental',
#   'theorem',
#   'provides',
#   'way',
#   'use',
#   'antiderivatives',
#   'evaluate',
#   'definite',
#   'integrals.',
#   'difficult',
#   'step',
#   'usually',
#   'find',
#   'antiderivative',
#   'f',
#   'rarely',
#   'possible',
#   'function',
#   'write',
#   'often,',
#   'necessary',
#   'use',
#   'one',
#   'many',
#   'techniques',
#   'developed',
#   'evaluate',
#   'integrals.',
#   'techniques',
#   'rewrite',
#   'one',
#   'integral',
#   'different',
#   'one',
#   'techniques',
#   'include:',
#   'basic',
#   'methods',
#   'fundamental',
#   'methods',
#   'necessary',
#   'know',
#   'integrate',
#   'function.',
#   'derived',
#   'methods',
#   'methods',
#   'derived',
#   'basic',
#   'methods',
#   'make',
#   'process',
#   'integration',
#   'easier',
#   'special',
#   'kinds',
#   'functions',
#   'functions.',
#   'alternative',
#   'methods',
#   'exist',
#   'compute',
#   'complex',
#   'integrals.',
#   'many',
#   'integrals',
#   'expanded',
#   'taylor',
#   'series',
#   'integrated',
#   'term',
#   'term.',
#   'occasionally,',
#   'resulting',
#   'infinite',
#   'series',
#   'summed',
#   'method',
#   'using',
#   'meijer',
#   'also',
#   'used,',
#   'assuming',
#   'integrand',
#   'written',
#   'product',
#   'meijer',
#   'also',
#   'many',
#   'less',
#   'common',
#   'ways',
#   'calculating',
#   'definite',
#   'integrals;',
#   'instance,',
#   'identity',
#   'used',
#   'transform',
#   'integral',
#   'rectangular',
#   'region',
#   'infinite',
#   'sum.',
#   'occasionally,',
#   'integral',
#   'evaluated',
#   'example',
#   'this,',
#   'see',
#   'gaussian',
#   'integral',
#   'volumes',
#   'revolution',
#   'usually',
#   'done',
#   'integration',
#   'shell',
#   'integration',
#   'specific',
#   'results',
#   'worked',
#   'various',
#   'techniques',
#   'collected',
#   'list',
#   'integrals',
#   'many',
#   'problems',
#   'physics,',
#   'engineering',
#   'involve',
#   'integration',
#   'explicit',
#   'formula',
#   'integral',
#   'extensive',
#   'tables',
#   'integrals',
#   'compiled',
#   'published',
#   'years',
#   'spread',
#   'many',
#   'students',
#   'turned',
#   'computer',
#   'algebra',
#   'systems',
#   'specifically',
#   'designed',
#   'perform',
#   'difficult',
#   'tedious',
#   'including',
#   'integration.',
#   'symbolic',
#   'integration',
#   'one',
#   'development',
#   'first',
#   'like',
#   'maple',
#   'major',
#   'mathematical',
#   'difficulty',
#   'symbolic',
#   'integration',
#   'many',
#   'cases,',
#   'closed',
#   'formula',
#   'antiderivative',
#   'rather',
#   'function',
#   'exist.',
#   'instance,',
#   'known',
#   'antiderivatives',
#   'functions',
#   'exp(',
#   'x',
#   '2',
#   '),',
#   'x',
#   'x',
#   'x',
#   'x',
#   'cannot',
#   'expressed',
#   'closed',
#   'form',
#   'involving',
#   'rational',
#   'exponential',
#   'functions,',
#   'trigonometric',
#   'functions',
#   'inverse',
#   'trigonometric',
#   'functions',
#   'operations',
#   'multiplication',
#   'words,',
#   'none',
#   'three',
#   'given',
#   'functions',
#   'integrable',
#   'elementary',
#   'functions',
#   'functions',
#   'may',
#   'built',
#   'rational',
#   'functions,',
#   'roots',
#   'polynomial',
#   'logarithm,',
#   'exponential',
#   'functions.',
#   'risch',
#   'algorithm',
#   'provides',
#   'general',
#   'criterion',
#   'determine',
#   'whether',
#   'antiderivative',
#   'elementary',
#   'function',
#   'and,',
#   'is,',
#   'compute',
#   'it.',
#   'unfortunately,',
#   'turns',
#   'functions',
#   'closed',
#   'expressions',
#   'antiderivatives',
#   'rather',
#   'consequently,',
#   'algebra',
#   'systems',
#   'hope',
#   'able',
#   'find',
#   'antiderivative',
#   'constructed',
#   'elementary',
#   'function.',
#   'positive',
#   'side,',
#   'antiderivatives',
#   'fixed',
#   'advance,',
#   'may',
#   'still',
#   'possible',
#   'decide',
#   'whether',
#   'antiderivative',
#   'given',
#   'function',
#   'expressed',
#   'using',
#   'operations',
#   'multiplication',
#   'find',
#   'symbolic',
#   'answer',
#   'whenever',
#   'exists.',
#   'risch',
#   'implemented',
#   'maple',
#   'computer',
#   'algebra',
#   'systems',
#   'functions',
#   'antiderivatives',
#   'built',
#   'rational',
#   'functions,',
#   'logarithm,',
#   'exponential',
#   'functions.',
#   'special',
#   'integrands',
#   'occur',
#   'often',
#   'enough',
#   'warrant',
#   'special',
#   'particular,',
#   'may',
#   'useful',
#   'have,',
#   'set',
#   'special',
#   'functions',
#   'functions',
#   'hypergeometric',
#   'function',
#   'gamma',
#   'function',
#   'incomplete',
#   'gamma',
#   'function',
#   '—',
#   'see',
#   'symbolic',
#   'integration',
#   'extending',
#   'algorithm',
#   'include',
#   'functions',
#   'possible',
#   'active',
#   'research',
#   'subject.',
#   'recently',
#   'new',
#   'approach',
#   'using',
#   '-finite',
#   'functions',
#   'linear',
#   'differential',
#   'equations',
#   'polynomial',
#   'elementary',
#   'special',
#   'functions',
#   'integral',
#   '-finite',
#   'function',
#   'also',
#   '-finite',
#   'function.',
#   'provides',
#   'algorithm',
#   'express',
#   'antiderivative',
#   '-finite',
#   'function',
#   'solution',
#   'differential',
#   'theory',
#   'also',
#   'allows',
#   'one',
#   'compute',
#   'definite',
#   'integral',
#   'sum',
#   'series',
#   'given',
#   'first',
#   'provides',
#   'algorithm',
#   'compute',
#   'integrals',
#   'found',
#   'real',
#   'applications',
#   'computed',
#   'others',
#   'antiderivatives',
#   'closed',
#   'forms,',
#   'closed',
#   'forms',
#   'require',
#   'special',
#   'functions',
#   'others',
#   'complex',
#   'finding',
#   'exact',
#   'answer',
#   'motivates',
#   'study',
#   'numerical',
#   'approximations',
#   'integrals.',
#   'called',
#   'numerical',
#   'integration',
#   'numerical',
#   'quadrature',
#   'arose',
#   'early',
#   'study',
#   'integration',
#   'purpose',
#   'making',
#   'hand',
#   'development',
#   'made',
#   'numerical',
#   'integration',
#   'practical',
#   'desire',
#   'goals',
#   'numerical',
#   'integration',
#   'generality,',
#   'sophisticated',
#   'modern',
#   'methods',
#   'method',
#   'four',
#   'measures.',
#   '[41]',
#   'example,',
#   'integral',
#   'exact',
#   'answer',
#   '3.76',
#   '(in',
#   'ordinary',
#   'practice,',
#   'answer',
#   'known',
#   'advance,',
#   'important',
#   '—',
#   'explored',
#   '—',
#   'decide',
#   'approximation',
#   'good',
#   'approach',
#   'divides',
#   'integration',
#   'range',
#   'say,',
#   '16',
#   'equal',
#   'pieces,',
#   'function',
#   'using',
#   'left',
#   'end',
#   'piece,',
#   'rectangle',
#   'method',
#   'sums',
#   '16',
#   'function',
#   'values',
#   'multiplies',
#   'step',
#   'width,',
#   'h',
#   'get',
#   'approximate',
#   'value',
#   'integral.',
#   'accuracy',
#   'calculus',
#   'formally',
#   'uses',
#   'pieces',
#   'infinitesimal',
#   'width,',
#   'initially',
#   'may',
#   'seem',
#   'little',
#   'cause',
#   'indeed,',
#   'repeatedly',
#   'doubling',
#   'number',
#   'steps',
#   'eventually',
#   'produces',
#   'approximation',
#   'however,',
#   '2',
#   '18',
#   'pieces',
#   'great',
#   'little',
#   'reach',
#   'greater',
#   'accuracy',
#   'force',
#   'steps',
#   'small',
#   'arithmetic',
#   'precision',
#   'becomes',
#   'better',
#   'approach',
#   'rectangles',
#   'used',
#   'riemann',
#   'sum',
#   'trapezoid',
#   'rule',
#   'sums',
#   '17',
#   'function',
#   'values,',
#   'first',
#   'last',
#   'one',
#   'multiplies',
#   'step',
#   'width.',
#   'immediately',
#   'approximation',
#   'noticeably',
#   'furthermore,',
#   '2',
#   '10',
#   'pieces',
#   'needed',
#   'achieve',
#   'less',
#   'computation',
#   'rectangle',
#   'method',
#   'accuracy.',
#   'idea',
#   'behind',
#   'trapezoid',
#   'rule,',
#   'accurate',
#   'approximations',
#   'function',
#   'yield',
#   'better',
#   'approximations',
#   'integral,',
#   'carried',
#   "simpson's",
#   'rule',
#   'approximates',
#   'integrand',
#   'piecewise',
#   'quadratic',
#   'function.',
#   'riemann',
#   'sums,',
#   'trapezoid',
#   'rule,',
#   "simpson's",
#   'rule',
#   'examples',
#   'family',
#   'quadrature',
#   'rules',
#   'called',
#   'newton–cotes',
#   'formulas',
#   'degree',
#   'n',
#   'newton–cotes',
#   'quadrature',
#   'rule',
#   'approximates',
#   'polynomial',
#   'subinterval',
#   'degree',
#   'n',
#   'polynomial',
#   'chosen',
#   'interpolate',
#   'values',
#   'function',
#   'interval.',
#   'higher',
#   'degree',
#   'approximations',
#   'require',
#   'function',
#   'evaluations',
#   "simpson's",
#   'rule',
#   'requires',
#   'twice',
#   'function',
#   'evaluations',
#   'trapezoid',
#   'numerical',
#   'due',
#   'one',
#   'solution',
#   'problem',
#   'quadrature',
#   'integrand',
#   'approximated',
#   'terms',
#   'polynomials',
#   'produces',
#   'approximation',
#   'whose',
#   'values',
#   'never',
#   'far',
#   'original',
#   'function.',
#   'method',
#   'trapezoid',
#   'method',
#   'great',
#   'effect.',
#   'first,',
#   'step',
#   'lengths',
#   'giving',
#   'trapezoid',
#   'approximations',
#   'denoted',
#   'h',
#   '0',
#   '),',
#   'h',
#   '1',
#   'on,',
#   'h',
#   'k',
#   '+1',
#   'half',
#   'h',
#   'k',
#   'new',
#   'step',
#   'half',
#   'new',
#   'function',
#   'values',
#   'need',
#   'others',
#   'carry',
#   'previous',
#   'size',
#   '(as',
#   'shown',
#   'table',
#   'really',
#   'powerful',
#   'idea',
#   'interpolate',
#   'polynomial',
#   'approximations,',
#   '(0)',
#   'method',
#   'numerically',
#   'exact',
#   'answer',
#   'requires',
#   'four',
#   'pieces',
#   'function',
#   'lagrange',
#   'polynomial',
#   'h',
#   'k',
#   'h',
#   'k',
#   ')}',
#   'k',
#   '3.76',
#   'h',
#   '2',
#   'producing',
#   'value',
#   '3.76',
#   'h',
#   '0',
#   'gaussian',
#   'quadrature',
#   'often',
#   'requires',
#   'noticeably',
#   'less',
#   'work',
#   'superior',
#   'accuracy.',
#   'example,',
#   'compute',
#   'function',
#   'values',
#   'two',
#   'x',
#   '⁄',
#   '√',
#   '3',
#   'double',
#   'value',
#   'sum',
#   'get',
#   'numerically',
#   'exact',
#   'dramatic',
#   'success',
#   'lies',
#   'choice',
#   'points.',
#   'unlike',
#   'newton–cotes',
#   'interpolate',
#   'integrand',
#   'points,',
#   'gaussian',
#   'quadrature',
#   'function',
#   'roots',
#   'set',
#   'polynomials',
#   'n',
#   'gaussian',
#   'method',
#   'exact',
#   'polynomials',
#   'degree',
#   '2',
#   'n',
#   '−',
#   '1',
#   'function',
#   'example',
#   'degree',
#   '3',
#   'plus',
#   'term',
#   'chosen',
#   'around',
#   'zero.',
#   'also',
#   'benefits',
#   'practice,',
#   'method',
#   'must',
#   'use',
#   'evaluations',
#   'ensure',
#   'error',
#   'bound',
#   'unknown',
#   'tends',
#   'advantage',
#   'pure',
#   'gaussian',
#   'method,',
#   'motivates',
#   'popular',
#   'quadrature',
#   'formulae',
#   'adaptive',
#   'quadrature',
#   'partitions',
#   'range',
#   'pieces',
#   'based',
#   'function',
#   'data',
#   'points',
#   'concentrated',
#   'needed',
#   'computation',
#   'higher-dimensional',
#   'integrals',
#   '(for',
#   'example,',
#   'volume',
#   'makes',
#   'important',
#   'use',
#   'monte',
#   'carlo',
#   'integration',
#   'calculus',
#   'text',
#   'substitute',
#   'numerical',
#   'reverse',
#   'also',
#   'true.',
#   'even',
#   'best',
#   'adaptive',
#   'numerical',
#   'code',
# ...
#   'extending',
#   'almost',
#   'lines',
#   'old',
#   'english',
#   'beowulf',
#   'modern',
#   'english.',
#   'though',
#   'inspired',
#   'high',
#   'medieval',
#   'arthurian',
#   'fiction,',
#   'historical',
#   'setting',
#   'poem',
#   'period',
#   'form',
#   'germanic',
#   'verse',
#   'content,',
#   'showing',
#   'arthur',
#   'british',
#   'saxon',
#   'avoids',
#   'high',
#   'medieval',
#   'aspects',
#   'arthurian',
#   'cycle',
#   '(such',
#   'poem',
#   'begins',
#   'british',
#   'saxon',
#   'lands',
#   'arthur',
#   'eastward',
#   'arms',
#   ').',
#   '[175]',
#   'beowulf:',
#   'translation',
#   'commentary',
#   'published',
#   '22',
#   'may',
#   '2014,',
#   'prose',
#   'translation',
#   'early',
#   'medieval',
#   'epic',
#   'poem',
#   'beowulf',
#   'old',
#   'english',
#   'modern',
#   'english.',
#   'translated',
#   'tolkien',
#   '1920',
#   '1926,',
#   'edited',
#   'son',
#   'translation',
#   'followed',
#   '200',
#   'commentary',
#   'commentary',
#   'basis',
#   "tolkien's",
#   'acclaimed',
#   '1936',
#   'lecture',
#   'beowulf:',
#   'monsters',
#   'critics',
#   '".',
#   '[176]',
#   'book',
#   'also',
#   'includes',
#   'previously',
#   'unpublished',
#   'two',
#   'versions',
#   '"the',
#   'lay',
#   'former',
#   'fantasy',
#   'piece',
#   'biographical',
#   'latter',
#   'poem',
#   'beowulf',
#   '[177]',
#   'story',
#   'kullervo',
#   'first',
#   'published',
#   'tolkien',
#   'studies',
#   '2010',
#   'additional',
#   'material',
#   '2015,',
#   '19th-century',
#   'finnish',
#   'poem.',
#   'written',
#   '1915',
#   'tolkien',
#   'studying',
#   '[178]',
#   'tale',
#   'beren',
#   'lúthien',
#   'one',
#   'oldest',
#   'often',
#   'revised',
#   "tolkien's",
#   'story',
#   'one',
#   'three',
#   'contained',
#   'within',
#   'silmarillion',
#   'tolkien',
#   'believed',
#   'warrant',
#   'published',
#   'standalone',
#   'book,',
#   'edited',
#   'christopher',
#   'tolkien,',
#   'title',
#   'beren',
#   'lúthien',
#   '[179]',
#   'fall',
#   'gondolin',
#   'tale',
#   'mysterious',
#   'city',
#   'destroyed',
#   'dark',
#   'tolkien',
#   'called',
#   '"the',
#   'first',
#   'real',
#   'middle-earth',
#   'published',
#   '30',
#   'august',
#   '[180]',
#   'standalone',
#   'book,',
#   'edited',
#   'christopher',
#   'tolkien',
#   'illustrated',
#   '[181]',
#   'death,',
#   'tolkien',
#   'manuscripts,',
#   'proofs',
#   'materials',
#   'related',
#   'lord',
#   'rings',
#   'hobbit',
#   'farmer',
#   'giles',
#   'ham',
#   '—to',
#   'department',
#   'special',
#   'collections',
#   'university',
#   'archives',
#   'university',
#   "'s",
#   'john',
#   'library',
#   '[182]',
#   'death',
#   'estate',
#   'papers',
#   "tolkien's",
#   'silmarillion',
#   'mythology',
#   'academic',
#   'work',
#   'bodleian',
#   'library',
#   'oxford',
#   'university',
#   '[183]',
#   'library',
#   'held',
#   'exhibition',
#   'work',
#   'including',
#   'never',
#   'seen',
#   'public',
#   'before.',
#   '[184]',
#   'partial',
#   'draft',
#   'language',
#   'human',
#   'nature',
#   'tolkien',
#   'begun',
#   'c.',
#   's.',
#   'lewis',
#   'never',
#   'discovered',
#   'bodleian',
#   'library.',
#   '[185]',
#   "tolkien's",
#   'academic',
#   'career',
#   'literary',
#   'production',
#   'inseparable',
#   'love',
#   'language',
#   'philology',
#   'specialized',
#   'english',
#   'philology',
#   'university',
#   '1915',
#   'old',
#   'norse',
#   'special',
#   'subject.',
#   'worked',
#   'oxford',
#   'english',
#   'dictionary',
#   '1918',
#   'worked',
#   'number',
#   'words',
#   'starting',
#   'letter',
#   'including',
#   'struggled',
#   '[186]',
#   '1920,',
#   'became',
#   'reader',
#   'english',
#   'language',
#   'university',
#   'leeds',
#   'claimed',
#   'number',
#   'students',
#   'five',
#   'gave',
#   'old',
#   'english',
#   'verse',
#   'history',
#   'english',
#   'various',
#   'old',
#   'english',
#   'middle',
#   'english',
#   'old',
#   'middle',
#   'english',
#   'philology,',
#   'introductory',
#   'germanic',
#   'philology,',
#   'gothic',
#   'old',
#   'medieval',
#   'welsh',
#   '1925,',
#   'aged',
#   'tolkien',
#   'applied',
#   'rawlinson',
#   'bosworth',
#   'anglo-saxon',
#   'pembroke',
#   'college,',
#   'oxford',
#   'students',
#   'germanic',
#   'philology',
#   'leeds',
#   'even',
#   'formed',
#   'club',
#   '".',
#   '[187]',
#   'also',
#   'knowledge',
#   'finnish',
#   '[188]',
#   'privately,',
#   'tolkien',
#   'attracted',
#   'linguistic',
#   'lecture',
#   'english',
#   'welsh',
#   'crucial',
#   'understanding',
#   'race',
#   'language,',
#   'entertained',
#   'notions',
#   'linguistic',
#   'termed',
#   '"native',
#   'opposed',
#   'person',
#   'first',
#   '[189]',
#   'considered',
#   'west',
#   'middle',
#   'english',
#   '"native',
#   'and,',
#   'wrote',
#   'w.',
#   'h.',
#   'auden',
#   '1955,',
#   '"i',
#   'blood',
#   'took',
#   'early',
#   'middle',
#   'english',
#   'known',
#   'tongue',
#   'soon',
#   'set',
#   'eyes',
#   '[190]',
#   'parallel',
#   "tolkien's",
#   'work',
#   'sometimes',
#   'work,',
#   'effect',
#   'academic',
#   'output',
#   'remained',
#   'rather',
#   'affection',
#   'languages',
#   'developed',
#   'quenya',
#   'connection',
#   'formed',
#   'core',
#   'much',
#   "tolkien's",
#   'legendarium',
#   'language',
#   'tolkien',
#   'matter',
#   'aesthetics',
#   'quenya',
#   'particular',
#   'designed',
#   'intended',
#   'based',
#   'latin,',
#   'welsh,',
#   'english,',
#   '[157]',
#   'notable',
#   'addition',
#   'came',
#   'late',
#   '1945',
#   'language',
#   'connected',
#   "tolkien's",
#   'atlantis',
#   'notion',
#   'club',
#   'papers',
#   'directly',
#   'ideas',
#   'inability',
#   'language',
#   'via',
#   'second',
#   'age',
#   'story',
#   'legendarium',
#   'link',
#   "tolkien's",
#   '20th-century',
#   'primary',
#   'past',
#   'middle-earth.',
#   'tolkien',
#   'considered',
#   'languages',
#   'inseparable',
#   'mythology',
#   'associated',
#   'them,',
#   'took',
#   'view',
#   'auxiliary',
#   'languages',
#   '1930',
#   'told',
#   'much',
#   'him,',
#   'lecture',
#   'secret',
#   'vice',
#   '[191]',
#   'language',
#   'construction',
#   'mythology",',
#   '1956',
#   'concluded',
#   'esperanto',
#   '&amp;c,',
#   '&amp;c,',
#   'far',
#   'ancient',
#   'languages,',
#   'authors',
#   'never',
#   'invented',
#   'esperanto',
#   '[192]',
#   'popularity',
#   "tolkien's",
#   'books',
#   'small',
#   'lasting',
#   'effect',
#   'use',
#   'language',
#   'fantasy',
#   'literature',
#   'particular,',
#   'even',
#   'today',
#   'commonly',
#   'accept',
#   "tolkien's",
#   'dwarves',
#   '),',
#   'little',
#   'used',
#   'since',
#   'century',
#   '(in',
#   'fact,',
#   'according',
#   'tolkien,',
#   'old',
#   'english',
#   'would',
#   '.)',
#   'also',
#   'coined',
#   'term',
#   'though',
#   'remains',
#   'mainly',
#   'used',
#   'connection',
#   'work.',
#   'tolkien',
#   'accomplished',
#   'artist,',
#   'learned',
#   'paint',
#   'draw',
#   'child',
#   'continued',
#   'life.',
#   '[193]',
#   'early',
#   'writing',
#   'development',
#   'stories',
#   'accompanied',
#   'drawings',
#   'paintings,',
#   'especially',
#   'landscapes,',
#   'maps',
#   'lands',
#   'tales',
#   'also',
#   'produced',
#   'pictures',
#   'stories',
#   'told',
#   'children,',
#   'including',
#   'later',
#   'published',
#   'mr',
#   'bliss',
#   'roverandom',
#   'sent',
#   'illustrated',
#   'letters',
#   'come',
#   'father',
#   'christmas.',
#   'although',
#   'regarded',
#   'publisher',
#   'used',
#   "author's",
#   'cover',
#   'art,',
#   'maps',
#   'illustrations',
#   'early',
#   'editions',
#   'hobbit',
#   'prepared',
#   'maps',
#   'illustrations',
#   'lord',
#   'rings',
#   'first',
#   'edition',
#   'contained',
#   'inscription',
#   'one',
#   'drawing',
#   'much',
#   'artwork',
#   'collected',
#   'published',
#   '1995',
#   'j.',
#   'r.',
#   'r.',
#   'tolkien:',
#   'artist',
#   'illustrator',
#   'book',
#   'discusses',
#   "tolkien's",
#   'paintings,',
#   'drawings,',
#   'sketches,',
#   'approximately',
#   '200',
#   'examples',
#   'work.',
#   '[194]',
#   'catherine',
#   'major',
#   'exhibition',
#   "tolkien's",
#   'artwork',
#   'bodleian',
#   'library',
#   'tolkien:',
#   'middle-earth',
#   'accompanied',
#   'book',
#   'name',
#   'analyses',
#   "tolkien's",
#   'full',
#   'range',
#   'types',
#   'artwork',
#   '[195]',
#   '1951',
#   'letter',
#   'publisher',
#   'milton',
#   'waldman',
#   'tolkien',
#   'wrote',
#   'create',
#   'less',
#   'connected',
#   'linked',
#   'yet',
#   'leave',
#   'scope',
#   'minds',
#   'paint',
#   'music',
#   '[196]',
#   'hands',
#   'minds',
#   'many',
#   'artists',
#   'inspired',
#   "tolkien's",
#   'legends.',
#   'personally',
#   'known',
#   'favourite',
#   'illustrator',
#   'adventures',
#   'tom',
#   'bombadil',
#   'farmer',
#   'giles',
#   'ham',
#   'donald',
#   'set',
#   'music',
#   'road',
#   'goes',
#   'ever',
#   ').',
#   'queen',
#   'ii',
#   'created',
#   'illustrations',
#   'lord',
#   'rings',
#   'early',
#   '1970s.',
#   'sent',
#   'tolkien,',
#   'struck',
#   'similarity',
#   'bore',
#   'style',
#   'drawings.',
#   '[197]',
#   'tolkien',
#   'scholar',
#   'james',
#   'coined',
#   'word',
#   'derived',
#   '"tolkien',
#   'describe',
#   'attempts',
#   'create',
#   'adaptation',
#   'stories',
#   "tolkien's",
#   'legendarium',
#   'good',
#   'box',
#   'office',
#   'rather',
#   'idea',
#   '[198]',
#   'tolkien',
#   'opposed',
#   'idea',
#   'dramatic',
#   'however,',
#   'sold',
#   'film,',
#   'stage',
#   'rights',
#   'hobbit',
#   'lord',
#   'rings',
#   'united',
#   'artists',
#   'united',
#   'artists',
#   'never',
#   'made',
#   'film,',
#   'although',
#   'director',
#   'john',
#   'planning',
#   'live-action',
#   'film',
#   'early',
#   '1970s.',
#   'rights',
#   'sold',
#   'tolkien',
#   'division',
#   'company,',
#   'first',
#   'film',
#   'adaptation',
#   'lord',
#   'rings',
#   'released',
#   'animated',
#   'film',
#   'directed',
#   'ralph',
#   'bakshi',
#   'fantasy',
#   'writer',
#   'peter',
#   's.',
#   'covered',
#   'first',
#   'half',
#   'story',
#   'lord',
#   'rings',
#   '[199]',
#   'animated',
#   'musical',
#   'television',
#   'film',
#   'hobbit',
#   'made',
#   '1980,',
#   'produced',
#   'animated',
#   'musical',
#   'television',
#   'film',
#   'return',
#   'king',
#   'covered',
#   'portions',
#   'lord',
#   'rings',
#   'bakshi',
#   'unable',
#   'complete.',
#   '2003,',
#   'new',
#   'line',
#   'cinema',
#   'released',
#   'lord',
#   'rings',
#   'live-action',
#   'films',
#   'filmed',
#   'new',
#   'zealand',
#   'directed',
#   'peter',
#   'jackson',
#   'series',
#   'successful,',
#   'extremely',
#   'well',
#   'commercially',
#   'numerous',
#   'oscars',
#   '[200]',
#   '2012',
#   '2014,',
#   'new',
#   'line',
#   'cinema',
#   'released',
#   'hobbit',
#   'series',
#   'three',
#   'films',
#   'based',
#   'hobbit',
#   'peter',
#   'jackson',
#   '[201]',
#   'first',
#   'instalment,',
#   'hobbit:',
#   'unexpected',
#   'journey',
#   'released',
#   'december',
#   '[202]',
#   'second,',
#   'hobbit:',
#   'december',
#   '[203]',
#   'last',
#   'instalment,',
#   'hobbit:',
#   'battle',
#   'five',
#   'december',
#   '[204]',
#   'biographical',
#   'film',
#   'tolkien',
#   'released',
#   '10',
#   'may',
#   'focused',
#   "tolkien's",
#   'early',
#   'life',
#   'war',
#   '[205]',
#   'tolkien',
#   'family',
#   'estate',
#   'stated',
#   'participate',
#   'making',
#   'film.',
#   '[206]',
#   '2017,',
#   'amazon',
#   'acquired',
#   'television',
#   'rights',
#   'lord',
#   'rings',
#   'series',
#   'introduce',
#   'new',
#   'stories',
#   'set',
#   'fellowship',
#   'ring.',
#   '[207]',
#   'press',
#   'release',
#   'referred',
#   'stories',
#   'based',
#   'j.',
#   'r.',
#   'r.',
#   "tolkien's",
#   'original',
#   'amazon',
#   'tolkien',
#   'estate',
#   'tolkien',
#   'trust',
#   'harpercollins',
#   'new',
#   'line',
#   'cinema',
#   '[208]',
#   'tolkien',
#   'characters',
#   'places',
#   'works',
#   'become',
#   'various',
#   'things',
#   'around',
#   'world.',
#   'include',
#   'street',
#   'names,',
#   'species',
#   'well',
#   'notable',
#   'objects.',
#   'convention,',
#   'certain',
#   'classes',
#   'features',
#   'named',
#   'elements',
#   'middle-earth.',
#   '[209]',
#   'hills',
#   'named',
#   'characters,',
#   '[210]',
#   'named',
#   'mountains',
#   'middle-earth.',
#   '[211]',
#   'also',
#   'named',
#   'bilbo',
#   'baggins',
#   'tolkien',
#   'himself.',
#   '[212]',
#   '[213]',
#   'three',
#   'mountains',
#   'range',
#   'british',
#   'columbia',
#   'named',
#   "tolkien's",
#   'characters.',
#   'mount',
#   'mount',
#   'gandalf',
#   'mount',
#   '[214]',
#   '[215]',
#   'nearby',
#   'tolkien',
#   'peak',
#   'named',
#   'him.',
#   '[216]',
#   '1',
#   'december',
#   '2012,',
#   'announced',
#   'new',
#   'zealand',
#   'press',
#   'new',
#   'zealand',
#   'board',
#   'name',
#   'peak',
#   'near',
#   'tolkien',
#   'historical',
#   'literary',
#   'reasons',
#   'mark',
#   "tolkien's",
#   'birthday.',
#   '[217]',
#   '"tolkien',
#   'east',
#   'named',
#   'tolkien',
#   'whereas',
#   '"tolkien',
#   'named',
#   "tolkien's",
#   'son,',
#   'john',
#   'francis',
#   'tolkien,',
#   'priest',
#   'charge',
#   'nearby',
#   'roman',
#   'catholic',
#   'church',
#   'lady',
#   'angels',
#   'st.',
#   'peter',
#   '[218]',
#   'hall',
#   'green',
#   'moseley',
#   'areas',
#   'birmingham',
#   'number',
#   'parks',
#   'dedicated',
#   'j.',
#   'r.',
#   'r.',
#   'way',
#   'moseley',
#   'bog',
#   '[219]',
#   'parks',
#   'known',
#   'shire',
#   'country',
#   '[219]',
#   'also',
#   'england',
#   'collection',
#   'named',
#   'middle',
#   'earth,',
#   'namely',
#   'road,',
#   'close,',
#   'close,',
#   'way',
#   'green.',
#   'dutch',
#   'town',
#   'near',
#   'entire',
#   'new',
#   'neighbourhood',
#   'named',
#   'tolkien',
#   'van',
#   'characters',
#   'books.',
#   '[220]',
#   'valley',
#   'towns',
#   'san',
#   'california,',
#   'two',
#   'developments',
#   'street',
#   'names',
#   'drawn',
#   "tolkien's",
#   'works.',
#   'dozen',
#   'street',
#   'names',
#   'also',
#   'appear',
#   'throughout',
#   'town',
#   'lake',
#   'california',
#   'columbia',
#   'neighbourhood',
#   'street',
#   'names',
#   '(including',
#   'way,',
#   'come',
#   "tolkien's",
#   'works.',
#   '[221]',
#   'field',
#   '80',
#   'taxa',
#   'given',
#   'scientific',
#   'names',
#   'deriving',
#   'characters',
#   'fictional',
#   'elements',
#   'lord',
#   'rings',
#   'hobbit',
#   'works',
#   'set',
#   'middle-earth',
#   '[222]',
#   'several',
#   'taxa',
#   'named',
#   'character',
#   '(also',
#   'known',
#   'well',
#   'various',
#   'small',
#   'creatures',
#   'bilbo',
#   'frodo',
#   'baggins',
#   'various',
#   'elves',
#   'dwarves',
#   'creatures',
#   'appear',
#   'writings,',
#   'well',
#   'tolkien',
#   'himself,',
#   'honoured',
#   'names',
#   'several',
#   'including',
#   'tolkieni',
#   'tolkieni',
#   '2004,',
#   'extinct',
#   'quickly',
#   'earned',
#   'due',
#   'small',
#   '[223]',
#   'van',
#   'named',
#   '20',
#   'taxa',
#   'extinct',
#   'tolkien',
#   'single',
#   'paper.',
#   '[224]',
#   '[225]',
#   '1999,',
#   'described',
#   'new',
#   'species',
#   'named',
#   '37',
#   'tolkien',
#   'mythology.',
#   '[222]',
#   '[226]',
#   'noted',
#   '"tolkien',
#   'formal',
#   'like',
#   '[227]',
#   'since',
#   '2003,',
#   'tolkien',
#   'society',
#   'organized',
#   'tolkien',
#   'reading',
#   'day',
#   'takes',
#   'place',
#   '25',
#   'march',
#   'schools',
#   'around',
#   'world.',
#   '[228]',
#   '2013,',
#   'pembroke',
#   'college,',
#   'oxford',
#   'university',
#   'established',
#   'annual',
#   'lecture',
#   'fantasy',
#   'literature',
#   "tolkien's",
#   '[229]',
#   'seven',
#   'blue',
#   'plaques',
#   'england',
#   'commemorate',
#   'places',
#   'associated',
#   'tolkien:',
#   'one',
#   'oxford,',
#   'one',
#   'bournemouth,',
#   'four',
#   'birmingham',
#   'one',
#   'one',
#   'birmingham',
#   'plaques',
#   'commemorates',
#   'inspiration',
#   'provided',
#   'sarehole',
#   'near',
#   'lived',
#   'four',
#   'two',
#   'mark',
#   'childhood',
#   'time',
#   'left',
#   'attend',
#   'oxford',
#   'university',
#   'marks',
#   'hotel',
#   'stayed',
#   'leaving',
#   'france',
#   'world',
#   'war',
#   'plaque',
#   'west',
#   'leeds,',
#   'commemorates',
#   'five',
#   'years',
#   'tolkien',
#   'enjoyed',
#   'leeds',
#   'reader',
#   'professor',
#   'english',
#   'language',
#   'oxford',
#   'plaque',
#   'commemorates',
#   'tolkien',
#   'wrote',
#   'hobbit',
#   'lord',
#   'rings',
#   'another',
#   'two',
#   'plaques',
#   'associated',
#   'tolkien',
#   '2012,',
#   'tolkien',
#   'among',
#   'british',
#   'cultural',
#   'selected',
#   'artist',
#   'sir',
#   'peter',
#   'appear',
#   'new',
#   'version',
#   'famous',
#   'lonely',
#   'club',
#   'album',
#   'celebrate',
#   'british',
#   'cultural',
#   'figures',
#   'life',
#   '[238]',
#   '[239]',
#   'unlike',
#   'authors',
#   'tolkien',
#   'never',
#   'works.',
#   'owing',
#   'copies',
#   'letters',
#   'first',
#   'editions',
#   'individual',
#   'writings',
#   'however',
#   'achieved',
#   'high',
#   'values',
#   'may',
#   'occur',
#   'example,',
#   'signed',
#   'first',
#   'edition',
#   'hobbit',
#   'offered',
#   'also',
#   'include',
#   'non-fiction',
#   'books',
#   "tolkien's",
#   'private',
#   'library.',
#   '[240]',
#   '2',
#   'september',
#   '2017,',
#   'oxford',
#   'oratory',
#   "tolkien's",
#   'church',
#   'time',
#   'oxford,',
#   'offered',
#   'first',
#   'mass',
#   'intention',
#   "tolkien's",
#   'cause',
#   '[241]',
#   '[242]',
#   'prayer',
#   'written',
#   '[241]',
#   'small',
#   'selection',
#   'books',
#   'tolkien']]

# %% [markdown]
# # Zad
#
# Proszę
# * utworzyć reprezentację **bag-of-words**

# %%
from gensim import corpora, models, similarities, matutils
dictionary = corpora.Dictionary(texts)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
print(corpus)
# Out:
# [[(0, 2), (1, 2), (2, 1), (3, 1), (4, 1), (5, 4), (6, 3), (7, 1), (8, 2), (9, 1), (10, 1), (11, 2), (12, 1), (13, 1), (14, 1), (15, 2), (16, 3), (17, 1), (18, 2), (19, 2), (20, 1), (21, 2), (22, 3), (23, 1), (24, 1), (25, 4), (26, 3), (27, 1), (28, 1), (29, 2), (30, 5), (31, 1), (32, 4), (33, 2), (34, 1), (35, 10), (36, 1), (37, 21), (38, 3), (39, 3), (40, 1), (41, 1), (42, 2), (43, 1), (44, 4), (45, 1), (46, 2), (47, 1), (48, 1), (49, 18), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1), (55, 4), (56, 3), (57, 2), (58, 3), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 7), (65, 6), (66, 1), (67, 5), (68, 1), (69, 1), (70, 1), (71, 1), (72, 1), (73, 1), (74, 2), (75, 1), (76, 2), (77, 1), (78, 1), (79, 2), (80, 1), (81, 1), (82, 1), (83, 1), (84, 2), (85, 2), (86, 1), (87, 1), (88, 1), (89, 1), (90, 1), (91, 1), (92, 1), (93, 2), (94, 1), (95, 1), (96, 1), (97, 1), (98, 1), (99, 2), (100, 1), (101, 3), (102, 5), (103, 2), (104, 5), (105, 1), (106, 3), (107, 13), (108, 3), (109, 2), (110, 2), (111, 1), (112, 1), (113, 4), (114, 1), (115, 2), (116, 3), (117, 5), (118, 13), (119, 2), (120, 7), (121, 2), (122, 4), (123, 1), (124, 1), (125, 5), (126, 3), (127, 2), (128, 1), (129, 3), (130, 11), (131, 2), (132, 6), (133, 1), (134, 1), (135, 2), (136, 2), (137, 1), (138, 1), (139, 25), (140, 1), (141, 2), (142, 8), (143, 2), (144, 1), (145, 1), (146, 4), (147, 1), (148, 3), (149, 2), (150, 1), (151, 1), (152, 1), (153, 1), (154, 1), (155, 1), (156, 2), (157, 1), (158, 1), (159, 3), (160, 47), (161, 1), (162, 2), (163, 2), (164, 5), (165, 3), (166, 1), (167, 1), (168, 2), (169, 2), (170, 1), (171, 2), (172, 1), (173, 1), (174, 1), (175, 1), (176, 1), (177, 4), (178, 2), (179, 2), (180, 2), (181, 1), (182, 5), (183, 2), (184, 2), (185, 2), (186, 2), (187, 1), (188, 1), (189, 3), (190, 10), (191, 2), (192, 3), (193, 6), (194, 2), (195, 1), (196, 19), (197, 8), (198, 1), (199, 2), (200, 16), (201, 1), (202, 1), (203, 1), (204, 1), (205, 1), (206, 1), (207, 1), (208,
#
# Wypisz z czego składają się tematy:

# %%
import numpy as np

topic_inex = 0
print(model.print_topic(topicno=topic_inex))

topic_inex = 1
print(model.print_topic(topicno=topic_inex))
# Out:
# 0.009*"van" + 0.008*"x" + 0.006*"gogh" + 0.006*"kafka" + 0.006*"f" + 0.005*"n" + 0.004*"first" + 0.004*"kafka's" + 0.004*"tolkien" + 0.004*"function"
# 0.011*"x" + 0.010*"f" + 0.009*"function" + 0.007*"integral" + 0.006*"tolkien" + 0.005*"{\displaystyle" + 0.005*"van" + 0.004*"munch" + 0.004*"derivative" + 0.004*"1"

# %% [markdown]
# # Zad
#
# Proszę posortować zdania najbardziej pasujące do danego tematu.

# %%
import gensim

top_inex = 0

numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort(numpy_corpus[top_inex,:])[::-1]
for x in docs[:5]:
    print(corpus[x])
    
#trzeba by wypisać raczej zdania niż ich reprezentacje bag-of-words, ale tu nie mam dostepu do tekstu
# Out:
# [(0, 2), (2, 2), (3, 1), (4, 1), (5, 1), (21, 1), (23, 1), (25, 3), (26, 1), (27, 1), (37, 2), (41, 3), (43, 3), (45, 1), (49, 2), (58, 1), (62, 1), (63, 1), (69, 1), (70, 1), (71, 1), (72, 5), (78, 1), (79, 4), (82, 6), (83, 7), (89, 3), (95, 1), (96, 1), (103, 1), (105, 3), (106, 1), (107, 13), (109, 3), (115, 5), (116, 3), (121, 2), (125, 2), (140, 2), (145, 1), (146, 9), (157, 1), (161, 5), (164, 3), (166, 2), (167, 20), (169, 12), (171, 1), (173, 2), (176, 6), (179, 1), (186, 1), (191, 1), (200, 2), (203, 6), (204, 1), (205, 2), (208, 2), (209, 1), (217, 1), (227, 1), (229, 1), (231, 1), (232, 1), (233, 1), (237, 1), (238, 7), (243, 2), (248, 1), (249, 11), (252, 1), (261, 1), (271, 2), (274, 1), (275, 1), (281, 8), (282, 1), (283, 6), (285, 1), (294, 13), (304, 1), (308, 3), (310, 1), (319, 1), (320, 5), (323, 2), (327, 2), (332, 2), (341, 1), (349, 1), (350, 2), (357, 1), (364, 1), (365, 1), (369, 16), (373, 3), (374, 1), (376, 1), (378, 1), (381, 1), (383, 3), (386, 1), (388, 1), (390, 1), (398, 3), (405, 2), (406, 1), (407, 2), (408, 1), (409, 1), (410, 1), (411, 1), (418, 1), (423, 1), (424, 2), (426, 1), (431, 1), (441, 9), (442, 2), (443, 11), (445, 11), (447, 4), (448, 1), (449, 1), (453, 20), (454, 1), (456, 1), (458, 2), (463, 6), (467, 2), (469, 1), (476, 3), (477, 1), (479, 1), (484, 3), (486, 1), (500, 11), (501, 1), (513, 2), (514, 1), (516, 1), (519, 2), (520, 4), (525, 3), (530, 3), (532, 1), (535, 2), (536, 2), (539, 3), (544, 1), (545, 1), (549, 2), (550, 1), (551, 1), (555, 1), (556, 4), (558, 8), (560, 15), (584, 1), (585, 1), (610, 1), (617, 5), (622, 1), (626, 1), (629, 4), (632, 3), (633, 1), (634, 1), (635, 6), (636, 2), (638, 1), (639, 1), (640, 9), (641, 5), (642, 15), (645, 4), (650, 16), (655, 5), (656, 3), (
numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort( numpy_corpus[top_inex,:] )[::-1]
print("------------------------------")
for x in docs:
    print(titles[x])
    print("------------------------------")
# Out:
# ------------------------------
# Vincent_van_Gogh
# ------------------------------
# Franz_Kafka
# ------------------------------
# Lev_Tolstoj
# ------------------------------
# J._R._R._Tolkien
# ------------------------------
# Limit_of_a_sequence
# ------------------------------
# Edvard_Munch
# ------------------------------
# Jan_Matejko
# ------------------------------
# Derivative
# ------------------------------
# Riemann-Stieltjes_integral
# ------------------------------
# Riemann_integral
# ------------------------------
# Integral
# ------------------------------

# %%
top_inex = 1

numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort( numpy_corpus[top_inex,:] )[::-1]
print("------------------------------")
for x in docs:
    print(titles[x])
    print("------------------------------")
# Out:
# ------------------------------
# Integral
# ------------------------------
# Derivative
# ------------------------------
# Riemann_integral
# ------------------------------
# Riemann-Stieltjes_integral
# ------------------------------
# Jan_Matejko
# ------------------------------
# Edvard_Munch
# ------------------------------
# Limit_of_a_sequence
# ------------------------------
# J._R._R._Tolkien
# ------------------------------
# Lev_Tolstoj
# ------------------------------
# Franz_Kafka
# ------------------------------
# Vincent_van_Gogh
# ------------------------------

# %% [markdown]
# # Zad.
# Sprawdzić do jakiego tematu pasuje nowy dokument i jakie są mu najbliższe

# %%
doc = "Machine Learning"

doc_rep = dictionary.doc2bow(doc.split(' '))
# print(doc_rep)
doc_assignments = model[doc_rep]
print(doc_assignments)
# Out:
# [(0, 0.5), (1, 0.5)]

# %%
index = similarities.MatrixSimilarity(corpus_lda)

sims = index[doc_assignments]
# print(list(enumerate(sims)))

sims = sorted(enumerate(sims), key=lambda item: -item[1])
print(sims)
# Out:
# [(8, 0.82882303), (10, 0.79924476), (4, 0.72984236), (5, 0.71507466), (0, 0.70710677), (1, 0.70710677), (2, 0.70710677), (3, 0.70710677), (6, 0.70710677), (7, 0.70710677), (9, 0.70710677)]

# %% [markdown]
# # Zad
# Wizualizacja modelu LDA:

# %%
import pyLDAvis.gensim

pyLDAvis.enable_notebook()

# %%
pyLDAvis.gensim.prepare(model, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=              x    y  topics  cluster       Freq
# topic
# 1      0.010229  0.0       1        1  62.548946
# 0     -0.010229  0.0       2        1  37.451054, topic_info=            Term        Freq       Total Category  logprob  loglift
# 4492       kafka  112.000000  112.000000  Default  30.0000  30.0000
# 2745         van  198.000000  198.000000  Default  29.0000  29.0000
# 2287        gogh  133.000000  133.000000  Default  28.0000  28.0000
# 4494     kafka's   64.000000   64.000000  Default  27.0000  27.0000
# 4356        brod   24.000000   24.000000  Default  26.0000  26.0000
# ...          ...         ...         ...      ...      ...      ...
# 588     integral   37.421501  182.277588   Topic2  -5.7664  -0.6012
# 2468       munch   30.528894  118.588913   Topic2  -5.9700  -0.3749
# 35             0   22.533049   61.435333   Topic2  -6.2737  -0.0209
# 160            b   23.499044   85.893433   Topic2  -6.2317  -0.3140
# 317   derivative   24.072763  111.297691   Topic2  -6.2076  -0.5490
#
# [181 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 4266      1  0.398306  "definitive
# 4266      2  0.796611  "definitive
# 4272      1  0.398090        ("the
# 4272      2  0.597135        ("the
# 35        1  0.634814            0
# ...     ...       ...          ...
# 1187      2  0.230651            ×
# 1447      1  0.720253            ε
# 1447      2  0.281074            ε
# 1194      1  0.777429            ′
# 1194      2  0.212026            ′
#
# [260 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1])
