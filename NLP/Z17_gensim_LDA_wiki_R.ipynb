# %%
from urllib import request
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# # Zad
# Zczytaj z wikipedi artykuły o tytułach
# ```python
# ["Integral", "Riemann_integral", "Riemann-Stieltjes_integral", "Derivative",
#     "Limit_of_a_sequence", "Edvard_Munch", "Vincent_van_Gogh", "Jan_Matejko",
#     "Lev_Tolstoj", "Franz_Kafka", "J._R._R._Tolkien"]
# ```
# i zapisz w tablicy zawartości tych podstron ($id="bodyContent"$)

# %%
wiki = "http://en.wikipedia.org/wiki/"
titles = ["Integral", "Riemann_integral", "Riemann-Stieltjes_integral", "Derivative",
    "Limit_of_a_sequence", "Edvard_Munch", "Vincent_van_Gogh", "Jan_Matejko",
    "Lev_Tolstoj", "Franz_Kafka", "J._R._R._Tolkien"]

# %%
def parse(url):        
    x = urlopen(url).read()
    x = BeautifulSoup(x).find("div",id="bodyContent").find_all("p")
    return(x)

articles = [parse(url) for url in [wiki+x for x in titles]]
articles = [" ".join([str(paragraph) for paragraph in article]) for article in articles]

articles[0][:200]
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\admin\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# '<p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, an <b>integral</b> assigns numbers to functions in a way that can describe displacement, area, volume, and other concepts that ar'

# %%
import re
articles = [re.sub("<.+?>"," ",a) for a in articles] # ew (str(a))

# %%
articles[0]
# Out:
# ' In  mathematics , an  integral  assigns numbers to functions in a way that can describe displacement, area, volume, and other concepts that arise by combining  infinitesimal  data. Integration is one of the two main operations of  calculus , with its inverse operation,  differentiation , being the other. Given a  function   f  of a  real   variable   x  and an  interval   [ a ,  b ]  of the  real line , the  definite integral \n   is defined informally as the signed  area  of the region in the  xy -plane that is bounded by the  graph  of  f , the  x -axis and the vertical lines   x  =  a   and   x  =  b  . The area above the  x -axis adds to the total and that below the  x -axis subtracts from the total.\n   The operation of integration, up to an additive constant, is the inverse of the operation of differentiation. For this reason, the term  integral  may also refer to the related notion of the  antiderivative , a function  F  whose derivative is the given function  f . In this case, it is called an indefinite integral and is written:\n   The integrals discussed in this article are those termed  definite integrals . It is the  fundamental theorem of calculus  that connects differentiation with the definite integral: if  f  is a continuous real-valued function defined on a  closed interval   [ a ,  b ] , then, once an antiderivative  F  of  f  is known, the definite integral of  f  over that interval is given by\n   The principles of integration were formulated independently by  Isaac Newton  and  Gottfried Wilhelm Leibniz  in the late 17th century, who thought of the integral as an infinite sum of rectangles of  infinitesimal  width.  Bernhard Riemann  gave a rigorous mathematical definition of integrals. It is based on a limiting procedure that approximates the area of a  curvilinear  region by breaking the region into thin vertical slabs. Beginning in the 19th century, more sophisticated notions of integrals began to appear, where the type of the function as well as the  domain  over which the integration is performed has been generalised. A  line integral  is defined for functions of two or more variables, and the interval of integration  [ a ,  b ]  is replaced by a  curve  connecting the two endpoints. In a  surface integral , the curve is replaced by a piece of a  surface  in  three-dimensional space .\n   The first documented systematic technique capable of determining integrals is the  method of exhaustion  of the  ancient Greek  astronomer  Eudoxus  ( ca.  370 BC), which sought to find areas and volumes by breaking them up into an infinite number of divisions for which the area or volume was known. This method was further developed and employed by  Archimedes  in the 3rd century BC and used to calculate areas for  parabolas  and an approximation to the  area of a circle .\n   A similar method was independently developed in China around the 3rd century AD by  Liu Hui , who used it to find the area of the circle. This method was later used in the 5th century by Chinese father-and-son mathematicians  Zu Chongzhi  and  Zu Geng  to find the volume of a sphere ( Shea 2007 ;  Katz 2004 , pp.\xa0125–126).\n   In the Middle East, Hasan Ibn al-Haytham, Latinized as  Alhazen  (c. \u2009965 \xa0– c. \u20091040 \xa0  CE  ) derived a formula for the sum of  fourth powers . He used the results to carry out what would now be called an integration of this function, where the formulae for the sums of integral squares and fourth powers allowed him to calculate the volume of a  paraboloid .  [1]  \n   The next significant advances in integral calculus did not begin to appear until the 17th century. At this time, the work of  Cavalieri  with his  method of Indivisibles , and work by  Fermat , began to lay the foundations of modern calculus, with Cavalieri computing the integrals of   x   n    up to degree   n  = 9  in  Cavalieri\'s quadrature formula . Further steps were made in the early 17th century by  Barrow  and  Torricelli , who  ...

# %%
articles[1]
# Out:
# ' In the branch of  mathematics  known as  real analysis , the  Riemann integral , created by  Bernhard Riemann , was the first rigorous definition of the  integral  of a  function  on an  interval .  It was presented to the faculty at the  University of Göttingen  in 1854, but not published in a journal until 1868.  [1]   For many functions and practical applications, the Riemann integral can be evaluated by the  fundamental theorem of calculus  or approximated by  numerical integration .\n   The Riemann integral is unsuitable for many theoretical purposes. Some of the technical deficiencies in Riemann integration can be remedied with the  Riemann–Stieltjes integral , and most disappear with the  Lebesgue integral .\n   Let  f  be a non-negative  real -valued function on the interval  [ a ,  b ] , and let\n   be the region of the plane under the graph of the function  f  and above the interval  [ a ,  b ]  (see the figure on the top right). We are interested in measuring the area of  S . Once we have measured it, we will denote the area by:\n   The basic idea of the Riemann integral is to use very simple approximations for the area of  S . By taking better and better approximations, we can say that "in the limit" we get exactly the area of  S  under the curve.\n   Note that where  f  can be both positive and negative, the definition of  S  is modified so that the integral corresponds to the  signed area  under the graph of  f : that is, the area above the  x -axis minus the area below the  x -axis.\n   A  partition of an interval   [ a ,  b ]  is a finite sequence of numbers of the form\n   Each  [ x i  ,  x   i  + 1 ]  is called a  sub-interval  of the partition. The  mesh  or  norm  of a partition is defined to be the length of the longest sub-interval, that is,\n   A  tagged partition    P ( x ,  t )  of an interval  [ a ,  b ]  is a partition together with a finite sequence of numbers   t  0 , ...,  t   n  − 1   subject to the conditions that for each  i ,   t i   ∈ [ x i  ,  x   i  + 1 ] . In other words, it is a partition together with a distinguished point of every sub-interval. The mesh of a tagged partition is the same as that of an ordinary partition.\n   Suppose that two partitions   P ( x ,  t )  and   Q ( y ,  s )  are both partitions of the interval  [ a ,  b ] . We say that   Q ( y ,  s )  is a  refinement  of   P ( x ,  t )  if for each integer  i , with   i  ∈ [0,  n ] , there exists an integer   r ( i )  such that   x i   =  y   r ( i )   and such that   t i   =  s j    for some  j  with   j  ∈ [ r ( i ),  r ( i  + 1)) . Said more simply, a refinement of a tagged partition breaks up some of the sub-intervals and adds tags to the partition where necessary, thus it "refines" the accuracy of the partition.\n   We can define a  partial order  on the set of all tagged partitions by saying that one tagged partition is greater or equal to another if the former is a refinement of the latter.\n   Let  f  be a real-valued function defined on the interval  [ a ,  b ] . The   Riemann sum   of  f  with respect to the tagged partition   x  0 , ...,  x n    together with   t  0 , ...,  t   n  − 1   is  [2]  \n   Each term in the sum is the product of the value of the function at a given point and the length of an interval. Consequently, each term represents the (signed) area of a rectangle with height   f ( t i  )  and width   x   i  + 1  −  x i   . The Riemann sum is the (signed) area of all the rectangles.\n   A closely related concept are the  lower and upper Darboux sums . These are similar to Riemann sums, but the tags are replaced by the  infimum and supremum  (respectively) of  f  on each sub-interval:\n   If  f  is continuous, then the lower and upper Darboux sums for an untagged partition are equal to the Riemann sum for that partition, where the tags are chosen to be the minimum or maximum (respectively) of  f  on each subinterval. (When  f  is discontinuous on a subinterval, there may not be a tag that achieves  ...

# %%
import numpy as np
with open ('wiki_mycorpus.txt', 'w', encoding="utf-8") as f:
    for el in articles:
        f.write(el)

# %% [markdown]
# # Zad
#
# Oczyszczamy tekst:
#
# * tokenizacja
#
# * usuwanie stopwords
#
# * usuwanie tokenów występujących tylko 1 raz
#
# * zmiana dużych liter na małe

# %%
from pprint import pprint  # pretty-printer
from collections import defaultdict
from nltk.corpus import stopwords
import string

# remove common words and tokenize
stoplist = set('for a of the and to in'.split() + list(string.punctuation) + stopwords.words('english') )
texts = [[word for word in articles.lower().split() if word not in stoplist] for articles in articles]

# remove words that appear only once
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1]
         for text in texts]
print(len(texts))
pprint(texts)
# Out:
# 11
# [['mathematics',
#   'integral',
#   'assigns',
#   'numbers',
#   'functions',
#   'way',
#   'describe',
#   'displacement,',
#   'area,',
#   'volume,',
#   'concepts',
#   'arise',
#   'combining',
#   'infinitesimal',
#   'integration',
#   'one',
#   'two',
#   'main',
#   'operations',
#   'calculus',
#   'inverse',
#   'differentiation',
#   'other.',
#   'given',
#   'function',
#   'f',
#   'real',
#   'variable',
#   'x',
#   'interval',
#   'b',
#   'real',
#   'line',
#   'definite',
#   'integral',
#   'defined',
#   'signed',
#   'area',
#   'region',
#   'bounded',
#   'graph',
#   'f',
#   'x',
#   '-axis',
#   'vertical',
#   'lines',
#   'x',
#   'x',
#   'b',
#   'area',
#   'x',
#   '-axis',
#   'adds',
#   'total',
#   'x',
#   '-axis',
#   'operation',
#   'integration,',
#   'inverse',
#   'operation',
#   'differentiation.',
#   'reason,',
#   'term',
#   'integral',
#   'may',
#   'also',
#   'refer',
#   'related',
#   'notion',
#   'antiderivative',
#   'function',
#   'f',
#   'whose',
#   'derivative',
#   'given',
#   'function',
#   'f',
#   'case,',
#   'called',
#   'indefinite',
#   'integral',
#   'integrals',
#   'discussed',
#   'article',
#   'termed',
#   'definite',
#   'integrals',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'differentiation',
#   'definite',
#   'f',
#   'continuous',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'then,',
#   'antiderivative',
#   'f',
#   'f',
#   'known,',
#   'definite',
#   'integral',
#   'f',
#   'interval',
#   'given',
#   'principles',
#   'integration',
#   'formulated',
#   'independently',
#   'isaac',
#   'newton',
#   'gottfried',
#   'wilhelm',
#   'leibniz',
#   'late',
#   '17th',
#   'century,',
#   'thought',
#   'integral',
#   'infinite',
#   'sum',
#   'rectangles',
#   'infinitesimal',
#   'width.',
#   'bernhard',
#   'riemann',
#   'gave',
#   'rigorous',
#   'mathematical',
#   'definition',
#   'integrals.',
#   'based',
#   'limiting',
#   'procedure',
#   'approximates',
#   'area',
#   'region',
#   'breaking',
#   'region',
#   'thin',
#   'vertical',
#   'beginning',
#   'century,',
#   'sophisticated',
#   'notions',
#   'integrals',
#   'began',
#   'type',
#   'function',
#   'well',
#   'domain',
#   'integration',
#   'performed',
#   'line',
#   'integral',
#   'defined',
#   'functions',
#   'two',
#   'variables,',
#   'interval',
#   'integration',
#   'b',
#   'replaced',
#   'curve',
#   'two',
#   'surface',
#   'integral',
#   'curve',
#   'replaced',
#   'piece',
#   'surface',
#   'three-dimensional',
#   'space',
#   'first',
#   'documented',
#   'systematic',
#   'technique',
#   'integrals',
#   'method',
#   'exhaustion',
#   'ancient',
#   'greek',
#   'astronomer',
#   'eudoxus',
#   'sought',
#   'find',
#   'areas',
#   'volumes',
#   'breaking',
#   'infinite',
#   'number',
#   'area',
#   'volume',
#   'known.',
#   'method',
#   'developed',
#   'employed',
#   'archimedes',
#   '3rd',
#   'century',
#   'used',
#   'calculate',
#   'areas',
#   'approximation',
#   'area',
#   'circle',
#   'similar',
#   'method',
#   'independently',
#   'developed',
#   'china',
#   'around',
#   '3rd',
#   'century',
#   'used',
#   'find',
#   'area',
#   'circle.',
#   'method',
#   'later',
#   'used',
#   '5th',
#   'century',
#   'chinese',
#   'mathematicians',
#   'zu',
#   'zu',
#   'find',
#   'volume',
#   '2004',
#   'pp.',
#   'middle',
#   '–',
#   'c.',
#   'derived',
#   'formula',
#   'sum',
#   'fourth',
#   'powers',
#   'used',
#   'results',
#   'carry',
#   'would',
#   'called',
#   'integration',
#   'function,',
#   'formulae',
#   'sums',
#   'integral',
#   'squares',
#   'fourth',
#   'powers',
#   'allowed',
#   'calculate',
#   'volume',
#   '[1]',
#   'next',
#   'significant',
#   'integral',
#   'calculus',
#   'begin',
#   'appear',
#   '17th',
#   'century.',
#   'time,',
#   'work',
#   'cavalieri',
#   'method',
#   'work',
#   'began',
#   'lay',
#   'foundations',
#   'modern',
#   'calculus,',
#   'cavalieri',
#   'computing',
#   'integrals',
#   'x',
#   'n',
#   'degree',
#   'n',
#   '9',
#   "cavalieri's",
#   'quadrature',
#   'formula',
#   'steps',
#   'made',
#   'early',
#   '17th',
#   'century',
#   'barrow',
#   'provided',
#   'first',
#   'hints',
#   'connection',
#   'integration',
#   'differentiation',
#   'barrow',
#   'provided',
#   'first',
#   'proof',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'generalized',
#   "cavalieri's",
#   'method,',
#   'computing',
#   'integrals',
#   'x',
#   'general',
#   'power,',
#   'including',
#   'negative',
#   'powers',
#   'major',
#   'advance',
#   'integration',
#   'came',
#   '17th',
#   'century',
#   'independent',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'newton',
#   'leibniz',
#   'theorem',
#   'demonstrates',
#   'connection',
#   'integration',
#   'differentiation.',
#   'combined',
#   'comparative',
#   'differentiation,',
#   'calculate',
#   'integrals.',
#   'particular,',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'allows',
#   'one',
#   'much',
#   'class',
#   'problems.',
#   'equal',
#   'importance',
#   'comprehensive',
#   'mathematical',
#   'framework',
#   'newton',
#   'leibniz',
#   'given',
#   'name',
#   'infinitesimal',
#   'calculus,',
#   'allowed',
#   'precise',
#   'analysis',
#   'functions',
#   'within',
#   'continuous',
#   'framework',
#   'eventually',
#   'became',
#   'modern',
#   'calculus',
#   'whose',
#   'notation',
#   'integrals',
#   'drawn',
#   'directly',
#   'work',
#   'newton',
#   'leibniz',
#   'provided',
#   'systematic',
#   'approach',
#   'integration,',
#   'work',
#   'lacked',
#   'degree',
#   'rigour',
#   'attacked',
#   'used',
#   'calling',
#   'quantities',
#   '".',
#   'calculus',
#   'acquired',
#   'development',
#   'limits',
#   'integration',
#   'first',
#   'rigorously',
#   'using',
#   'riemann',
#   'although',
#   'bounded',
#   'piecewise',
#   'continuous',
#   'functions',
#   'riemann-integrable',
#   'bounded',
#   'interval,',
#   'general',
#   'functions',
#   'context',
#   'fourier',
#   'analysis',
#   '—to',
#   "riemann's",
#   'definition',
#   'lebesgue',
#   'formulated',
#   'different',
#   'definition',
#   'integral',
#   'founded',
#   'measure',
#   'theory',
#   '(a',
#   'real',
#   'analysis',
#   ').',
#   'definitions',
#   'integral,',
#   'extending',
#   "riemann's",
#   "lebesgue's",
#   'proposed.',
#   'approaches',
#   'based',
#   'real',
#   'number',
#   'system',
#   'ones',
#   'common',
#   'today,',
#   'alternative',
#   'approaches',
#   'exist,',
#   'definition',
#   'integral',
#   'standard',
#   'part',
#   'infinite',
#   'riemann',
#   'sum,',
#   'based',
#   'hyperreal',
#   'number',
#   'system.',
#   'isaac',
#   'newton',
#   'used',
#   'small',
#   'vertical',
#   'bar',
#   'variable',
#   'indicate',
#   'integration,',
#   'placed',
#   'variable',
#   'inside',
#   'vertical',
#   'bar',
#   'easily',
#   'confused',
#   'x',
#   'x',
#   '′',
#   'used',
#   'indicate',
#   'differentiation,',
#   'box',
#   'notation',
#   'difficult',
#   'printers',
#   'notations',
#   'widely',
#   'modern',
#   'notation',
#   'indefinite',
#   'integral',
#   'introduced',
#   'gottfried',
#   'wilhelm',
#   'leibniz',
#   'burton',
#   '1988',
#   'p.',
#   'leibniz',
#   '1899',
#   'p.',
#   'adapted',
#   'integral',
#   'symbol',
#   '∫',
#   'letter',
#   'long',
#   '),',
#   'standing',
#   '(written',
#   'latin',
#   'modern',
#   'notation',
#   'definite',
#   'integral,',
#   'limits',
#   'integral',
#   'first',
#   'used',
#   'joseph',
#   'fourier',
#   'french',
#   'academy',
#   'around',
#   'reprinted',
#   'book',
#   '1822',
#   'pp.',
#   'fourier',
#   '1822',
#   'integrals',
#   'used',
#   'extensively',
#   'many',
#   'areas',
#   'mathematics',
#   'well',
#   'many',
#   'areas',
#   'example,',
#   'probability',
#   'theory',
#   'integrals',
#   'used',
#   'determine',
#   'probability',
#   'random',
#   'variable',
#   'within',
#   'certain',
#   'moreover,',
#   'integral',
#   'entire',
#   'probability',
#   'density',
#   'function',
#   'must',
#   'equal',
#   '1,',
#   'provides',
#   'whether',
#   'function',
#   'negative',
#   'values',
#   'could',
#   'density',
#   'function',
#   'integrals',
#   'used',
#   'computing',
#   'area',
#   'two-dimensional',
#   'region',
#   'curved',
#   'well',
#   'computing',
#   'volume',
#   'three-dimensional',
#   'object',
#   'curved',
#   'area',
#   'two-dimensional',
#   'region',
#   'calculated',
#   'using',
#   'definite',
#   'integral.',
#   'volume',
#   'three-dimensional',
#   'object',
#   'disc',
#   'outlined',
#   'disc',
#   'integration',
#   'computed',
#   'using',
#   'equation',
#   'volume',
#   'r',
#   '2',
#   'h',
#   '{\\displaystyle',
#   'r',
#   '{\\displaystyle',
#   'case',
#   'would',
#   'distance',
#   'curve',
#   'function',
#   'line',
#   'simple',
#   'radius',
#   'equation',
#   'function',
#   'minus',
#   'given',
#   'x',
#   '{\\displaystyle',
#   'x}',
#   '-value',
#   '{\\displaystyle',
#   'y}',
#   '-value',
#   'line.',
#   'instance,',
#   'radius',
#   'disc',
#   'created',
#   'quadratic',
#   '−',
#   'x',
#   '2',
#   '4',
#   '{\\displaystyle',
#   'y=-x^{2}+4}',
#   'around',
#   'line',
#   '−',
#   '1',
#   '{\\displaystyle',
#   'y=-1}',
#   'would',
#   'given',
#   'expression',
#   '−',
#   'x',
#   '2',
#   '4',
#   '−',
#   '−',
#   '1',
#   '{\\displaystyle',
#   '−',
#   'x',
#   '2',
#   '5',
#   '{\\displaystyle',
#   'order',
#   'find',
#   'volume',
#   'integral',
#   'bounds',
#   '{\\displaystyle',
#   'a}',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   '{\\displaystyle',
#   'a}',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   'line',
#   '−',
#   'x',
#   '2',
#   '4',
#   '{\\displaystyle',
#   'y=-x^{2}+4}',
#   '−',
#   '1',
#   '{\\displaystyle',
#   'y=-1}',
#   'would',
#   'used',
#   'follows:',
#   'integrals',
#   'also',
#   'used',
#   'physics,',
#   'areas',
#   'like',
#   'find',
#   'quantities',
#   'like',
#   'displacement',
#   'time',
#   'velocity',
#   'example,',
#   'displacement',
#   'object',
#   'time',
#   'interval',
#   'b',
#   '{\\displaystyle',
#   'given',
#   'by:',
#   'v',
#   '{\\displaystyle',
#   'velocity',
#   'expressed',
#   'function',
#   'time.',
#   'work',
#   'done',
#   'force',
#   'f',
#   'x',
#   '{\\displaystyle',
#   'f(x)}',
#   'function',
#   'initial',
#   'position',
#   '{\\displaystyle',
#   'a}',
#   'final',
#   'position',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   'is:',
#   'integrals',
#   'also',
#   'used',
#   'integration',
#   'used',
#   'calculate',
#   'difference',
#   'free',
#   'energy',
#   'two',
#   'given',
#   'states.',
#   'integral',
#   'respect',
#   'x',
#   'real-valued',
#   'function',
#   'f',
#   'x',
#   'real',
#   'variable',
#   'x',
#   'interval',
#   'b',
#   'written',
#   'integral',
#   'sign',
#   '∫',
#   'represents',
#   'integration.',
#   'symbol',
#   'dx',
#   'called',
#   'differential',
#   'variable',
#   'x',
#   'indicates',
#   'variable',
#   'integration',
#   'x',
#   'function',
#   'f',
#   'x',
#   'integrated',
#   'called',
#   'integrand.',
#   'symbol',
#   'dx',
#   'separated',
#   'integrand',
#   'space',
#   '(as',
#   'function',
#   'integral,',
#   'said',
#   'integrable.',
#   'points',
#   'b',
#   'called',
#   'limits',
#   'integral.',
#   'integral',
#   'limits',
#   'specified',
#   'called',
#   'definite',
#   'integral.',
#   'integral',
#   'said',
#   'interval',
#   'b',
#   'integral',
#   'goes',
#   'finite',
#   'value',
#   'upper',
#   'limit',
#   'infinity,',
#   'integral',
#   'expresses',
#   'limit',
#   'integral',
#   'value',
#   'b',
#   'b',
#   'goes',
#   'infinity.',
#   'value',
#   'integral',
#   'gets',
#   'closer',
#   'closer',
#   'finite',
#   'value,',
#   'integral',
#   'said',
#   'converge',
#   'value.',
#   'not,',
#   'integral',
#   'said',
#   'limits',
#   'integral',
#   'called',
#   'indefinite',
#   'integral,',
#   'represents',
#   'class',
#   'functions',
#   '(the',
#   'antiderivative',
#   'whose',
#   'derivative',
#   'integrand.',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'relates',
#   'definite',
#   'integrals',
#   'indefinite',
#   'integrals.',
#   'occasionally,',
#   'limits',
#   'integration',
#   'omitted',
#   'definite',
#   'integrals',
#   'limits',
#   'occur',
#   'repeatedly',
#   'particular',
#   'author',
#   'make',
#   'convention',
#   'clear',
#   'beginning',
#   'relevant',
#   'text.',
#   'several',
#   'notation',
#   'integrals',
#   'integration',
#   'unbounded',
#   'domains',
#   'multiple',
#   'dimensions',
#   '(see',
#   'later',
#   'sections',
#   'historically,',
#   'symbol',
#   'dx',
#   'taken',
#   'represent',
#   'independent',
#   'variable',
#   'x',
#   'multiplied',
#   'integrand',
#   'summed',
#   'infinite',
#   'sense.',
#   'notion',
#   'still',
#   'useful,',
#   'later',
#   'mathematicians',
#   'deemed',
#   'infinitesimal',
#   'quantities',
#   'real',
#   'number',
#   'system.',
#   '[2]',
#   'introductory',
#   'calculus,',
#   'expression',
#   'dx',
#   'therefore',
#   'assigned',
#   'independent',
#   'meaning;',
#   'instead,',
#   'viewed',
#   'part',
#   'symbol',
#   'integration',
#   'serves',
#   'right',
#   'side',
#   'expression',
#   'integrated.',
#   'sophisticated',
#   'dx',
#   'meaning',
#   'particular',
#   'area',
#   'mathematics',
#   'used',
#   'one',
#   'ways,',
#   'original',
#   'notation',
#   'apply',
#   'generalization',
#   'original',
#   'definition',
#   'integral.',
#   'common',
#   'interpretations',
#   'dx',
#   'include:',
#   'integrator',
#   'function',
#   'riemann-stieltjes',
#   'integration',
#   '(indicated',
#   'x',
#   'general),',
#   'measure',
#   'lebesgue',
#   'theory',
#   '(indicated',
#   'general),',
#   'differential',
#   'form',
#   'exterior',
#   'calculus',
#   '(indicated',
#   'x',
#   '1',
#   '∧',
#   '∧',
#   'x',
#   'k',
#   '{\\displaystyle',
#   '\\wedge',
#   'last',
#   'case,',
#   'even',
#   'letter',
#   'independent',
#   'meaning',
#   '—',
#   'exterior',
#   'derivative',
#   'operator',
#   'differential',
#   'leave',
#   'dx',
#   'simple',
#   'riemann',
#   'integral',
#   'used,',
#   'exact',
#   'type',
#   'integral',
#   'instance,',
#   'one',
#   'might',
#   'write',
#   '∫',
#   'b',
#   'c',
#   '1',
#   'f',
#   'c',
#   '2',
#   'g',
#   'c',
#   '1',
#   '∫',
#   'b',
#   'f',
#   'c',
#   '2',
#   '∫',
#   'b',
#   'g',
#   '\\int',
#   'express',
#   'linearity',
#   'integral,',
#   'property',
#   'shared',
#   'riemann',
#   'integral',
#   'modern',
#   'arabic',
#   'mathematical',
#   'notation',
#   'reflected',
#   'integral',
#   'symbol',
#   'used',
#   'instead',
#   'symbol',
#   '∫',
#   'since',
#   'arabic',
#   'script',
#   'mathematical',
#   'expressions',
#   'go',
#   'right',
#   '[3]',
#   'authors,',
#   'particularly',
#   'european',
#   'origin,',
#   'use',
#   '"d"',
#   'indicate',
#   'variable',
#   'integration',
#   '(i.e.,',
#   'x',
#   'instead',
#   'dx',
#   '),',
#   'since',
#   'properly',
#   'speaking,',
#   '"d"',
#   'variable.',
#   'symbol',
#   'dx',
#   'always',
#   'placed',
#   'f',
#   'x',
#   'instance',
#   'first',
#   'expression,',
#   'differential',
#   'treated',
#   'infinitesimal',
#   'formally',
#   'following',
#   'expression',
#   'x',
#   '2',
#   'second',
#   'expression,',
#   'showing',
#   'differentials',
#   'first',
#   'variables',
#   'integrated',
#   'respect',
#   'to,',
#   'practice',
#   'particularly',
#   'popular',
#   'integrals',
#   'appear',
#   'many',
#   'practical',
#   'situations.',
#   'rectangular',
#   'flat',
#   'bottom,',
#   'length,',
#   'width,',
#   'depth',
#   'easily',
#   'determine',
#   'volume',
#   'water',
#   'contain',
#   '(to',
#   'fill',
#   'it),',
#   'area',
#   'surface',
#   '(to',
#   'cover',
#   'it),',
#   'length',
#   'edge',
#   '(to',
#   'rounded',
#   'bottom,',
#   'quantities',
#   'call',
#   'integrals.',
#   'practical',
#   'approximations',
#   'may',
#   'trivial',
#   'precision',
#   'engineering',
#   '(of',
#   'requires',
#   'exact',
#   'rigorous',
#   'values',
#   'elements.',
#   'start',
#   'off,',
#   'consider',
#   'curve',
#   'f',
#   'x',
#   'x',
#   '0',
#   'x',
#   '1',
#   'f',
#   'x',
#   '√',
#   'x',
#   '(see',
#   'call',
#   'area',
#   'integral',
#   'f',
#   'notation',
#   'integral',
#   'first',
#   'approximation,',
#   'look',
#   'unit',
#   'square',
#   'given',
#   'sides',
#   'x',
#   '0',
#   'x',
#   '1',
#   'f',
#   '(0)',
#   '0',
#   'f',
#   '(1)',
#   '1',
#   'area',
#   'exactly',
#   '1.',
#   'true',
#   'value',
#   'integral',
#   'must',
#   'somewhat',
#   'less',
#   '1.',
#   'decreasing',
#   'width',
#   'approximation',
#   'rectangles',
#   'increasing',
#   'number',
#   'rectangles',
#   'gives',
#   'better',
#   'cross',
#   'interval',
#   'five',
#   'using',
#   'approximation',
#   'points',
#   '0,',
#   '1.',
#   'fit',
#   'box',
#   'step',
#   'using',
#   'right',
#   'end',
#   'height',
#   'curve',
#   'piece,',
#   'thus',
#   '√',
#   '√',
#   '√',
#   '1',
#   '1',
#   'summing',
#   'areas',
#   'get',
#   'better',
#   'approximation',
#   'sought',
#   'integral,',
#   'namely',
#   'taking',
#   'sum',
#   'finitely',
#   'many',
#   'function',
#   'values',
#   'f',
#   'multiplied',
#   'differences',
#   'two',
#   'subsequent',
#   'approximation',
#   'points.',
#   'easily',
#   'see',
#   'approximation',
#   'still',
#   'using',
#   'steps',
#   'produces',
#   'closer',
#   'approximation,',
#   'always',
#   'high',
#   'never',
#   'replacing',
#   'subintervals',
#   'ones',
#   'left',
#   'end',
#   'height',
#   'piece,',
#   'get',
#   'approximation',
#   'example,',
#   'twelve',
#   'subintervals',
#   'get',
#   'approximate',
#   'value',
#   'area',
#   'key',
#   'idea',
#   'transition',
#   'adding',
#   'finitely',
#   'many',
#   'differences',
#   'approximation',
#   'points',
#   'multiplied',
#   'function',
#   'values',
#   'using',
#   'infinitely',
#   'many',
#   'fine,',
#   'infinitesimal',
#   'transition',
#   'completed',
#   'example,',
#   'turns',
#   'area',
#   'curve',
#   'within',
#   'stated',
#   'bounds',
#   'notation',
#   'integral',
#   'weighted',
#   'sum,',
#   'denoted',
#   'function',
#   'values,',
#   'f',
#   'x',
#   'multiplied',
#   'infinitesimal',
#   'step',
#   'so-called',
#   'differentials',
#   'denoted',
#   'dx',
#   'historically,',
#   'early',
#   'efforts',
#   'rigorously',
#   'interpret',
#   'riemann',
#   'formally',
#   'defined',
#   'integrals',
#   'limit',
#   'weighted',
#   'sums,',
#   'dx',
#   'suggested',
#   'limit',
#   'difference',
#   'interval',
#   "riemann's",
#   'intervals',
#   'continuity',
#   'definitions,',
#   'especially',
#   'lebesgue',
#   'integral',
#   'founded',
#   'ability',
#   'extend',
#   'idea',
#   'much',
#   'flexible',
#   'ways.',
#   'thus',
#   'notation',
#   'refers',
#   'weighted',
#   'sum',
#   'function',
#   'values',
#   'μ',
#   'measuring',
#   'weight',
#   'assigned',
#   'value.',
#   'denotes',
#   'region',
#   'integration.',
#   'many',
#   'ways',
#   'formally',
#   'integral,',
#   'equivalent.',
#   'differences',
#   'exist',
#   'mostly',
#   'deal',
#   'special',
#   'cases',
#   'may',
#   'integrable',
#   'definitions,',
#   'also',
#   'occasionally',
#   'commonly',
#   'used',
#   'definitions',
#   'integral',
#   'riemann',
#   'integrals',
#   'lebesgue',
#   'integrals.',
#   'riemann',
#   'integral',
#   'defined',
#   'terms',
#   'riemann',
#   'sums',
#   'functions',
#   'respect',
#   'tagged',
#   'partitions',
#   'interval.',
#   '[4]',
#   'let',
#   'b',
#   'closed',
#   'interval',
#   'real',
#   'tagged',
#   'partition',
#   'b',
#   'finite',
#   'sequence',
#   'partitions',
#   'interval',
#   'b',
#   'n',
#   'sub-intervals',
#   'x',
#   '−1',
#   'x',
#   'indexed',
#   'distinguished',
#   'point',
#   '∈',
#   'x',
#   '−1',
#   'x',
#   'riemann',
#   'sum',
#   'function',
#   'f',
#   'respect',
#   'tagged',
#   'partition',
#   'defined',
#   'thus',
#   'term',
#   'sum',
#   'area',
#   'rectangle',
#   'height',
#   'equal',
#   'function',
#   'value',
#   'distinguished',
#   'point',
#   'given',
#   'sub-interval,',
#   'width',
#   'sub-interval',
#   'width.',
#   'let',
#   'δ',
#   'x',
#   '−',
#   'x',
#   '−1',
#   'width',
#   'sub-interval',
#   'mesh',
#   'tagged',
#   'partition',
#   'width',
#   'largest',
#   'sub-interval',
#   'formed',
#   'partition,',
#   'max',
#   'n',
#   'δ',
#   'riemann',
#   'integral',
#   'function',
#   'f',
#   'interval',
#   'b',
#   'equal',
#   'chosen',
#   'tags',
#   'give',
#   'maximum',
#   '(respectively,',
#   'value',
#   'interval,',
#   'riemann',
#   'sum',
#   'becomes',
#   'upper',
#   '(respectively,',
#   'darboux',
#   'sum',
#   'suggesting',
#   'close',
#   'connection',
#   'riemann',
#   'integral',
#   'darboux',
#   'integral',
#   'often',
#   'interest,',
#   'theory',
#   'applications,',
#   'able',
#   'pass',
#   'limit',
#   'integral.',
#   'instance,',
#   'sequence',
#   'functions',
#   'frequently',
#   'constructed',
#   'suitable',
#   'sense,',
#   'solution',
#   'integral',
#   'solution',
#   'function',
#   'limit',
#   'integrals',
#   'approximations.',
#   'however,',
#   'many',
#   'functions',
#   'obtained',
#   'limits',
#   'riemann-integrable,',
#   'limit',
#   'theorems',
#   'hold',
#   'riemann',
#   'integral.',
#   'therefore,',
#   'great',
#   'importance',
#   'definition',
#   'integral',
#   'allows',
#   'wider',
#   'class',
#   'functions',
#   'integrated',
#   ').',
#   'integral',
#   'lebesgue',
#   'integral,',
#   'following',
#   'fact',
#   'class',
#   'integrable',
#   'functions:',
#   'values',
#   'function',
#   'rearranged',
#   'domain,',
#   'integral',
#   'function',
#   'remain',
#   'thus',
#   'henri',
#   'lebesgue',
#   'introduced',
#   'integral',
#   'name,',
#   'integral',
#   'thus',
#   'letter',
#   'paul',
#   'pay',
#   'certain',
#   'sum,',
#   'collected',
#   'take',
#   'bills',
#   'coins',
#   'pocket',
#   'give',
#   'order',
#   'find',
#   'reached',
#   'total',
#   'sum.',
#   'riemann',
#   'integral.',
#   'taken',
#   'money',
#   'pocket',
#   'order',
#   'bills',
#   'coins',
#   'according',
#   'values',
#   'pay',
#   'several',
#   'one',
#   'integral.',
#   'p.',
#   'it,',
#   '"to',
#   'compute',
#   'riemann',
#   'integral',
#   'f',
#   'one',
#   'partitions',
#   'domain',
#   'b',
#   'lebesgue',
#   'integral,',
#   '"one',
#   'effect',
#   'partitioning',
#   'range',
#   'f',
#   '".',
#   'definition',
#   'lebesgue',
#   'integral',
#   'thus',
#   'begins',
#   'measure',
#   'simplest',
#   'case,',
#   'lebesgue',
#   'measure',
#   'μ',
#   'interval',
#   'b',
#   'width,',
#   'b',
#   '−',
#   'lebesgue',
#   'integral',
#   'riemann',
#   'integral',
#   'exist.',
#   'complicated',
#   'cases,',
#   'sets',
#   'measured',
#   'highly',
#   'continuity',
#   'resemblance',
#   'intervals.',
#   'using',
#   'range',
#   'f',
#   'philosophy,',
#   'integral',
#   'non-negative',
#   'function',
#   'f',
#   'r',
#   '→',
#   'r',
#   'sum',
#   'areas',
#   'thin',
#   'dt',
#   'area',
#   'μ',
#   'x',
#   'f',
#   'x',
#   '&gt;',
#   'dt',
#   'let',
#   'f',
#   '∗',
#   'μ',
#   'x',
#   'f',
#   'x',
#   '&gt;',
#   'lebesgue',
#   'integral',
#   'f',
#   'defined',
#   '&amp;',
#   'loss',
#   '2001',
#   'integral',
#   'right',
#   'ordinary',
#   'improper',
#   'riemann',
#   'integral',
#   'f',
#   '∗',
#   'strictly',
#   'decreasing',
#   'positive',
#   'function,',
#   'therefore',
#   'well-defined',
#   'improper',
#   'riemann',
#   'suitable',
#   'class',
#   'functions',
#   '(the',
#   'measurable',
#   'functions',
#   'lebesgue',
#   'integral.',
#   'general',
#   'measurable',
#   'function',
#   'f',
#   'lebesgue-integrable',
#   'sum',
#   'absolute',
#   'values',
#   'areas',
#   'regions',
#   'graph',
#   'f',
#   'x',
#   '-axis',
#   'case,',
#   'integral',
#   'is,',
#   'case,',
#   'difference',
#   'area',
#   'x',
#   '-axis',
#   'area',
#   'x',
#   'although',
#   'riemann',
#   'lebesgue',
#   'integrals',
#   'widely',
#   'used',
#   'definitions',
#   'integral,',
#   'number',
#   'others',
#   'exist,',
#   'collection',
#   'riemann-integrable',
#   'functions',
#   'closed',
#   'interval',
#   'b',
#   'forms',
#   'vector',
#   'space',
#   'operations',
#   'pointwise',
#   'addition',
#   'multiplication',
#   'operation',
#   'integration',
#   'linear',
#   'functional',
#   'vector',
#   'space.',
#   'thus,',
#   'collection',
#   'integrable',
#   'functions',
#   'closed',
#   'taking',
#   'linear',
#   'combinations',
#   'and,',
#   'integral',
#   'linear',
#   'combination',
#   'linear',
#   'combination',
#   'integrals,',
#   'similarly,',
#   'set',
#   'real',
#   '-valued',
#   'lebesgue-integrable',
#   'functions',
#   'given',
#   'measure',
#   'space',
#   'e',
#   'measure',
#   'μ',
#   'closed',
#   'taking',
#   'linear',
#   'combinations',
#   'hence',
#   'form',
#   'vector',
#   'space,',
#   'lebesgue',
#   'integral',
#   'linear',
#   'functional',
#   'vector',
#   'space,',
#   'generally,',
#   'consider',
#   'vector',
#   'space',
#   'measurable',
#   'functions',
#   'measure',
#   'space',
#   'e',
#   'μ',
#   'taking',
#   'values',
#   'locally',
#   'compact',
#   'complete',
#   'topological',
#   'vector',
#   'space',
#   'v',
#   'locally',
#   'compact',
#   'topological',
#   'field',
#   'k',
#   'f',
#   'e',
#   '→',
#   'v',
#   'one',
#   'may',
#   'define',
#   'integration',
#   'map',
#   'function',
#   'f',
#   'element',
#   'v',
#   'symbol',
#   '∞',
#   'linear',
#   'situation,',
#   'linearity',
#   'holds',
#   'functions',
#   'whose',
#   'integral',
#   'element',
#   'v',
#   '(i.e.',
#   'important',
#   'special',
#   'cases',
#   'arise',
#   'k',
#   'r',
#   'c',
#   'finite',
#   'extension',
#   'field',
#   'q',
#   'p',
#   'numbers',
#   'v',
#   'vector',
#   'space',
#   'k',
#   'k',
#   'c',
#   'v',
#   'complex',
#   'hilbert',
#   'space',
#   'together',
#   'natural',
#   'continuity',
#   'properties',
#   'certain',
#   'class',
#   'functions,',
#   'may',
#   'used',
#   'give',
#   'alternative',
#   'definition',
#   'integral.',
#   'approach',
#   'case',
#   'real-valued',
#   'functions',
#   'set',
#   'x',
#   'generalized',
#   'functions',
#   'values',
#   'locally',
#   'compact',
#   'topological',
#   'vector',
#   'space.',
#   'see',
#   'integral.',
#   'number',
#   'general',
#   'inequalities',
#   'hold',
#   'riemann-integrable',
#   'functions',
#   'defined',
#   'closed',
#   'bounded',
#   'interval',
#   'b',
#   'generalized',
#   'notions',
#   'integral',
#   'f',
#   'real-valued',
#   'riemann-integrable',
#   'function',
#   'integral',
#   'interval',
#   'b',
#   'defined',
#   '&lt;',
#   'b',
#   'means',
#   'upper',
#   'lower',
#   'sums',
#   'function',
#   'f',
#   'evaluated',
#   'partition',
#   'x',
#   '0',
#   '≤',
#   'x',
#   '1',
#   '≤',
#   '≤',
#   'x',
#   'n',
#   'b',
#   'whose',
#   'values',
#   'x',
#   'geometrically,',
#   'integration',
#   'takes',
#   'place',
#   'f',
#   'within',
#   'intervals',
#   'x',
#   'x',
#   '+1',
#   'interval',
#   'higher',
#   'index',
#   'lies',
#   'right',
#   'one',
#   'lower',
#   'values',
#   'b',
#   'interval',
#   'called',
#   'limits',
#   'integration',
#   'f',
#   'integrals',
#   'also',
#   'defined',
#   '&gt;',
#   'b',
#   'this,',
#   'b',
#   'implies:',
#   'first',
#   'convention',
#   'necessary',
#   'taking',
#   'integrals',
#   'subintervals',
#   'b',
#   'second',
#   'says',
#   'integral',
#   'taken',
#   'degenerate',
#   'interval,',
#   'point',
#   'zero',
#   'one',
#   'reason',
#   'first',
#   'convention',
#   'integrability',
#   'f',
#   'interval',
#   'b',
#   'implies',
#   'f',
#   'integrable',
#   'subinterval',
#   'c',
#   'particular',
#   'integrals',
#   'property',
#   'first',
#   'convention,',
#   'resulting',
#   'relation',
#   'well-defined',
#   'b',
#   'c',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'statement',
#   'differentiation',
#   'integration',
#   'inverse',
#   'continuous',
#   'function',
#   'first',
#   'integrated',
#   'original',
#   'function',
#   'important',
#   'sometimes',
#   'called',
#   'second',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'allows',
#   'one',
#   'compute',
#   'integrals',
#   'using',
#   'antiderivative',
#   'function',
#   'integrated.',
#   'let',
#   'f',
#   'continuous',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'let',
#   'f',
#   'function',
#   'x',
#   'b',
#   'then,',
#   'f',
#   'continuous',
#   'b',
#   'differentiable',
#   'open',
#   'interval',
#   'b',
#   'x',
#   'b',
#   'let',
#   'f',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'admits',
#   'antiderivative',
#   'f',
#   'b',
#   'is,',
#   'f',
#   'f',
#   'functions',
#   'x',
#   'b',
#   'f',
#   'integrable',
#   'b',
#   'second',
#   'fundamental',
#   'theorem',
#   'allows',
#   'many',
#   'integrals',
#   'calculated',
#   'example,',
#   'calculate',
#   'integral',
#   'square',
#   'function',
#   'f',
#   'x',
#   'x',
#   '1/2',
#   '0',
#   '1,',
#   'sufficient',
#   'find',
#   'antiderivative,',
#   'is,',
#   'function',
#   'f',
#   'x',
#   'whose',
#   'derivative',
#   'equals',
#   'f',
#   'x',
#   'one',
#   'function',
#   'f',
#   'x',
#   '2',
#   '3',
#   'x',
#   'value',
#   'integral',
#   'question',
#   'case',
#   'general',
#   'rule,',
#   'f',
#   'x',
#   'x',
#   'q',
#   'q',
#   '≠',
#   '−1',
#   'related',
#   'function,',
#   'so-called',
#   'antiderivative',
#   'f',
#   'x',
#   'x',
#   'q',
#   '1',
#   'q',
#   'tables',
#   'similar',
#   'antiderivatives',
#   'used',
#   'calculate',
#   'integrals',
#   'much',
#   'way',
#   'tables',
#   'derivatives',
#   'used.',
#   'riemann',
#   'integral',
#   'integrand',
#   'defined',
#   'finite',
#   'closed',
#   'bounded',
#   'interval,',
#   'limits',
#   'integration.',
#   'improper',
#   'integral',
#   'one',
#   'conditions',
#   'cases',
#   'integrals',
#   'may',
#   'defined',
#   'considering',
#   'limit',
#   'sequence',
#   'proper',
#   'riemann',
#   'integrals',
#   'larger',
#   'intervals.',
#   'interval',
#   'instance',
#   'upper',
#   'end,',
#   'improper',
#   'integral',
#   'limit',
#   'endpoint',
#   'goes',
#   'infinity.',
#   'integrand',
#   'defined',
#   'finite',
#   'interval,',
#   'instance',
#   'b',
#   'limit',
#   'may',
#   'provide',
#   'finite',
#   'result.',
#   'is,',
#   'improper',
#   'integral',
#   'limit',
#   'proper',
#   'integrals',
#   'one',
#   'endpoint',
#   'interval',
#   'integration',
#   'approaches',
#   'either',
#   'specified',
#   'real',
#   'number',
#   '∞',
#   'complicated',
#   'cases,',
#   'limits',
#   'required',
#   'interior',
#   'points.',
#   'definite',
#   'integral',
#   'positive',
#   'function',
#   'one',
#   'variable',
#   'represents',
#   'area',
#   'region',
#   'graph',
#   'function',
#   'x',
#   'double',
#   'integral',
#   'positive',
#   'function',
#   'two',
#   'variables',
#   'represents',
#   'volume',
#   'region',
#   'surface',
#   'defined',
#   'function',
#   'plane',
#   'domain',
#   'example,',
#   'function',
#   'two',
#   'dimensions',
#   'depends',
#   'two',
#   'real',
#   'variables,',
#   'x',
#   'integral',
#   'function',
#   'f',
#   'rectangle',
#   'r',
#   'given',
#   'product',
#   'two',
#   'intervals',
#   'r',
#   'b',
#   '×',
#   'c',
#   '{\\displaystyle',
#   'written',
#   'differential',
#   'da',
#   'indicates',
#   'integration',
#   'taken',
#   'respect',
#   'area.',
#   'double',
#   'integral',
#   'defined',
#   'using',
#   'riemann',
#   'sums',
#   'represents',
#   '(signed)',
#   'volume',
#   'graph',
#   'z',
#   'f',
#   'x',
#   'domain',
#   'r',
#   'suitable',
#   'conditions',
#   '(e.g.,',
#   'f',
#   'theorem',
#   'integral',
#   'expressed',
#   'equivalent',
#   'integral',
#   'reduces',
#   'problem',
#   'computing',
#   'double',
#   'integral',
#   'computing',
#   'integrals.',
#   'this,',
#   'another',
#   'notation',
#   'integral',
#   'r',
#   'uses',
#   'double',
#   'integral',
#   'integration',
#   'general',
#   'domains',
#   'possible.',
#   'integral',
#   'function',
#   'f',
#   'respect',
#   'volume,',
#   'subset',
#   'n',
#   'denoted',
#   'notation',
#   'see',
#   'volume',
#   'integral',
#   'concept',
#   'integral',
#   'extended',
#   'general',
#   'domains',
#   'integration,',
#   'curved',
#   'lines',
#   'integrals',
#   'known',
#   'line',
#   'integrals',
#   'surface',
#   'integrals',
#   'respectively.',
#   'important',
#   'applications',
#   'physics,',
#   'dealing',
#   'vector',
#   'fields',
#   'line',
#   'integral',
#   'called',
#   'path',
#   'integral',
#   'integral',
#   'function',
#   'integrated',
#   'evaluated',
#   'along',
#   'curve',
#   'various',
#   'different',
#   'line',
#   'integrals',
#   'use.',
#   'case',
#   'closed',
#   'curve',
#   'also',
#   'called',
#   'contour',
#   'integral',
#   'function',
#   'integrated',
#   'may',
#   'scalar',
#   'field',
#   'vector',
#   'field',
#   'value',
#   'line',
#   'integral',
#   'sum',
#   'values',
#   'field',
#   'points',
#   'weighted',
#   'scalar',
#   'function',
#   'curve',
#   'arc',
#   'length',
#   'vector',
#   'field,',
#   'scalar',
#   'product',
#   'vector',
#   'field',
#   'differential',
#   'vector',
#   'line',
#   'integral',
#   'simpler',
#   'integrals',
#   'defined',
#   'intervals',
#   'many',
#   'simple',
#   'formulas',
#   'physics',
#   'natural',
#   'continuous',
#   'terms',
#   'line',
#   'integrals;',
#   'example,',
#   'fact',
#   'work',
#   'equal',
#   'force',
#   'f',
#   'multiplied',
#   'displacement,',
#   'may',
#   'expressed',
#   '(in',
#   'terms',
#   'vector',
#   'as:',
#   'object',
#   'moving',
#   'along',
#   'path',
#   'c',
#   'vector',
#   'field',
#   'f',
#   'field',
#   'field',
#   'total',
#   'work',
#   'done',
#   'field',
#   'object',
#   'obtained',
#   'summing',
#   'differential',
#   'work',
#   'done',
#   'moving',
#   'gives',
#   'line',
#   'integral',
#   'surface',
#   'integral',
#   'definite',
#   'integral',
#   'taken',
#   'surface',
#   '(which',
#   'may',
#   'curved',
#   'set',
#   'space',
#   ');',
#   'thought',
#   'double',
#   'integral',
#   'analog',
#   'line',
#   'integral',
#   'function',
#   'integrated',
#   'may',
#   'scalar',
#   'field',
#   'vector',
#   'field',
#   'value',
#   'surface',
#   'integral',
#   'sum',
#   'field',
#   'points',
#   'achieved',
#   'surface',
#   'surface',
#   'provide',
#   'partitioning',
#   'riemann',
#   'sums.',
#   'example',
#   'applications',
#   'surface',
#   'integrals,',
#   'consider',
#   'vector',
#   'field',
#   'v',
#   'surface',
#   'is,',
#   'point',
#   'x',
#   'v',
#   'x',
#   'vector.',
#   'fluid',
#   'flowing',
#   'v',
#   'x',
#   'determines',
#   'velocity',
#   'fluid',
#   'x',
#   'flux',
#   'defined',
#   'fluid',
#   'flowing',
#   'unit',
#   'amount',
#   'time.',
#   'find',
#   'need',
#   'take',
#   'dot',
#   'product',
#   'v',
#   'unit',
#   'surface',
#   'normal',
#   'point,',
#   'give',
#   'us',
#   'scalar',
#   'field,',
#   'integrate',
#   'fluid',
#   'flux',
#   'example',
#   'may',
#   'physical',
#   'fluid',
#   'water',
#   'thus',
#   'surface',
#   'integrals',
#   'applications',
#   'physics,',
#   'particularly',
#   'classical',
#   'theory',
#   'complex',
#   'analysis',
#   'integrand',
#   'function',
#   'complex',
#   'variable',
#   'z',
#   'instead',
#   'real',
#   'function',
#   'real',
#   'variable',
#   'x',
#   'complex',
#   'function',
#   'integrated',
#   'along',
#   'curve',
#   '{\\displaystyle',
#   'complex',
#   'integral',
#   'denoted',
#   'follows',
#   'known',
#   'contour',
#   'integral',
#   'differential',
#   'form',
#   'mathematical',
#   'concept',
#   'fields',
#   'multivariable',
#   'calculus',
#   'differential',
#   'topology',
#   'differential',
#   'forms',
#   'organized',
#   'degree.',
#   'example,',
#   'one-form',
#   'weighted',
#   'sum',
#   'differentials',
#   'as:',
#   'e',
#   'f',
#   'g',
#   'functions',
#   'three',
#   'differential',
#   'one-form',
#   'integrated',
#   'oriented',
#   'resulting',
#   'integral',
#   'another',
#   'way',
#   'writing',
#   'line',
#   'integral.',
#   'basic',
#   'differentials',
#   'dx',
#   'dy',
#   'measure',
#   'infinitesimal',
#   'oriented',
#   'lengths',
#   'parallel',
#   'three',
#   'coordinate',
#   'axes.',
#   'differential',
#   'two-form',
#   'sum',
#   'form',
#   'basic',
#   'x',
#   '∧',
#   'z',
#   '∧',
#   'x',
#   '∧',
#   'z',
#   '{\\displaystyle',
#   'measure',
#   'oriented',
#   'areas',
#   'parallel',
#   'coordinate',
#   'symbol',
#   '∧',
#   '{\\displaystyle',
#   '\\wedge',
#   'denotes',
#   'wedge',
#   'product',
#   'similar',
#   'cross',
#   'product',
#   'sense',
#   'wedge',
#   'product',
#   'two',
#   'forms',
#   'representing',
#   'oriented',
#   'lengths',
#   'represents',
#   'oriented',
#   'area.',
#   'two-form',
#   'integrated',
#   'oriented',
#   'surface,',
#   'resulting',
#   'integral',
#   'equivalent',
#   'surface',
#   'integral',
#   'giving',
#   'flux',
#   'e',
#   'f',
#   'j',
#   'g',
#   'k',
#   '{\\displaystyle',
#   'unlike',
#   'cross',
#   'three-dimensional',
#   'vector',
#   'calculus,',
#   'wedge',
#   'product',
#   'calculus',
#   'differential',
#   'forms',
#   'makes',
#   'sense',
#   'arbitrary',
#   'dimension',
#   'general',
#   'higher-dimensional',
#   'exterior',
#   'derivative',
#   'plays',
#   'role',
#   'gradient',
#   'vector',
#   'calculus,',
#   'theorem',
#   'simultaneously',
#   'generalizes',
#   'three',
#   'theorems',
#   'vector',
#   'theorem',
#   'theorem',
#   'theorem',
#   'discrete',
#   'equivalent',
#   'integration',
#   'integrals',
#   'put',
#   'foundations',
#   'using',
#   'theory',
#   'lebesgue',
#   'integrals',
#   'time',
#   'calculus',
#   'basic',
#   'technique',
#   'computing',
#   'definite',
#   'integrals',
#   'one',
#   'real',
#   'variable',
#   'based',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'let',
#   'f',
#   'x',
#   'function',
#   'x',
#   'integrated',
#   'given',
#   'interval',
#   'b',
#   'then,',
#   'find',
#   'antiderivative',
#   'f',
#   'is,',
#   'function',
#   'f',
#   'f',
#   '′',
#   'f',
#   'interval.',
#   'provided',
#   'integrand',
#   'integral',
#   'singularities',
#   'path',
#   'integration,',
#   'fundamental',
#   'theorem',
#   'calculus,',
#   'integral',
#   'actually',
#   'antiderivative,',
#   'fundamental',
#   'theorem',
#   'provides',
#   'way',
#   'use',
#   'antiderivatives',
#   'evaluate',
#   'definite',
#   'integrals.',
#   'difficult',
#   'step',
#   'usually',
#   'find',
#   'antiderivative',
#   'f',
#   'rarely',
#   'possible',
#   'function',
#   'write',
#   'often,',
#   'necessary',
#   'use',
#   'one',
#   'many',
#   'techniques',
#   'developed',
#   'evaluate',
#   'integrals.',
#   'techniques',
#   'rewrite',
#   'one',
#   'integral',
#   'different',
#   'one',
#   'techniques',
#   'include:',
#   'alternative',
#   'methods',
#   'exist',
#   'compute',
#   'complex',
#   'integrals.',
#   'many',
#   'integrals',
#   'expanded',
#   'taylor',
#   'series',
#   'integrated',
#   'term',
#   'term.',
#   'occasionally,',
#   'resulting',
#   'infinite',
#   'series',
#   'summed',
#   'method',
#   'using',
#   'meijer',
#   'also',
#   'used,',
#   'assuming',
#   'integrand',
#   'written',
#   'product',
#   'meijer',
#   'also',
#   'many',
#   'less',
#   'common',
#   'ways',
#   'calculating',
#   'definite',
#   'integrals;',
#   'instance,',
#   'identity',
#   'used',
#   'transform',
#   'integral',
#   'rectangular',
#   'region',
#   'infinite',
#   'sum.',
#   'occasionally,',
#   'integral',
#   'evaluated',
#   'example',
#   'this,',
#   'see',
#   'gaussian',
#   'integral',
#   'computations',
#   'volumes',
#   'revolution',
#   'usually',
#   'done',
#   'integration',
#   'shell',
#   'integration',
#   'specific',
#   'results',
#   'worked',
#   'various',
#   'techniques',
#   'collected',
#   'list',
#   'integrals',
#   'many',
#   'problems',
#   'physics,',
#   'engineering',
#   'involve',
#   'integration',
#   'explicit',
#   'formula',
#   'integral',
#   'extensive',
#   'tables',
#   'integrals',
#   'compiled',
#   'published',
#   'years',
#   'spread',
#   'many',
#   'students',
#   'turned',
#   'computer',
#   'algebra',
#   'systems',
#   'specifically',
#   'designed',
#   'perform',
#   'difficult',
#   'tedious',
#   'including',
#   'integration.',
#   'symbolic',
#   'integration',
#   'one',
#   'development',
#   'first',
#   'like',
#   'major',
#   'mathematical',
#   'difficulty',
#   'symbolic',
#   'integration',
#   'many',
#   'cases,',
#   'closed',
#   'formula',
#   'antiderivative',
#   'rather',
#   'function',
#   'exist.',
#   'instance,',
#   'known',
#   'antiderivatives',
#   'functions',
#   'exp(',
#   'x',
#   '2',
#   '),',
#   'x',
#   'x',
#   'x',
#   'x',
#   'cannot',
#   'expressed',
#   'closed',
#   'form',
#   'involving',
#   'rational',
#   'exponential',
#   'functions,',
#   'trigonometric',
#   'functions',
#   'inverse',
#   'trigonometric',
#   'functions',
#   'operations',
#   'multiplication',
#   'words,',
#   'none',
#   'three',
#   'given',
#   'functions',
#   'integrable',
#   'elementary',
#   'functions',
#   'functions',
#   'may',
#   'built',
#   'rational',
#   'functions,',
#   'roots',
#   'polynomial',
#   'logarithm,',
#   'exponential',
#   'functions.',
#   'risch',
#   'algorithm',
#   'provides',
#   'general',
#   'criterion',
#   'determine',
#   'whether',
#   'antiderivative',
#   'elementary',
#   'function',
#   'and,',
#   'is,',
#   'compute',
#   'it.',
#   'unfortunately,',
#   'turns',
#   'functions',
#   'closed',
#   'expressions',
#   'antiderivatives',
#   'rather',
#   'consequently,',
#   'algebra',
#   'systems',
#   'hope',
#   'able',
#   'find',
#   'antiderivative',
#   'constructed',
#   'elementary',
#   'function.',
#   'positive',
#   'side,',
#   'antiderivatives',
#   'fixed',
#   'advance,',
#   'may',
#   'still',
#   'possible',
#   'decide',
#   'whether',
#   'antiderivative',
#   'given',
#   'function',
#   'expressed',
#   'using',
#   'operations',
#   'multiplication',
#   'find',
#   'symbolic',
#   'answer',
#   'whenever',
#   'exists.',
#   'risch',
#   'algorithm',
#   'implemented',
#   'computer',
#   'algebra',
#   'systems',
#   'functions',
#   'antiderivatives',
#   'built',
#   'rational',
#   'functions,',
#   'logarithm,',
#   'exponential',
#   'functions.',
#   'special',
#   'occur',
#   'often',
#   'enough',
#   'warrant',
#   'special',
#   'particular,',
#   'may',
#   'useful',
#   'have,',
#   'set',
#   'special',
#   'functions',
#   'functions',
#   'hypergeometric',
#   'function',
#   'gamma',
#   'function',
#   'incomplete',
#   'gamma',
#   'function',
#   '—',
#   'see',
#   'symbolic',
#   'integration',
#   'extending',
#   'algorithm',
#   'include',
#   'functions',
#   'possible',
#   'active',
#   'subject.',
#   'recently',
#   'new',
#   'approach',
#   'using',
#   '-finite',
#   'functions',
#   'linear',
#   'differential',
#   'equations',
#   'polynomial',
#   'elementary',
#   'special',
#   'functions',
#   'integral',
#   '-finite',
#   'function',
#   'also',
#   '-finite',
#   'function.',
#   'provides',
#   'algorithm',
#   'express',
#   'antiderivative',
#   '-finite',
#   'function',
#   'solution',
#   'differential',
#   'theory',
#   'also',
#   'allows',
#   'one',
#   'compute',
#   'definite',
#   'integral',
#   'sum',
#   'series',
#   'given',
#   'first',
#   'provides',
#   'algorithm',
#   'compute',
#   '[5]',
#   'integrals',
#   'found',
#   'real',
#   'applications',
#   'computed',
#   'others',
#   'antiderivatives',
#   'closed',
#   'forms,',
#   'closed',
#   'forms',
#   'require',
#   'special',
#   'functions',
#   'others',
#   'complex',
#   'finding',
#   'exact',
#   'answer',
#   'motivates',
#   'study',
#   'application',
#   'numerical',
#   'approximations',
#   'integrals.',
#   'called',
#   'numerical',
#   'integration',
#   'numerical',
#   'quadrature',
#   'arose',
#   'early',
#   'study',
#   'integration',
#   'purpose',
#   'making',
#   'hand',
#   'development',
#   'made',
#   'numerical',
#   'integration',
#   'practical',
#   'desire',
#   'goals',
#   'numerical',
#   'integration',
#   'generality,',
#   'sophisticated',
#   'modern',
#   'methods',
#   'method',
#   'four',
#   'measures',
#   '&amp;',
#   '2008',
#   '&amp;',
#   '&amp;',
#   '2002',
#   ').',
#   'example,',
#   'integral',
#   'exact',
#   'answer',
#   '3.76',
#   '(in',
#   'ordinary',
#   'practice,',
#   'answer',
#   'known',
#   'advance,',
#   'important',
#   '—',
#   'explored',
#   '—',
#   'decide',
#   'approximation',
#   'good',
#   'approach',
#   'divides',
#   'integration',
#   'range',
#   'say,',
#   '16',
#   'equal',
#   'pieces,',
#   'function',
#   'using',
#   'left',
#   'end',
#   'piece,',
#   'rectangle',
#   'method',
#   'sums',
#   '16',
#   'function',
#   'values',
#   'multiplies',
#   'step',
#   'width,',
#   'h',
#   'get',
#   'approximate',
#   'value',
#   'integral.',
#   'accuracy',
#   'calculus',
#   'formally',
#   'uses',
#   'pieces',
#   'infinitesimal',
#   'width,',
#   'initially',
#   'may',
#   'seem',
#   'little',
#   'cause',
#   'indeed,',
#   'repeatedly',
#   'doubling',
#   'number',
#   'steps',
#   'eventually',
#   'produces',
#   'approximation',
#   'however,',
#   '2',
#   '18',
#   'pieces',
#   'great',
#   'little',
#   'reach',
#   'greater',
#   'accuracy',
#   'force',
#   'steps',
#   'small',
#   'arithmetic',
#   'precision',
#   'becomes',
#   'better',
#   'approach',
#   'rectangles',
#   'used',
#   'riemann',
#   'sum',
#   'trapezoid',
#   'rule',
#   'almost',
#   'easy',
#   'sums',
#   '17',
#   'function',
#   'values,',
#   'first',
#   'last',
#   'one',
#   'multiplies',
#   'step',
#   'width.',
#   'immediately',
#   'approximation',
#   'noticeably',
#   'furthermore,',
#   '2',
#   '10',
#   'pieces',
#   'needed',
#   'achieve',
#   'less',
#   'computation',
#   'rectangle',
#   'method',
#   'accuracy.',
#   'idea',
#   'behind',
#   'trapezoid',
#   'rule,',
#   'accurate',
#   'approximations',
#   'function',
#   'yield',
#   'better',
#   'approximations',
#   'integral,',
#   'carried',
#   "simpson's",
#   'rule',
#   'approximates',
#   'integrand',
#   'piecewise',
#   'quadratic',
#   'function.',
#   'riemann',
#   'sums,',
#   'trapezoid',
#   'rule,',
#   "simpson's",
#   'rule',
#   'examples',
#   'family',
#   'quadrature',
#   'rules',
#   'called',
#   'newton–cotes',
#   'formulas',
#   'degree',
#   'n',
#   'newton–cotes',
#   'quadrature',
#   'rule',
#   'approximates',
#   'polynomial',
#   'subinterval',
#   'degree',
#   'n',
#   'polynomial',
#   'chosen',
#   'interpolate',
#   'values',
#   'function',
#   'interval.',
#   'higher',
#   'degree',
#   'approximations',
#   'require',
#   'function',
#   'evaluations',
#   "simpson's",
#   'rule',
#   'requires',
#   'twice',
#   'function',
#   'evaluations',
#   'trapezoid',
#   'numerical',
#   'due',
#   'one',
#   'solution',
#   'problem',
#   'quadrature',
#   'integrand',
#   'approximated',
#   'terms',
#   'polynomials',
#   'produces',
#   'approximation',
#   'whose',
#   'values',
#   'never',
#   'far',
#   'original',
#   'function.',
#   'method',
#   'trapezoid',
#   'method',
#   'great',
#   'effect.',
#   'first,',
#   'step',
#   'lengths',
#   'giving',
#   'trapezoid',
#   'approximations',
#   'denoted',
#   'h',
#   '0',
#   '),',
#   'h',
#   '1',
#   'on,',
#   'h',
#   'k',
#   '+1',
#   'half',
#   'h',
#   'k',
#   'new',
#   'step',
#   'half',
#   'new',
#   'function',
#   'values',
#   'need',
#   'others',
#   'carry',
#   'previous',
#   'size',
#   '(as',
#   'shown',
#   'table',
#   'really',
#   'powerful',
#   'idea',
#   'interpolate',
#   'polynomial',
#   'approximations,',
#   '(0)',
#   'method',
#   'numerically',
#   'exact',
#   'answer',
#   'requires',
#   'four',
#   'pieces',
#   'function',
#   'lagrange',
#   'polynomial',
#   'h',
#   'k',
#   'h',
#   'k',
#   ')}',
#   'k',
#   '3.76',
#   'h',
#   '2',
#   'producing',
#   'value',
#   '3.76',
#   'h',
#   '0',
#   'gaussian',
#   'quadrature',
#   'often',
#   'requires',
#   'noticeably',
#   'less',
#   'work',
#   'superior',
#   'accuracy.',
#   'example,',
#   'compute',
#   'function',
#   'values',
#   'two',
#   'x',
#   '⁄',
#   '√',
#   '3',
#   'double',
#   'value',
#   'sum',
#   'get',
#   'numerically',
#   'exact',
#   'dramatic',
#   'success',
#   'lies',
#   'choice',
#   'points.',
#   'unlike',
#   'newton–cotes',
#   'interpolate',
#   'integrand',
#   'points,',
#   'gaussian',
#   'quadrature',
#   'function',
#   'roots',
#   'set',
#   'polynomials',
#   'n',
#   'gaussian',
#   'method',
#   'exact',
#   'polynomials',
#   'degree',
#   '2',
#   'n',
#   '−',
#   '1',
#   'function',
#   'example',
#   'degree',
#   '3',
#   'plus',
#   'term',
#   'chosen',
#   'around',
#   'zero.',
#   'also',
#   'benefits',
#   'practice,',
#   'method',
#   'must',
#   'use',
#   'evaluations',
#   'ensure',
#   'error',
#   'bound',
#   'unknown',
#   'tends',
#   'advantage',
#   'pure',
#   'gaussian',
#   'method,',
#   'motivates',
#   'popular',
#   'quadrature',
#   'formulae',
#   'adaptive',
#   'quadrature',
#   'partitions',
#   'range',
#   'pieces',
#   'based',
#   'function',
#   'data',
#   'points',
#   'concentrated',
#   'needed',
#   'computation',
#   'higher-dimensional',
#   'integrals',
#   '(for',
#   'example,',
#   'volume',
#   'makes',
#   'important',
#   'use',
#   'monte',
#   'carlo',
#   'integration',
#   'calculus',
#   'text',
#   'substitute',
#   'numerical',
#   'reverse',
#   'also',
#   'true.',
#   'even',
#   'best',
#   'adaptive',
#   'numerical',
#   'code',
#   'sometimes',
#   'requires',
#   'help',
#   'demanding',
#   'integrals.',
#   'example,',
#   'improper',
#   'integrals',
#   'may',
#   'require',
#   'change',
#   'variable',
#   'methods',
#   'avoid',
#   'infinite',
#   'function',
#   'values,',
#   'known',
#   'properties',
#   'like',
#   'may',
#   'provide',
#   'critical',
#   'example,',
#   'integral',
#   '∫',
#   '0',
#   '1',
#   'x',
#   '−',
#   '1',
#   '2',
#   'e',
#   '−',
#   'x',
#   'x',
#   '{\\displaystyle',
#   '\\int',
#   'difficult',
#   'evaluate',
#   'numerically',
#   'infinite',
#   'x',
#   '0',
#   'however,',
#   'u',
#   '√',
#   'x',
#   'integral',
#   '2',
#   '∫',
#   '0',
#   '1',
#   'e',
#   '−',
#   'u',
#   '2',
#   'u',
#   '{\\displaystyle',
#   'singularities',
#   'area',
#   'arbitrary',
#   'two-dimensional',
#   'determined',
#   'using',
#   'measuring',
#   'called',
#   'volume',
#   'measured',
#   'precision',
#   'fluid',
#   'object',
#   'area',
#   'sometimes',
#   'found',
#   'via',
#   'constructions',
#   'equivalent',
#   'square'],
#  ['branch',
#   'mathematics',
#   'known',
#   'real',
#   'analysis',
#   'riemann',
#   'integral',
#   'created',
#   'bernhard',
#   'riemann',
#   'first',
#   'rigorous',
#   'definition',
#   'integral',
#   'function',
#   'interval',
#   'presented',
#   'university',
#   'published',
#   'journal',
#   '[1]',
#   'many',
#   'functions',
#   'practical',
#   'applications,',
#   'riemann',
#   'integral',
#   'evaluated',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'approximated',
#   'numerical',
#   'integration',
#   'riemann',
#   'integral',
#   'unsuitable',
#   'many',
#   'technical',
#   'riemann',
#   'integration',
#   'riemann–stieltjes',
#   'integral',
#   'lebesgue',
#   'integral',
#   'let',
#   'f',
#   'non-negative',
#   'real',
#   '-valued',
#   'function',
#   'interval',
#   'b',
#   'let',
#   'region',
#   'plane',
#   'graph',
#   'function',
#   'f',
#   'interval',
#   'b',
#   '(see',
#   'figure',
#   'top',
#   'interested',
#   'measuring',
#   'area',
#   'measured',
#   'it,',
#   'denote',
#   'area',
#   'by:',
#   'basic',
#   'idea',
#   'riemann',
#   'integral',
#   'use',
#   'simple',
#   'approximations',
#   'area',
#   'taking',
#   'better',
#   'better',
#   'approximations,',
#   'say',
#   '"in',
#   'get',
#   'exactly',
#   'area',
#   'note',
#   'f',
#   'positive',
#   'negative,',
#   'definition',
#   'integral',
#   'signed',
#   'area',
#   'graph',
#   'f',
#   'is,',
#   'area',
#   'x',
#   '-axis',
#   'minus',
#   'area',
#   'x',
#   'partition',
#   'interval',
#   'b',
#   'finite',
#   'sequence',
#   'numbers',
#   'form',
#   'x',
#   'x',
#   '1',
#   'called',
#   'sub-interval',
#   'partition.',
#   'mesh',
#   'norm',
#   'partition',
#   'defined',
#   'length',
#   'longest',
#   'sub-interval,',
#   'is,',
#   'tagged',
#   'partition',
#   'p',
#   'x',
#   'interval',
#   'b',
#   'partition',
#   'together',
#   'finite',
#   'sequence',
#   'numbers',
#   '0',
#   '...,',
#   'n',
#   '−',
#   '1',
#   'subject',
#   'conditions',
#   '∈',
#   'x',
#   'x',
#   '1',
#   'words,',
#   'partition',
#   'together',
#   'distinguished',
#   'point',
#   'every',
#   'mesh',
#   'tagged',
#   'partition',
#   'ordinary',
#   'partition.',
#   'suppose',
#   'two',
#   'partitions',
#   'p',
#   'x',
#   'q',
#   'partitions',
#   'interval',
#   'b',
#   'say',
#   'q',
#   'refinement',
#   'p',
#   'x',
#   'integer',
#   '∈',
#   '[0,',
#   'n',
#   'exists',
#   'integer',
#   'r',
#   'x',
#   'r',
#   'j',
#   'j',
#   'j',
#   '∈',
#   'r',
#   '),',
#   'r',
#   'said',
#   'refinement',
#   'tagged',
#   'partition',
#   'sub-intervals',
#   'adds',
#   'tags',
#   'partition',
#   'thus',
#   'accuracy',
#   'partition.',
#   'define',
#   'partial',
#   'order',
#   'set',
#   'tagged',
#   'partitions',
#   'one',
#   'tagged',
#   'partition',
#   'greater',
#   'equal',
#   'another',
#   'former',
#   'refinement',
#   'let',
#   'f',
#   'real-valued',
#   'function',
#   'defined',
#   'interval',
#   'b',
#   'riemann',
#   'sum',
#   'f',
#   'respect',
#   'tagged',
#   'partition',
#   'x',
#   '0',
#   '...,',
#   'x',
#   'n',
#   'together',
#   '0',
#   '...,',
# ...
#   'material',
#   '19th-century',
#   'finnish',
#   'poem.',
#   'written',
#   '1915',
#   'tolkien',
#   'studying',
#   'oxford.',
#   '[173]',
#   'tale',
#   'beren',
#   'lúthien',
#   'one',
#   'oldest',
#   'often',
#   'revised',
#   "tolkien's",
#   'story',
#   'one',
#   'three',
#   'contained',
#   'within',
#   'silmarillion',
#   'tolkien',
#   'believed',
#   'warrant',
#   'published',
#   'standalone',
#   'book,',
#   'edited',
#   'christopher',
#   'tolkien,',
#   'title',
#   'beren',
#   'lúthien',
#   '[174]',
#   'fall',
#   'gondolin',
#   'tale',
#   'mysterious',
#   'city',
#   'destroyed',
#   'dark',
#   'tolkien',
#   'called',
#   '"the',
#   'first',
#   'real',
#   'middle-earth',
#   'published',
#   '30',
#   'august',
#   '[175]',
#   'standalone',
#   'book,',
#   'edited',
#   'christopher',
#   'tolkien',
#   'illustrated',
#   '[176]',
#   'death,',
#   'tolkien',
#   'manuscripts,',
#   'proofs',
#   'materials',
#   'related',
#   'lord',
#   'rings',
#   'hobbit',
#   'farmer',
#   'giles',
#   'ham',
#   '—to',
#   'department',
#   'special',
#   'collections',
#   'university',
#   'archives',
#   'university',
#   "'s",
#   'john',
#   'p.',
#   'library',
#   '[177]',
#   'death',
#   'estate',
#   'papers',
#   "tolkien's",
#   'silmarillion',
#   'mythology',
#   'academic',
#   'work',
#   'bodleian',
#   'library',
#   'oxford',
#   'university',
#   '[178]',
#   'library',
#   'held',
#   'exhibition',
#   'work',
#   'including',
#   'never',
#   'seen',
#   'public',
#   'before.',
#   '[179]',
#   'partial',
#   'draft',
#   'language',
#   'human',
#   'nature',
#   'tolkien',
#   'begun',
#   'c.',
#   's.',
#   'lewis',
#   'never',
#   'discovered',
#   'bodleian',
#   'library.',
#   '[180]',
#   "tolkien's",
#   'academic',
#   'career',
#   'literary',
#   'production',
#   'inseparable',
#   'love',
#   'language',
#   'philology',
#   'specialized',
#   'english',
#   'philology',
#   'university',
#   '1915',
#   'old',
#   'norse',
#   'special',
#   'subject.',
#   'worked',
#   'oxford',
#   'english',
#   'dictionary',
#   '1918',
#   'worked',
#   'number',
#   'words',
#   'starting',
#   'letter',
#   'including',
#   'struggled',
#   '[181]',
#   '1920,',
#   'became',
#   'reader',
#   'english',
#   'language',
#   'university',
#   'leeds',
#   'claimed',
#   'number',
#   'students',
#   'five',
#   'gave',
#   'old',
#   'english',
#   'verse',
#   'history',
#   'english',
#   'various',
#   'old',
#   'english',
#   'middle',
#   'english',
#   'old',
#   'middle',
#   'english',
#   'philology,',
#   'introductory',
#   'germanic',
#   'philology,',
#   'gothic',
#   'old',
#   'medieval',
#   'welsh',
#   '1925,',
#   'aged',
#   'tolkien',
#   'applied',
#   'rawlinson',
#   'bosworth',
#   'anglo-saxon',
#   'pembroke',
#   'college,',
#   'oxford',
#   'students',
#   'germanic',
#   'philology',
#   'leeds',
#   'even',
#   'formed',
#   'club',
#   '".',
#   '[182]',
#   'also',
#   'knowledge',
#   'finnish',
#   '[183]',
#   'tolkien',
#   'attracted',
#   'linguistic',
#   'lecture',
#   'english',
#   'welsh',
#   'crucial',
#   'understanding',
#   'race',
#   'language,',
#   'entertained',
#   'notions',
#   'linguistic',
#   'termed',
#   '"native',
#   'opposed',
#   'person',
#   'first',
#   '[184]',
#   'considered',
#   'west',
#   'middle',
#   'english',
#   '"native',
#   'and,',
#   'wrote',
#   'w.',
#   'h.',
#   'auden',
#   '1955,',
#   '"i',
#   'blood',
#   '(and',
#   'took',
#   'early',
#   'middle',
#   'english',
#   'known',
#   'tongue',
#   'soon',
#   'set',
#   'eyes',
#   '[185]',
#   'parallel',
#   "tolkien's",
#   'work',
#   'sometimes',
#   'work,',
#   'effect',
#   'academic',
#   'output',
#   'remained',
#   'rather',
#   'affection',
#   'languages',
#   'developed',
#   'quenya',
#   'connection',
#   'formed',
#   'much',
#   "tolkien's",
#   'legendarium',
#   'language',
#   'tolkien',
#   'matter',
#   'quenya',
#   'particular',
#   'designed',
#   'intended',
#   'based',
#   'english,',
#   '[150]',
#   'notable',
#   'addition',
#   'came',
#   'late',
#   '1945',
#   'language',
#   'connected',
#   "tolkien's",
#   'atlantis',
#   'notion',
#   'club',
#   'papers',
#   'directly',
#   'ideas',
#   'inability',
#   'language',
#   'via',
#   'second',
#   'age',
#   'story',
#   'legendarium',
#   'link',
#   "tolkien's",
#   '20th-century',
#   'primary',
#   'legendary',
#   'past',
#   'middle-earth.',
#   'tolkien',
#   'considered',
#   'languages',
#   'inseparable',
#   'mythology',
#   'associated',
#   'them,',
#   'took',
#   'view',
#   'auxiliary',
#   'languages',
#   '1930',
#   'told',
#   'much',
#   'him,',
#   'lecture',
#   'secret',
#   'vice',
#   '[186]',
#   'language',
#   'construction',
#   'mythology",',
#   '1956',
#   'concluded',
#   'esperanto',
#   '&amp;c,',
#   '&amp;c,',
#   'dead,',
#   'far',
#   'ancient',
#   'languages,',
#   'authors',
#   'never',
#   'invented',
#   'esperanto',
#   '[187]',
#   'popularity',
#   "tolkien's",
#   'books',
#   'small',
#   'lasting',
#   'effect',
#   'use',
#   'language',
#   'fantasy',
#   'literature',
#   'particular,',
#   'even',
#   'today',
#   'commonly',
#   'accept',
#   "tolkien's",
#   'dwarves',
#   '),',
#   'little',
#   'used',
#   'since',
#   'century',
#   '(in',
#   'fact,',
#   'according',
#   'tolkien,',
#   'old',
#   'english',
#   'would',
#   '.)',
#   'also',
#   'coined',
#   'term',
#   'though',
#   'remains',
#   'mainly',
#   'used',
#   'connection',
#   'work.',
#   'tolkien',
#   'accomplished',
#   'artist,',
#   'learned',
#   'paint',
#   'draw',
#   'child',
#   'continued',
#   'life.',
#   '[188]',
#   'early',
#   'writing',
#   'development',
#   'stories',
#   'accompanied',
#   'drawings',
#   'paintings,',
#   'especially',
#   'landscapes,',
#   'maps',
#   'lands',
#   'tales',
#   'also',
#   'produced',
#   'pictures',
#   'stories',
#   'told',
#   'children,',
#   'including',
#   'later',
#   'published',
#   'bliss',
#   'roverandom',
#   'sent',
#   'illustrated',
#   'letters',
#   'come',
#   'father',
#   'christmas.',
#   'although',
#   'regarded',
#   'publisher',
#   'used',
#   "author's",
#   'cover',
#   'art,',
#   'illustrations',
#   'early',
#   'editions',
#   'hobbit',
#   'much',
#   'artwork',
#   'collected',
#   'published',
#   '1995',
#   'j.',
#   'r.',
#   'r.',
#   'tolkien:',
#   'artist',
#   'illustrator',
#   'book',
#   'discusses',
#   "tolkien's",
#   'paintings,',
#   'drawings,',
#   'sketches,',
#   'approximately',
#   '200',
#   'examples',
#   'work.',
#   '[189]',
#   '1951',
#   'letter',
#   'publisher',
#   'milton',
#   'waldman',
#   'tolkien',
#   'wrote',
#   'create',
#   'less',
#   'connected',
#   'linked',
#   'yet',
#   'leave',
#   'scope',
#   'minds',
#   'paint',
#   'music',
#   '[190]',
#   'hands',
#   'minds',
#   'many',
#   'artists',
#   'indeed',
#   'inspired',
#   "tolkien's",
#   'legends.',
#   'personally',
#   'known',
#   'favourite',
#   'illustrator',
#   'adventures',
#   'tom',
#   'bombadil',
#   'farmer',
#   'giles',
#   'ham',
#   'donald',
#   'set',
#   'music',
#   'road',
#   'goes',
#   'ever',
#   ').',
#   'queen',
#   'ii',
#   'created',
#   'illustrations',
#   'lord',
#   'rings',
#   'early',
#   '1970s.',
#   'sent',
#   'tolkien,',
#   'struck',
#   'similarity',
#   'bore',
#   'style',
#   'drawings.',
#   '[191]',
#   'however,',
#   'tolkien',
#   'fond',
#   'artistic',
#   'representation',
#   'works',
#   'produced',
#   'lifetime,',
#   'sometimes',
#   'harshly',
#   'rejected',
#   'illustrations',
#   'german',
#   'edition',
#   'hobbit',
#   '...',
#   'bilbo',
#   'gandalf',
#   'figure',
#   'rather',
#   'think',
#   '[192]',
#   'tolkien',
#   'tolkien',
#   'united',
#   '1954',
#   'returned',
#   'american',
#   'edition',
#   'lord',
#   'rings',
#   'thank',
#   'rule',
#   'amenable',
#   'criticism',
#   'think',
#   'effort',
#   'poor',
#   'feel',
#   'make',
#   'effort',
#   'improve',
#   'it.',
#   '[150]',
#   'dismissed',
#   'dramatic',
#   'representations',
#   'fantasy',
#   'essay',
#   'fairy-stories',
#   '",',
#   'first',
#   'presented',
#   'human',
#   'art',
#   'fantasy',
#   'thing',
#   'best',
#   'left',
#   'words,',
#   'true',
#   'literature.',
#   '...',
#   'fantasy.',
#   'even',
#   'simplest',
#   'hardly',
#   'ever',
#   'presented',
#   'be,',
#   '[193]',
#   'tolkien',
#   'scholar',
#   'james',
#   'coined',
#   'word',
#   'derived',
#   '"tolkien',
#   'describe',
#   'attempts',
#   'create',
#   'adaptation',
#   'stories',
#   "tolkien's",
#   'legendarium',
#   'good',
#   'box',
#   'office',
#   'rather',
#   'idea',
#   '[194]',
#   'receiving',
#   'screenplay',
#   'proposed',
#   'film',
#   'adaptation',
#   'lord',
#   'rings',
#   'tolkien',
#   'wrote:',
#   'would',
#   'ask',
#   'make',
#   'effort',
#   'imagination',
#   'sufficient',
#   'understand',
#   '(and',
#   'occasion',
#   'author,',
#   'increasingly',
#   'work',
#   'treated',
#   'would',
#   'seem',
#   'general,',
#   'places',
#   'evident',
#   'signs',
#   'appreciation',
#   '[195]',
#   'tolkien',
#   'went',
#   'script',
#   'scene',
#   'scene',
#   'one',
#   'scene',
#   'rather',
#   'opposed',
#   'idea',
#   'dramatic',
#   'however,',
#   'sold',
#   'film,',
#   'stage',
#   'rights',
#   'hobbit',
#   'lord',
#   'rings',
#   'united',
#   'artists',
#   'united',
#   'artists',
#   'never',
#   'made',
#   'film,',
#   'although',
#   'director',
#   'john',
#   'planning',
#   'live-action',
#   'film',
#   'early',
#   '1970s.',
#   'rights',
#   'sold',
#   'tolkien',
#   'division',
#   'company,',
#   'first',
#   'film',
#   'adaptation',
#   'lord',
#   'rings',
#   'released',
#   'animated',
#   'film',
#   'directed',
#   'bakshi',
#   'screenplay',
#   'fantasy',
#   'writer',
#   'peter',
#   's.',
#   'covered',
#   'first',
#   'half',
#   'story',
#   'lord',
#   'rings',
#   '[196]',
#   'animated',
#   'musical',
#   'television',
#   'film',
#   'hobbit',
#   'made',
#   '1980,',
#   'produced',
#   'animated',
#   'musical',
#   'television',
#   'film',
#   'return',
#   'king',
#   'covered',
#   'portions',
#   'lord',
#   'rings',
#   'bakshi',
#   'unable',
#   'complete.',
#   '2001',
#   '2003,',
#   'new',
#   'line',
#   'cinema',
#   'released',
#   'lord',
#   'rings',
#   'live-action',
#   'films',
#   'filmed',
#   'new',
#   'zealand',
#   'directed',
#   'peter',
#   'jackson',
#   'series',
#   'successful,',
#   'extremely',
#   'well',
#   'commercially',
#   'numerous',
#   'oscars',
#   '[197]',
#   '2012',
#   '2014,',
#   'new',
#   'line',
#   'cinema',
#   'released',
#   'hobbit',
#   'series',
#   'three',
#   'films',
#   'based',
#   'hobbit',
#   'peter',
#   'jackson',
#   '[198]',
#   'first',
#   'instalment,',
#   'hobbit:',
#   'unexpected',
#   'journey',
#   'released',
#   'december',
#   '[199]',
#   'second,',
#   'hobbit:',
#   'december',
#   '[200]',
#   'last',
#   'instalment,',
#   'hobbit:',
#   'battle',
#   'five',
#   'december',
#   '[201]',
#   'biographical',
#   'film',
#   'tolkien',
#   'released',
#   '10',
#   'may',
#   'focused',
#   "tolkien's",
#   'early',
#   'life',
#   'war',
#   '[202]',
#   'tolkien',
#   'family',
#   'estate',
#   'stated',
#   'participate',
#   'making',
#   'film.',
#   '[203]',
#   '13',
#   'november',
#   '2017,',
#   'announced',
#   'amazon',
#   'acquired',
#   'television',
#   'rights',
#   'lord',
#   'rings',
#   'series',
#   'direct',
#   'adaptation',
#   'books,',
#   'instead',
#   'new',
#   'stories',
#   'set',
#   'fellowship',
#   'ring.',
#   '[204]',
#   'press',
#   'release',
#   'referred',
#   'stories',
#   'based',
#   'j.',
#   'r.',
#   'r.',
#   "tolkien's",
#   'original',
#   'amazon',
#   'tolkien',
#   'estate',
#   'tolkien',
#   'trust',
#   'harpercollins',
#   'new',
#   'line',
#   'cinema',
#   '[205]',
#   'tolkien',
#   'characters',
#   'places',
#   'works',
#   'become',
#   'various',
#   'things',
#   'around',
#   'world.',
#   'include',
#   'street',
#   'names,',
#   'species',
#   'well',
#   'notable',
#   'objects.',
#   'convention,',
#   'certain',
#   'classes',
#   'features',
#   'named',
#   'elements',
#   'middle-earth.',
#   '[206]',
#   'hills',
#   'named',
#   'characters,',
#   '[207]',
#   'named',
#   'mountains',
#   'middle-earth.',
#   '[208]',
#   'also',
#   'named',
#   'bilbo',
#   'baggins',
#   'tolkien',
#   'himself.',
#   '[209]',
#   '[210]',
#   'three',
#   'mountains',
#   'range',
#   'british',
#   'columbia',
#   'named',
#   "tolkien's",
#   'characters.',
#   'mount',
#   'mount',
#   'gandalf',
#   'mount',
#   '[211]',
#   '[212]',
#   '1',
#   'december',
#   '2012,',
#   'announced',
#   'new',
#   'zealand',
#   'press',
#   'new',
#   'zealand',
#   'board',
#   'name',
#   'peak',
#   'near',
#   'tolkien',
#   'historical',
#   'literary',
#   'reasons',
#   'mark',
#   "tolkien's",
#   'birthday.',
#   '[213]',
#   '"tolkien',
#   'east',
#   'named',
#   'tolkien',
#   'whereas',
#   '"tolkien',
#   'named',
#   "tolkien's",
#   'son,',
#   'fr.',
#   'john',
#   'francis',
#   'tolkien,',
#   'priest',
#   'charge',
#   'nearby',
#   'roman',
#   'catholic',
#   'church',
#   'lady',
#   'angels',
#   'st.',
#   'peter',
#   '[214]',
#   'hall',
#   'green',
#   'moseley',
#   'areas',
#   'birmingham',
#   'number',
#   'parks',
#   'dedicated',
#   'j.',
#   'r.',
#   'r.',
#   'way',
#   'moseley',
#   'bog',
#   '[215]',
#   'parks',
#   'known',
#   'shire',
#   'country',
#   '[215]',
#   'also',
#   'england',
#   'collection',
#   'named',
#   'middle',
#   'namely',
#   'road,',
#   'close,',
#   'close,',
#   'way',
#   'green.',
#   'dutch',
#   'town',
#   'near',
#   'entire',
#   'new',
#   'neighbourhood',
#   'named',
#   'tolkien',
#   'van',
#   'characters',
#   'books.',
#   'towns',
#   'san',
#   'california,',
#   'two',
#   'developments',
#   'street',
#   'names',
#   'drawn',
#   "tolkien's",
#   'works.',
#   'dozen',
#   'street',
#   'names',
#   'also',
#   'appear',
#   'throughout',
#   'town',
#   'lake',
#   'california',
#   'columbia',
#   'neighbourhood',
#   'street',
#   'names',
#   '(including',
#   'come',
#   "tolkien's",
#   'works.',
#   '[216]',
#   'field',
#   '80',
#   'taxa',
#   'given',
#   'scientific',
#   'names',
#   'deriving',
#   'characters',
#   'fictional',
#   'elements',
#   'lord',
#   'rings',
#   'hobbit',
#   'works',
#   'set',
#   'middle-earth',
#   '[217]',
#   'several',
#   'taxa',
#   'named',
#   'character',
#   '(also',
#   'known',
#   'well',
#   'various',
#   'small',
#   'creatures',
#   'bilbo',
#   'frodo',
#   'baggins',
#   'various',
#   'elves',
#   'dwarves',
#   'creatures',
#   'appear',
#   'writings',
#   'well',
#   'tolkien',
#   'honoured',
#   'names',
#   'several',
#   'including',
#   'tolkieni',
#   'tolkieni',
#   '2004,',
#   'extinct',
#   'quickly',
#   'earned',
#   'due',
#   'small',
#   '[218]',
#   'van',
#   'named',
#   '20',
#   'taxa',
#   'extinct',
#   'tolkien',
#   'single',
#   'paper.',
#   '[219]',
#   '[220]',
#   '1999,',
#   'described',
#   'new',
#   'species',
#   'named',
#   '37',
#   'tolkien',
#   'mythology.',
#   '[217]',
#   '[221]',
#   'noted',
#   '"tolkien',
#   'formal',
#   'like',
#   '[222]',
#   'since',
#   '2003,',
#   'tolkien',
#   'society',
#   'organized',
#   'tolkien',
#   'reading',
#   'day',
#   'takes',
#   'place',
#   '25',
#   'march',
#   'schools',
#   'around',
#   'world.',
#   '[223]',
#   '2013,',
#   'pembroke',
#   'college,',
#   'oxford',
#   'university',
#   'established',
#   'annual',
#   'lecture',
#   'fantasy',
#   'literature',
#   "tolkien's",
#   '[224]',
#   'seven',
#   'blue',
#   'plaques',
#   'england',
#   'commemorate',
#   'places',
#   'associated',
#   'tolkien:',
#   'one',
#   'oxford,',
#   'one',
#   'four',
#   'birmingham',
#   'one',
#   'one',
#   'birmingham',
#   'plaques',
#   'commemorates',
#   'inspiration',
#   'provided',
#   'sarehole',
#   'near',
#   'lived',
#   'four',
#   'two',
#   'mark',
#   'childhood',
#   'time',
#   'left',
#   'attend',
#   'oxford',
#   'university',
#   'marks',
#   'hotel',
#   'stayed',
#   'leaving',
#   'france',
#   'world',
#   'war',
#   'plaque',
#   'west',
#   'leeds,',
#   'commemorates',
#   'five',
#   'years',
#   'tolkien',
#   'enjoyed',
#   'leeds',
#   'reader',
#   'professor',
#   'english',
#   'language',
#   'oxford',
#   'plaque',
#   'commemorates',
#   'tolkien',
#   'wrote',
#   'hobbit',
#   'lord',
#   'rings',
#   'another',
#   'two',
#   'plaques',
#   'associated',
#   'tolkien',
#   '2012,',
#   'tolkien',
#   'among',
#   'british',
#   'cultural',
#   'selected',
#   'artist',
#   'sir',
#   'peter',
#   'appear',
#   'new',
#   'version',
#   'famous',
#   'lonely',
#   'club',
#   'album',
#   'celebrate',
#   'british',
#   'cultural',
#   'figures',
#   'life',
#   '[233]',
#   '[234]',
#   'unlike',
#   'authors',
#   'tolkien',
#   'never',
#   'works.',
#   'owing',
#   'copies',
#   'letters',
#   'first',
#   'editions',
#   'individual',
#   'writings',
#   'however',
#   'achieved',
#   'high',
#   'values',
#   'may',
#   'occur',
#   'particular,',
#   'signed',
#   'first',
#   'edition',
#   'hobbit',
#   '1937',
#   'offered',
#   'also',
#   'include',
#   'non-fiction',
#   'books',
#   "tolkien's",
#   'private',
#   'library.',
#   '[235]',
#   'september',
#   '2017,',
#   'oxford',
#   'oratory',
#   "tolkien's",
#   'church',
#   'time',
#   'oxford,',
#   'offered',
#   'first',
#   'mass',
#   'intention',
#   "tolkien's",
#   'cause',
#   '[236]',
#   '[237]',
#   'prayer',
#   'written',
#   'thank',
#   'church',
#   'john',
#   'ronald',
#   'reuel',
#   'tolkien',
#   'poetry',
#   'passion',
#   'son,',
#   'symphony',
#   'spirit,',
#   'fully',
#   'infinite',
#   'maternal',
#   'given',
#   'us',
#   'living',
#   'image',
#   'jesus',
#   'wisdom',
#   'god',
#   'shown',
#   'us',
#   'necessary',
#   'measure',
#   'ordinary',
#   'christian',
#   'life',
#   'way',
#   'achieving',
#   'eternal',
#   'us,',
#   'according',
#   'will,',
#   'hoping',
#   'soon',
#   'numbered',
#   'among',
#   '[238]',
#   'small',
#   'selection',
#   'books',
#   'tolkien']]

# %% [markdown]
# # Zad
#
# Proszę
# * utworzyć reprezentację **bag-of-words**

# %%
from gensim import corpora, models, similarities, matutils
dictionary = corpora.Dictionary(texts)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
print(corpus)
# Out:
# [[(0, 2), (1, 2), (2, 1), (3, 1), (4, 4), (5, 3), (6, 1), (7, 2), (8, 1), (9, 1), (10, 2), (11, 1), (12, 1), (13, 1), (14, 1), (15, 2), (16, 3), (17, 1), (18, 2), (19, 2), (20, 1), (21, 2), (22, 3), (23, 1), (24, 1), (25, 4), (26, 3), (27, 1), (28, 1), (29, 2), (30, 5), (31, 4), (32, 2), (33, 1), (34, 10), (35, 1), (36, 18), (37, 2), (38, 3), (39, 1), (40, 1), (41, 2), (42, 1), (43, 4), (44, 1), (45, 2), (46, 1), (47, 1), (48, 17), (49, 1), (50, 1), (51, 1), (52, 1), (53, 3), (54, 3), (55, 2), (56, 3), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 1), (65, 2), (66, 2), (67, 1), (68, 2), (69, 1), (70, 1), (71, 1), (72, 2), (73, 2), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 2), (82, 1), (83, 1), (84, 1), (85, 1), (86, 1), (87, 2), (88, 1), (89, 3), (90, 5), (91, 2), (92, 5), (93, 1), (94, 3), (95, 12), (96, 3), (97, 2), (98, 2), (99, 1), (100, 1), (101, 4), (102, 1), (103, 2), (104, 2), (105, 5), (106, 13), (107, 2), (108, 7), (109, 2), (110, 1), (111, 4), (112, 1), (113, 1), (114, 5), (115, 3), (116, 2), (117, 1), (118, 3), (119, 12), (120, 2), (121, 6), (122, 1), (123, 1), (124, 2), (125, 2), (126, 1), (127, 1), (128, 21), (129, 1), (130, 2), (131, 9), (132, 2), (133, 1), (134, 1), (135, 4), (136, 1), (137, 2), (138, 2), (139, 1), (140, 1), (141, 1), (142, 1), (143, 1), (144, 1), (145, 1), (146, 1), (147, 3), (148, 46), (149, 2), (150, 2), (151, 5), (152, 3), (153, 1), (154, 2), (155, 2), (156, 1), (157, 2), (158, 1), (159, 1), (160, 1), (161, 1), (162, 1), (163,
# create a double wrapper over the original corpus: bow->tfidf->fold-in-lsi
for d in corpus_lda:
    print(d)
# Out:
# [(1, 0.9997882)]
# [(1, 0.9993463)]
# [(1, 0.9988674)]
# [(0, 0.9997009)]
# [(0, 0.1775278), (1, 0.8224722)]
# [(0, 0.5615931), (1, 0.43840688)]
# [(0, 0.98917115), (1, 0.010828832)]
# [(0, 0.9992584)]
# [(0, 0.094619244), (1, 0.9053808)]
# [(0, 0.1645873), (1, 0.83541274)]
# [(0, 0.9998014)]

# %% [markdown]
# # Zad
#
# Wypisz z czego składają się tematy:

# %%
import numpy as np

topic_inex = 0
print(model.print_topic(topicno=topic_inex))

topic_inex = 1
print(model.print_topic(topicno=topic_inex))
# Out:
# 0.010*"f" + 0.009*"x" + 0.008*"tolkien" + 0.007*"van" + 0.006*"function" + 0.006*"derivative" + 0.005*"n" + 0.004*"gogh" + 0.004*"also" + 0.004*"munch"
# 0.011*"x" + 0.009*"integral" + 0.007*"function" + 0.006*"f" + 0.005*"van" + 0.005*"kafka" + 0.005*"{\displaystyle" + 0.004*"one" + 0.004*"riemann" + 0.004*"gogh"

# %% [markdown]
# # Zad
#
# Proszę posortować zdania najbardziej pasujące do danego tematu.

# %%
import gensim

top_inex = 0

numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort(numpy_corpus[top_inex,:])[::-1]
for x in docs[:5]:
    print(corpus[x])
    
#trzeba by wypisać raczej zdania niż ich reprezentacje bag-of-words, ale tu nie mam dostepu do tekstu
# Out:
# [(0, 2), (3, 1), (4, 7), (12, 1), (15, 3), (17, 1), (21, 1), (22, 1), (25, 3), (26, 4), (36, 2), (40, 2), (42, 1), (44, 1), (48, 3), (49, 1), (50, 1), (51, 3), (53, 3), (57, 2), (58, 1), (62, 1), (63, 1), (64, 1), (67, 1), (68, 1), (71, 14), (76, 1), (77, 1), (79, 1), (80, 1), (83, 2), (91, 1), (93, 4), (94, 3), (95, 21), (97, 7), (98, 2), (99, 2), (102, 3), (103, 4), (104, 3), (109, 5), (128, 1), (131, 2), (135, 5), (136, 2), (138, 3), (142, 1), (143, 7), (151, 6), (153, 11), (155, 5), (156, 3), (157, 5), (158, 1), (159, 1), (162, 3), (163, 2), (165, 11), (167, 2), (168, 1), (170, 1), (177, 7), (184, 10), (186, 7), (187, 6), (189, 3), (190, 1), (195, 1), (198, 2), (199, 2), (201, 2), (206, 2), (209, 3), (212, 4), (215, 2), (217, 1), (218, 3), (224, 1), (227, 2), (228, 1), (229, 1), (230, 1), (244, 2), (247, 1), (248, 3), (250, 1), (253, 1), (256, 1), (259, 9), (260, 1), (261, 1), (270, 3), (271, 1), (274, 1), (282, 3), (283, 1), (291, 1), (293, 2), (294, 1), (295, 1), (300, 3), (301, 1), (302, 1), (315, 4), (332, 4), (333, 2), (335, 1), (339, 15), (341, 2), (343, 2), (345, 1), (347, 1), (349, 2), (351, 4), (352, 1), (356, 2), (357, 1), (358, 2), (366, 6), (372, 9), (373, 3), (374, 2), (376, 2), (378, 2), (389, 1), (390, 3), (395, 1), (397, 1), (399, 2), (404, 1), (405, 9), (406, 3), (407, 5), (408, 1), (411, 2), (412, 3), (417, 32), (418, 2), (419, 1), (420, 3), (427, 5), (428, 1), (430, 2), (431, 2), (432, 1), (433, 3), (440, 
(1229, 2), (1247, 1), (1248, 2), (1258, 3), (1260, 2), (1263, 1), (1266, 1), (1272, 1), (1277, 1), (1297, 1), (1299, 1), (1301, 1), (1318, 1), (1320, 2), (1322, 3), (1323, 1), (1324, 1), (1329, 2), (1332, 1), (1339, 4), (1344, 1), (1348, 1), (1349, 2), (1351, 2), (1359, 1), (1362, 1), (1363, 1), (1368, 2), (1369, 2), (1370, 15), (1377, 1), (1382, 1), (1388, 4), (1395, 1), (1405, 1), (1411, 2), (1422, 5), (1443, 1), (1447, 1), (1450, 1), (1452, 3), (1453, 1), (1459, 1), (1463, 1), (1466, 2), (1467, 1), (1468, 1), (1469, 3), (1473, 1), (1479, 2), (1499, 2), (1501, 6), (1502, 2), (1506, 3), (1508, 2), (1510, 1), (1513, 1), (1518, 1), (1521, 1), (1523, 1), (1528, 1), (1541, 1), (1546, 1), (1551, 1), (1553, 1), (1561, 3), (1563, 2), (1565, 5), (1566, 1), (1574, 2), (1576, 1), (1588, 1), (1595, 1), (1610, 5), (1635, 1), (1650, 3), (1658, 3), (1661, 1), (1681, 1), (1690, 7), (1699, 3), (1700, 3), (1701, 2), (1702, 4), (1703, 1 ...

# %%
top_inex = 0

numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort( numpy_corpus[top_inex,:] )[::-1]
print("------------------------------")
for x in docs:
    print(titles[x])
    print("------------------------------")
# Out:
# ------------------------------
# J._R._R._Tolkien
# ------------------------------
# Derivative
# ------------------------------
# Jan_Matejko
# ------------------------------
# Vincent_van_Gogh
# ------------------------------
# Edvard_Munch
# ------------------------------
# Limit_of_a_sequence
# ------------------------------
# Franz_Kafka
# ------------------------------
# Lev_Tolstoj
# ------------------------------
# Riemann-Stieltjes_integral
# ------------------------------
# Riemann_integral
# ------------------------------
# Integral
# ------------------------------

# %%
top_inex = 1

numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort( numpy_corpus[top_inex,:] )[::-1]
print("------------------------------")
for x in docs:
    print(titles[x])
    print("------------------------------")
# Out:
# ------------------------------
# Integral
# ------------------------------
# Riemann_integral
# ------------------------------
# Riemann-Stieltjes_integral
# ------------------------------
# Lev_Tolstoj
# ------------------------------
# Franz_Kafka
# ------------------------------
# Limit_of_a_sequence
# ------------------------------
# Edvard_Munch
# ------------------------------
# Vincent_van_Gogh
# ------------------------------
# J._R._R._Tolkien
# ------------------------------
# Jan_Matejko
# ------------------------------
# Derivative
# ------------------------------

# %% [markdown]
# # Zad.
# Sprawdzić do jakiego tematu pasuje nowy dokument i jakie są mu najbliższe

# %%
doc = "Machine Learning"

doc_rep = dictionary.doc2bow(doc.split(' '))
# print(doc_rep)
doc_assignments = model[doc_rep]
print(doc_assignments)
# Out:
# [(0, 0.5), (1, 0.5)]

# %%
index = similarities.MatrixSimilarity(corpus_lda)

sims = index[doc_assignments]
# print(list(enumerate(sims)))

sims = sorted(enumerate(sims), key=lambda item: -item[1])
print(sims)
# Out:
# [(5, 0.9983149), (4, 0.83848196), (9, 0.8086794), (8, 0.7737471), (6, 0.7171822), (0, 0.70710677), (1, 0.70710677), (2, 0.70710677), (3, 0.70710677), (7, 0.70710677), (10, 0.70710677)]

# %% [markdown]
# # Zad
# Wizualizacja modelu LDA:

# %%
import pyLDAvis.gensim

pyLDAvis.enable_notebook()

# %%
pyLDAvis.gensim.prepare(model, corpus, dictionary)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x    y  topics  cluster       Freq
# topic
# 0      0.009076  0.0       1        1  55.452381
# 1     -0.009076  0.0       2        1  44.547619, topic_info=     Category        Freq               Term       Total  loglift  logprob
# term
# 547   Default  163.000000           integral  163.000000  30.0000  30.0000
# 291   Default  116.000000         derivative  116.000000  29.0000  29.0000
# 4935  Default  185.000000            tolkien  185.000000  28.0000  28.0000
# 460   Default   34.000000                  g   34.000000  27.0000  27.0000
# 550   Default   47.000000          integrals   47.000000  26.0000  26.0000
# 568   Default   39.000000           interval   39.000000  25.0000  25.0000
# 148   Default   77.000000                  b   77.000000  24.0000  24.0000
# 1315  Default   17.000000  riemann–stieltjes   17.000000  23.0000  23.0000
# 559   Default   39.000000        integration   39.000000  22.0000  22.0000
# 4443  Default  112.000000              kafka  112.000000  21.0000  21.0000
# 454   Default   52.000000          functions   52.000000  20.0000  20.0000
# 601   Default   33.000000           lebesgue   33.000000  19.0000  19.0000
# 1100  Default  305.000000                  x  305.000000  18.0000  18.0000
# 859   Default  102.000000            riemann  102.000000  17.0000  17.0000
# 1111  Default  117.000000     {\displaystyle  117.000000  16.0000  16.0000
# 4445  Default   66.000000            kafka's   66.000000  15.0000  15.0000
# 711   Default  118.000000                one  118.000000  14.0000  14.0000
# 997   Default   22.000000            theorem   22.000000  13.0000  13.0000
# 727   Default   14.000000                  p   14.000000  12.0000  12.0000
# 1398  Default    7.000000                 g}    7.000000  11.0000  11.0000
# 554   Default   10.000000          integrand   10.000000  10.0000  10.0000
# 292   Default   36.000000        derivatives   36.000000   9.0000   9.0000
# 960   Default   42.000000                sum   42.000000   8.0000   8.0000
# 549   Default   20.000000          integral.   20.000000   7.0000   7.0000
# 168   Default   20.000000            bounded   20.000000   6.0000   6.0000
# 1221  Default   38.000000              every   38.000000   5.0000   5.0000
# 734   Default   37.000000          partition   37.000000   4.0000   4.0000
# 402   Default  270.000000                  f  270.000000   3.0000   3.0000
# 969   Default   14.000000            surface   14.000000   2.0000   2.0000
# 450   Default  208.000000           function  208.000000   1.0000   1.0000
# ...       ...         ...                ...         ...      ...      ...
# 859    Topic2   58.265060            riemann  102.826935   0.2406  -5.4977
# 552    Topic2    6.917714         integrals.   10.012277   0.4389  -7.6286
# 1111   Topic2   64.405807     {\displaystyle  117.579971   0.2067  -5.3975
# 1100   Topic2  151.037903                  x  305.732727   0.1034  -4.5452
# 4445   Topic2   38.088886            kafka's   66.181046   0.2561  -5.9228
# 648    Topic2   15.014468            measure   23.543312   0.3588  -6.8537
# 711    Topic2   62.386272                one  118.827896   0.1643  -5.4293
# 960    Topic2   24.956572                sum   42.342545   0.2800  -6.3456
# 450    Topic2   98.517258           function  208.466599   0.0591  -4.9725
# 1221   Topic2   22.794357              every   38.981678   0.2720  -6.4362
# 734    Topic2   21.930742          partition   37.254627   0.2787  -6.4748
# 2407   Topic2   36.103088             museum   68.366714   0.1701  -5.9763
