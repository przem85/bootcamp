# %%
from urllib import request
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# # Zad
# Zczytaj z wikipedi artykuły o tytułach
# ```python
# ["Integral", "Riemann_integral", "Riemann-Stieltjes_integral", "Derivative",
#     "Limit_of_a_sequence", "Edvard_Munch", "Vincent_van_Gogh", "Jan_Matejko",
#     "Lev_Tolstoj", "Franz_Kafka", "J._R._R._Tolkien"]
# ```
# i zapisz w tablicy zawartości tych podstron ($id="bodyContent"$)

# %%
wiki = "http://en.wikipedia.org/wiki/"
titles = ["Integral", "Riemann_integral", "Riemann-Stieltjes_integral", "Derivative",
    "Limit_of_a_sequence", "Edvard_Munch", "Vincent_van_Gogh", "Jan_Matejko",
    "Lev_Tolstoj", "Franz_Kafka", "J._R._R._Tolkien"]

# %%
def parse(url):        
    x = urlopen(url).read()
    x = BeautifulSoup(x).find("div",id="bodyContent").find_all("p")
    return(x)

articles = [parse(url) for url in [wiki+x for x in titles]]
articles = [" ".join([str(paragraph) for paragraph in article]) for article in articles]

articles[0][:200]
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\admin\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# '<p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, an <b>integral</b> assigns numbers to functions in a way that can describe displacement, area, volume, and other concepts that ar'

# %%
import re
articles = [re.sub("<.+?>"," ",a) for a in articles] # ew (str(a))

# %%
articles[0]
# Out:
# ' In  mathematics , an  integral  assigns numbers to functions in a way that can describe displacement, area, volume, and other concepts that arise by combining  infinitesimal  data. Integration is one of the two main operations of  calculus , with its inverse operation,  differentiation , being the other. Given a  function   f  of a  real   variable   x  and an  interval   [ a ,  b ]  of the  real line , the  definite integral \n   is defined informally as the signed  area  of the region in the  xy -plane that is bounded by the  graph  of  f , the  x -axis and the vertical lines   x  =  a   and   x  =  b  . The area above the  x -axis adds to the total and that below the  x -axis subtracts from the total.\n   The operation of integration, up to an additive constant, is the inverse of the operation of differentiation. For this reason, the term  integral  may also refer to the related notion of the  antiderivative , a function  F  whose derivative is the given function  f . In this case, it is called an indefinite integral and is written:\n   The integrals discussed in this article are those termed  definite integrals . It is the  fundamental theorem of calculus  that connects differentiation with the definite integral: if  f  is a continuous real-valued function defined on a  closed interval   [ a ,  b ] , then, once an antiderivative  F  of  f  is known, the definite integral of  f  over that interval is given by\n   The principles of integration were formulated independently by  Isaac Newton  and  Gottfried Wilhelm Leibniz  in the late 17th century, who thought of the integral as an infinite sum of rectangles of  infinitesimal  width.  Bernhard Riemann  gave a rigorous mathematical definition of integrals. It is based on a limiting procedure that approximates the area of a  curvilinear  region by breaking the region into thin vertical slabs. Beginning in the nineteenth century, more sophisticated notions of integrals began to appear, where the type of the function as well as the  domain  over which the integration is performed has been generalised. A  line integral  is defined for functions of two or more variables, and the interval of integration  [ a ,  b ]  is replaced by a  curve  connecting the two endpoints. In a  surface integral , the curve is replaced by a piece of a  surface  in  three-dimensional space .\n   The first documented systematic technique capable of determining integrals is the  method of exhaustion  of the  ancient Greek  astronomer  Eudoxus  ( ca.  370 BC), which sought to find areas and volumes by breaking them up into an infinite number of divisions for which the area or volume was known. This method was further developed and employed by  Archimedes  in the 3rd century BC and used to calculate areas for  parabolas  and an approximation to the  area of a circle .\n   A similar method was independently developed in China around the 3rd century AD by  Liu Hui , who used it to find the area of the circle. This method was later used in the 5th century by Chinese father-and-son mathematicians  Zu Chongzhi  and  Zu Geng  to find the volume of a sphere ( Shea 2007 ;  Katz 2004 , pp.\xa0125–126).\n   The next significant advances in integral calculus did not begin to appear until the 17th century. At this time, the work of  Cavalieri  with his  method of Indivisibles , and work by  Fermat , began to lay the foundations of modern calculus, with Cavalieri computing the integrals of   x   n    up to degree   n  = 9  in  Cavalieri\'s quadrature formula . Further steps were made in the early 17th century by  Barrow  and  Torricelli , who provided the first hints of a connection between integration and  differentiation . Barrow provided the first proof of the  fundamental theorem of calculus .  Wallis  generalized Cavalieri\'s method, computing integrals of  x  to a general power, including negative powers and fractional powers.\n   The major advance in integration came in the 17th century with the independent dis ...

# %%
articles[1]
# Out:
# ' In the branch of  mathematics  known as  real analysis , the  Riemann integral , created by  Bernhard Riemann , was the first rigorous definition of the  integral  of a  function  on an  interval .  It was presented to the faculty at the  University of Göttingen  in 1854, but not published in a journal until 1868.  [1]   For many functions and practical applications, the Riemann integral can be evaluated by the  fundamental theorem of calculus  or approximated by  numerical integration .\n   The Riemann integral is unsuitable for many theoretical purposes. Some of the technical deficiencies in Riemann integration can be remedied with the  Riemann–Stieltjes integral , and most disappear with the  Lebesgue integral .\n   Let  f  be a non-negative  real -valued function on the interval  [ a ,  b ] , and let\n   be the region of the plane under the graph of the function  f  and above the interval  [ a ,  b ]  (see the figure on the top right). We are interested in measuring the area of  S . Once we have measured it, we will denote the area by:\n   The basic idea of the Riemann integral is to use very simple approximations for the area of  S . By taking better and better approximations, we can say that "in the limit" we get exactly the area of  S  under the curve.\n   Note that where  f  can be both positive and negative, the definition of  S  is modified so that the integral corresponds to the  signed area  under the graph of  f : that is, the area above the  x -axis minus the area below the  x -axis.\n   A  partition of an interval   [ a ,  b ]  is a finite sequence of numbers of the form\n   Each  [ x i  ,  x   i  + 1 ]  is called a  sub-interval  of the partition. The  mesh  or  norm  of a partition is defined to be the length of the longest sub-interval, that is,\n   A  tagged partition    P ( x ,  t )  of an interval  [ a ,  b ]  is a partition together with a finite sequence of numbers   t  0 , ...,  t   n  − 1   subject to the conditions that for each  i ,   t i   ∈ [ x i  ,  x   i  + 1 ] . In other words, it is a partition together with a distinguished point of every sub-interval. The mesh of a tagged partition is the same as that of an ordinary partition.\n   Suppose that two partitions   P ( x ,  t )  and   Q ( y ,  s )  are both partitions of the interval  [ a ,  b ] . We say that   Q ( y ,  s )  is a  refinement  of   P ( x ,  t )  if for each integer  i , with   i  ∈ [0,  n ] , there exists an integer   r ( i )  such that   x i   =  y   r ( i )   and such that   t i   =  s j    for some  j  with   j  ∈ [ r ( i ),  r ( i  + 1)) . Said more simply, a refinement of a tagged partition breaks up some of the sub-intervals and adds tags to the partition where necessary, thus it "refines" the accuracy of the partition.\n   We can define a  partial order  on the set of all tagged partitions by saying that one tagged partition is greater or equal to another if the former is a refinement of the latter.\n   Let  f  be a real-valued function defined on the interval  [ a ,  b ] . The   Riemann sum   of  f  with respect to the tagged partition   x  0 , ...,  x n    together with   t  0 , ...,  t   n  − 1   is  [2]  \n   Each term in the sum is the product of the value of the function at a given point and the length of an interval. Consequently, each term represents the (signed) area of a rectangle with height   f ( t i  )  and width   x   i  + 1  −  x i   . The Riemann sum is the (signed) area of all the rectangles.\n   A closely related concept are the  lower and upper Darboux sums . These are similar to Riemann sums, but the tags are replaced by the  infimum and supremum  (respectively) of  f  on each sub-interval:\n   If  f  is continuous, then the lower and upper Darboux sums for an untagged partition are equal to the Riemann sum for that partition, where the tags are chosen to be the minimum or maximum (respectively) of  f  on each subinterval. (When  f  is discontinuous on a subinterval, there may not be a tag that achieves  ...

# %%
import numpy as np
with open ('wiki_mycorpus.txt', 'w', encoding="utf-8") as f:
    for el in articles:
        f.write(el)

# %% [markdown]
# # Zad
#
# Oczyszczamy tekst:
#
# * tokenizacja
#
# * usuwanie stopwords
#
# * usuwanie tokenów występujących tylko 1 raz
#
# * zmiana dużych liter na małe

# %%
from pprint import pprint  # pretty-printer
from collections import defaultdict
from nltk.corpus import stopwords
import string

# remove common words and tokenize
stoplist = set('for a of the and to in'.split() + list(string.punctuation) + stopwords.words('english') )
texts = [[word for word in articles.lower().split() if word not in stoplist] for articles in articles]

# remove words that appear only once
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1]
         for text in texts]
print(len(texts))
pprint(texts)
# Out:
# 11
# [['mathematics',
#   'integral',
#   'assigns',
#   'numbers',
#   'functions',
#   'way',
#   'describe',
#   'displacement,',
#   'area,',
#   'volume,',
#   'concepts',
#   'arise',
#   'combining',
#   'infinitesimal',
#   'integration',
#   'one',
#   'two',
#   'main',
#   'operations',
#   'calculus',
#   'inverse',
#   'differentiation',
#   'other.',
#   'given',
#   'function',
#   'f',
#   'real',
#   'variable',
#   'x',
#   'interval',
#   'b',
#   'real',
#   'line',
#   'definite',
#   'integral',
#   'defined',
#   'signed',
#   'area',
#   'region',
#   'bounded',
#   'graph',
#   'f',
#   'x',
#   '-axis',
#   'vertical',
#   'lines',
#   'x',
#   'x',
#   'b',
#   'area',
#   'x',
#   '-axis',
#   'adds',
#   'total',
#   'x',
#   '-axis',
#   'operation',
#   'integration,',
#   'inverse',
#   'operation',
#   'differentiation.',
#   'reason,',
#   'term',
#   'integral',
#   'may',
#   'also',
#   'refer',
#   'related',
#   'notion',
#   'antiderivative',
#   'function',
#   'f',
#   'whose',
#   'derivative',
#   'given',
#   'function',
#   'f',
#   'case,',
#   'called',
#   'indefinite',
#   'integral',
#   'integrals',
#   'discussed',
#   'article',
#   'termed',
#   'definite',
#   'integrals',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'differentiation',
#   'definite',
#   'f',
#   'continuous',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'then,',
#   'antiderivative',
#   'f',
#   'f',
#   'known,',
#   'definite',
#   'integral',
#   'f',
#   'interval',
#   'given',
#   'principles',
#   'integration',
#   'formulated',
#   'independently',
#   'isaac',
#   'newton',
#   'gottfried',
#   'wilhelm',
#   'leibniz',
#   'late',
#   '17th',
#   'century,',
#   'thought',
#   'integral',
#   'infinite',
#   'sum',
#   'rectangles',
#   'infinitesimal',
#   'width.',
#   'bernhard',
#   'riemann',
#   'gave',
#   'rigorous',
#   'mathematical',
#   'definition',
#   'integrals.',
#   'based',
#   'limiting',
#   'procedure',
#   'approximates',
#   'area',
#   'region',
#   'breaking',
#   'region',
#   'thin',
#   'vertical',
#   'beginning',
#   'century,',
#   'sophisticated',
#   'notions',
#   'integrals',
#   'began',
#   'type',
#   'function',
#   'well',
#   'domain',
#   'integration',
#   'performed',
#   'line',
#   'integral',
#   'defined',
#   'functions',
#   'two',
#   'variables,',
#   'interval',
#   'integration',
#   'b',
#   'replaced',
#   'curve',
#   'two',
#   'surface',
#   'integral',
#   'curve',
#   'replaced',
#   'piece',
#   'surface',
#   'three-dimensional',
#   'space',
#   'first',
#   'documented',
#   'systematic',
#   'technique',
#   'integrals',
#   'method',
#   'exhaustion',
#   'ancient',
#   'greek',
#   'astronomer',
#   'eudoxus',
#   'sought',
#   'find',
#   'areas',
#   'volumes',
#   'breaking',
#   'infinite',
#   'number',
#   'area',
#   'volume',
#   'known.',
#   'method',
#   'developed',
#   'employed',
#   'archimedes',
#   '3rd',
#   'century',
#   'used',
#   'calculate',
#   'areas',
#   'approximation',
#   'area',
#   'circle',
#   'similar',
#   'method',
#   'independently',
#   'developed',
#   'china',
#   'around',
#   '3rd',
#   'century',
#   'used',
#   'find',
#   'area',
#   'circle.',
#   'method',
#   'later',
#   'used',
#   '5th',
#   'century',
#   'chinese',
#   'mathematicians',
#   'zu',
#   'zu',
#   'find',
#   'volume',
#   '2004',
#   'pp.',
#   'next',
#   'significant',
#   'integral',
#   'calculus',
#   'begin',
#   'appear',
#   '17th',
#   'century.',
#   'time,',
#   'work',
#   'cavalieri',
#   'method',
#   'work',
#   'began',
#   'lay',
#   'foundations',
#   'modern',
#   'calculus,',
#   'cavalieri',
#   'computing',
#   'integrals',
#   'x',
#   'n',
#   'degree',
#   'n',
#   '9',
#   "cavalieri's",
#   'quadrature',
#   'formula',
#   'steps',
#   'made',
#   'early',
#   '17th',
#   'century',
#   'barrow',
#   'provided',
#   'first',
#   'hints',
#   'connection',
#   'integration',
#   'differentiation',
#   'barrow',
#   'provided',
#   'first',
#   'proof',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'generalized',
#   "cavalieri's",
#   'method,',
#   'computing',
#   'integrals',
#   'x',
#   'general',
#   'power,',
#   'including',
#   'negative',
#   'major',
#   'advance',
#   'integration',
#   'came',
#   '17th',
#   'century',
#   'independent',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'newton',
#   'leibniz',
#   'theorem',
#   'demonstrates',
#   'connection',
#   'integration',
#   'differentiation.',
#   'combined',
#   'comparative',
#   'differentiation,',
#   'calculate',
#   'integrals.',
#   'particular,',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'allows',
#   'one',
#   'much',
#   'class',
#   'problems.',
#   'equal',
#   'importance',
#   'comprehensive',
#   'mathematical',
#   'framework',
#   'newton',
#   'leibniz',
#   'given',
#   'name',
#   'infinitesimal',
#   'calculus,',
#   'allowed',
#   'precise',
#   'analysis',
#   'functions',
#   'within',
#   'continuous',
#   'framework',
#   'eventually',
#   'became',
#   'modern',
#   'calculus',
#   'whose',
#   'notation',
#   'integrals',
#   'drawn',
#   'directly',
#   'work',
#   'newton',
#   'leibniz',
#   'provided',
#   'systematic',
#   'approach',
#   'integration,',
#   'work',
#   'lacked',
#   'degree',
#   'rigour',
#   'attacked',
#   'used',
#   'calling',
#   'quantities',
#   '".',
#   'calculus',
#   'acquired',
#   'development',
#   'limits',
#   'integration',
#   'first',
#   'rigorously',
#   'using',
#   'riemann',
#   'although',
#   'bounded',
#   'piecewise',
#   'continuous',
#   'functions',
#   'riemann-integrable',
#   'bounded',
#   'interval,',
#   'general',
#   'functions',
#   'context',
#   'fourier',
#   'analysis',
#   '—to',
#   "riemann's",
#   'definition',
#   'lebesgue',
#   'formulated',
#   'different',
#   'definition',
#   'integral',
#   'founded',
#   'measure',
#   'theory',
#   '(a',
#   'real',
#   'analysis',
#   ').',
#   'definitions',
#   'integral,',
#   'extending',
#   "riemann's",
#   "lebesgue's",
#   'proposed.',
#   'approaches',
#   'based',
#   'real',
#   'number',
#   'system',
#   'ones',
#   'common',
#   'today,',
#   'alternative',
#   'approaches',
#   'exist,',
#   'definition',
#   'integral',
#   'standard',
#   'part',
#   'infinite',
#   'riemann',
#   'sum,',
#   'based',
#   'hyperreal',
#   'number',
#   'system.',
#   'isaac',
#   'newton',
#   'used',
#   'small',
#   'vertical',
#   'bar',
#   'variable',
#   'indicate',
#   'integration,',
#   'placed',
#   'variable',
#   'inside',
#   'vertical',
#   'bar',
#   'easily',
#   'confused',
#   'x',
#   'x',
#   '′',
#   'used',
#   'indicate',
#   'differentiation,',
#   'box',
#   'notation',
#   'difficult',
#   'printers',
#   'notations',
#   'widely',
#   'modern',
#   'notation',
#   'indefinite',
#   'integral',
#   'introduced',
#   'gottfried',
#   'wilhelm',
#   'leibniz',
#   'burton',
#   '1988',
#   'p.',
#   'leibniz',
#   '1899',
#   'p.',
#   'adapted',
#   'integral',
#   'symbol',
#   '∫',
#   'letter',
#   'long',
#   '),',
#   'standing',
#   '(written',
#   'latin',
#   'modern',
#   'notation',
#   'definite',
#   'integral,',
#   'limits',
#   'integral',
#   'first',
#   'used',
#   'joseph',
#   'fourier',
#   'french',
#   'academy',
#   'around',
#   'reprinted',
#   'book',
#   '1822',
#   'pp.',
#   'fourier',
#   '1822',
#   'integrals',
#   'used',
#   'extensively',
#   'many',
#   'areas',
#   'mathematics',
#   'well',
#   'many',
#   'areas',
#   'example,',
#   'probability',
#   'theory',
#   'integrals',
#   'used',
#   'determine',
#   'probability',
#   'random',
#   'variable',
#   'within',
#   'certain',
#   'moreover,',
#   'integral',
#   'entire',
#   'probability',
#   'density',
#   'function',
#   'must',
#   'equal',
#   '1,',
#   'provides',
#   'whether',
#   'function',
#   'negative',
#   'values',
#   'could',
#   'density',
#   'function',
#   'integrals',
#   'used',
#   'computing',
#   'area',
#   'two-dimensional',
#   'region',
#   'curved',
#   'well',
#   'computing',
#   'volume',
#   'three-dimensional',
#   'object',
#   'curved',
#   'area',
#   'two-dimensional',
#   'region',
#   'calculated',
#   'using',
#   'definite',
#   'integral.',
#   'volume',
#   'three-dimensional',
#   'object',
#   'disc',
#   'outlined',
#   'disc',
#   'integration',
#   'computed',
#   'using',
#   'equation',
#   'volume',
#   'r',
#   '2',
#   'h',
#   '{\\displaystyle',
#   'r',
#   '{\\displaystyle',
#   'case',
#   'would',
#   'distance',
#   'curve',
#   'function',
#   'line',
#   'simple',
#   'radius',
#   'equation',
#   'function',
#   'minus',
#   'given',
#   'x',
#   '{\\displaystyle',
#   'x}',
#   '-value',
#   '{\\displaystyle',
#   'y}',
#   '-value',
#   'line.',
#   'instance,',
#   'radius',
#   'disc',
#   'created',
#   'quadratic',
#   '−',
#   'x',
#   '2',
#   '4',
#   '{\\displaystyle',
#   'y=-x^{2}+4}',
#   'around',
#   'line',
#   '−',
#   '1',
#   '{\\displaystyle',
#   'y=-1}',
#   'would',
#   'given',
#   'expression',
#   '−',
#   'x',
#   '2',
#   '4',
#   '−',
#   '−',
#   '1',
#   '{\\displaystyle',
#   '−',
#   'x',
#   '2',
#   '5',
#   '{\\displaystyle',
#   'order',
#   'find',
#   'volume',
#   'integral',
#   'bounds',
#   '{\\displaystyle',
#   'a}',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   '{\\displaystyle',
#   'a}',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   'line',
#   '−',
#   'x',
#   '2',
#   '4',
#   '{\\displaystyle',
#   'y=-x^{2}+4}',
#   '−',
#   '1',
#   '{\\displaystyle',
#   'y=-1}',
#   'would',
#   'used',
#   'follows:',
#   'integrals',
#   'also',
#   'used',
#   'physics,',
#   'areas',
#   'like',
#   'find',
#   'quantities',
#   'like',
#   'displacement',
#   'time',
#   'velocity',
#   'example,',
#   'displacement',
#   'object',
#   'time',
#   'interval',
#   'b',
#   '{\\displaystyle',
#   'given',
#   'by:',
#   'v',
#   '{\\displaystyle',
#   'velocity',
#   'expressed',
#   'function',
#   'time.',
#   'work',
#   'done',
#   'force',
#   'f',
#   'x',
#   '{\\displaystyle',
#   'f(x)}',
#   'function',
#   'initial',
#   'position',
#   '{\\displaystyle',
#   'a}',
#   'final',
#   'position',
#   'b',
#   '{\\displaystyle',
#   'b}',
#   'is:',
#   'integrals',
#   'also',
#   'used',
#   'integration',
#   'used',
#   'calculate',
#   'difference',
#   'free',
#   'energy',
#   'two',
#   'given',
#   'states.',
#   'integral',
#   'respect',
#   'x',
#   'real-valued',
#   'function',
#   'f',
#   'x',
#   'real',
#   'variable',
#   'x',
#   'interval',
#   'b',
#   'written',
#   'integral',
#   'sign',
#   '∫',
#   'represents',
#   'integration.',
#   'symbol',
#   'dx',
#   'called',
#   'differential',
#   'variable',
#   'x',
#   'indicates',
#   'variable',
#   'integration',
#   'x',
#   'function',
#   'f',
#   'x',
#   'integrated',
#   'called',
#   'integrand.',
#   'symbol',
#   'dx',
#   'separated',
#   'integrand',
#   'space',
#   '(as',
#   'function',
#   'integral,',
#   'said',
#   'integrable.',
#   'points',
#   'b',
#   'called',
#   'limits',
#   'integral.',
#   'integral',
#   'limits',
#   'specified',
#   'called',
#   'definite',
#   'integral.',
#   'integral',
#   'said',
#   'interval',
#   'b',
#   'integral',
#   'goes',
#   'finite',
#   'value',
#   'upper',
#   'limit',
#   'infinity,',
#   'integral',
#   'expresses',
#   'limit',
#   'integral',
#   'value',
#   'b',
#   'b',
#   'goes',
#   'infinity.',
#   'value',
#   'integral',
#   'gets',
#   'closer',
#   'closer',
#   'finite',
#   'value,',
#   'integral',
#   'said',
#   'converge',
#   'value.',
#   'not,',
#   'integral',
#   'said',
#   'limits',
#   'integral',
#   'called',
#   'indefinite',
#   'integral,',
#   'represents',
#   'class',
#   'functions',
#   '(the',
#   'antiderivative',
#   'whose',
#   'derivative',
#   'integrand.',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'relates',
#   'definite',
#   'integrals',
#   'indefinite',
#   'integrals.',
#   'occasionally,',
#   'limits',
#   'integration',
#   'omitted',
#   'definite',
#   'integrals',
#   'limits',
#   'occur',
#   'repeatedly',
#   'particular',
#   'author',
#   'make',
#   'convention',
#   'clear',
#   'beginning',
#   'relevant',
#   'text.',
#   'several',
#   'notation',
#   'integrals',
#   'integration',
#   'unbounded',
#   'domains',
#   'multiple',
#   'dimensions',
#   '(see',
#   'later',
#   'sections',
#   'historically,',
#   'symbol',
#   'dx',
#   'taken',
#   'represent',
#   'independent',
#   'variable',
#   'x',
#   'multiplied',
#   'integrand',
#   'summed',
#   'infinite',
#   'sense.',
#   'notion',
#   'still',
#   'useful,',
#   'later',
#   'mathematicians',
#   'deemed',
#   'infinitesimal',
#   'quantities',
#   'real',
#   'number',
#   'system.',
#   '[1]',
#   'introductory',
#   'calculus,',
#   'expression',
#   'dx',
#   'therefore',
#   'assigned',
#   'independent',
#   'meaning;',
#   'instead,',
#   'viewed',
#   'part',
#   'symbol',
#   'integration',
#   'serves',
#   'right',
#   'side',
#   'expression',
#   'integrated.',
#   'sophisticated',
#   'dx',
#   'meaning',
#   'particular',
#   'area',
#   'mathematics',
#   'used',
#   'one',
#   'ways,',
#   'original',
#   'notation',
#   'apply',
#   'generalization',
#   'original',
#   'definition',
#   'integral.',
#   'common',
#   'interpretations',
#   'dx',
#   'include:',
#   'integrator',
#   'function',
#   'riemann-stieltjes',
#   'integration',
#   '(indicated',
#   'x',
#   'general),',
#   'measure',
#   'lebesgue',
#   'theory',
#   '(indicated',
#   'general),',
#   'differential',
#   'form',
#   'exterior',
#   'calculus',
#   '(indicated',
#   'x',
#   '1',
#   '∧',
#   '∧',
#   'x',
#   'k',
#   '{\\displaystyle',
#   '\\wedge',
#   'last',
#   'case,',
#   'even',
#   'letter',
#   'independent',
#   'meaning',
#   '—',
#   'exterior',
#   'derivative',
#   'operator',
#   'differential',
#   'leave',
#   'dx',
#   'simple',
#   'riemann',
#   'integral',
#   'used,',
#   'exact',
#   'type',
#   'integral',
#   'instance,',
#   'one',
#   'might',
#   'write',
#   '∫',
#   'b',
#   'c',
#   '1',
#   'f',
#   'c',
#   '2',
#   'g',
#   'c',
#   '1',
#   '∫',
#   'b',
#   'f',
#   'c',
#   '2',
#   '∫',
#   'b',
#   'g',
#   '\\int',
#   'express',
#   'linearity',
#   'integral,',
#   'property',
#   'shared',
#   'riemann',
#   'integral',
#   'modern',
#   'arabic',
#   'mathematical',
#   'notation',
#   'reflected',
#   'integral',
#   'symbol',
#   'used',
#   'instead',
#   'symbol',
#   '∫',
#   'since',
#   'arabic',
#   'script',
#   'mathematical',
#   'expressions',
#   'go',
#   'right',
#   '[2]',
#   'authors,',
#   'particularly',
#   'european',
#   'origin,',
#   'use',
#   '"d"',
#   'indicate',
#   'variable',
#   'integration',
#   '(i.e.,',
#   'x',
#   'instead',
#   'dx',
#   '),',
#   'since',
#   'properly',
#   'speaking,',
#   '"d"',
#   'variable.',
#   'symbol',
#   'dx',
#   'always',
#   'placed',
#   'f',
#   'x',
#   'instance',
#   'first',
#   'expression,',
#   'differential',
#   'treated',
#   'infinitesimal',
#   'formally',
#   'following',
#   'expression',
#   'x',
#   '2',
#   'second',
#   'expression,',
#   'showing',
#   'differentials',
#   'first',
#   'variables',
#   'integrated',
#   'respect',
#   'to,',
#   'practice',
#   'particularly',
#   'popular',
#   'integrals',
#   'appear',
#   'many',
#   'practical',
#   'situations.',
#   'rectangular',
#   'flat',
#   'bottom,',
#   'length,',
#   'width,',
#   'depth',
#   'easily',
#   'determine',
#   'volume',
#   'water',
#   'contain',
#   '(to',
#   'fill',
#   'it),',
#   'area',
#   'surface',
#   '(to',
#   'cover',
#   'it),',
#   'length',
#   'edge',
#   '(to',
#   'rounded',
#   'bottom,',
#   'quantities',
#   'call',
#   'integrals.',
#   'practical',
#   'approximations',
#   'may',
#   'trivial',
#   'precision',
#   'engineering',
#   '(of',
#   'requires',
#   'exact',
#   'rigorous',
#   'values',
#   'elements.',
#   'start',
#   'off,',
#   'consider',
#   'curve',
#   'f',
#   'x',
#   'x',
#   '0',
#   'x',
#   '1',
#   'f',
#   'x',
#   '√',
#   'x',
#   '(see',
#   'call',
#   'area',
#   'integral',
#   'f',
#   'notation',
#   'integral',
#   'first',
#   'approximation,',
#   'look',
#   'unit',
#   'square',
#   'given',
#   'sides',
#   'x',
#   '0',
#   'x',
#   '1',
#   'f',
#   '(0)',
#   '0',
#   'f',
#   '(1)',
#   '1',
#   'area',
#   'exactly',
#   '1.',
#   'true',
#   'value',
#   'integral',
#   'must',
#   'somewhat',
#   'less',
#   '1.',
#   'decreasing',
#   'width',
#   'approximation',
#   'rectangles',
#   'increasing',
#   'number',
#   'rectangles',
#   'gives',
#   'better',
#   'cross',
#   'interval',
#   'five',
#   'using',
#   'approximation',
#   'points',
#   '0,',
#   '1.',
#   'fit',
#   'box',
#   'step',
#   'using',
#   'right',
#   'end',
#   'height',
#   'curve',
#   'piece,',
#   'thus',
#   '√',
#   '√',
#   '√',
#   '1',
#   '1',
#   'summing',
#   'areas',
#   'get',
#   'better',
#   'approximation',
#   'sought',
#   'integral,',
#   'namely',
#   'taking',
#   'sum',
#   'finitely',
#   'many',
#   'function',
#   'values',
#   'f',
#   'multiplied',
#   'differences',
#   'two',
#   'subsequent',
#   'approximation',
#   'points.',
#   'easily',
#   'see',
#   'approximation',
#   'still',
#   'using',
#   'steps',
#   'produces',
#   'closer',
#   'approximation,',
#   'always',
#   'high',
#   'never',
#   'replacing',
#   'subintervals',
#   'ones',
#   'left',
#   'end',
#   'height',
#   'piece,',
#   'get',
#   'approximation',
#   'example,',
#   'twelve',
#   'subintervals',
#   'get',
#   'approximate',
#   'value',
#   'area',
#   'key',
#   'idea',
#   'transition',
#   'adding',
#   'finitely',
#   'many',
#   'differences',
#   'approximation',
#   'points',
#   'multiplied',
#   'function',
#   'values',
#   'using',
#   'infinitely',
#   'many',
#   'fine,',
#   'infinitesimal',
#   'transition',
#   'completed',
#   'example,',
#   'turns',
#   'area',
#   'curve',
#   'within',
#   'stated',
#   'bounds',
#   'notation',
#   'integral',
#   'weighted',
#   'sum,',
#   'denoted',
#   'function',
#   'values,',
#   'f',
#   'x',
#   'multiplied',
#   'infinitesimal',
#   'step',
#   'so-called',
#   'differentials',
#   'denoted',
#   'dx',
#   'historically,',
#   'early',
#   'efforts',
#   'rigorously',
#   'interpret',
#   'riemann',
#   'formally',
#   'defined',
#   'integrals',
#   'limit',
#   'weighted',
#   'sums,',
#   'dx',
#   'suggested',
#   'limit',
#   'difference',
#   'interval',
#   "riemann's",
#   'intervals',
#   'continuity',
#   'definitions,',
#   'especially',
#   'lebesgue',
#   'integral',
#   'founded',
#   'ability',
#   'extend',
#   'idea',
#   'much',
#   'flexible',
#   'ways.',
#   'thus',
#   'notation',
#   'refers',
#   'weighted',
#   'sum',
#   'function',
#   'values',
#   'μ',
#   'measuring',
#   'weight',
#   'assigned',
#   'value.',
#   'denotes',
#   'region',
#   'integration.',
#   'many',
#   'ways',
#   'formally',
#   'integral,',
#   'equivalent.',
#   'differences',
#   'exist',
#   'mostly',
#   'deal',
#   'special',
#   'cases',
#   'may',
#   'integrable',
#   'definitions,',
#   'also',
#   'occasionally',
#   'commonly',
#   'used',
#   'definitions',
#   'integral',
#   'riemann',
#   'integrals',
#   'lebesgue',
#   'integrals.',
#   'riemann',
#   'integral',
#   'defined',
#   'terms',
#   'riemann',
#   'sums',
#   'functions',
#   'respect',
#   'tagged',
#   'partitions',
#   'interval.',
#   '[3]',
#   'let',
#   'b',
#   'closed',
#   'interval',
#   'real',
#   'tagged',
#   'partition',
#   'b',
#   'finite',
#   'sequence',
#   'partitions',
#   'interval',
#   'b',
#   'n',
#   'sub-intervals',
#   'x',
#   '−1',
#   'x',
#   'indexed',
#   'distinguished',
#   'point',
#   '∈',
#   'x',
#   '−1',
#   'x',
#   'riemann',
#   'sum',
#   'function',
#   'f',
#   'respect',
#   'tagged',
#   'partition',
#   'defined',
#   'thus',
#   'term',
#   'sum',
#   'area',
#   'rectangle',
#   'height',
#   'equal',
#   'function',
#   'value',
#   'distinguished',
#   'point',
#   'given',
#   'sub-interval,',
#   'width',
#   'sub-interval',
#   'width.',
#   'let',
#   'δ',
#   'x',
#   '−',
#   'x',
#   '−1',
#   'width',
#   'sub-interval',
#   'mesh',
#   'tagged',
#   'partition',
#   'width',
#   'largest',
#   'sub-interval',
#   'formed',
#   'partition,',
#   'max',
#   'n',
#   'δ',
#   'riemann',
#   'integral',
#   'function',
#   'f',
#   'interval',
#   'b',
#   'equal',
#   'chosen',
#   'tags',
#   'give',
#   'maximum',
#   '(respectively,',
#   'value',
#   'interval,',
#   'riemann',
#   'sum',
#   'becomes',
#   'upper',
#   '(respectively,',
#   'darboux',
#   'sum',
#   'suggesting',
#   'close',
#   'connection',
#   'riemann',
#   'integral',
#   'darboux',
#   'integral',
#   'often',
#   'interest,',
#   'theory',
#   'applications,',
#   'able',
#   'pass',
#   'limit',
#   'integral.',
#   'instance,',
#   'sequence',
#   'functions',
#   'frequently',
#   'constructed',
#   'suitable',
#   'sense,',
#   'solution',
#   'integral',
#   'solution',
#   'function',
#   'limit',
#   'integrals',
#   'approximations.',
#   'however,',
#   'many',
#   'functions',
#   'obtained',
#   'limits',
#   'riemann-integrable,',
#   'limit',
#   'theorems',
#   'hold',
#   'riemann',
#   'integral.',
#   'therefore,',
#   'great',
#   'importance',
#   'definition',
#   'integral',
#   'allows',
#   'wider',
#   'class',
#   'functions',
#   'integrated',
#   ').',
#   'integral',
#   'lebesgue',
#   'integral,',
#   'following',
#   'fact',
#   'class',
#   'integrable',
#   'functions:',
#   'values',
#   'function',
#   'rearranged',
#   'domain,',
#   'integral',
#   'function',
#   'remain',
#   'thus',
#   'henri',
#   'lebesgue',
#   'introduced',
#   'integral',
#   'name,',
#   'integral',
#   'thus',
#   'letter',
#   'paul',
#   'pay',
#   'certain',
#   'sum,',
#   'collected',
#   'take',
#   'bills',
#   'coins',
#   'pocket',
#   'give',
#   'order',
#   'find',
#   'reached',
#   'total',
#   'sum.',
#   'riemann',
#   'integral.',
#   'taken',
#   'money',
#   'pocket',
#   'order',
#   'bills',
#   'coins',
#   'according',
#   'values',
#   'pay',
#   'several',
#   'one',
#   'integral.',
#   'p.',
#   'it,',
#   '"to',
#   'compute',
#   'riemann',
#   'integral',
#   'f',
#   'one',
#   'partitions',
#   'domain',
#   'b',
#   'lebesgue',
#   'integral,',
#   '"one',
#   'effect',
#   'partitioning',
#   'range',
#   'f',
#   '".',
#   'definition',
#   'lebesgue',
#   'integral',
#   'thus',
#   'begins',
#   'measure',
#   'simplest',
#   'case,',
#   'lebesgue',
#   'measure',
#   'μ',
#   'interval',
#   'b',
#   'width,',
#   'b',
#   '−',
#   'lebesgue',
#   'integral',
#   'riemann',
#   'integral',
#   'exist.',
#   'complicated',
#   'cases,',
#   'sets',
#   'measured',
#   'highly',
#   'continuity',
#   'resemblance',
#   'intervals.',
#   'using',
#   'range',
#   'f',
#   'philosophy,',
#   'integral',
#   'non-negative',
#   'function',
#   'f',
#   'r',
#   '→',
#   'r',
#   'sum',
#   'areas',
#   'thin',
#   'dt',
#   'area',
#   'μ',
#   'x',
#   'f',
#   'x',
#   '&gt;',
#   'dt',
#   'let',
#   'f',
#   '∗',
#   'μ',
#   'x',
#   'f',
#   'x',
#   '&gt;',
#   'lebesgue',
#   'integral',
#   'f',
#   'defined',
#   '&amp;',
#   'loss',
#   '2001',
#   'integral',
#   'right',
#   'ordinary',
#   'improper',
#   'riemann',
#   'integral',
#   'f',
#   '∗',
#   'strictly',
#   'decreasing',
#   'positive',
#   'function,',
#   'therefore',
#   'well-defined',
#   'improper',
#   'riemann',
#   'suitable',
#   'class',
#   'functions',
#   '(the',
#   'measurable',
#   'functions',
#   'lebesgue',
#   'integral.',
#   'general',
#   'measurable',
#   'function',
#   'f',
#   'lebesgue-integrable',
#   'sum',
#   'absolute',
#   'values',
#   'areas',
#   'graph',
#   'f',
#   'x',
#   '-axis',
#   'case,',
#   'integral',
#   'is,',
#   'case,',
#   'difference',
#   'area',
#   'x',
#   '-axis',
#   'area',
#   'x',
#   'although',
#   'riemann',
#   'lebesgue',
#   'integrals',
#   'widely',
#   'used',
#   'definitions',
#   'integral,',
#   'number',
#   'others',
#   'exist,',
#   'collection',
#   'riemann-integrable',
#   'functions',
#   'closed',
#   'interval',
#   'b',
#   'forms',
#   'vector',
#   'space',
#   'operations',
#   'pointwise',
#   'addition',
#   'multiplication',
#   'operation',
#   'integration',
#   'linear',
#   'functional',
#   'vector',
#   'space.',
#   'thus,',
#   'collection',
#   'integrable',
#   'functions',
#   'closed',
#   'taking',
#   'linear',
#   'combinations',
#   'and,',
#   'integral',
#   'linear',
#   'combination',
#   'linear',
#   'combination',
#   'integrals,',
#   'similarly,',
#   'set',
#   'real',
#   '-valued',
#   'lebesgue-integrable',
#   'functions',
#   'given',
#   'measure',
#   'space',
#   'e',
#   'measure',
#   'μ',
#   'closed',
#   'taking',
#   'linear',
#   'combinations',
#   'hence',
#   'form',
#   'vector',
#   'space,',
#   'lebesgue',
#   'integral',
#   'linear',
#   'functional',
#   'vector',
#   'space,',
#   'generally,',
#   'consider',
#   'vector',
#   'space',
#   'measurable',
#   'functions',
#   'measure',
#   'space',
#   'e',
#   'μ',
#   'taking',
#   'values',
#   'locally',
#   'compact',
#   'complete',
#   'topological',
#   'vector',
#   'space',
#   'v',
#   'locally',
#   'compact',
#   'topological',
#   'field',
#   'k',
#   'f',
#   'e',
#   '→',
#   'v',
#   'one',
#   'may',
#   'define',
#   'integration',
#   'map',
#   'function',
#   'f',
#   'element',
#   'v',
#   'symbol',
#   '∞',
#   'linear',
#   'situation,',
#   'linearity',
#   'holds',
#   'functions',
#   'whose',
#   'integral',
#   'element',
#   'v',
#   '(i.e.',
#   'important',
#   'special',
#   'cases',
#   'arise',
#   'k',
#   'r',
#   'c',
#   'finite',
#   'extension',
#   'field',
#   'q',
#   'p',
#   'numbers',
#   'v',
#   'vector',
#   'space',
#   'k',
#   'k',
#   'c',
#   'v',
#   'complex',
#   'hilbert',
#   'space',
#   'together',
#   'natural',
#   'continuity',
#   'properties',
#   'certain',
#   'class',
#   'functions,',
#   'may',
#   'used',
#   'give',
#   'alternative',
#   'definition',
#   'integral.',
#   'approach',
#   'case',
#   'real-valued',
#   'functions',
#   'set',
#   'x',
#   'generalized',
#   'functions',
#   'values',
#   'locally',
#   'compact',
#   'topological',
#   'vector',
#   'space.',
#   'see',
#   'hildebrandt',
#   'integral.',
#   'number',
#   'general',
#   'inequalities',
#   'hold',
#   'riemann-integrable',
#   'functions',
#   'defined',
#   'closed',
#   'bounded',
#   'interval',
#   'b',
#   'generalized',
#   'notions',
#   'integral',
#   'f',
#   'real-valued',
#   'riemann-integrable',
#   'function',
#   'integral',
#   'interval',
#   'b',
#   'defined',
#   '&lt;',
#   'b',
#   'means',
#   'upper',
#   'lower',
#   'sums',
#   'function',
#   'f',
#   'evaluated',
#   'partition',
#   'x',
#   '0',
#   '≤',
#   'x',
#   '1',
#   '≤',
#   '≤',
#   'x',
#   'n',
#   'b',
#   'whose',
#   'values',
#   'x',
#   'geometrically,',
#   'integration',
#   'takes',
#   'place',
#   'f',
#   'within',
#   'intervals',
#   'x',
#   'x',
#   '+1',
#   'interval',
#   'higher',
#   'index',
#   'lies',
#   'right',
#   'one',
#   'lower',
#   'values',
#   'b',
#   'interval',
#   'called',
#   'limits',
#   'integration',
#   'f',
#   'integrals',
#   'also',
#   'defined',
#   '&gt;',
#   'b',
#   'this,',
#   'b',
#   'implies:',
#   'first',
#   'convention',
#   'necessary',
#   'taking',
#   'integrals',
#   'subintervals',
#   'b',
#   'second',
#   'says',
#   'integral',
#   'taken',
#   'degenerate',
#   'interval,',
#   'point',
#   'zero',
#   'one',
#   'reason',
#   'first',
#   'convention',
#   'integrability',
#   'f',
#   'interval',
#   'b',
#   'implies',
#   'f',
#   'integrable',
#   'subinterval',
#   'c',
#   'particular',
#   'integrals',
#   'property',
#   'first',
#   'convention,',
#   'resulting',
#   'relation',
#   'well-defined',
#   'b',
#   'c',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'statement',
#   'differentiation',
#   'integration',
#   'inverse',
#   'continuous',
#   'function',
#   'first',
#   'integrated',
#   'original',
#   'function',
#   'important',
#   'sometimes',
#   'called',
#   'second',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'allows',
#   'one',
#   'compute',
#   'integrals',
#   'using',
#   'antiderivative',
#   'function',
#   'integrated.',
#   'let',
#   'f',
#   'continuous',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'let',
#   'f',
#   'function',
#   'x',
#   'b',
#   'then,',
#   'f',
#   'continuous',
#   'b',
#   'differentiable',
#   'open',
#   'interval',
#   'b',
#   'x',
#   'b',
#   'let',
#   'f',
#   'real-valued',
#   'function',
#   'defined',
#   'closed',
#   'interval',
#   'b',
#   'admits',
#   'antiderivative',
#   'f',
#   'b',
#   'is,',
#   'f',
#   'f',
#   'functions',
#   'x',
#   'b',
#   'f',
#   'integrable',
#   'b',
#   'second',
#   'fundamental',
#   'theorem',
#   'allows',
#   'many',
#   'integrals',
#   'calculated',
#   'example,',
#   'calculate',
#   'integral',
#   'square',
#   'function',
#   'f',
#   'x',
#   'x',
#   '1/2',
#   '0',
#   '1,',
#   'sufficient',
#   'find',
#   'antiderivative,',
#   'is,',
#   'function',
#   'f',
#   'x',
#   'whose',
#   'derivative',
#   'equals',
#   'f',
#   'x',
#   'one',
#   'function',
#   'f',
#   'x',
#   '2',
#   '3',
#   'x',
#   'value',
#   'integral',
#   'question',
#   'case',
#   'general',
#   'rule,',
#   'f',
#   'x',
#   'x',
#   'q',
#   'q',
#   '≠',
#   '−1',
#   'related',
#   'function,',
#   'so-called',
#   'antiderivative',
#   'f',
#   'x',
#   'x',
#   'q',
#   '1',
#   'q',
#   'tables',
#   'similar',
#   'antiderivatives',
#   'used',
#   'calculate',
#   'integrals',
#   'much',
#   'way',
#   'tables',
#   'derivatives',
#   'used.',
#   'riemann',
#   'integral',
#   'assumes',
#   'integrand',
#   'defined',
#   'finite',
#   'closed',
#   'bounded',
#   'interval,',
#   'limits',
#   'integration.',
#   'improper',
#   'integral',
#   'one',
#   'conditions',
#   'cases',
#   'integrals',
#   'may',
#   'defined',
#   'considering',
#   'limit',
#   'sequence',
#   'proper',
#   'riemann',
#   'integrals',
#   'larger',
#   'intervals.',
#   'interval',
#   'instance',
#   'upper',
#   'end,',
#   'improper',
#   'integral',
#   'limit',
#   'endpoint',
#   'goes',
#   'infinity.',
#   'integrand',
#   'defined',
#   'finite',
#   'interval,',
#   'instance',
#   'b',
#   'limit',
#   'may',
#   'provide',
#   'finite',
#   'result.',
#   'is,',
#   'improper',
#   'integral',
#   'limit',
#   'proper',
#   'integrals',
#   'one',
#   'endpoint',
#   'interval',
#   'integration',
#   'approaches',
#   'either',
#   'specified',
#   'real',
#   'number',
#   '∞',
#   'complicated',
#   'cases,',
#   'limits',
#   'required',
#   'interior',
#   'points.',
#   'definite',
#   'integral',
#   'positive',
#   'function',
#   'one',
#   'variable',
#   'represents',
#   'area',
#   'region',
#   'graph',
#   'function',
#   'x',
#   'double',
#   'integral',
#   'positive',
#   'function',
#   'two',
#   'variables',
#   'represents',
#   'volume',
#   'region',
#   'surface',
#   'defined',
#   'function',
#   'plane',
#   'domain',
#   'example,',
#   'function',
#   'two',
#   'dimensions',
#   'depends',
#   'two',
#   'real',
#   'variables,',
#   'x',
#   'integral',
#   'function',
#   'f',
#   'rectangle',
#   'r',
#   'given',
#   'product',
#   'two',
#   'intervals',
#   'r',
#   'b',
#   '×',
#   'c',
#   '{\\displaystyle',
#   'written',
#   'differential',
#   'da',
#   'indicates',
#   'integration',
#   'taken',
#   'respect',
#   'area.',
#   'double',
#   'integral',
#   'defined',
#   'using',
#   'riemann',
#   'sums',
#   'represents',
#   '(signed)',
#   'volume',
#   'graph',
#   'z',
#   'f',
#   'x',
#   'domain',
#   'r',
#   'suitable',
#   'conditions',
#   '(e.g.,',
#   'f',
#   'theorem',
#   'integral',
#   'expressed',
#   'equivalent',
#   'integral',
#   'reduces',
#   'problem',
#   'computing',
#   'double',
#   'integral',
#   'computing',
#   'integrals.',
#   'this,',
#   'another',
#   'notation',
#   'integral',
#   'r',
#   'uses',
#   'double',
#   'integral',
#   'integration',
#   'general',
#   'domains',
#   'possible.',
#   'integral',
#   'function',
#   'f',
#   'respect',
#   'volume,',
#   'subset',
#   'n',
#   'denoted',
#   'notation',
#   'see',
#   'volume',
#   'integral',
#   'concept',
#   'integral',
#   'extended',
#   'general',
#   'domains',
#   'integration,',
#   'curved',
#   'lines',
#   'integrals',
#   'known',
#   'line',
#   'integrals',
#   'surface',
#   'integrals',
#   'respectively.',
#   'important',
#   'applications',
#   'physics,',
#   'dealing',
#   'vector',
#   'fields',
#   'line',
#   'integral',
#   'called',
#   'path',
#   'integral',
#   'integral',
#   'function',
#   'integrated',
#   'evaluated',
#   'along',
#   'curve',
#   'various',
#   'different',
#   'line',
#   'integrals',
#   'use.',
#   'case',
#   'closed',
#   'curve',
#   'also',
#   'called',
#   'contour',
#   'integral',
#   'function',
#   'integrated',
#   'may',
#   'scalar',
#   'field',
#   'vector',
#   'field',
#   'value',
#   'line',
#   'integral',
#   'sum',
#   'values',
#   'field',
#   'points',
#   'weighted',
#   'scalar',
#   'function',
#   'curve',
#   'arc',
#   'length',
#   'vector',
#   'field,',
#   'scalar',
#   'product',
#   'vector',
#   'field',
#   'differential',
#   'vector',
#   'line',
#   'integral',
#   'simpler',
#   'integrals',
#   'defined',
#   'intervals',
#   'many',
#   'simple',
#   'formulas',
#   'physics',
#   'natural',
#   'continuous',
#   'terms',
#   'line',
#   'integrals;',
#   'example,',
#   'fact',
#   'work',
#   'equal',
#   'force',
#   'f',
#   'multiplied',
#   'displacement,',
#   'may',
#   'expressed',
#   '(in',
#   'terms',
#   'vector',
#   'as:',
#   'object',
#   'moving',
#   'along',
#   'path',
#   'c',
#   'vector',
#   'field',
#   'f',
#   'field',
#   'field',
#   'total',
#   'work',
#   'done',
#   'field',
#   'object',
#   'obtained',
#   'summing',
#   'differential',
#   'work',
#   'done',
#   'moving',
#   'gives',
#   'line',
#   'integral',
#   'surface',
#   'integral',
#   'definite',
#   'integral',
#   'taken',
#   'surface',
#   '(which',
#   'may',
#   'curved',
#   'set',
#   'space',
#   ');',
#   'thought',
#   'double',
#   'integral',
#   'analog',
#   'line',
#   'integral',
#   'function',
#   'integrated',
#   'may',
#   'scalar',
#   'field',
#   'vector',
#   'field',
#   'value',
#   'surface',
#   'integral',
#   'sum',
#   'field',
#   'points',
#   'achieved',
#   'surface',
#   'surface',
#   'provide',
#   'partitioning',
#   'riemann',
#   'sums.',
#   'example',
#   'applications',
#   'surface',
#   'integrals,',
#   'consider',
#   'vector',
#   'field',
#   'v',
#   'surface',
#   'is,',
#   'point',
#   'x',
#   'v',
#   'x',
#   'vector.',
#   'fluid',
#   'flowing',
#   'v',
#   'x',
#   'determines',
#   'velocity',
#   'fluid',
#   'x',
#   'flux',
#   'defined',
#   'fluid',
#   'flowing',
#   'unit',
#   'amount',
#   'time.',
#   'find',
#   'need',
#   'take',
#   'dot',
#   'product',
#   'v',
#   'unit',
#   'surface',
#   'normal',
#   'point,',
#   'give',
#   'us',
#   'scalar',
#   'field,',
#   'integrate',
#   'fluid',
#   'flux',
#   'example',
#   'may',
#   'physical',
#   'fluid',
#   'water',
#   'thus',
#   'surface',
#   'integrals',
#   'applications',
#   'physics,',
#   'particularly',
#   'classical',
#   'theory',
#   'complex',
#   'analysis',
#   'integrand',
#   'function',
#   'complex',
#   'variable',
#   'z',
#   'instead',
#   'real',
#   'function',
#   'real',
#   'variable',
#   'x',
#   'complex',
#   'function',
#   'integrated',
#   'along',
#   'curve',
#   '{\\displaystyle',
#   'complex',
#   'integral',
#   'denoted',
#   'follows',
#   'known',
#   'contour',
#   'integral',
#   'differential',
#   'form',
#   'mathematical',
#   'concept',
#   'fields',
#   'multivariable',
#   'calculus',
#   'differential',
#   'topology',
#   'differential',
#   'forms',
#   'organized',
#   'degree.',
#   'example,',
#   'one-form',
#   'weighted',
#   'sum',
#   'differentials',
#   'as:',
#   'e',
#   'f',
#   'g',
#   'functions',
#   'three',
#   'differential',
#   'one-form',
#   'integrated',
#   'oriented',
#   'resulting',
#   'integral',
#   'another',
#   'way',
#   'writing',
#   'line',
#   'integral.',
#   'basic',
#   'differentials',
#   'dx',
#   'dy',
#   'measure',
#   'infinitesimal',
#   'oriented',
#   'lengths',
#   'parallel',
#   'three',
#   'coordinate',
#   'axes.',
#   'differential',
#   'two-form',
#   'sum',
#   'form',
#   'basic',
#   'x',
#   '∧',
#   'z',
#   '∧',
#   'x',
#   '∧',
#   'z',
#   '{\\displaystyle',
#   'measure',
#   'oriented',
#   'areas',
#   'parallel',
#   'coordinate',
#   'symbol',
#   '∧',
#   '{\\displaystyle',
#   '\\wedge',
#   'denotes',
#   'wedge',
#   'product',
#   'similar',
#   'cross',
#   'product',
#   'sense',
#   'wedge',
#   'product',
#   'two',
#   'forms',
#   'representing',
#   'oriented',
#   'lengths',
#   'represents',
#   'oriented',
#   'area.',
#   'two-form',
#   'integrated',
#   'oriented',
#   'surface,',
#   'resulting',
#   'integral',
#   'equivalent',
#   'surface',
#   'integral',
#   'giving',
#   'flux',
#   'e',
#   'f',
#   'j',
#   'g',
#   'k',
#   '{\\displaystyle',
#   'unlike',
#   'cross',
#   'three-dimensional',
#   'vector',
#   'calculus,',
#   'wedge',
#   'product',
#   'calculus',
#   'differential',
#   'forms',
#   'makes',
#   'sense',
#   'arbitrary',
#   'dimension',
#   'general',
#   'higher-dimensional',
#   'exterior',
#   'derivative',
#   'plays',
#   'role',
#   'gradient',
#   'vector',
#   'calculus,',
#   'theorem',
#   'simultaneously',
#   'generalizes',
#   'three',
#   'theorems',
#   'vector',
#   'theorem',
#   'theorem',
#   'theorem',
#   'discrete',
#   'equivalent',
#   'integration',
#   'integrals',
#   'put',
#   'foundations',
#   'using',
#   'theory',
#   'lebesgue',
#   'integrals',
#   'time',
#   'calculus',
#   'basic',
#   'technique',
#   'computing',
#   'definite',
#   'integrals',
#   'one',
#   'real',
#   'variable',
#   'based',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'let',
#   'f',
#   'x',
#   'function',
#   'x',
#   'integrated',
#   'given',
#   'interval',
#   'b',
#   'then,',
#   'find',
#   'antiderivative',
#   'f',
#   'is,',
#   'function',
#   'f',
#   'f',
#   '′',
#   'f',
#   'interval.',
#   'provided',
#   'integrand',
#   'integral',
#   'singularities',
#   'path',
#   'integration,',
#   'fundamental',
#   'theorem',
#   'calculus,',
#   'integral',
#   'actually',
#   'antiderivative,',
#   'fundamental',
#   'theorem',
#   'provides',
#   'way',
#   'use',
#   'antiderivatives',
#   'evaluate',
#   'definite',
#   'integrals.',
#   'difficult',
#   'step',
#   'usually',
#   'find',
#   'antiderivative',
#   'f',
#   'rarely',
#   'possible',
#   'function',
#   'write',
#   'often,',
#   'necessary',
#   'use',
#   'one',
#   'many',
#   'techniques',
#   'developed',
#   'evaluate',
#   'integrals.',
#   'techniques',
#   'rewrite',
#   'one',
#   'integral',
#   'different',
#   'one',
#   'techniques',
#   'include:',
#   'alternative',
#   'methods',
#   'exist',
#   'compute',
#   'complex',
#   'integrals.',
#   'many',
#   'integrals',
#   'expanded',
#   'taylor',
#   'series',
#   'integrated',
#   'term',
#   'term.',
#   'occasionally,',
#   'resulting',
#   'infinite',
#   'series',
#   'summed',
#   'method',
#   'using',
#   'meijer',
#   'also',
#   'used,',
#   'assuming',
#   'integrand',
#   'written',
#   'product',
#   'meijer',
#   'also',
#   'many',
#   'less',
#   'common',
#   'ways',
#   'calculating',
#   'definite',
#   'integrals;',
#   'instance,',
#   'identity',
#   'used',
#   'transform',
#   'integral',
#   'rectangular',
#   'region',
#   'infinite',
#   'sum.',
#   'occasionally,',
#   'integral',
#   'evaluated',
#   'example',
#   'this,',
#   'see',
#   'gaussian',
#   'integral',
#   'computations',
#   'volumes',
#   'revolution',
#   'usually',
#   'done',
#   'integration',
#   'shell',
#   'integration',
#   'specific',
#   'results',
#   'worked',
#   'various',
#   'techniques',
#   'collected',
#   'list',
#   'integrals',
#   'many',
#   'problems',
#   'physics,',
#   'engineering',
#   'involve',
#   'integration',
#   'explicit',
#   'formula',
#   'integral',
#   'extensive',
#   'tables',
#   'integrals',
#   'compiled',
#   'published',
#   'years',
#   'spread',
#   'many',
#   'students',
#   'turned',
#   'computer',
#   'algebra',
#   'systems',
#   'specifically',
#   'designed',
#   'perform',
#   'difficult',
#   'tedious',
#   'including',
#   'integration.',
#   'symbolic',
#   'integration',
#   'one',
#   'development',
#   'first',
#   'like',
#   'major',
#   'mathematical',
#   'difficulty',
#   'symbolic',
#   'integration',
#   'many',
#   'cases,',
#   'closed',
#   'formula',
#   'antiderivative',
#   'rather',
#   'function',
#   'exist.',
#   'instance,',
#   'known',
#   'antiderivatives',
#   'functions',
#   'exp(',
#   'x',
#   '2',
#   '),',
#   'x',
#   'x',
#   'x',
#   'x',
#   'cannot',
#   'expressed',
#   'closed',
#   'form',
#   'involving',
#   'rational',
#   'exponential',
#   'functions,',
#   'trigonometric',
#   'functions',
#   'inverse',
#   'trigonometric',
#   'functions',
#   'operations',
#   'multiplication',
#   'words,',
#   'none',
#   'three',
#   'given',
#   'functions',
#   'integrable',
#   'elementary',
#   'functions',
#   'functions',
#   'may',
#   'built',
#   'rational',
#   'functions,',
#   'roots',
#   'polynomial',
#   'logarithm,',
#   'exponential',
#   'functions.',
#   'risch',
#   'algorithm',
#   'provides',
#   'general',
#   'criterion',
#   'determine',
#   'whether',
#   'antiderivative',
#   'elementary',
#   'function',
#   'and,',
#   'is,',
#   'compute',
#   'it.',
#   'unfortunately,',
#   'turns',
#   'functions',
#   'closed',
#   'expressions',
#   'antiderivatives',
#   'rather',
#   'consequently,',
#   'algebra',
#   'systems',
#   'hope',
#   'able',
#   'find',
#   'antiderivative',
#   'constructed',
#   'elementary',
#   'function.',
#   'positive',
#   'side,',
#   'antiderivatives',
#   'fixed',
#   'advance,',
#   'may',
#   'still',
#   'possible',
#   'decide',
#   'whether',
#   'antiderivative',
#   'given',
#   'function',
#   'expressed',
#   'using',
#   'operations',
#   'multiplication',
#   'find',
#   'symbolic',
#   'answer',
#   'whenever',
#   'exists.',
#   'risch',
#   'algorithm',
#   'implemented',
#   'computer',
#   'algebra',
#   'systems',
#   'functions',
#   'antiderivatives',
#   'built',
#   'rational',
#   'functions,',
#   'logarithm,',
#   'exponential',
#   'functions.',
#   'special',
#   'occur',
#   'often',
#   'enough',
#   'warrant',
#   'special',
#   'particular,',
#   'may',
#   'useful',
#   'have,',
#   'set',
#   'special',
#   'functions',
#   'functions',
#   'hypergeometric',
#   'function',
#   'gamma',
#   'function',
#   'incomplete',
#   'gamma',
#   'function',
#   '—',
#   'see',
#   'symbolic',
#   'integration',
#   'extending',
#   'algorithm',
#   'include',
#   'functions',
#   'possible',
#   'active',
#   'subject.',
#   'recently',
#   'new',
#   'approach',
#   'using',
#   '-finite',
#   'functions',
#   'linear',
#   'differential',
#   'equations',
#   'polynomial',
#   'elementary',
#   'special',
#   'functions',
#   'integral',
#   '-finite',
#   'function',
#   'also',
#   '-finite',
#   'function.',
#   'provides',
#   'algorithm',
#   'express',
#   'antiderivative',
#   '-finite',
#   'function',
#   'solution',
#   'differential',
#   'theory',
#   'also',
#   'allows',
#   'one',
#   'compute',
#   'definite',
#   'integral',
#   'sum',
#   'series',
#   'given',
#   'first',
#   'provides',
#   'algorithm',
#   'compute',
#   '[4]',
#   'integrals',
#   'found',
#   'real',
#   'applications',
#   'computed',
#   'others',
#   'antiderivatives',
#   'closed',
#   'forms,',
#   'closed',
#   'forms',
#   'require',
#   'special',
#   'functions',
#   'others',
#   'complex',
#   'finding',
#   'exact',
#   'answer',
#   'motivates',
#   'study',
#   'application',
#   'numerical',
#   'approximations',
#   'integrals.',
#   'called',
#   'numerical',
#   'integration',
#   'numerical',
#   'quadrature',
#   'arose',
#   'early',
#   'study',
#   'integration',
#   'purpose',
#   'making',
#   'hand',
#   'development',
#   'made',
#   'numerical',
#   'integration',
#   'practical',
#   'desire',
#   'goals',
#   'numerical',
#   'integration',
#   'generality,',
#   'sophisticated',
#   'modern',
#   'methods',
#   'method',
#   'four',
#   'measures',
#   '&amp;',
#   '2008',
#   '&amp;',
#   '&amp;',
#   '2002',
#   ').',
#   'example,',
#   'integral',
#   'exact',
#   'answer',
#   '3.76',
#   '(in',
#   'ordinary',
#   'practice,',
#   'answer',
#   'known',
#   'advance,',
#   'important',
#   '—',
#   'explored',
#   '—',
#   'decide',
#   'approximation',
#   'good',
#   'approach',
#   'divides',
#   'integration',
#   'range',
#   'say,',
#   '16',
#   'equal',
#   'pieces,',
#   'function',
#   'using',
#   'left',
#   'end',
#   'piece,',
#   'rectangle',
#   'method',
#   'sums',
#   '16',
#   'function',
#   'values',
#   'multiplies',
#   'step',
#   'width,',
#   'h',
#   'get',
#   'approximate',
#   'value',
#   'integral.',
#   'accuracy',
#   'calculus',
#   'formally',
#   'uses',
#   'pieces',
#   'infinitesimal',
#   'width,',
#   'initially',
#   'may',
#   'seem',
#   'little',
#   'cause',
#   'indeed,',
#   'repeatedly',
#   'doubling',
#   'number',
#   'steps',
#   'eventually',
#   'produces',
#   'approximation',
#   'however,',
#   '2',
#   '18',
#   'pieces',
#   'great',
#   'little',
#   'reach',
#   'greater',
#   'accuracy',
#   'force',
#   'steps',
#   'small',
#   'arithmetic',
#   'precision',
#   'becomes',
#   'better',
#   'approach',
#   'rectangles',
#   'used',
#   'riemann',
#   'sum',
#   'trapezoid',
#   'rule',
#   'almost',
#   'easy',
#   'sums',
#   '17',
#   'function',
#   'values,',
#   'first',
#   'last',
#   'one',
#   'multiplies',
#   'step',
#   'width.',
#   'immediately',
#   'approximation',
#   'noticeably',
#   'furthermore,',
#   '2',
#   '10',
#   'pieces',
#   'needed',
#   'achieve',
#   'less',
#   'computation',
#   'rectangle',
#   'method',
#   'accuracy.',
#   'idea',
#   'behind',
#   'trapezoid',
#   'rule,',
#   'accurate',
#   'approximations',
#   'function',
#   'yield',
#   'better',
#   'approximations',
#   'integral,',
#   'carried',
#   "simpson's",
#   'rule',
#   'approximates',
#   'integrand',
#   'piecewise',
#   'quadratic',
#   'function.',
#   'riemann',
#   'sums,',
#   'trapezoid',
#   'rule,',
#   "simpson's",
#   'rule',
#   'examples',
#   'family',
#   'quadrature',
#   'rules',
#   'called',
#   'newton–cotes',
#   'formulas',
#   'degree',
#   'n',
#   'newton–cotes',
#   'quadrature',
#   'rule',
#   'approximates',
#   'polynomial',
#   'subinterval',
#   'degree',
#   'n',
#   'polynomial',
#   'chosen',
#   'interpolate',
#   'values',
#   'function',
#   'interval.',
#   'higher',
#   'degree',
#   'approximations',
#   'require',
#   'function',
#   'evaluations',
#   "simpson's",
#   'rule',
#   'requires',
#   'twice',
#   'function',
#   'evaluations',
#   'trapezoid',
#   'numerical',
#   'due',
#   'one',
#   'solution',
#   'problem',
#   'quadrature',
#   'integrand',
#   'approximated',
#   'terms',
#   'polynomials',
#   'produces',
#   'approximation',
#   'whose',
#   'values',
#   'never',
#   'far',
#   'original',
#   'function.',
#   'method',
#   'trapezoid',
#   'method',
#   'great',
#   'effect.',
#   'first,',
#   'step',
#   'lengths',
#   'giving',
#   'trapezoid',
#   'approximations',
#   'denoted',
#   'h',
#   '0',
#   '),',
#   'h',
#   '1',
#   'on,',
#   'h',
#   'k',
#   '+1',
#   'half',
#   'h',
#   'k',
#   'new',
#   'step',
#   'half',
#   'new',
#   'function',
#   'values',
#   'need',
#   'others',
#   'carry',
#   'previous',
#   'size',
#   '(as',
#   'shown',
#   'table',
#   'really',
#   'powerful',
#   'idea',
#   'interpolate',
#   'polynomial',
#   'approximations,',
#   '(0)',
#   'method',
#   'numerically',
#   'exact',
#   'answer',
#   'requires',
#   'four',
#   'pieces',
#   'function',
#   'lagrange',
#   'polynomial',
#   'h',
#   'k',
#   'h',
#   'k',
#   ')}',
#   'k',
#   '3.76',
#   'h',
#   '2',
#   'producing',
#   'value',
#   '3.76',
#   'h',
#   '0',
#   'gaussian',
#   'quadrature',
#   'often',
#   'requires',
#   'noticeably',
#   'less',
#   'work',
#   'superior',
#   'accuracy.',
#   'example,',
#   'compute',
#   'function',
#   'values',
#   'two',
#   'x',
#   '⁄',
#   '√',
#   '3',
#   'double',
#   'value',
#   'sum',
#   'get',
#   'numerically',
#   'exact',
#   'dramatic',
#   'success',
#   'lies',
#   'choice',
#   'points.',
#   'unlike',
#   'newton–cotes',
#   'interpolate',
#   'integrand',
#   'points,',
#   'gaussian',
#   'quadrature',
#   'function',
#   'roots',
#   'set',
#   'polynomials',
#   'n',
#   'gaussian',
#   'method',
#   'exact',
#   'polynomials',
#   'degree',
#   '2',
#   'n',
#   '−',
#   '1',
#   'function',
#   'example',
#   'degree',
#   '3',
#   'plus',
#   'term',
#   'chosen',
#   'around',
#   'zero.',
#   'also',
#   'benefits',
#   'practice,',
#   'method',
#   'must',
#   'use',
#   'evaluations',
#   'ensure',
#   'error',
#   'bound',
#   'unknown',
#   'tends',
#   'advantage',
#   'pure',
#   'gaussian',
#   'method,',
#   'motivates',
#   'popular',
#   'quadrature',
#   'adaptive',
#   'quadrature',
#   'partitions',
#   'range',
#   'pieces',
#   'based',
#   'function',
#   'data',
#   'points',
#   'concentrated',
#   'needed',
#   'computation',
#   'higher-dimensional',
#   'integrals',
#   '(for',
#   'example,',
#   'volume',
#   'makes',
#   'important',
#   'use',
#   'monte',
#   'carlo',
#   'integration',
#   'calculus',
#   'text',
#   'substitute',
#   'numerical',
#   'analysis,',
#   'reverse',
#   'also',
#   'true.',
#   'even',
#   'best',
#   'adaptive',
#   'numerical',
#   'code',
#   'sometimes',
#   'requires',
#   'help',
#   'demanding',
#   'integrals.',
#   'example,',
#   'improper',
#   'integrals',
#   'may',
#   'require',
#   'change',
#   'variable',
#   'methods',
#   'avoid',
#   'infinite',
#   'function',
#   'values,',
#   'known',
#   'properties',
#   'like',
#   'may',
#   'provide',
#   'critical',
#   'example,',
#   'integral',
#   '∫',
#   '0',
#   '1',
#   'x',
#   '−',
#   '1',
#   '2',
#   'e',
#   '−',
#   'x',
#   'x',
#   '{\\displaystyle',
#   '\\int',
#   'difficult',
#   'evaluate',
#   'numerically',
#   'infinite',
#   'x',
#   '0',
#   'however,',
#   'u',
#   '√',
#   'x',
#   'integral',
#   '2',
#   '∫',
#   '0',
#   '1',
#   'e',
#   '−',
#   'u',
#   '2',
#   'u',
#   '{\\displaystyle',
#   'singularities',
#   'area',
#   'arbitrary',
#   'two-dimensional',
#   'determined',
#   'using',
#   'measuring',
#   'called',
#   'volume',
#   'measured',
#   'precision',
#   'fluid',
#   'object',
#   'area',
#   'sometimes',
#   'found',
#   'via',
#   'constructions',
#   'equivalent',
#   'square'],
#  ['branch',
#   'mathematics',
#   'known',
#   'real',
#   'analysis',
#   'riemann',
#   'integral',
#   'created',
#   'bernhard',
#   'riemann',
#   'first',
#   'rigorous',
#   'definition',
#   'integral',
#   'function',
#   'interval',
#   'presented',
#   'university',
#   'published',
#   'journal',
#   '[1]',
#   'many',
#   'functions',
#   'practical',
#   'applications,',
#   'riemann',
#   'integral',
#   'evaluated',
#   'fundamental',
#   'theorem',
#   'calculus',
#   'approximated',
#   'numerical',
#   'integration',
#   'riemann',
#   'integral',
#   'unsuitable',
#   'many',
#   'technical',
#   'riemann',
#   'integration',
#   'riemann–stieltjes',
#   'integral',
#   'lebesgue',
#   'integral',
#   'let',
#   'f',
#   'non-negative',
#   'real',
#   '-valued',
#   'function',
#   'interval',
#   'b',
#   'let',
#   'region',
#   'plane',
#   'graph',
#   'function',
#   'f',
#   'interval',
#   'b',
#   '(see',
#   'figure',
#   'top',
#   'interested',
#   'measuring',
#   'area',
#   'measured',
#   'it,',
#   'denote',
#   'area',
#   'by:',
#   'basic',
#   'idea',
#   'riemann',
#   'integral',
#   'use',
#   'simple',
#   'approximations',
#   'area',
#   'taking',
#   'better',
#   'better',
#   'approximations,',
#   'say',
#   '"in',
#   'get',
#   'exactly',
#   'area',
#   'note',
#   'f',
#   'positive',
#   'negative,',
#   'definition',
#   'integral',
#   'signed',
#   'area',
#   'graph',
#   'f',
#   'is,',
#   'area',
#   'x',
#   '-axis',
#   'minus',
#   'area',
#   'x',
#   'partition',
#   'interval',
#   'b',
#   'finite',
#   'sequence',
#   'numbers',
#   'form',
#   'x',
#   'x',
#   '1',
#   'called',
#   'sub-interval',
#   'partition.',
#   'mesh',
#   'norm',
#   'partition',
#   'defined',
#   'length',
#   'longest',
#   'sub-interval,',
#   'is,',
#   'tagged',
#   'partition',
#   'p',
#   'x',
#   'interval',
#   'b',
#   'partition',
#   'together',
#   'finite',
#   'sequence',
#   'numbers',
#   '0',
#   '...,',
#   'n',
#   '−',
#   '1',
#   'subject',
#   'conditions',
#   '∈',
#   'x',
#   'x',
#   '1',
#   'words,',
#   'partition',
#   'together',
#   'distinguished',
#   'point',
#   'every',
#   'mesh',
#   'tagged',
#   'partition',
#   'ordinary',
#   'partition.',
#   'suppose',
#   'two',
#   'partitions',
#   'p',
#   'x',
#   'q',
#   'partitions',
#   'interval',
#   'b',
#   'say',
#   'q',
#   'refinement',
#   'p',
#   'x',
#   'integer',
#   '∈',
#   '[0,',
#   'n',
#   'exists',
#   'integer',
#   'r',
#   'x',
#   'r',
#   'j',
#   'j',
#   'j',
#   '∈',
#   'r',
#   '),',
#   'r',
#   'said',
#   'refinement',
#   'tagged',
#   'partition',
#   'sub-intervals',
#   'adds',
#   'tags',
#   'partition',
#   'thus',
#   'accuracy',
#   'partition.',
#   'define',
#   'partial',
#   'order',
#   'set',
#   'tagged',
#   'partitions',
#   'one',
#   'tagged',
#   'partition',
#   'greater',
#   'equal',
#   'another',
#   'former',
#   'refinement',
#   'let',
#   'f',
#   'real-valued',
#   'function',
#   'defined',
#   'interval',
#   'b',
#   'riemann',
#   'sum',
#   'f',
#   'respect',
#   'tagged',
#   'partition',
#   'x',
#   '0',
#   '...,',
#   'x',
#   'n',
#   'together',
#   '0',
#   '...,',
#   'n',
#   '−',
#   '1',
#   '[2]',
#   'term',
#   'sum',
#   'product',
#   'value',
#   'function',
#   'given',
#   'point',
#   'length',
#   'interval.',
#   'consequently,',
#   'term',
#   'represents',
#   '(signed)',
#   'area',
#   'rectangle',
#   'height',
#   'f',
#   'width',
#   'x',
#   '1',
#   '−',
#   'x',
#   'riemann',
# ...
#   '(such',
#   'poem',
#   'begins',
#   'british',
#   'saxon',
#   'lands',
#   'arthur',
#   'arms',
#   ').',
#   '[168]',
#   'beowulf:',
#   'translation',
#   'commentary',
#   'published',
#   '22',
#   'may',
#   '2014,',
#   'prose',
#   'translation',
#   'early',
#   'medieval',
#   'epic',
#   'poem',
#   'beowulf',
#   'old',
#   'english',
#   'modern',
#   'english.',
#   'translated',
#   'tolkien',
#   '1920',
#   '1926,',
#   'edited',
#   'son',
#   'translation',
#   'followed',
#   '200',
#   'commentary',
#   'commentary',
#   'basis',
#   "tolkien's",
#   'acclaimed',
#   '1936',
#   'lecture',
#   'monsters',
#   '[169]',
#   'book',
#   'also',
#   'includes',
#   'previously',
#   'unpublished',
#   'two',
#   'versions',
#   '"the',
#   'lay',
#   'former',
#   'fantasy',
#   'piece',
#   'biographical',
#   'latter',
#   'poem',
#   'beowulf',
#   '[170]',
#   'story',
#   'kullervo',
#   'first',
#   'published',
#   'tolkien',
#   'studies',
#   '2010',
#   'additional',
#   'material',
#   '19th-century',
#   'finnish',
#   'poem.',
#   'written',
#   '1915',
#   'tolkien',
#   'studying',
#   'oxford.',
#   '[171]',
#   'tale',
#   'beren',
#   'lúthien',
#   'one',
#   'oldest',
#   'often',
#   'revised',
#   "tolkien's",
#   'story',
#   'one',
#   'three',
#   'contained',
#   'within',
#   'silmarillion',
#   'tolkien',
#   'believed',
#   'warrant',
#   'published',
#   'standalone',
#   'book,',
#   'edited',
#   'christopher',
#   'tolkien,',
#   'title',
#   'beren',
#   'lúthien',
#   '[172]',
#   'fall',
#   'gondolin',
#   'tale',
#   'mysterious',
#   'city',
#   'destroyed',
#   'dark',
#   'tolkien',
#   'called',
#   '"the',
#   'first',
#   'real',
#   'middle-earth',
#   'published',
#   '30',
#   'august',
#   '[173]',
#   'standalone',
#   'book,',
#   'edited',
#   'christopher',
#   'tolkien',
#   'illustrated',
#   '[174]',
#   'death',
#   'tolkien',
#   'manuscripts,',
#   'proofs',
#   'materials',
#   'related',
#   'lord',
#   'rings',
#   'hobbit',
#   'farmer',
#   'giles',
#   'ham',
#   '—to',
#   'department',
#   'special',
#   'collections',
#   'university',
#   'archives',
#   'university',
#   "'s",
#   'john',
#   'p.',
#   'library',
#   '[175]',
#   'death',
#   'estate',
#   'papers',
#   "tolkien's",
#   'silmarillion',
#   'mythology',
#   'academic',
#   'work',
#   'bodleian',
#   'library',
#   'oxford',
#   'university',
#   '[176]',
#   'library',
#   'held',
#   'exhibition',
#   'work',
#   'including',
#   'never',
#   'seen',
#   'public',
#   'before.',
#   '[177]',
#   'partial',
#   'draft',
#   'language',
#   'human',
#   'nature',
#   'tolkien',
#   'begun',
#   'c.',
#   's.',
#   'lewis',
#   'never',
#   'discovered',
#   'bodleian',
#   'library.',
#   '[178]',
#   "tolkien's",
#   'academic',
#   'career',
#   'literary',
#   'production',
#   'inseparable',
#   'love',
#   'language',
#   'philology',
#   'specialized',
#   'english',
#   'philology',
#   'university',
#   '1915',
#   'old',
#   'norse',
#   'special',
#   'subject.',
#   'worked',
#   'oxford',
#   'english',
#   'dictionary',
#   '1918',
#   'worked',
#   'number',
#   'words',
#   'starting',
#   'letter',
#   'including',
#   'struggled',
#   '[179]',
#   '1920,',
#   'became',
#   'reader',
#   'english',
#   'language',
#   'university',
#   'leeds',
#   'claimed',
#   'number',
#   'students',
#   'five',
#   'gave',
#   'old',
#   'english',
#   'verse',
#   'history',
#   'english',
#   'various',
#   'old',
#   'english',
#   'middle',
#   'english',
#   'old',
#   'middle',
#   'english',
#   'philology,',
#   'introductory',
#   'germanic',
#   'philology,',
#   'gothic',
#   'old',
#   'medieval',
#   'welsh',
#   '1925,',
#   'aged',
#   'tolkien',
#   'applied',
#   'rawlinson',
#   'bosworth',
#   'anglo-saxon',
#   'pembroke',
#   'college,',
#   'oxford',
#   'students',
#   'germanic',
#   'philology',
#   'leeds',
#   'even',
#   'formed',
#   'club',
#   '".',
#   '[180]',
#   'also',
#   'knowledge',
#   '[181]',
#   'tolkien',
#   'attracted',
#   'linguistic',
#   'lecture',
#   'english',
#   'welsh',
#   'crucial',
#   'understanding',
#   'race',
#   'language,',
#   'entertained',
#   'notions',
#   'linguistic',
#   'termed',
#   '"native',
#   'opposed',
#   'person',
#   'first',
#   '[182]',
#   'considered',
#   'west',
#   'middle',
#   'english',
#   '"native',
#   'and,',
#   'wrote',
#   'w.',
#   'h.',
#   'auden',
#   '1955,',
#   '"i',
#   'blood',
#   '(and',
#   'took',
#   'early',
#   'middle',
#   'english',
#   'known',
#   'tongue',
#   'soon',
#   'set',
#   'eyes',
#   '[183]',
#   'parallel',
#   "tolkien's",
#   'work',
#   'sometimes',
#   'work,',
#   'effect',
#   'academic',
#   'output',
#   'remained',
#   'rather',
#   'affection',
#   'languages',
#   'developed',
#   'quenya',
#   'connection',
#   'formed',
#   'much',
#   "tolkien's",
#   'legendarium',
#   'language',
#   'tolkien',
#   'matter',
#   'quenya',
#   'particular',
#   'designed',
#   'intended',
#   'based',
#   'english,',
#   '[148]',
#   'notable',
#   'addition',
#   'came',
#   'late',
#   '1945',
#   'language',
#   'connected',
#   "tolkien's",
#   'atlantis',
#   'notion',
#   'club',
#   'papers',
#   'directly',
#   'ideas',
#   'inability',
#   'language',
#   'via',
#   'second',
#   'age',
#   'story',
#   'legendarium',
#   'link',
#   "tolkien's",
#   '20th-century',
#   'primary',
#   'legendary',
#   'past',
#   'middle-earth.',
#   'tolkien',
#   'considered',
#   'languages',
#   'inseparable',
#   'mythology',
#   'associated',
#   'them,',
#   'took',
#   'view',
#   'auxiliary',
#   'languages',
#   '1930',
#   'told',
#   'much',
#   'him,',
#   'lecture',
#   'secret',
#   'vice',
#   '[184]',
#   'language',
#   'construction',
#   'mythology",',
#   '1956',
#   'concluded',
#   'esperanto',
#   '&amp;c,',
#   '&amp;c,',
#   'dead,',
#   'far',
#   'ancient',
#   'languages,',
#   'authors',
#   'never',
#   'invented',
#   'esperanto',
#   '[185]',
#   'popularity',
#   "tolkien's",
#   'books',
#   'small',
#   'lasting',
#   'effect',
#   'use',
#   'language',
#   'fantasy',
#   'literature',
#   'particular,',
#   'even',
#   'today',
#   'commonly',
#   'accept',
#   "tolkien's",
#   'dwarves',
#   '),',
#   'little',
#   'used',
#   'since',
#   'century',
#   '(in',
#   'fact,',
#   'according',
#   'tolkien,',
#   'old',
#   'english',
#   'would',
#   '.)',
#   'also',
#   'coined',
#   'term',
#   'though',
#   'remains',
#   'mainly',
#   'used',
#   'connection',
#   'work.',
#   'artist,',
#   'learned',
#   'paint',
#   'draw',
#   'child',
#   'continued',
#   'life.',
#   '[186]',
#   'early',
#   'writing',
#   'career,',
#   'development',
#   'stories',
#   'accompanied',
#   'drawings',
#   'paintings,',
#   'especially',
#   'landscapes,',
#   'maps',
#   'lands',
#   'tales',
#   'also',
#   'produced',
#   'pictures',
#   'stories',
#   'told',
#   'children,',
#   'including',
#   'later',
#   'published',
#   'bliss',
#   'roverandom',
#   'sent',
#   'illustrated',
#   'letters',
#   'come',
#   'father',
#   'christmas.',
#   'although',
#   'regarded',
#   'publisher',
#   'used',
#   "author's",
#   'cover',
#   'art,',
#   'illustrations',
#   'early',
#   'editions',
#   'hobbit',
#   'much',
#   'artwork',
#   'collected',
#   'published',
#   '1995',
#   'j.',
#   'r.',
#   'r.',
#   'tolkien:',
#   'artist',
#   'illustrator',
#   'book',
#   'discusses',
#   "tolkien's",
#   'paintings,',
#   'drawings,',
#   'sketches,',
#   'approximately',
#   '200',
#   'examples',
#   'work.',
#   '[187]',
#   '1951',
#   'letter',
#   'publisher',
#   'milton',
#   'waldman',
#   'tolkien',
#   'wrote',
#   'create',
#   'less',
#   'connected',
#   'linked',
#   'yet',
#   'leave',
#   'scope',
#   'minds',
#   'paint',
#   'music',
#   '[188]',
#   'hands',
#   'minds',
#   'many',
#   'artists',
#   'indeed',
#   'inspired',
#   "tolkien's",
#   'legends.',
#   'personally',
#   'known',
#   'favourite',
#   'illustrator',
#   'adventures',
#   'tom',
#   'bombadil',
#   'farmer',
#   'giles',
#   'ham',
#   'set',
#   'music',
#   'road',
#   'goes',
#   'ever',
#   ').',
#   'queen',
#   'ii',
#   'created',
#   'illustrations',
#   'lord',
#   'rings',
#   'early',
#   '1970s.',
#   'sent',
#   'tolkien,',
#   'struck',
#   'similarity',
#   'bore',
#   'style',
#   'drawings.',
#   '[189]',
#   'however,',
#   'tolkien',
#   'fond',
#   'artistic',
#   'representation',
#   'works',
#   'produced',
#   'lifetime,',
#   'sometimes',
#   'harshly',
#   'rejected',
#   'illustrations',
#   'german',
#   'edition',
#   'hobbit',
#   '...',
#   'bilbo',
#   'gandalf',
#   'figure',
#   'rather',
#   'think',
#   '[190]',
#   'tolkien',
#   'tolkien',
#   'united',
#   '1954',
#   'returned',
#   'american',
#   'edition',
#   'lord',
#   'rings',
#   'thank',
#   'rule',
#   'amenable',
#   'criticism',
#   'think',
#   'effort',
#   'poor',
#   'feel',
#   'make',
#   'effort',
#   'improve',
#   'it.',
#   '[148]',
#   'dismissed',
#   'dramatic',
#   'representations',
#   'fantasy',
#   'essay',
#   'fairy-stories',
#   '",',
#   'first',
#   'presented',
#   'human',
#   'art',
#   'fantasy',
#   'thing',
#   'best',
#   'left',
#   'words,',
#   'true',
#   'literature.',
#   '...',
#   'fantasy.',
#   'even',
#   'simplest',
#   'hardly',
#   'ever',
#   'presented',
#   'be,',
#   '[191]',
#   'tolkien',
#   'scholar',
#   'james',
#   'coined',
#   'word',
#   'derived',
#   '"tolkien',
#   'describe',
#   'attempts',
#   'create',
#   'adaptation',
#   'stories',
#   "tolkien's",
#   'legendarium',
#   'good',
#   'box',
#   'office',
#   'rather',
#   'idea',
#   '[192]',
#   'receiving',
#   'screenplay',
#   'proposed',
#   'film',
#   'adaptation',
#   'lord',
#   'rings',
#   'tolkien',
#   'wrote:',
#   'would',
#   'ask',
#   'make',
#   'effort',
#   'imagination',
#   'sufficient',
#   'understand',
#   '(and',
#   'occasion',
#   'author,',
#   'increasingly',
#   'work',
#   'treated',
#   'would',
#   'seem',
#   'general,',
#   'places',
#   'evident',
#   'signs',
#   'appreciation',
#   '[193]',
#   'tolkien',
#   'went',
#   'script',
#   'scene',
#   'scene',
#   'one',
#   'scene',
#   'rather',
#   'opposed',
#   'idea',
#   'dramatic',
#   'however,',
#   'sold',
#   'film,',
#   'stage',
#   'rights',
#   'hobbit',
#   'lord',
#   'rings',
#   'united',
#   'artists',
#   'united',
#   'artists',
#   'never',
#   'made',
#   'film,',
#   'although',
#   'director',
#   'john',
#   'planning',
#   'live-action',
#   'film',
#   'early',
#   '1970s.',
#   'rights',
#   'sold',
#   'tolkien',
#   'division',
#   'company,',
#   'first',
#   'film',
#   'adaptation',
#   'lord',
#   'rings',
#   'released',
#   'animated',
#   'film',
#   'directed',
#   'bakshi',
#   'screenplay',
#   'fantasy',
#   'writer',
#   'peter',
#   's.',
#   'covered',
#   'first',
#   'half',
#   'story',
#   'lord',
#   'rings',
#   '[194]',
#   'animated',
#   'musical',
#   'television',
#   'film',
#   'hobbit',
#   'made',
#   'produced',
#   'animated',
#   'musical',
#   'television',
#   'film',
#   'return',
#   'king',
#   'covered',
#   'portions',
#   'lord',
#   'rings',
#   'bakshi',
#   'unable',
#   'complete.',
#   '2001',
#   'new',
#   'line',
#   'cinema',
#   'released',
#   'lord',
#   'rings',
#   'live-action',
#   'films',
#   'filmed',
#   'new',
#   'zealand',
#   'directed',
#   'peter',
#   'jackson',
#   'series',
#   'successful,',
#   'extremely',
#   'well',
#   'commercially',
#   'numerous',
#   'oscars',
#   '[195]',
#   '2012',
#   '2014,',
#   'new',
#   'line',
#   'cinema',
#   'released',
#   'hobbit',
#   'series',
#   'three',
#   'films',
#   'based',
#   'hobbit',
#   'peter',
#   'jackson',
#   '[196]',
#   'first',
#   'instalment,',
#   'hobbit:',
#   'unexpected',
#   'journey',
#   'released',
#   'december',
#   '[197]',
#   'second,',
#   'hobbit:',
#   'december',
#   '[198]',
#   'last',
#   'instalment,',
#   'hobbit:',
#   'battle',
#   'five',
#   'december',
#   '[199]',
#   'biographical',
#   'film',
#   'tolkien',
#   'set',
#   'released',
#   '10',
#   'may',
#   '2019,',
#   'focusing',
#   "tolkien's",
#   'early',
#   'life',
#   'war',
#   '[200]',
#   '13',
#   'november',
#   'announced',
#   'amazon',
#   'acquired',
#   'television',
#   'rights',
#   'lord',
#   'rings',
#   'series',
#   'direct',
#   'adaptation',
#   'books,',
#   'instead',
#   'new',
#   'stories',
#   'set',
#   'fellowship',
#   'ring.',
#   '[201]',
#   'press',
#   'release',
#   'referred',
#   'stories',
#   'based',
#   'j.',
#   'r.',
#   'r.',
#   "tolkien's",
#   'original',
#   'amazon',
#   'tolkien',
#   'estate',
#   'tolkien',
#   'trust',
#   'harpercollins',
#   'new',
#   'line',
#   'cinema',
#   '[202]',
#   'tolkien',
#   'characters',
#   'places',
#   'works',
#   'become',
#   'various',
#   'things',
#   'around',
#   'world.',
#   'include',
#   'street',
#   'names,',
#   'species',
#   'well',
#   'notable',
#   'objects.',
#   'convention,',
#   'certain',
#   'classes',
#   'features',
#   'named',
#   'elements',
#   'middle-earth.',
#   '[203]',
#   'hills',
#   'named',
#   'characters,',
#   '[204]',
#   'named',
#   'mountains',
#   'middle-earth.',
#   '[205]',
#   'also',
#   'named',
#   'bilbo',
#   'baggins',
#   'tolkien',
#   'himself.',
#   '[206]',
#   '[207]',
#   'three',
#   'mountains',
#   'range',
#   'british',
#   'columbia',
#   'named',
#   "tolkien's",
#   'characters.',
#   'mount',
#   'mount',
#   'gandalf',
#   'mount',
#   '[208]',
#   '[209]',
#   '1',
#   'december',
#   '2012,',
#   'announced',
#   'new',
#   'zealand',
#   'press',
#   'new',
#   'zealand',
#   'board',
#   'name',
#   'peak',
#   'near',
#   'tolkien',
#   'historical',
#   'literary',
#   'reasons',
#   'mark',
#   "tolkien's",
#   'birthday.',
#   '[210]',
#   '"tolkien',
#   'east',
#   'named',
#   'tolkien',
#   'whereas',
#   '"tolkien',
#   'named',
#   "tolkien's",
#   'son,',
#   'fr.',
#   'john',
#   'francis',
#   'tolkien,',
#   'priest',
#   'charge',
#   'nearby',
#   'roman',
#   'catholic',
#   'church',
#   'lady',
#   'angels',
#   'st.',
#   'peter',
#   '[211]',
#   'hall',
#   'green',
#   'moseley',
#   'areas',
#   'birmingham',
#   'number',
#   'parks',
#   'dedicated',
#   'j.',
#   'r.',
#   'r.',
#   'way',
#   'moseley',
#   'bog',
#   '[212]',
#   'parks',
#   'known',
#   'shire',
#   'country',
#   '[212]',
#   'also',
#   'england',
#   'collection',
#   'named',
#   'middle',
#   'namely',
#   'road,',
#   'close,',
#   'close,',
#   'way',
#   'green.',
#   'dutch',
#   'town',
#   'near',
#   'entire',
#   'new',
#   'neighbourhood',
#   'named',
#   'tolkien',
#   'van',
#   'characters',
#   'books.',
#   'towns',
#   'san',
#   'two',
#   'developments',
#   'street',
#   'names',
#   'drawn',
#   "tolkien's",
#   'works.',
#   'dozen',
#   'street',
#   'names',
#   'also',
#   'appear',
#   'throughout',
#   'town',
#   'lake',
#   'california',
#   'columbia',
#   'neighbourhood',
#   'street',
#   'names',
#   '(including',
#   'come',
#   "tolkien's",
#   'works.',
#   '[213]',
#   'field',
#   '80',
#   'taxa',
#   'given',
#   'scientific',
#   'names',
#   'deriving',
#   'characters',
#   'fictional',
#   'elements',
#   'lord',
#   'rings',
#   'hobbit',
#   'works',
#   'set',
#   'middle-earth',
#   '[214]',
#   'several',
#   'taxa',
#   'named',
#   'character',
#   '(also',
#   'known',
#   'well',
#   'various',
#   'small',
#   'creatures',
#   'bilbo',
#   'frodo',
#   'baggins',
#   'various',
#   'elves',
#   'dwarves',
#   'creatures',
#   'appear',
#   'writings',
#   'well',
#   'tolkien',
#   'honoured',
#   'names',
#   'several',
#   'including',
#   'tolkieni',
#   'tolkieni',
#   '2004,',
#   'extinct',
#   'quickly',
#   'earned',
#   'due',
#   'small',
#   '[215]',
#   'van',
#   'named',
#   '20',
#   'taxa',
#   'extinct',
#   'tolkien',
#   'single',
#   'paper.',
#   '[216]',
#   '[217]',
#   '1999,',
#   'described',
#   'new',
#   'species',
#   'named',
#   '37',
#   'tolkien',
#   'mythology.',
#   '[214]',
#   '[218]',
#   'noted',
#   '"tolkien',
#   'formal',
#   'like',
#   '[219]',
#   'since',
#   '2003',
#   'tolkien',
#   'society',
#   'organized',
#   'tolkien',
#   'reading',
#   'day',
#   'takes',
#   'place',
#   '25',
#   'march',
#   'schools',
#   'around',
#   'world.',
#   '[220]',
#   '2013',
#   'pembroke',
#   'college,',
#   'oxford',
#   'university',
#   'established',
#   'annual',
#   'lecture',
#   'fantasy',
#   'literature',
#   "tolkien's",
#   '[221]',
#   'seven',
#   'blue',
#   'plaques',
#   'england',
#   'commemorate',
#   'places',
#   'associated',
#   'tolkien:',
#   'one',
#   'one',
#   'four',
#   'birmingham',
#   'one',
#   'one',
#   'birmingham',
#   'plaques',
#   'commemorates',
#   'inspiration',
#   'provided',
#   'sarehole',
#   'near',
#   'lived',
#   'four',
#   'two',
#   'mark',
#   'childhood',
#   'time',
#   'left',
#   'attend',
#   'oxford',
#   'university',
#   'marks',
#   'hotel',
#   'stayed',
#   'leaving',
#   'france',
#   'world',
#   'war',
#   'plaque',
#   'west',
#   'leeds,',
#   'commemorates',
#   'five',
#   'years',
#   'tolkien',
#   'enjoyed',
#   'leeds',
#   'reader',
#   'professor',
#   'english',
#   'language',
#   'oxford',
#   'plaque',
#   'commemorates',
#   'tolkien',
#   'wrote',
#   'hobbit',
#   'lord',
#   'rings',
#   'another',
#   'two',
#   'plaques',
#   'associated',
#   'tolkien',
#   '2012,',
#   'tolkien',
#   'among',
#   'british',
#   'cultural',
#   'selected',
#   'artist',
#   'sir',
#   'peter',
#   'appear',
#   'new',
#   'version',
#   'famous',
#   'lonely',
#   'club',
#   'album',
#   'celebrate',
#   'british',
#   'cultural',
#   'figures',
#   'life',
#   '[230]',
#   '[231]',
#   'unlike',
#   'authors',
#   'tolkien',
#   'never',
#   'works.',
#   'owing',
#   'copies',
#   'letters',
#   'first',
#   'editions',
#   'individual',
#   'writings',
#   'however',
#   'achieved',
#   'high',
#   'values',
#   'may',
#   'occur',
#   'particular,',
#   'signed',
#   'first',
#   'edition',
#   'hobbit',
#   '1937',
#   'offered',
#   'also',
#   'include',
#   'non-fiction',
#   'books',
#   "tolkien's",
#   'private',
#   'library.',
#   '[232]',
#   'small',
#   'selection',
#   'books',
#   'tolkien']]

# %% [markdown]
# # Zad
#
# Proszę
# * utworzyć reprezentację **bag-of-words**

# %%
from gensim import corpora, models, similarities, matutils
dictionary = corpora.Dictionary(texts)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
print(corpus)
# Out:
# [[(0, 2), (1, 2), (2, 1), (3, 1), (4, 4), (5, 3), (6, 1), (7, 2), (8, 1), (9, 1), (10, 2), (11, 1), (12, 1), (13, 1), (14, 1), (15, 2), (16, 3), (17, 1), (18, 2), (19, 2), (20, 1), (21, 2), (22, 3), (23, 1), (24, 1), (25, 4), (26, 3), (27, 1), (28, 1), (29, 2), (30, 5), (31, 4), (32, 2), (33, 1), (34, 10), (35, 1), (36, 18), (37, 2), (38, 3), (39, 1), (40, 1), (41, 2), (42, 1), (43, 4), (44, 1), (45, 2), (46, 1), (47, 1), (48, 17), (49, 1), (50, 1), (51, 1), (52, 1), (53, 3), (54, 3), (55, 2), (56, 3), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 2), (65, 2), (66, 1), (67, 2), (68, 1), (69, 1), (70, 1), (71, 2), (72, 2), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 2), (81, 1), (82, 1), (83, 1), (84, 1), (85, 1), (86, 2), (87, 1), (88, 3), (89, 5), (90, 1), (91, 5), (92, 1), (93, 3), (94, 12), (95, 3), (96, 2), (97, 2), (98, 1), (99, 1), (100, 4), (101, 1), (102, 1), (103, 2), (104, 2), (105, 5), (106, 13), (107, 2), (108, 7), (109, 2), (110, 1), (111, 4), (112, 1), (113, 1), (114, 5), (115, 3), (116, 2), (117, 1), (118, 3), (119, 12), (120, 2), (121, 6), (122, 1), (123, 1), (124, 2), (125, 2), (126, 1), (127, 1), (128, 21), (129, 1), (130, 2), (131, 9), (132, 2), (133, 1), (134, 1), (135, 4), (136, 1), (137, 2), (138, 2), (139, 1), (140, 1), (141, 1), (142, 1), (143, 1), (144, 1), (145, 1), (146, 1), (147, 1), (148, 3), (149, 46), (150, 2), (151, 2), (152, 5), (153, 3), (154, 1), (155, 2), (156, 2), (157, 1), (158, 2), (159, 1), (160, 1), (161, 1), (162, 1), (163, 1), (164, 4), (165, 2), (166, 1), (167, 2), (168, 1), (169, 5), (170, 2), (171, 2), (172, 2), (173, 2), (174, 1), (175, 1), (176, 3), (177, 10), (178, 5), (179, 2), (180, 1), (181, 18), (182, 6), (183, 2), (184, 13), (185, 1), (186, 1), (187, 1), (188, 1), (189, 1), (190, 1), (191, 4), (192, 5), (193, 3), (194, 3), (195, 1), (196, 2), (197, 2), (198, 5), (199, 2), (200, 1), (201, 3), (202, 1), (203, 1), (204, 1), (205, 1), (206, 3), (207, 1), (208, 1), (209, 6), (210, 1), (211, 1), (212, 1), (213, 15), (214, 3), (215, 1), (216, 2), (217, 2), (218, 2), (219, 2), (220, 2), (221, 1), (222, 1), (223, 3), (224, 1), (225, 3), (226, 1), (227, 1), (228, 1), (229, 1), (230, 7), (231, 2), (232, 1), (233, 2), (234, 1), (235, 7), (236, 2), (237, 2), (238, 7), (239, 1), (240, 2), (241, 1), (242, 2), (243, 1), (244, 3), (245, 1), (246, 3), (247, 1), (248, 2), (249, 1), (250, 1), (251, 1), (252, 3), (253, 7), (254, 2), (255, 3), (256, 1), (257, 1), (258, 2), (259, 1), (260, 1), (261, 1), (262, 1), (263, 1), (264, 3), (265, 10), (266, 4), (267, 1), (268, 2), (269, 1), (270, 1), (271, 1), (272, 2), (273, 2), (274, 1), (275, 1), (276, 19), (277, 15), (278, 8), (279, 3), (280, 2), (281, 1), (282, 7), (283, 1), (284, 1), (285, 1), (286, 5), (287, 2), (288, 2), (289, 1), (290, 1), (291, 5), (292, 1), (293, 1), (294, 1), (295, 1), (296, 3), (297, 1), (298, 1), (299, 3), (300, 3), (301, 3), (302, 3), (303, 3), (304, 1), (305, 15), (306, 4), (307, 4), (308, 2), (309, 2), (310, 4), (311, 1), (312, 1), (313, 2), (314, 1), (315, 3), (316, 1), (317, 1), (318, 2), (319, 2), (320, 1), (321, 2), (322, 1), (323, 1), (324, 4), (325, 1), (326, 3), (327, 4), (328, 1), (329, 6), (330, 1), (331, 1), (332, 1), (333, 2), (334, 1), (335, 12), (336, 1), (337, 7), (338, 3), (339, 3), (340, 1), (341, 1), (342, 1), (343, 1), (344, 1), (345, 1), (346, 2), (347, 4), (348, 1), (349, 1), (350, 3), (351, 1), (352, 2), (353, 1), (354, 2), (355, 1), (356, 1), (357, 1), (358, 6), (359, 1), (360, 2), (361, 1), (362, 4), (363, 1), (364, 1), (365, 1), (366, 1), (367, 1), (368, 3), (369, 3), (370, 3), (371, 2), (372, 2), (373, 7), (374, 1), (375, 4), (376, 13), (377, 1), (378, 1), (379, 2), (380, 2), (381, 2), (382, 1), (383, 1), (384, 1), (385, 1), (386, 1), (387, 3), (388, 2), (389, 5), (390, 1), (391, 4), (392, 2), (393, 2), (394, 1), (395, 1), (396, 2), (397, 1), (398, 1), (399, 1), (400, 3), (401, 70), (402, 1), (403, 2), (404, 1), (405, 1), (406, 14), (407, 2), (408, 2) ...

# %% [markdown]
# # Zad
# Stwórz model **Lda** (Latent Dirichlet Allocation) z
# * **num_topics=2**

# %%
model = models.LdaModel(corpus, id2word=dictionary, num_topics=2)
corpus_lda = model[corpus] # create a double wrapper over the original corpus: bow->tfidf->fold-in-lsi
for d in corpus_lda:
    print(d)
# Out:
# [(0, 0.99978524)]
# [(0, 0.99970067)]
# [(0, 0.99892145)]
# [(0, 0.9874), (1, 0.012599949)]
# [(0, 0.9991382)]
# [(0, 0.9682697), (1, 0.0317303)]
# [(1, 0.99986374)]
# [(0, 0.7326792), (1, 0.26732078)]
# [(0, 0.6293526), (1, 0.37064746)]
# [(0, 0.1458256), (1, 0.8541744)]
# [(1, 0.99558246)]

# %% [markdown]
# # Zad
#
# Wypisz z czego składają się tematy:

# %%
import numpy as np

topic_inex = 0
print(model.print_topic(topicno=topic_inex))

topic_inex = 1
print(model.print_topic(topicno=topic_inex))
# Out:
# 0.012*"x" + 0.009*"f" + 0.008*"function" + 0.007*"integral" + 0.006*"n" + 0.005*"riemann" + 0.005*"munch" + 0.005*"tolkien" + 0.005*"{\displaystyle" + 0.004*"1"
# 0.009*"van" + 0.007*"f" + 0.007*"x" + 0.007*"tolkien" + 0.006*"gogh" + 0.005*"function" + 0.004*"derivative" + 0.004*"one" + 0.003*"integral" + 0.003*"first"

# %% [markdown]
# # Zad
#
# Proszę posortować zdania najbardziej pasujące do danego tematu.

# %%
import gensim

top_inex = 0

numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort(numpy_corpus[top_inex,:])[::-1]
for x in docs[:5]:
    print(corpus[x])
    
#trzeba by wypisać raczej zdania niż ich reprezentacje bag-of-words, ale tu nie mam dostepu do tekstu
# Out:
# [(0, 2), (1, 2), (2, 1), (3, 1), (4, 4), (5, 3), (6, 1), (7, 2), (8, 1), (9, 1), (10, 2), (11, 1), (12, 1), (13, 1), (14, 1), (15, 2), (16, 3), (17, 1), (18, 2), (19, 2), (20, 1), (21, 2), (22, 3), (23, 1), (24, 1), (25, 4), (26, 3), (27, 1), (28, 1), (29, 2), (30, 5), (31, 4), (32, 2), (33, 1), (34, 10), (35, 1), (36, 18), (37, 2), (38, 3), (39, 1), (40, 1), (41, 2), (42, 1), (43, 4), (44, 1), (45, 2), (46, 1), (47, 1), (48, 17), (49, 1), (50, 1), (51, 1), (52, 1), (53, 3), (54, 3), (55, 2), (56, 3), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 2), (65, 2), (66, 1), (67, 2), (68, 1), (69, 1), (70, 1), (71, 2), (72, 2), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 2), (81, 1), (82, 1), (83, 1), (84, 1), (85, 1), (86, 2), (87, 1), (88, 3), (89, 5), (90, 1), (91, 5), (92, 1), (93, 3), (94, 12), (95, 3), (96, 2), (97, 2), (98, 1), (99, 1), (100, 4), (101, 1), (102, 1), (103, 2), (104, 2), (105, 5), (106, 13), (107, 2), (108, 7), (109, 2), (110, 1), (111, 4), (112, 1), (113, 1), (114, 5), (115, 3), (116, 2), (117, 1), (118, 3), (119, 12), (120, 2), (121, 6), (122, 1), (123, 1), (124, 2), (125, 2), (126, 1), (127, 1), (128, 21), (129, 1), (130, 2), (131, 9), (132, 2), (133, 1), (134, 1), (135, 4), (136, 1), (137, 2), (138, 2), (139, 1), (140, 1), (141, 1), (142, 1), (143, 1), (144, 1), (145, 1), (146, 1), (147, 1), (148, 3), (149, 46), (150, 2), (151, 2), (152, 5), (153, 3), (154, 1), (155, 2), (156, 2), (157, 1), (158, 2), (159, 1), (160, 1), (161, 1), (162, 1), (163, 1), (164, 4), (165, 2), (166, 1), (167, 2), (168, 1), (169, 5), (170, 2), (171, 2), (172, 2), (173, 2), (174, 1), (175, 1), (176, 3), (177, 10), (178, 5), (179, 2), (180, 1), (181, 18), (182, 6), (183, 2), (184, 13), (185, 1), (186, 1), (187, 1), (188, 1), (189, 1), (190, 1), (191, 4), (192, 5), (193, 3), (194, 3), (195, 1), (196, 2), (197, 2), (198, 5), (199, 2), (200, 1), (201, 3), (202, 1), (203, 1), (204, 1), (205, 1), (206, 3), (207, 1), (208, 1), (209, 6), (210, 1), (211, 1), (212, 1), (213, 15), (214, 3), (215, 1), (216, 2), (217, 2), (218, 2), (219, 2), (220, 2), (221, 1), (222, 1), (223, 3), (224, 1), (225, 3), (226, 1), (227, 1), (228, 1), (229, 1), (230, 7), (231, 2), (232, 1), (233, 2), (234, 1), (235, 7), (236, 2), (237, 2), (238, 7), (239, 1), (240, 2), (241, 1), (242, 2), (243, 1), (244, 3), (245, 1), (246, 3), (247, 1), (248, 2), (249, 1), (250, 1), (251, 1), (252, 3), (253, 7), (254, 2), (255, 3), (256, 1), (257, 1), (258, 2), (259, 1), (260, 1), (261, 1), (262, 1), (263, 1), (264, 3), (265, 10), (266, 4), (267, 1), (268, 2), (269, 1), (270, 1), (271, 1), (272, 2), (273, 2), (274, 1), (275, 1), (276, 19), (277, 15), (278, 8), (279, 3), (280, 2), (281, 1), (282, 7), (283, 1), (284, 1), (285, 1), (286, 5), (287, 2), (288, 2), (289, 1), (290, 1), (291, 5), (292, 1), (293, 1), (294, 1), (295, 1), (296, 3), (297, 1), (298, 1), (299, 3), (300, 3), (301, 3), (302, 3), (303, 3), (304, 1), (305, 15), (306, 4), (307, 4), (308, 2), (309, 2), (310, 4), (311, 1), (312, 1), (313, 2), (314, 1), (315, 3), (316, 1), (317, 1), (318, 2), (319, 2), (320, 1), (321, 2), (322, 1), (323, 1), (324, 4), (325, 1), (326, 3), (327, 4), (328, 1), (329, 6), (330, 1), (331, 1), (332, 1), (333, 2), (334, 1), (335, 12), (336, 1), (337, 7), (338, 3), (339, 3), (340, 1), (341, 1), (342, 1), (343, 1), (344, 1), (345, 1), (346, 2), (347, 4), (348, 1), (349, 1), (350, 3), (351, 1), (352, 2), (353, 1), (354, 2), (355, 1), (356, 1), (357, 1), (358, 6), (359, 1), (360, 2), (361, 1), (362, 4), (363, 1), (364, 1), (365, 1), (366, 1), (367, 1), (368, 3), (369, 3), (370, 3), (371, 2), (372, 2), (373, 7), (374, 1), (375, 4), (376, 13), (377, 1), (378, 1), (379, 2), (380, 2), (381, 2), (382, 1), (383, 1), (384, 1), (385, 1), (386, 1), (387, 3), (388, 2), (389, 5), (390, 1), (391, 4), (392, 2), (393, 2), (394, 1), (395, 1), (396, 2), (397, 1), (398, 1), (399, 1), (400, 3), (401, 70), (402, 1), (403, 2), (404, 1), (405, 1), (406, 14), (407, 2), (408, 2), ...
# [(5, 9), (6, 1), (10, 1), (12, 2), (19, 1), (20, 2), (21, 1), (23, 1), (25, 1), (26, 4), (30, 1), (33, 1), (34, 33), (36, 49), (37, 1), (38, 2), (39, 1), (48, 2), (60, 1), (61, 1), (62, 1), (63, 2), (67, 1), (71, 1), (78, 1), (83, 1), (85, 1), (91, 1), (92, 4), (94, 5), (97, 9), (100, 1), (104, 3), (109, 3), (111, 2), (112, 1), (114, 2), (116, 2), (117, 1), (119, 1), (121, 2), (122, 1), (125, 1), (128, 9), (135, 1), (136, 1), (139, 1), (149, 22), (152, 1), (153, 1), (155, 1), (162, 1), (164, 3), (168, 1), (169, 10), (175, 1), (177, 11), (181, 3), (184, 1), (187, 1), (191, 4), (192, 2), (201, 1), (202, 1), (206, 1), (212, 5), (218, 4), (222, 1), (225, 6), (230, 2), (235, 2), (240, 1), (242, 2), (245, 2), (246, 2), (250, 1), (253, 2), (257, 2), (260, 3), (261, 1), (262, 4), (268, 18), (275, 4), (276, 8), (278, 17), (279, 2), (285, 1), (297, 1), (301, 3), (303, 3), (310, 5), (314, 1), (320, 2), (321, 1), (322, 1), (334, 1), (340, 1), (341, 3), (342, 2), (345, 2), (351, 1), (352, 2), (355, 2), (358, 10), (359, 3), (360, 1), (362, 7), (363, 1), (369, 2), (371, 2), (372, 1), (374, 1), (376, 5), (381, 1), (394, 2), (397, 1), (401, 45), (403, 4), (405, 1), (409, 1), (414, 13), (415, 2), (416, 6), (417, 2), (426, 3), (427, 1), (428, 1), (430, 1), (442, 1), (447, 32), (448, 3), (449, 3), (450, 1), (451, 6), (453, 3), (455, 1), (457, 6), (461, 4), (463, 1), (464, 2), (469, 3), (470, 1), (471, 1), (472, 1), (473, 1), (478, 1), (481, 2), (483, 1), (489, 1), (490, 1), (491, 1), (496, 1), (504, 3), (507, 1), (511, 3), (514, 2), (515, 6), (516, 2), (518, 1), (529, 1), (541, 1), (542, 6), (543, 9), (544, 6), (545, 58), (546, 3), (547, 7), (548, 8), (549, 1), (554, 1), (557, 5), (558, 1), (559, 2), (566, 19), (567, 1), (568, 2), (569, 17), (570, 2), (576, 6), (580, 1), (582, 25), (584, 7), (586, 3), (598, 1), (599, 18), (600, 3), (601, 2), (602, 1), (604, 9), (605, 1), (606, 1), (607, 9), (608, 12), (611, 1), (612, 7), (614, 2), (615, 1), (617, 2), (626, 1), (627, 6), (628, 1), (631, 3), (632, 5), (633, 1), (634, 5), (638, 1), (640, 1), (641, 8), (645, 2), (646, 10), (647, 1), (649, 1), (651, 7), (656, 1), (660, 2), (665, 1), (669, 1), (670, 4), (671, 42), (675, 2), (681, 2), (685, 1), (692, 1), (694, 8), (695, 6), (696, 1), (708, 13), (711, 7), (715, 1), (716, 1), (724, 3), (728, 1), (729, 2), (731, 32), (732, 2), (734, 6), (747, 1), (752, 1), (756, 5), (757, 2), (758, 12), (760, 1), (761, 1), (764, 3), (766, 6), (767, 2), (768, 2), (770, 1), (772, 1), (777, 2), (781, 3), (787, 1), (788, 2), (789, 1), (797, 1), (801, 7), (806, 15), (812, 5), (813, 1), (815, 6), (816, 3), (822, 1), (829, 1), (830, 1), (836, 1), (840, 1), (843, 1), (846, 4), (854, 88), (856, 7), (857, 2), (859, 1), (860, 1), (870, 2), (872, 1), (875, 4), (877, 3), (879, 2), (883, 5), (884, 1), (886, 16), (887, 1), (895, 1), (896, 1), (897, 1), (899, 2), (901, 1), (902, 1), (903, 1), (906, 14), (911, 4), (918, 3), (921, 2), (922, 1), (923, 1), (924, 1), (928, 1), (930, 1), (931, 1), (934, 1), (936, 1), (940, 1), (941, 1), (942, 1), (943, 2), (944, 2), (954, 29), (955, 2), (959, 14), (960, 4), (961, 2), (973, 16), (974, 4), (975, 3), (976, 1), (977, 2), (978, 2), (980, 1), (984, 8), (987, 1), (990, 1), (991, 4), (992, 1), (994, 2), (995, 5), (997, 2), (999, 1), (1001, 6), (1008, 4), (1011, 8), (1018, 4), (1024, 11), (1027, 1), (1029, 2), (1030, 2), (1034, 6), (1036, 7), (1037, 1), (1043, 2), (1044, 3), (1047, 11), (1050, 2), (1056, 1), (1057, 3), (1068, 6), (1069, 2), (1070, 1), (1071, 1), (1075, 1), (1077, 1), (1079, 5), (1080, 1), (1082, 1), (1086, 9), (1087, 5), (1088, 2), (1090, 4), (1094, 61), (1102, 15), (1103, 5), (1107, 18), (1113, 3), (1114, 5), (1115, 21), (1116, 2), (1119, 2), (1123, 4), (1124, 1), (1125, 1), (1126, 1), (1127, 2), (1128, 2), (1129, 1), (1130, 2), (1131, 1), (1132, 1), (1133, 19), (1134, 4), (1135, 1), (1136, 8), (1137, 7), (1138, 2), (1139, 10), (1140, 1), (1141, 1), (1142, 1), (1143, 1), (1144, 1), (1145, 1), (1146, 1), (1147, 1), (1148, 1), (1149, 1), ...
# [(5, 5), (6, 2), (12, 1), (24, 3), (25, 1), (26, 2), (28, 1), (34, 7), (36, 10), (60, 2), (61, 1), (94, 1), (100, 4), (103, 2), (121, 1), (127, 2), (128, 1), (133, 1), (148, 2), (149, 13), (155, 3), (162, 1), (176, 1), (177, 1), (183, 1), (184, 2), (187, 1), (191, 2), (199, 2), (205, 1), (212, 4), (214, 2), (228, 1), (242, 1), (253, 4), (257, 3), (259, 1), (262, 1), (276, 2), (278, 4), (296, 1), (299, 1), (300, 1), (301, 1), (314, 1), (320, 1), (324, 1), (340, 1), (350, 1), (359, 1), (360, 1), (366, 1), (372, 2), (375, 2), (378, 1), (380, 1), (381, 1), (395, 1), (399, 1), (401, 8), (402, 2), (415, 1), (416, 2), (420, 1), (426, 2), (435, 1), (447, 6), (455, 1), (461, 1), (472, 3), (484, 1), (485, 5), (486, 1), (488, 1), (505, 1), (506, 1), (514, 3), (516, 1), (523, 1), (525, 3), (530, 5), (531, 1), (532, 1), (533, 2), (535, 1), (537, 1), (574, 1), (576, 1), (577, 1), (584, 5), (590, 1), (591, 2), (596, 1), (607, 1), (610, 1), (612, 18), (613, 1), (614, 10), (621, 1), (624, 1), (634, 2), (637, 1), (638, 1), (646, 1), (652, 2), (656, 2), (657, 1), (664, 2), (670, 1), (671, 63), (677, 3), (682, 2), (692, 2), (693, 1), (694, 2), (695, 6), (708, 1), (713, 1), (720, 1), (727, 1), (729, 2), (730, 1), (754, 1), (756, 3), (758, 3), (760, 1), (766, 2), (791, 3), (797, 4), (806, 1), (809, 1), (815, 9), (816, 1), (846, 1), (859, 2), (861, 1), (862, 1), (870, 4), (882, 1), (883, 30), (884, 7), (893, 1), (900, 1), (918, 8), (922, 1), (928, 1), (939, 1), (958, 2), (967, 1), (975, 1), (978, 1), (983, 3), (984, 2), (987, 6), (1002, 1), (1003, 1), (1009, 3), (1010, 2), (1018, 2), (1024, 1), (1028, 2), (1036, 1), (1038, 1), (1043, 1), (1044, 3), (1045, 1), (1047, 3), (1075, 1), (1078, 1), (1079, 1), (1086, 1), (1087, 1), (1093, 2), (1094, 47), (1095, 6), (1105, 64), (1113, 17), (1114, 2), (1115, 6), (1119, 6), (1122, 1), (1148, 1), (1159, 2), (1163, 2), (1171, 4), (1180, 1), (1187, 1), (1188, 3), (1189, 3), (1191, 1), (1198, 1), (1215, 9), (1218, 2), (1219, 1), (1220, 2), (1228, 1), (1235, 1), (1239, 1), (1256, 1), (1269, 1), (1271, 1), (1284, 1), (1295, 1), (1296, 1), (1301, 1), (1304, 1), (1312, 1), (1316, 1), (1320, 1), (1334, 1), (1342, 4), (1349, 1), (1360, 1), (1363, 1), (1364, 1), (1366, 1), (1370, 7), (1373, 4), (1399, 4), (1405, 1), (1419, 1), (1422, 1), (1444, 1), (1455, 1), (1488, 1), (1494, 1), (1496, 1), (1503, 1), (1523, 1), (1525, 2), (1526, 3), (1537, 1), (1594, 3), (1602, 2), (1603, 1), (1610, 1), (1613, 1), (1619, 5), (1626, 2), (1627, 3), (1628, 2), (1629, 1), (1630, 6), (1631, 2), (1632, 2), (1633, 1), (1634, 1), (1635, 2), (1636, 1), (1637, 2), (1638, 5), (1639, 3), (1640, 2), (1641, 2), (1642, 2), (1643, 2), (1644, 2), (1645, 2), (1646, 1), (1647, 1), (1648, 2), (1649, 1), (1650, 1), (1651, 1), (1652, 1), (1653, 1), (1654, 2), (1655, 5), (1656, 1), (1657, 3), (1658, 2), (1659, 1), (1660, 1), (1661, 1), (1662, 1), (1663, 6), (1664, 1), (1665, 2), (1666, 1), (1667, 1), (1668, 6), (1669, 2), (1670, 4), (1671, 1), (1672, 1), (1673, 1), (1674, 6), (1675, 1), (1676, 1), (1677, 1), (1678, 1), (1679, 1), (1680, 1), (1681, 2), (1682, 1), (1683, 7), (1684, 2), (1685, 3), (1686, 2), (1687, 1), (1688, 2), (1689, 2), (1690, 1), (1691, 1), (1692, 5), (1693, 2), (1694, 2), (1695, 2), (1696, 4), (1697, 6), (1698, 2), (1699, 4), (1700, 3)]
# [(4, 2), (5, 5), (6, 1), (12, 1), (13, 1), (14, 1), (15, 1), (21, 1), (26, 1), (29, 3), (33, 1), (34, 3), (35, 2), (38, 1), (60, 1), (61, 1), (82, 1), (84, 1), (91, 1), (92, 1), (94, 2), (101, 1), (104, 1), (113, 1), (115, 1), (140, 1), (149, 8), (162, 1), (163, 1), (169, 6), (177, 4), (184, 2), (187, 1), (191, 3), (193, 2), (205, 2), (210, 2), (246, 2), (253, 9), (259, 1), (268, 2), (275, 1), (276, 1), (278, 2), (286, 1), (288, 3), (291, 2), (292, 1), (301, 1), (304, 1), (316, 2), (345, 3), (358, 1), (359, 1), (362, 1), (369, 1), (371, 1), (375, 2), (376, 1), (382, 1), (391, 1), (401, 12), (404, 1), (414, 1), (416, 1), (430, 1), (433, 1), (435, 1), (447, 15), (451, 4), (453, 1), (456, 1), (457, 31), (461, 1), (464, 5), (465, 2), (466, 3), (467, 2), (472, 1), (497, 1), (498, 1), (502, 1), (508, 1), (511, 1), (514, 1), (515, 1), (520, 1), (543, 2), (545, 29), (547, 4), (548, 4), (552, 2), (555, 1), (557, 1), (560, 1), (566, 3), (571, 1), (575, 1), (593, 1), (599, 5), (604, 1), (612, 1), (627, 1), (638, 1), (639, 1), (641, 3), (642, 2), (646, 1), (651, 1), (671, 1), (675, 1), (694, 2), (720, 1), (724, 11), (729, 2), (731, 7), (734, 4), (753, 1), (756, 1), (758, 3), (759, 1), (780, 6), (797, 1), (806, 1), (808, 2), (811, 1), (815, 4), (840, 1), (842, 1), (846, 9), (854, 6), (858, 3), (864, 1), (870, 1), (877, 2), (885, 1), (886, 1), (892, 1), (893, 2), (901, 1), (918, 4), (920, 1), (924, 1), (928, 4), (936, 1), (937, 1), (939, 1), (943, 1), (954, 3), (959, 1), (975, 1), (976, 3), (977, 1), (987, 1), (991, 4), (992, 1), (1012, 1), (1024, 2), (1034, 1), (1041, 1), (1044, 1), (1047, 2), (1050, 2), (1052, 3), (1061, 1), (1068, 1), (1076, 2), (1088, 3), (1094, 20), (1095, 1), (1102, 1), (1105, 17), (1107, 2), (1113, 1), (1129, 3), (1156, 1), (1158, 1), (1160, 1), (1185, 2), (1205, 1), (1215, 7), (1216, 1), (1218, 4), (1219, 1), (1230, 1), (1254, 1), (1256, 1), (1258, 1), (1259, 1), (1260, 2), (1262, 1), (1264, 2), (1270, 1), (1298, 1), (1309, 18), (1310, 2), (1326, 2), (1336, 1), (1366, 1), (1368, 2), (1369, 2), (1370, 7), (1372, 1), (1373, 1), (1374, 2), (1375, 3), (1376, 2), (1377, 2), (1378, 1), (1379, 3), (1380, 1), (1381, 2), (1382, 1), (1383, 1), (1384, 1), (1385, 1), (1386, 1), (1387, 4), (1388, 1), (1389, 1), (1390, 5), (1391, 1), (1392, 3), (1393, 1), (1394, 2), (1395, 3), (1396, 2), (1397, 1), (1398, 8), (1399, 1), (1400, 1), (1401, 1), (1402, 1), (1403, 1), (1404, 1), (1405, 1), (1406, 1), (1407, 1), (1408, 1), (1409, 1), (1410, 2), (1411, 1), (1412, 1), (1413, 1), (1414, 1), (1415, 1), (1416, 1), (1417, 4), (1418, 1), (1419, 1)]
# [(0, 1), (5, 1), (7, 2), (8, 1), (11, 1), (12, 1), (13, 1), (14, 1), (15, 3), (19, 1), (21, 1), (25, 6), (26, 6), (34, 17), (36, 17), (40, 1), (48, 15), (53, 6), (56, 3), (60, 1), (61, 1), (62, 1), (63, 1), (68, 5), (79, 1), (81, 1), (82, 1), (91, 1), (92, 2), (93, 1), (94, 9), (96, 2), (99, 2), (103, 1), (104, 4), (105, 1), (110, 1), (111, 1), (114, 3), (115, 2), (116, 4), (119, 17), (120, 1), (121, 2), (123, 1), (126, 1), (135, 1), (139, 1), (147, 1), (149, 2), (153, 1), (155, 5), (158, 1), (163, 7), (164, 1), (169, 1), (173, 1), (177, 1), (179, 1), (180, 1), (181, 6), (184, 21), (187, 5), (191, 7), (192, 3), (193, 1), (194, 1), (200, 1), (201, 2), (202, 8), (205, 3), (206, 3), (209, 1), (210, 1), (211, 1), (212, 2), (220, 1), (223, 6), (224, 3), (228, 2), (231, 3), (233, 4), (234, 1), (235, 2), (236, 3), (238, 2), (240, 1), (245, 3), (246, 1), (247, 2), (252, 1), (253, 12), (258, 5), (265, 1), (269, 1), (273, 1), (275, 5), (276, 13), (278, 16), (282, 1), (286, 8), (289, 3), (291, 120), (292, 38), (296, 2), (297, 1), (298, 5), (301, 22), (302, 1), (303, 6), (304, 16), (305, 4), (307, 10), (308, 1), (309, 1), (313, 1), (314, 2), (324, 7), (325, 1), (327, 2), (328, 2), (330, 2), (334, 1), (335, 4), (336, 3), (337, 5), (338, 2), (339, 1), (346, 1), (347, 1), (350, 1), (358, 3), (359, 3), (360, 4), (361, 2), (362, 1), (364, 5), (369, 5), (371, 6), (372, 1), (373, 1), (375, 7), (376, 11), (377, 2), (379, 4), (380, 2), (381, 1), (382, 2), (383, 1), (389, 3), (391, 5), (392, 1), (395, 1), (397, 3), (399, 1), (401, 173), (403, 3), (404, 2), (406, 1), (411, 1), (412, 2), (416, 4), (420, 1), (426, 1), (427, 1), (430, 1), (435, 10), (438, 2), (446, 2), (447, 109), (448, 9), (449, 3), (450, 1), (451, 15), (452, 3), (453, 5), (454, 2), (455, 3), (456, 2), (464, 1), (465, 2), (466, 1), (467, 1), (468, 2), (469, 2), (471, 4), (472, 12), (473, 7), (475, 1), (477, 1), (478, 1), (479, 2), (480, 4), (481, 14), (483, 1), (485, 47), (491, 1), (493, 1), (494, 4), (502, 1), (504, 8), (506, 1), (507, 2), (511, 1), (512, 1), (514, 1), (519, 1), (520, 1), (523, 7), (524, 1), (525, 1), (526, 1), (530, 1), (531, 5), (532, 6), (534, 1), (538, 1), (539, 3), (540, 1), (541, 2), (548, 1), (557, 2), (571, 1), (576, 7), (578, 1), (582, 2), (583, 1), (584, 16), (586, 3), (587, 1), (590, 2), (593, 2), (603, 4), (604, 4), (607, 2), (608, 6), (609, 1), (610, 2), (611, 1), (612, 23), (614, 1), (615, 18), (616, 3), (617, 30), (618, 1), (619, 4), (620, 1), (624, 1), (631, 6), (632, 2), (634, 5), (635, 2), (636, 1), (637, 1), (641, 10), (642, 8), (644, 1), (646, 4), (647, 1), (648, 2), (649, 1), (652, 1), (657, 1), (663, 1), (664, 1), (665, 1), (669, 1), (670, 6), (671, 38), (672, 1), (675, 2), (676, 2), (677, 2), (679, 1), (681, 1), (682, 3), (685, 1), (688, 1), (689, 17), (690, 2), (694, 6), (695, 5), (698, 4), (702, 1), (704, 5), (706, 1), (708, 15), (711, 2), (713, 1), (714, 4), (715, 4), (720, 1), (721, 1), (722, 1), (724, 1), (727, 2), (729, 3), (735, 1), (740, 1), (742, 1), (743, 1), (750, 1), (756, 25), (757, 4), (758, 3), (760, 1), (762, 3), (763, 1), (765, 4), (766, 1), (767, 2), (768, 1), (773, 2), (774, 2), (775, 4), (781, 1), (782, 1), (784, 1), (787, 2), (792, 2), (794, 1), (801, 10), (806, 36), (808, 1), (809, 2), (815, 20), (816, 4), (820, 1), (825, 3), (826, 1), (831, 1), (832, 2), (833, 1), (835, 2), (837, 1), (838, 2), (839, 1), (840, 2), (842, 1), (846, 14), (851, 1), (866, 1), (867, 5), (869, 3), (870, 3), (872, 1), (875, 10), (877, 3), (879, 2), (880, 1), (881, 1), (884, 3), (885, 1), (886, 4), (888, 4), (892, 2), (893, 2), (896, 1), (899, 2), (900, 3), (901, 1), (902, 1), (903, 1), (906, 2), (911, 5), (914, 5), (918, 8), (928, 4), (932, 1), (934, 1), (936, 4), (937, 2), (946, 1), (947, 1), (948, 1), (950, 1), (952, 1), (965, 2), (975, 1), (977, 3), (978, 6), (979, 2), (982, 1), (983, 7), (984, 1), (985, 1), (987, 3), (990, 1), (991, 1), (994, 3), (995, 3), (998, 1), (1001, 1), (1003, 7), (1008, 1), (1011, 18), (1017, 1), (1019, 1), (1023, 2),  ...

# %%
top_inex = 0

numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort( numpy_corpus[top_inex,:] )[::-1]
print("------------------------------")
for x in docs:
    print(titles[x])
    print("------------------------------")
# Out:
# ------------------------------
# Integral
# ------------------------------
# Riemann_integral
# ------------------------------
# Limit_of_a_sequence
# ------------------------------
# Riemann-Stieltjes_integral
# ------------------------------
# Derivative
# ------------------------------
# Edvard_Munch
# ------------------------------
# Jan_Matejko
# ------------------------------
# Lev_Tolstoj
# ------------------------------
# Franz_Kafka
# ------------------------------
# J._R._R._Tolkien
# ------------------------------
# Vincent_van_Gogh
# ------------------------------

# %%
top_inex = 1

numpy_corpus = gensim.matutils.corpus2dense(corpus_lda, num_terms=2)
docs = np.argsort( numpy_corpus[top_inex,:] )[::-1]
print("------------------------------")
for x in docs:
    print(titles[x])
    print("------------------------------")
# Out:
# ------------------------------
# Vincent_van_Gogh
# ------------------------------
# J._R._R._Tolkien
# ------------------------------
# Franz_Kafka
# ------------------------------
# Lev_Tolstoj
# ------------------------------
# Jan_Matejko
# ------------------------------
# Edvard_Munch
# ------------------------------
# Limit_of_a_sequence
# ------------------------------
# Derivative
# ------------------------------
# Riemann-Stieltjes_integral
# ------------------------------
# Riemann_integral
# ------------------------------
# Integral
# ------------------------------

# %% [markdown]
# # Zad.
# Sprawdzić do jakiego tematu pasuje nowy dokument i jakie są mu najbliższe

# %%
doc = "Machine Learning"

doc_rep = dictionary.doc2bow(doc.split(' '))
# print(doc_rep)
doc_assignments = model[doc_rep]
print(doc_assignments)
# Out:
# [(0, 0.5), (1, 0.5)]

# %%
index = similarities.MatrixSimilarity(corpus_lda)

sims = index[doc_assignments]
# print(list(enumerate(sims)))

sims = sorted(enumerate(sims), key=lambda item: -item[1])
print(sims)
# Out:
# [(8, 0.9680166), (7, 0.92565167), (9, 0.8216332), (5, 0.7315312), (0, 0.70710677), (1, 0.70710677), (2, 0.70710677), (3, 0.70710677), (4, 0.70710677), (6, 0.70710677), (10, 0.70710677)]

# %% [markdown]
# # Zad
# Wizualizacja modelu LDA:

# %%
import pyLDAvis.gensim

pyLDAvis.enable_notebook()

# %%
pyLDAvis.gensim.prepare(model, corpus, dictionary)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=            x    y  topics  cluster       Freq
# topic
# 0      0.0089  0.0       1        1  51.013256
# 1     -0.0089  0.0       2        1  48.986744, topic_info=     Category        Freq               Term       Total  loglift  logprob
# term
# 2688  Default  197.000000                van  197.000000  30.0000  30.0000
# 2211  Default  134.000000               gogh  134.000000  29.0000  29.0000
# 854   Default  102.000000            riemann  102.000000  28.0000  28.0000
# 545   Default  168.000000           integral  168.000000  27.0000  27.0000
# 1370  Default   55.000000                  ε   55.000000  26.0000  26.0000
# 3257  Default   45.000000             gogh's   45.000000  25.0000  25.0000
# 1094  Default  304.000000                  x  304.000000  24.0000  24.0000
# 671   Default  133.000000                  n  133.000000  23.0000  23.0000
# 457   Default   35.000000                  g   35.000000  22.0000  22.0000
# 291   Default  112.000000         derivative  112.000000  21.0000  21.0000
# 954   Default   41.000000                sum   41.000000  20.0000  20.0000
# 1364  Default   70.000000              works   70.000000  19.0000  19.0000
# 1309  Default   17.000000  riemann–stieltjes   17.000000  18.0000  18.0000
# 2402  Default  115.000000              munch  115.000000  17.0000  17.0000
# 4910  Default  176.000000            tolkien  176.000000  16.0000  16.0000
# 36    Default  111.000000                  1  111.000000  15.0000  15.0000
# 973   Default   17.000000             tagged   17.000000  14.0000  14.0000
# 451   Default   52.000000          functions   52.000000  13.0000  13.0000
# 2697  Default   27.000000            vincent   27.000000  12.0000  12.0000
# 3661  Default   27.000000               theo   27.000000  11.0000  11.0000
# 447   Default  208.000000           function  208.000000  10.0000  10.0000
# 2271  Default   22.000000               in),   22.000000   9.0000   9.0000
# 149   Default   78.000000                  b   78.000000   8.0000   8.0000
# 547   Default   21.000000          integral.   21.000000   7.0000   7.0000
# 548   Default   49.000000          integrals   49.000000   6.0000   6.0000
# 731   Default   37.000000          partition   37.000000   5.0000   5.0000
# 569   Default   18.000000          intervals   18.000000   4.0000   4.0000
# 1105  Default  118.000000     {\displaystyle  118.000000   3.0000   3.0000
# 4185  Default   75.000000            tolstoy   75.000000   2.0000   2.0000
# 991   Default   22.000000            theorem   22.000000   1.0000   1.0000
# ...       ...         ...                ...         ...      ...      ...
# 2334   Topic2   25.816921               life   44.429039   0.1708  -6.4008
# 1046   Topic2   22.164549                  v   37.479076   0.1883  -6.5533
# 1936   Topic2   29.664444                art   52.209286   0.1483  -6.2619
# 4431   Topic2   37.307404            kafka's   67.765175   0.1168  -6.0326
# 2439   Topic2   17.518318                old   28.800789   0.2165  -6.7886
# 1088   Topic2   42.879772               work   80.706146   0.0812  -5.8934
# 797    Topic2   35.854912          published   66.001183   0.1034  -6.0724
# 401    Topic2  115.030632                  f  266.151367  -0.1252  -4.9066
# 1024   Topic2   48.354118                two   95.289841   0.0352  -5.7733
# 404    Topic2   26.524639             family   47.813614   0.1244  -6.3738
# 4796   Topic2   22.090120               lord   38.314526   0.1629  -6.5567
# 708    Topic2   55.036469                one  119.939453  -0.0654  -5.6438
# 447    Topic2   83.688385           function  208.834412  -0.2008  -5.2247
# 1094   Topic2  111.928246                  x  304.281128  -0.2865  -4.9340
# 4911   Topic2   26.295256          tolkien's   47.798248   0.1160  -6.3824
# 416    Topic2   48.519890              first  107.807037  -0.0847  -5.7699
# 94     Topic2   46.343189               also  105.963333  -0.1134  -5.8158
# 154    Topic2   26.810572             became   50.338684   0.0836  -6.3630
# 4429   Topic2   46.566460              kafka  111.021622  -0.1552  -5.8110
# 1003   Topic2   30.504932               time   60.611679   0.0270  -6.2340
# 1105   Topic2   45.462650     {\displaystyle  118.433868  -0.2438  -5.8349
# 545    Topic2   50.408337           integral  168.044983  -0.4905  -5.7317
# 595    Topic2   29.448208              later   61.369034  -0.0207  -6.2692
# 2402   Topic2   40.887440              munch  115.606598  -0.3257  -5.9410
# 36     Topic2   39.628174                  1  111.354881  -0.3196  -5.9723
# 671    Topic2   41.785522                  n  133.188873  -0.4456  -5.9193
# 2408   Topic2   28.534750             museum   68.813965  -0.1667  -6.3007
# 612    Topic2   27.113779              limit   53.694939   0.0303  -6.3518
# 149    Topic2   27.997147                  b   78.799057  -0.3212  -6.3197
# 4185   Topic2   27.277653            tolstoy   75.409103  -0.3032  -6.3458
#
# [176 rows x 6 columns], token_table=      Topic      Freq            Term
# term
# 34        1  0.624179               0
# 34        2  0.377792               0
# 36        1  0.646581               1
# 36        2  0.359212               1
# 2773      1  0.227388           1887.
# 2773      2  0.682163           1887.
# 2777      1  0.283608           1888.
# 2777      2  0.709020           1888.
# 2780      1  0.309845           1890,
# 2780      2  0.722971           1890,
# 2781      1  0.284380           1890.
# 2781      2  0.710951           1890.
# 70        1  0.404411       according
# 70        2  0.606616       according
# 94        1  0.566234            also
# 94        2  0.434112            also
# 4630      1  0.325147     anglo-saxon
# 4630      2  0.650294     anglo-saxon
# 1932      1  0.310020           april
# 1932      2  0.723381           april
# 2977      1  0.324933          arles,
# 2977      2  0.649865          arles,
# 2978      1  0.252916          arles.
# 2978      2  0.758747          arles.
# 1936      1  0.440535             art
# 1936      2  0.574610             art
# 2990      1  0.379149          attend
# 2990      2  0.758298          attend
# 2997      1  0.227443          auvers
# 2997      2  0.682329          auvers
# ...     ...       ...             ...
# 1046      1  0.400223               v
# 1046      2  0.586994               v
# 2688      1  0.273802             van
# 2688      2  0.725069             van
# 2697      1  0.293752         vincent
# 2697      2  0.697660         vincent
# 3705      1  0.379264          visits
# 3705      2  0.758527          visits
# 1088      1  0.470844            work
# 1088      2  0.532797            work
# 1364      1  0.357001           works
# 1364      2  0.642602           works
# 1093      1  0.369336         written
# 1093      2  0.627871         written
# 2733      1  0.417181           wrote
# 2733      2  0.591007           wrote
# 1094      1  0.630995               x
# 1094      2  0.368081               x
# 1105      1  0.616378  {\displaystyle
# 1105      2  0.379959  {\displaystyle
# 1106      1  0.631247               ×
# 1106      2  0.363445               ×
# 3738      1  0.324922           émile
# 3738      2  0.649843           émile
# 1368      1  0.587360               α
# 1368      2  0.293680               α
# 1369      1  0.587150               β
# 1369      2  0.293575               β
# 1370      1  0.780108               ε
# 1370      2  0.217705               ε
#
# [250 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2])
